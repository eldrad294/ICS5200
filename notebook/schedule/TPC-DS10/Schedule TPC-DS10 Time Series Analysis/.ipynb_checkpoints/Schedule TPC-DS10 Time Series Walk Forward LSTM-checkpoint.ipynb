# %% [markdown]
# # Walk Foward Evaluation
#
# This section mimics a real-life like approach, where a model is trained on a week worth of data, and then used to predict 7 days worth of predictions.

# %% [markdown]
# ### Module Installation and Importing Libraries
#
# * https://machinelearningmastery.com/setup-python-environment-machine-learning-deep-learning-anaconda/
# * https://vertexai-plaidml.readthedocs-hosted.com/en/latest/installing.html

# %%
# scipy
import scipy as sc
print('scipy: %s' % sc.__version__)
# numpy
import numpy as np
print('numpy: %s' % np.__version__)
# matplotlib
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot
from statsmodels.graphics.tsaplots import plot_acf
# pandas
import pandas as pd
from pandas.plotting import lag_plot
print('pandas: %s' % pd.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn import preprocessing
from sklearn.metrics import r2_score
import sklearn as sk
print('sklearn: %s' % sk.__version__)
# theano
import theano
print('theano: %s' % theano.__version__)
# tensorflow
import tensorflow
print('tensorflow: %s' % tensorflow.__version__)
# plaidml keras
import plaidml.keras
plaidml.keras.install_backend()
# keras
import keras as ke
print('keras: %s' % ke.__version__)
# math
import math
import csv
import os.path
import time
# Out:
# scipy: 1.1.0
# numpy: 1.15.4
# pandas: 0.23.4
# statsmodels: 0.9.0
# sklearn: 0.20.2
# theano: 1.0.3
# tensorflow: 1.11.0
# keras: 2.2.4

# %% [markdown]
# ### Configuration Cell
#
# Tweak parametric changes from this cell to influence outcome of experiment.
# NB: This experiment demonstrates at time  step = 1 (1 minute in advance). Further down in experiment, other timestep results are also featured and evaluated.

# %%
# Experiment Config
tpcds='TPCDS10' # Schema upon which to operate test
lag=12 # Time Series shift / Lag Step. Each lag value equates to 1 minute. Cannot be less than 1
if lag < 1:
    raise ValueError('Lag value must be greater than 1!')
nrows=None
test_split=.5 # Denotes which Data Split to operate under when it comes to training / validation
sub_sample_start=350 # Denotes frist 0..n samples (Used for plotting purposes)
y_label = ['CPU_TIME_DELTA', 'IOWAIT_DELTA']# Denotes which label to use for time series experiments

# Feature Selection
parallel_degree = -1
n_estimators=100

# LSTM Network Structure
epochs=300
batch=64
activation='tanh'
initializer='normal'
dropout=0.4
layer=2
state=False

# %% [markdown]
# ### Read data from file into Pandas Dataframes

# %%
# Root path
#root_dir = 'C:/Users/gabriel.sammut/University/Data_ICS5200/Schedule/' + tpcds
root_dir = 'D:/Projects/Datagenerated_ICS5200/Schedule/' + tpcds

# Open Data
rep_hist_snapshot_path = root_dir + '/rep_hist_snapshot.csv'
rep_hist_sysmetric_summary_path = root_dir + '/rep_hist_sysmetric_summary.csv'
rep_hist_sysstat_path = root_dir + '/rep_hist_sysstat.csv'

rep_hist_snapshot_df = pd.read_csv(rep_hist_snapshot_path, nrows=nrows)
rep_hist_sysmetric_summary_df = pd.read_csv(rep_hist_sysmetric_summary_path, nrows=nrows)
rep_hist_sysstat_df = pd.read_csv(rep_hist_sysstat_path, nrows=nrows)

def prettify_header(headers):
    """
    Cleans header list from unwated character strings
    """
    header_list = []
    [header_list.append(header.replace("(","").replace(")","").replace("'","").replace(",","")) for header in headers]
    return header_list

rep_hist_snapshot_df.columns = prettify_header(rep_hist_snapshot_df.columns.values)
rep_hist_sysmetric_summary_df.columns = prettify_header(rep_hist_sysmetric_summary_df.columns.values)
rep_hist_sysstat_df.columns = prettify_header(rep_hist_sysstat_df.columns.values)

print(rep_hist_snapshot_df.columns.values)
print(rep_hist_sysmetric_summary_df.columns.values)
print(rep_hist_sysstat_df.columns.values)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'SQL_ID' 'PLAN_HASH_VALUE'
#  'OPTIMIZER_COST' 'OPTIMIZER_MODE' 'OPTIMIZER_ENV_HASH_VALUE'
#  'SHARABLE_MEM' 'LOADED_VERSIONS' 'VERSION_COUNT' 'MODULE' 'ACTION'
#  'SQL_PROFILE' 'FORCE_MATCHING_SIGNATURE' 'PARSING_SCHEMA_ID'
#  'PARSING_SCHEMA_NAME' 'PARSING_USER_ID' 'FETCHES_TOTAL' 'FETCHES_DELTA'
#  'END_OF_FETCH_COUNT_TOTAL' 'END_OF_FETCH_COUNT_DELTA' 'SORTS_TOTAL'
#  'SORTS_DELTA' 'EXECUTIONS_TOTAL' 'EXECUTIONS_DELTA'
#  'PX_SERVERS_EXECS_TOTAL' 'PX_SERVERS_EXECS_DELTA' 'LOADS_TOTAL'
#  'LOADS_DELTA' 'INVALIDATIONS_TOTAL' 'INVALIDATIONS_DELTA'
#  'PARSE_CALLS_TOTAL' 'PARSE_CALLS_DELTA' 'DISK_READS_TOTAL'
#  'DISK_READS_DELTA' 'BUFFER_GETS_TOTAL' 'BUFFER_GETS_DELTA'
#  'ROWS_PROCESSED_TOTAL' 'ROWS_PROCESSED_DELTA' 'CPU_TIME_TOTAL'
#  'CPU_TIME_DELTA' 'ELAPSED_TIME_TOTAL' 'ELAPSED_TIME_DELTA' 'IOWAIT_TOTAL'
#  'IOWAIT_DELTA' 'CLWAIT_TOTAL' 'CLWAIT_DELTA' 'APWAIT_TOTAL'
#  'APWAIT_DELTA' 'CCWAIT_TOTAL' 'CCWAIT_DELTA' 'DIRECT_WRITES_TOTAL'
#  'DIRECT_WRITES_DELTA' 'PLSEXEC_TIME_TOTAL' 'PLSEXEC_TIME_DELTA'
#  'JAVEXEC_TIME_TOTAL' 'JAVEXEC_TIME_DELTA' 'IO_OFFLOAD_ELIG_BYTES_TOTAL'
#  'IO_OFFLOAD_ELIG_BYTES_DELTA' 'IO_INTERCONNECT_BYTES_TOTAL'
#  'IO_INTERCONNECT_BYTES_DELTA' 'PHYSICAL_READ_REQUESTS_TOTAL'
#  'PHYSICAL_READ_REQUESTS_DELTA' 'PHYSICAL_READ_BYTES_TOTAL'
#  'PHYSICAL_READ_BYTES_DELTA' 'PHYSICAL_WRITE_REQUESTS_TOTAL'
#  'PHYSICAL_WRITE_REQUESTS_DELTA' 'PHYSICAL_WRITE_BYTES_TOTAL'
#  'PHYSICAL_WRITE_BYTES_DELTA' 'OPTIMIZED_PHYSICAL_READS_TOTAL'
#  'OPTIMIZED_PHYSICAL_READS_DELTA' 'CELL_UNCOMPRESSED_BYTES_TOTAL'
#  'CELL_UNCOMPRESSED_BYTES_DELTA' 'IO_OFFLOAD_RETURN_BYTES_TOTAL'
#  'IO_OFFLOAD_RETURN_BYTES_DELTA' 'BIND_DATA' 'FLAG' 'CON_DBID' 'CON_ID'
#  'SQL_TEXT' 'COMMAND_TYPE' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME'
#  'END_INTERVAL_TIME' 'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT'
#  'SNAP_FLAG' 'SNAP_TIMEZONE']
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'BEGIN_TIME' 'END_TIME' 'INTSIZE'
#  'GROUP_ID' 'METRIC_ID' 'METRIC_NAME' 'METRIC_UNIT' 'NUM_INTERVAL'
#  'MINVAL' 'MAXVAL' 'AVERAGE' 'STANDARD_DEVIATION' 'SUM_SQUARES' 'CON_DBID'
#  'CON_ID' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME' 'END_INTERVAL_TIME'
#  'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT' 'SNAP_FLAG' 'SNAP_TIMEZONE']
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'STAT_ID' 'STAT_NAME' 'VALUE'
#  'CON_DBID' 'CON_ID' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME'
#  'END_INTERVAL_TIME' 'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT'
#  'SNAP_FLAG' 'SNAP_TIMEZONE']

# %% [markdown]
# ### Pivoting Tables and Changing Matrix Shapes
#
# Changes all dataframe shapes to be similar to each other, where in a number of snap_id timestamps are cojoined with instance metrics.

# %%
print('Header Lengths [Before Pivot]')
print('REP_HIST_SNAPSHOT: ' + str(len(rep_hist_snapshot_df.columns)))
print('REP_HIST_SYSMETRIC_SUMMARY: ' + str(len(rep_hist_sysmetric_summary_df.columns)))
print('REP_HIST_SYSSTAT: ' + str(len(rep_hist_sysstat_df.columns)))

# Table REP_HIST_SYSMETRIC_SUMMARY
rep_hist_sysmetric_summary_df = rep_hist_sysmetric_summary_df.pivot_table(index='SNAP_ID', columns='METRIC_NAME', values='AVERAGE')
rep_hist_sysmetric_summary_df.reset_index(inplace=True)
rep_hist_sysmetric_summary_df[['SNAP_ID']] = rep_hist_sysmetric_summary_df[['SNAP_ID']].astype(int)
#rep_hist_sysmetric_summary_df = rep_hist_sysstat_df.groupby(['SNAP_ID']).sum()
rep_hist_sysmetric_summary_df.reset_index(inplace=True)
rep_hist_sysmetric_summary_df.sort_values(by=['SNAP_ID'],inplace=True,ascending=True)

# Table REP_HIST_SYSSTAT
rep_hist_sysstat_df = rep_hist_sysstat_df.pivot_table(index='SNAP_ID', columns='STAT_NAME', values='VALUE')
rep_hist_sysstat_df.reset_index(inplace=True)
rep_hist_sysstat_df[['SNAP_ID']] = rep_hist_sysstat_df[['SNAP_ID']].astype(int)
#rep_hist_sysstat_df = rep_hist_sysstat_df.groupby(['SNAP_ID']).sum()
rep_hist_sysstat_df.reset_index(inplace=True)
rep_hist_sysstat_df.sort_values(by=['SNAP_ID'],inplace=True,ascending=True)

rep_hist_sysmetric_summary_df.rename(str.upper, inplace=True, axis='columns')
rep_hist_sysstat_df.rename(str.upper, inplace=True, axis='columns')

# Group By Values by SNAP_ID , sum all metrics (for table REP_HIST_SNAPSHOT)
rep_hist_snapshot_df = rep_hist_snapshot_df.groupby(['SNAP_ID','DBID','INSTANCE_NUMBER']).sum()
rep_hist_snapshot_df.reset_index(inplace=True)

print('\nHeader Lengths [After Pivot]')
print('REP_HIST_SNAPSHOT: ' + str(len(rep_hist_snapshot_df.columns)))
print('REP_HIST_SYSMETRIC_SUMMARY: ' + str(len(rep_hist_sysmetric_summary_df.columns)))
print('REP_HIST_SYSSTAT: ' + str(len(rep_hist_sysstat_df.columns)))

# DF Shape
print('\nDataframe shapes:\nTable [REP_HIST_SNAPSHOT] - ' + str(rep_hist_snapshot_df.shape))
print('Table [REP_HIST_SYSMETRIC_SUMMARY] - ' + str(rep_hist_sysmetric_summary_df.shape))
print('Table [REP_HIST_SYSSTAT] - ' + str(rep_hist_sysstat_df.shape) + '\n')

print(rep_hist_snapshot_df.columns.values)
print(rep_hist_sysmetric_summary_df.columns.values)
print(rep_hist_sysstat_df.columns.values)
print(rep_hist_snapshot_df.shape)
print(rep_hist_sysmetric_summary_df.shape)
print(rep_hist_sysstat_df.shape)
# Out:
# Header Lengths [Before Pivot]
# REP_HIST_SNAPSHOT: 90
# REP_HIST_SYSMETRIC_SUMMARY: 26
# REP_HIST_SYSSTAT: 16
#
# Header Lengths [After Pivot]
# REP_HIST_SNAPSHOT: 77
# REP_HIST_SYSMETRIC_SUMMARY: 163
# REP_HIST_SYSSTAT: 1180
#
# Dataframe shapes:
# Table [REP_HIST_SNAPSHOT] - (12308, 77)
# Table [REP_HIST_SYSMETRIC_SUMMARY] - (12323, 163)
# Table [REP_HIST_SYSSTAT] - (12107, 1180)
#
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'PLAN_HASH_VALUE' 'OPTIMIZER_COST'
#  'OPTIMIZER_ENV_HASH_VALUE' 'SHARABLE_MEM' 'LOADED_VERSIONS'
#  'VERSION_COUNT' 'SQL_PROFILE' 'PARSING_SCHEMA_ID' 'PARSING_USER_ID'
#  'FETCHES_TOTAL' 'FETCHES_DELTA' 'END_OF_FETCH_COUNT_TOTAL'
#  'END_OF_FETCH_COUNT_DELTA' 'SORTS_TOTAL' 'SORTS_DELTA' 'EXECUTIONS_TOTAL'
#  'EXECUTIONS_DELTA' 'PX_SERVERS_EXECS_TOTAL' 'PX_SERVERS_EXECS_DELTA'
#  'LOADS_TOTAL' 'LOADS_DELTA' 'INVALIDATIONS_TOTAL' 'INVALIDATIONS_DELTA'
#  'PARSE_CALLS_TOTAL' 'PARSE_CALLS_DELTA' 'DISK_READS_TOTAL'
#  'DISK_READS_DELTA' 'BUFFER_GETS_TOTAL' 'BUFFER_GETS_DELTA'
#  'ROWS_PROCESSED_TOTAL' 'ROWS_PROCESSED_DELTA' 'CPU_TIME_TOTAL'
#  'CPU_TIME_DELTA' 'ELAPSED_TIME_TOTAL' 'ELAPSED_TIME_DELTA' 'IOWAIT_TOTAL'
#  'IOWAIT_DELTA' 'CLWAIT_TOTAL' 'CLWAIT_DELTA' 'APWAIT_TOTAL'
#  'APWAIT_DELTA' 'CCWAIT_TOTAL' 'CCWAIT_DELTA' 'DIRECT_WRITES_TOTAL'
#  'DIRECT_WRITES_DELTA' 'PLSEXEC_TIME_TOTAL' 'PLSEXEC_TIME_DELTA'
#  'JAVEXEC_TIME_TOTAL' 'JAVEXEC_TIME_DELTA' 'IO_OFFLOAD_ELIG_BYTES_TOTAL'
#  'IO_OFFLOAD_ELIG_BYTES_DELTA' 'IO_INTERCONNECT_BYTES_TOTAL'
#  'IO_INTERCONNECT_BYTES_DELTA' 'PHYSICAL_READ_REQUESTS_TOTAL'
#  'PHYSICAL_READ_REQUESTS_DELTA' 'PHYSICAL_READ_BYTES_TOTAL'
#  'PHYSICAL_READ_BYTES_DELTA' 'PHYSICAL_WRITE_REQUESTS_TOTAL'
#  'PHYSICAL_WRITE_REQUESTS_DELTA' 'PHYSICAL_WRITE_BYTES_TOTAL'
#  'PHYSICAL_WRITE_BYTES_DELTA' 'OPTIMIZED_PHYSICAL_READS_TOTAL'
#  'OPTIMIZED_PHYSICAL_READS_DELTA' 'CELL_UNCOMPRESSED_BYTES_TOTAL'
#  'CELL_UNCOMPRESSED_BYTES_DELTA' 'IO_OFFLOAD_RETURN_BYTES_TOTAL'
#  'IO_OFFLOAD_RETURN_BYTES_DELTA' 'FLAG' 'CON_DBID' 'CON_ID' 'COMMAND_TYPE'
#  'SNAP_LEVEL' 'ERROR_COUNT' 'SNAP_FLAG']
# ['INDEX' 'SNAP_ID' 'ACTIVE PARALLEL SESSIONS' 'ACTIVE SERIAL SESSIONS'
#  'AVERAGE ACTIVE SESSIONS' 'AVERAGE SYNCHRONOUS SINGLE-BLOCK READ LATENCY'
#  'BACKGROUND CPU USAGE PER SEC' 'BACKGROUND CHECKPOINTS PER SEC'
#  'BACKGROUND TIME PER SEC' 'BRANCH NODE SPLITS PER SEC'
#  'BRANCH NODE SPLITS PER TXN' 'BUFFER CACHE HIT RATIO' 'CPU USAGE PER SEC'
#  'CPU USAGE PER TXN' 'CR BLOCKS CREATED PER SEC'
#  'CR BLOCKS CREATED PER TXN' 'CR UNDO RECORDS APPLIED PER SEC'
#  'CR UNDO RECORDS APPLIED PER TXN' 'CAPTURED USER CALLS'
#  'CELL PHYSICAL IO INTERCONNECT BYTES' 'CONSISTENT READ CHANGES PER SEC'
#  'CONSISTENT READ CHANGES PER TXN' 'CONSISTENT READ GETS PER SEC'
#  'CONSISTENT READ GETS PER TXN' 'CURRENT LOGONS COUNT' 'CURRENT OS LOAD'
#  'CURRENT OPEN CURSORS COUNT' 'CURSOR CACHE HIT RATIO'
#  'DB BLOCK CHANGES PER SEC' 'DB BLOCK CHANGES PER TXN'
#  'DB BLOCK CHANGES PER USER CALL' 'DB BLOCK GETS PER SEC'
#  'DB BLOCK GETS PER TXN' 'DB BLOCK GETS PER USER CALL'
#  'DBWR CHECKPOINTS PER SEC' 'DDL STATEMENTS PARALLELIZED PER SEC'
#  'DML STATEMENTS PARALLELIZED PER SEC' 'DATABASE CPU TIME RATIO'
#  'DATABASE TIME PER SEC' 'DATABASE WAIT TIME RATIO' 'DISK SORT PER SEC'
#  'DISK SORT PER TXN' 'ENQUEUE DEADLOCKS PER SEC'
#  'ENQUEUE DEADLOCKS PER TXN' 'ENQUEUE REQUESTS PER SEC'
#  'ENQUEUE REQUESTS PER TXN' 'ENQUEUE TIMEOUTS PER SEC'
#  'ENQUEUE TIMEOUTS PER TXN' 'ENQUEUE WAITS PER SEC'
#  'ENQUEUE WAITS PER TXN' 'EXECUTE WITHOUT PARSE RATIO'
#  'EXECUTIONS PER SEC' 'EXECUTIONS PER TXN' 'EXECUTIONS PER USER CALL'
#  'FULL INDEX SCANS PER SEC' 'FULL INDEX SCANS PER TXN'
#  'GC CR BLOCK RECEIVED PER SECOND' 'GC CR BLOCK RECEIVED PER TXN'
#  'GC CURRENT BLOCK RECEIVED PER SECOND'
#  'GC CURRENT BLOCK RECEIVED PER TXN' 'GLOBAL CACHE AVERAGE CR GET TIME'
#  'GLOBAL CACHE AVERAGE CURRENT GET TIME' 'GLOBAL CACHE BLOCKS CORRUPTED'
#  'GLOBAL CACHE BLOCKS LOST' 'HARD PARSE COUNT PER SEC'
#  'HARD PARSE COUNT PER TXN' 'HOST CPU USAGE PER SEC'
#  'HOST CPU UTILIZATION (%)' 'I/O MEGABYTES PER SECOND'
#  'I/O REQUESTS PER SECOND' 'LEAF NODE SPLITS PER SEC'
#  'LEAF NODE SPLITS PER TXN' 'LIBRARY CACHE HIT RATIO'
#  'LIBRARY CACHE MISS RATIO' 'LOGICAL READS PER SEC'
#  'LOGICAL READS PER TXN' 'LOGICAL READS PER USER CALL' 'LOGONS PER SEC'
#  'LOGONS PER TXN' 'LONG TABLE SCANS PER SEC' 'LONG TABLE SCANS PER TXN'
#  'MEMORY SORTS RATIO' 'NETWORK TRAFFIC VOLUME PER SEC'
#  'OPEN CURSORS PER SEC' 'OPEN CURSORS PER TXN' 'PGA CACHE HIT %'
#  'PQ QC SESSION COUNT' 'PQ SLAVE SESSION COUNT'
#  'PX DOWNGRADED 1 TO 25% PER SEC' 'PX DOWNGRADED 25 TO 50% PER SEC'
#  'PX DOWNGRADED 50 TO 75% PER SEC' 'PX DOWNGRADED 75 TO 99% PER SEC'
#  'PX DOWNGRADED TO SERIAL PER SEC' 'PX OPERATIONS NOT DOWNGRADED PER SEC'
#  'PARSE FAILURE COUNT PER SEC' 'PARSE FAILURE COUNT PER TXN'
#  'PHYSICAL READ BYTES PER SEC' 'PHYSICAL READ IO REQUESTS PER SEC'
#  'PHYSICAL READ TOTAL BYTES PER SEC'
#  'PHYSICAL READ TOTAL IO REQUESTS PER SEC'
#  'PHYSICAL READS DIRECT LOBS PER SEC' 'PHYSICAL READS DIRECT LOBS PER TXN'
#  'PHYSICAL READS DIRECT PER SEC' 'PHYSICAL READS DIRECT PER TXN'
#  'PHYSICAL READS PER SEC' 'PHYSICAL READS PER TXN'
#  'PHYSICAL WRITE BYTES PER SEC' 'PHYSICAL WRITE IO REQUESTS PER SEC'
#  'PHYSICAL WRITE TOTAL BYTES PER SEC'
#  'PHYSICAL WRITE TOTAL IO REQUESTS PER SEC'
#  'PHYSICAL WRITES DIRECT LOBS  PER TXN'
#  'PHYSICAL WRITES DIRECT LOBS PER SEC' 'PHYSICAL WRITES DIRECT PER SEC'
#  'PHYSICAL WRITES DIRECT PER TXN' 'PHYSICAL WRITES PER SEC'
#  'PHYSICAL WRITES PER TXN' 'PROCESS LIMIT %'
#  'QUERIES PARALLELIZED PER SEC' 'RECURSIVE CALLS PER SEC'
#  'RECURSIVE CALLS PER TXN' 'REDO ALLOCATION HIT RATIO'
#  'REDO GENERATED PER SEC' 'REDO GENERATED PER TXN' 'REDO WRITES PER SEC'
#  'REDO WRITES PER TXN' 'REPLAYED USER CALLS' 'RESPONSE TIME PER TXN'
#  'ROW CACHE HIT RATIO' 'ROW CACHE MISS RATIO' 'ROWS PER SORT'
#  'RUN QUEUE PER SEC' 'SQL SERVICE RESPONSE TIME' 'SESSION COUNT'
#  'SESSION LIMIT %' 'SHARED POOL FREE %' 'SOFT PARSE RATIO'
#  'STREAMS POOL USAGE PERCENTAGE' 'TEMP SPACE USED'
#  'TOTAL INDEX SCANS PER SEC' 'TOTAL INDEX SCANS PER TXN'
#  'TOTAL PGA ALLOCATED' 'TOTAL PGA USED BY SQL WORKAREAS'
#  'TOTAL PARSE COUNT PER SEC' 'TOTAL PARSE COUNT PER TXN'
#  'TOTAL SORTS PER USER CALL' 'TOTAL TABLE SCANS PER SEC'
#  'TOTAL TABLE SCANS PER TXN' 'TOTAL TABLE SCANS PER USER CALL'
#  'TXNS PER LOGON' 'USER CALLS PER SEC' 'USER CALLS PER TXN'
#  'USER CALLS RATIO' 'USER COMMITS PER SEC' 'USER COMMITS PERCENTAGE'
#  'USER LIMIT %' 'USER ROLLBACK UNDO RECORDS APPLIED PER TXN'
#  'USER ROLLBACK UNDOREC APPLIED PER SEC' 'USER ROLLBACKS PER SEC'
#  'USER ROLLBACKS PERCENTAGE' 'USER TRANSACTION PER SEC'
#  'VM IN BYTES PER SEC' 'VM OUT BYTES PER SEC'
#  'WORKLOAD CAPTURE AND REPLAY STATUS']
# ['INDEX' 'SNAP_ID' 'ADG GLOBAL FLUSH' ...
#  'WRITE CLONES CREATED FOR RECOVERY' 'WRITE CLONES CREATED IN BACKGROUND'
#  'WRITE CLONES CREATED IN FOREGROUND']
# (12308, 77)
# (12323, 163)
# (12107, 1180)

# %% [markdown]
# ### Dealing with Empty Values

# %%
def get_na_columns(df, headers):
    """
    Return columns which consist of NAN values
    """
    na_list = []
    for head in headers:
        if df[head].isnull().values.any():
            na_list.append(head)
    return na_list

print('N/A Columns\n')
print('\n REP_HIST_SNAPSHOT Features ' + str(len(rep_hist_snapshot_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_snapshot_df,headers=rep_hist_snapshot_df.columns)) + "\n")
print('REP_HIST_SYSMETRIC_SUMMARY Features ' + str(len(rep_hist_sysmetric_summary_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_sysmetric_summary_df,headers=rep_hist_sysmetric_summary_df.columns)) + "\n")
print('REP_HIST_SYSSTAT Features ' + str(len(rep_hist_sysstat_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_sysstat_df,headers=rep_hist_sysstat_df.columns)) + "\n")

def fill_na(df):
    """
    Replaces NA columns with 0s
    """
    return df.fillna(0)

# Populating NaN values with amount '0'
rep_hist_snapshot_df.fillna(0, inplace=True)
rep_hist_sysmetric_summary_df.fillna(0, inplace=True)
rep_hist_sysstat_df.fillna(0, inplace=True)
# Out:
# N/A Columns
#
#
#  REP_HIST_SNAPSHOT Features 77: []
#
# REP_HIST_SYSMETRIC_SUMMARY Features 163: ['VM OUT BYTES PER SEC']
#
# REP_HIST_SYSSTAT Features 1180: ['BA SPARE STATISTIC 12', 'BA SPARE STATISTIC 9', 'CLI FLSTASK CREATE', 'CLUSTERWIDE GLOBAL TRANSACTIONS', 'DDL STATEMENTS PARALLELIZED', 'EHCC COMPRESSED LENGTH COMPRESSED', 'EFFECTIVE IO TIME', 'FORWARDED 2PC COMMANDS ACROSS RAC NODES', 'IM POPULATE (FASTSTART) CUS READ ATTEMPTS', 'IM POPULATE CUS MEMCOMPRESS FOR CAPACITY LOW', 'IM REPOPULATE (TRICKLE) CUS MEMCOMPRESS FOR QUERY LOW', 'IM REPOPULATE (TRICKLE) CUS REQUESTED', 'IM REPOPULATE CUS NO MEMCOMPRESS', 'IM SCAN ROWS JOURNAL', 'IM SCAN ROWS PROJECTED', 'IM SPACE SMU BYTES ALLOCATED', 'IM SPACE SMU CREATIONS COMMITTED', 'IM SPACE PRIVATE JOURNAL EXTENTS ALLOCATED', 'IPC CPU USED BY THIS SESSION', 'PARALLEL OPERATIONS DOWNGRADED TO SERIAL', 'WORKLOAD REPLAY: THINK TIME', 'BACKUP DATA COMPRESSED REMOTELY', 'CALLS TO KCMGRS', 'CELL CUS SENT UNCOMPRESSED', 'CONSISTENT GETS', 'DATA WAREHOUSING SCANNED BLOCKS', 'FLASH CACHE INSERT SKIP: MODIFICATION', 'GC IM SHRINKS', 'GC CLEANOUT SAVED', 'KA LOCAL MESSAGE WAITS', 'KA MESSAGES SENT', 'LOB WRITES UNALIGNED', 'PHYSICAL READ SNAP IO REQUESTS BASE', 'PHYSICAL READS CACHE', 'REDO SYNCH TIME', 'REDO WRITE SIZE COUNT (   4KB)', 'REDO WRITE SIZE COUNT (INF)', 'SESSION PGA MEMORY', 'TRACKED TRANSACTIONS', 'WRITE CLONES CREATED IN FOREGROUND']

# %% [markdown]
# ### Merging Frames
#
# This part merges the following pandas data frame into a single frame:
# * REP_HIST_SNAPSHOT
# * REP_HIST_SYSMETRIC_SUMMARY
# * REP_HIST_SYSSTAT

# %%
print
df = pd.merge(rep_hist_snapshot_df, rep_hist_sysmetric_summary_df,how='inner',on ='SNAP_ID')
df = pd.merge(df, rep_hist_sysstat_df,how='inner',on ='SNAP_ID')
print(df.shape)
print('----------------------------------')
print(df.columns.tolist())
# Out:
# (12019, 1418)
# ----------------------------------
# ['SNAP_ID', 'DBID', 'INSTANCE_NUMBER', 'PLAN_HASH_VALUE', 'OPTIMIZER_COST', 'OPTIMIZER_ENV_HASH_VALUE', 'SHARABLE_MEM', 'LOADED_VERSIONS', 'VERSION_COUNT', 'SQL_PROFILE', 'PARSING_SCHEMA_ID', 'PARSING_USER_ID', 'FETCHES_TOTAL', 'FETCHES_DELTA', 'END_OF_FETCH_COUNT_TOTAL', 'END_OF_FETCH_COUNT_DELTA', 'SORTS_TOTAL', 'SORTS_DELTA', 'EXECUTIONS_TOTAL', 'EXECUTIONS_DELTA', 'PX_SERVERS_EXECS_TOTAL', 'PX_SERVERS_EXECS_DELTA', 'LOADS_TOTAL', 'LOADS_DELTA', 'INVALIDATIONS_TOTAL', 'INVALIDATIONS_DELTA', 'PARSE_CALLS_TOTAL', 'PARSE_CALLS_DELTA', 'DISK_READS_TOTAL', 'DISK_READS_DELTA', 'BUFFER_GETS_TOTAL', 'BUFFER_GETS_DELTA', 'ROWS_PROCESSED_TOTAL', 'ROWS_PROCESSED_DELTA', 'CPU_TIME_TOTAL', 'CPU_TIME_DELTA', 'ELAPSED_TIME_TOTAL', 'ELAPSED_TIME_DELTA', 'IOWAIT_TOTAL', 'IOWAIT_DELTA', 'CLWAIT_TOTAL', 'CLWAIT_DELTA', 'APWAIT_TOTAL', 'APWAIT_DELTA', 'CCWAIT_TOTAL', 'CCWAIT_DELTA', 'DIRECT_WRITES_TOTAL', 'DIRECT_WRITES_DELTA', 'PLSEXEC_TIME_TOTAL', 'PLSEXEC_TIME_DELTA', 'JAVEXEC_TIME_TOTAL', 'JAVEXEC_TIME_DELTA', 'IO_OFFLOAD_ELIG_BYTES_TOTAL', 'IO_OFFLOAD_ELIG_BYTES_DELTA', 'IO_INTERCONNECT_BYTES_TOTAL', 'IO_INTERCONNECT_BYTES_DELTA', 'PHYSICAL_READ_REQUESTS_TOTAL', 'PHYSICAL_READ_REQUESTS_DELTA', 'PHYSICAL_READ_BYTES_TOTAL', 'PHYSICAL_READ_BYTES_DELTA', 'PHYSICAL_WRITE_REQUESTS_TOTAL', 'PHYSICAL_WRITE_REQUESTS_DELTA', 'PHYSICAL_WRITE_BYTES_TOTAL', 'PHYSICAL_WRITE_BYTES_DELTA', 'OPTIMIZED_PHYSICAL_READS_TOTAL', 'OPTIMIZED_PHYSICAL_READS_DELTA', 'CELL_UNCOMPRESSED_BYTES_TOTAL', 'CELL_UNCOMPRESSED_BYTES_DELTA', 'IO_OFFLOAD_RETURN_BYTES_TOTAL', 'IO_OFFLOAD_RETURN_BYTES_DELTA', 'FLAG', 'CON_DBID', 'CON_ID', 'COMMAND_TYPE', 'SNAP_LEVEL', 'ERROR_COUNT', 'SNAP_FLAG', 'INDEX_x', 'ACTIVE PARALLEL SESSIONS', 'ACTIVE SERIAL SESSIONS', 'AVERAGE ACTIVE SESSIONS', 'AVERAGE SYNCHRONOUS SINGLE-BLOCK READ LATENCY', 'BACKGROUND CPU USAGE PER SEC', 'BACKGROUND CHECKPOINTS PER SEC', 'BACKGROUND TIME PER SEC', 'BRANCH NODE SPLITS PER SEC', 'BRANCH NODE SPLITS PER TXN', 'BUFFER CACHE HIT RATIO', 'CPU USAGE PER SEC', 'CPU USAGE PER TXN', 'CR BLOCKS CREATED PER SEC', 'CR BLOCKS CREATED PER TXN', 'CR UNDO RECORDS APPLIED PER SEC', 'CR UNDO RECORDS APPLIED PER TXN', 'CAPTURED USER CALLS', 'CELL PHYSICAL IO INTERCONNECT BYTES_x', 'CONSISTENT READ CHANGES PER SEC', 'CONSISTENT READ CHANGES PER TXN', 'CONSISTENT READ GETS PER SEC', 'CONSISTENT READ GETS PER TXN', 'CURRENT LOGONS COUNT', 'CURRENT OS LOAD', 'CURRENT OPEN CURSORS COUNT', 'CURSOR CACHE HIT RATIO', 'DB BLOCK CHANGES PER SEC', 'DB BLOCK CHANGES PER TXN', 'DB BLOCK CHANGES PER USER CALL', 'DB BLOCK GETS PER SEC', 'DB BLOCK GETS PER TXN', 'DB BLOCK GETS PER USER CALL', 'DBWR CHECKPOINTS PER SEC', 'DDL STATEMENTS PARALLELIZED PER SEC', 'DML STATEMENTS PARALLELIZED PER SEC', 'DATABASE CPU TIME RATIO', 'DATABASE TIME PER SEC', 'DATABASE WAIT TIME RATIO', 'DISK SORT PER SEC', 'DISK SORT PER TXN', 'ENQUEUE DEADLOCKS PER SEC', 'ENQUEUE DEADLOCKS PER TXN', 'ENQUEUE REQUESTS PER SEC', 'ENQUEUE REQUESTS PER TXN', 'ENQUEUE TIMEOUTS PER SEC', 'ENQUEUE TIMEOUTS PER TXN', 'ENQUEUE WAITS PER SEC', 'ENQUEUE WAITS PER TXN', 'EXECUTE WITHOUT PARSE RATIO', 'EXECUTIONS PER SEC', 'EXECUTIONS PER TXN', 'EXECUTIONS PER USER CALL', 'FULL INDEX SCANS PER SEC', 'FULL INDEX SCANS PER TXN', 'GC CR BLOCK RECEIVED PER SECOND', 'GC CR BLOCK RECEIVED PER TXN', 'GC CURRENT BLOCK RECEIVED PER SECOND', 'GC CURRENT BLOCK RECEIVED PER TXN', 'GLOBAL CACHE AVERAGE CR GET TIME', 'GLOBAL CACHE AVERAGE CURRENT GET TIME', 'GLOBAL CACHE BLOCKS CORRUPTED', 'GLOBAL CACHE BLOCKS LOST', 'HARD PARSE COUNT PER SEC', 'HARD PARSE COUNT PER TXN', 'HOST CPU USAGE PER SEC', 'HOST CPU UTILIZATION (%)', 'I/O MEGABYTES PER SECOND', 'I/O REQUESTS PER SECOND', 'LEAF NODE SPLITS PER SEC', 'LEAF NODE SPLITS PER TXN', 'LIBRARY CACHE HIT RATIO', 'LIBRARY CACHE MISS RATIO', 'LOGICAL READS PER SEC', 'LOGICAL READS PER TXN', 'LOGICAL READS PER USER CALL', 'LOGONS PER SEC', 'LOGONS PER TXN', 'LONG TABLE SCANS PER SEC', 'LONG TABLE SCANS PER TXN', 'MEMORY SORTS RATIO', 'NETWORK  ...

# %% [markdown]
# ### Data Ordering
#
# Sorting of datasets in order of SNAP_ID.

# %%
df.sort_values(by=['SNAP_ID'], ascending=True, inplace=True)
print(df.shape)
# Out:
# (12019, 1418)

# %% [markdown]
# ### Floating point precision conversion
#
# Each column is converted into a column of type values which are floating point for higher precision.

# %%
df.astype('float32', inplace=True)
df = np.round(df, 3) # rounds to 3 dp
print(df.shape)
# Out:
# (12019, 1418)

# %% [markdown]
# ### Redundant Feature Removal
#
# In this step, redundant features are dropped. Features are considered redundant if exhibit a standard devaition of 0 (meaning no change in value).

# %%
def drop_flatline_columns(df):
    columns = df.columns
    flatline_features = []
    for i in range(len(columns)):
        try:
            std = df[columns[i]].std()
            if std == 0:
                flatline_features.append(columns[i])
        except:
            pass
    
    print('\nShape before changes: [' + str(df.shape) + ']')
    df = df.drop(columns=flatline_features)
    print('Shape after changes: [' + str(df.shape) + ']')
    print('Dropped a total [' + str(len(flatline_features)) + ']')
    return df

print('Before column drop:')
print(df.shape)
df = drop_flatline_columns(df=df)
print('\nAfter flatline column drop:')
print(df.shape)
dropped_columns_df = [ 'PLAN_HASH_VALUE',
                       'OPTIMIZER_ENV_HASH_VALUE',
                       'LOADED_VERSIONS',
                       'VERSION_COUNT',
                       'PARSING_SCHEMA_ID',
                       'PARSING_USER_ID',
                       'CON_DBID',
                       'SNAP_LEVEL',
                       'SNAP_FLAG',
                       'COMMAND_TYPE']
df.drop(columns=dropped_columns_df, inplace=True)
print('\nAfter additional column drop:')
print(df.shape)
# Out:
# Before column drop:
# (12019, 1418)
#
# Shape before changes: [(12019, 1418)]
# Shape after changes: [(12019, 536)]
# Dropped a total [882]
#
# After flatline column drop:
# (12019, 536)
#
# After additional column drop:
# (12019, 526)

# %% [markdown]
# ### Outlier Detection - Standard Deviation Method
#
# Detection and transformation of outliers, categorized as more than 3 standard deviations away.
#
# If we know that the distribution of values in the sample is Gaussian or Gaussian-like, we can use the standard deviation of the sample as a cut-off for identifying outliers.
#
# The Gaussian distribution has the property that the standard deviation from the mean can be used to reliably summarize the percentage of values in the sample.
#
# For example, within one standard deviation of the mean will cover 68% of the data.
#
# So, if the mean is 50 and the standard deviation is 5, as in the test dataset above, then all data in the sample between 45 and 55 will account for about 68% of the data sample. We can cover more of the data sample if we expand the range as follows:
#
# * 1 Standard Deviation from the Mean: 68%
# * 2 Standard Deviations from the Mean: 95%
# * 3 Standard Deviations from the Mean: 99.7%
#
# A value that falls outside of 3 standard deviations is part of the distribution, but it is an unlikely or rare event at approximately 1 in 370 samples.
#
# Three standard deviations from the mean is a common cut-off in practice for identifying outliers in a Gaussian or Gaussian-like distribution. For smaller samples of data, perhaps a value of 2 standard deviations (95%) can be used, and for larger samples, perhaps a value of 4 standard deviations (99.9%) can be used.
#
# More infor here: https://machinelearningmastery.com/how-to-use-statistics-to-identify-outliers-in-data/

# %%
def detect_and_transform_outliers_zscore(df, threshold=3):
    """
    Iterates over input dataframe and transforms outliers (greater then 3 std threshold) into mean value
    
    :param: (Pandas 2D Matrix) Input dataframe
    :param: (Integer) Input standard deviation threshold - 3 equates to the .99% threshold
    """
    for col in df.columns:
        mean = np.mean(df[col])
        std = np.std(df[col])
        
        counter = 0
        for val in df[col]:
            z_score = (val - mean) / std
            if np.abs(z_score) > threshold:
                df[col].iloc[counter] = mean
                print('Outlier detected for column [' + col + '] at location [' + str(counter) + '] with value [' + str(val) + ']')
            counter += 1
                
    return df

def detect_and_transform_outliers_iqr(df):
    """
    Iterates over input dataframe and transforms outliers (greater then 3 std threshold) into mean value
    
    :param: (Pandas 2D Matrix) Input dataframe
    :param: (Integer) Input standard deviation threshold - 3 equates to the .99% threshold
    """
    for col in df.columns:
        quartile_1, quartile_3 = np.percentile(df.values, [25, 75])
        iqr = quartile_3 - quartile_1
        lower_bound = quartile_1 - (iqr * 1.5)
        upper_bound = quartile_3 + (iqr * 1.5)
        
        counter = 0
        for val in df[col]:
            if (val > upper_bound) or (val < lower_bound):
                df[col].iloc[counter] = lower_bound
                print('Outlier detected for column [' + col + '] at location [' + str(counter) + '] with value [' + str(val) + ']')
            counter += 1
                
    return df

df[[y_label[0]]] = detect_and_transform_outliers_zscore(df=df[[y_label[0]]])
df[[y_label[1]]] = detect_and_transform_outliers_iqr(df=df[[y_label[1]]])

for label in y_label:
    
    df.plot.scatter(x='SNAP_ID',
                    y=label,
                    c='DarkBlue')
    plt.title(label + " over time (SNAP_ID)")
    plt.show()
    
    df[label].hist(bins=10)
    plt.title(label + ' value distribution')
    plt.show()
    
    qqplot(df[label], line='s')
    plt.show()
    
    df[label].plot.line()
    plt.title(label + ' over time')
    plt.show()
    print('---------------------------------------------------------------')
# Out:
# Outlier detected for column [CPU_TIME_DELTA] at location [35] with value [1860334766]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# Outlier detected for column [CPU_TIME_DELTA] at location [36] with value [3579433459]
# Outlier detected for column [CPU_TIME_DELTA] at location [37] with value [1714481645]
# Outlier detected for column [CPU_TIME_DELTA] at location [38] with value [1813313472]
# Outlier detected for column [CPU_TIME_DELTA] at location [250] with value [1639268256]
# Outlier detected for column [CPU_TIME_DELTA] at location [548] with value [2396388182]
# Outlier detected for column [CPU_TIME_DELTA] at location [565] with value [2632412043]
# Outlier detected for column [CPU_TIME_DELTA] at location [566] with value [2015728318]
# Outlier detected for column [CPU_TIME_DELTA] at location [692] with value [8047880163]
# Outlier detected for column [CPU_TIME_DELTA] at location [787] with value [3278140800]
# Outlier detected for column [CPU_TIME_DELTA] at location [848] with value [4652078888]
# Outlier detected for column [CPU_TIME_DELTA] at location [850] with value [1705276741]
# Outlier detected for column [CPU_TIME_DELTA] at location [852] with value [1665391036]
# Outlier detected for column [CPU_TIME_DELTA] at location [1089] with value [2108795450]
# Outlier detected for column [CPU_TIME_DELTA] at location [1111] with value [1895401400]
# Outlier detected for column [CPU_TIME_DELTA] at location [1367] with value [3483632236]
# Outlier detected for column [CPU_TIME_DELTA] at location [1372] with value [1733228681]
# Outlier detected for column [CPU_TIME_DELTA] at location [1375] with value [3494188991]
# Outlier detected for column [CPU_TIME_DELTA] at location [1655] with value [2311844562]
# Outlier detected for column [CPU_TIME_DELTA] at location [1682] with value [1903424626]
# Outlier detected for column [CPU_TIME_DELTA] at location [1796] with value [2770051644]
# Outlier detected for column [CPU_TIME_DELTA] at location [1861] with value [1909666439]
# Outlier detected for column [CPU_TIME_DELTA] at location [2063] with value [1702079406]
# Outlier detected for column [CPU_TIME_DELTA] at location [2299] with value [4572240806]
# Outlier detected for column [CPU_TIME_DELTA] at location [2300] with value [4069881506]
# Outlier detected for column [CPU_TIME_DELTA] at location [2572] with value [4484927448]
# Outlier detected for column [CPU_TIME_DELTA] at location [2573] with value [3030525996]
# Outlier detected for column [CPU_TIME_DELTA] at location [2575] with value [2130425222]
# Outlier detected for column [CPU_TIME_DELTA] at location [2694] with value [3224706688]
# Outlier detected for column [CPU_TIME_DELTA] at location [2767] with value [1860888405]
# Outlier detected for column [CPU_TIME_DELTA] at location [2778] with value [2212128085]
# Outlier detected for column [CPU_TIME_DELTA] at location [2783] with value [1928487685]
# Outlier detected for column [CPU_TIME_DELTA] at location [2784] with value [1606153908]
# Outlier detected for column [CPU_TIME_DELTA] at location [2785] with value [1606008356]
# Outlier detected for column [CPU_TIME_DELTA] at location [2786] with value [1555872826]
# Outlier detected for column [CPU_TIME_DELTA] at location [2787] with value [1834026762]
# Outlier detected for column [CPU_TIME_DELTA] at location [3007] with value [1851431232]
# Outlier detected for column [CPU_TIME_DELTA] at location [3009] with value [2255887197]
# Outlier detected for column [CPU_TIME_DELTA] at location [3011] with value [1605684950]
# Outlier detected for column [CPU_TIME_DELTA] at location [3320] with value [1666216825]
# Outlier detected for column [CPU_TIME_DELTA] at location [3321] with value [1816516694]
# Outlier detected for column [CPU_TIME_DELTA] at location [3327] with value [1666149683]
# Outlier detected for column [CPU_TIME_DELTA] at location [3328] with value [2132835674]
# Outlier detected for column [CPU_TIME_DELTA] at location [3774] with value [2577976648]
# Outlier detected for column [CPU_TIME_DELTA] at location [4016] with value [2129104931]
# Outlier detected for column [CPU_TIME_DELTA] at location [4017] with value [2598720803]
# Outlier detected for column [CPU_TIME_DELTA] at location [4185] with value [3052534272]
# Outlier detected for column [CPU_TIME_DELTA] at location [4186] with value [1761142127]
# Outlier detected for column [CPU_TIME_DELTA] at location [4202] with value [1594728539]
# Outlier detected for column [CPU_TIME_DELTA] at location [4424] with value [2122171056]
# Outlier detected for column [CPU_TIME_DELTA] at location [4563] with value [7199299103]
# Outlier detected for column [CPU_TIME_DELTA] at location [4564] with value [5703384144]
# Outlier detected for column [CPU_TIME_DELTA] at location [4565] with value [3068983752]
# Outlier detected for column [CPU_TIME_DELTA] at location [4566] with value [2443508396]
# Outlier detected for column [CPU_TIME_DELTA] at location [4567] with value [1853512073]
# Outlier detected for column [CPU_TIME_DELTA] at location [4755] with value [2669045365]
# Outlier detected for column [CPU_TIME_DELTA] at location [4756] with value [2157577878]
# Outlier detected for column [CPU_TIME_DELTA] at location [4757] with value [1815986758]
# Outlier detected for column [CPU_TIME_DELTA] at location [4879] with value [1810372467]
# Outlier detected for column [CPU_TIME_DELTA] at location [4892] with value [1580615050]
# Outlier detected for column [CPU_TIME_DELTA] at location [5103] with value [1912385488]
# Outlier detected for column [CPU_TIME_DELTA] at location [5121] with value [7374488266]
# Outlier detected for column [CPU_TIME_DELTA] at location [5285] with value [1561682141]
# Outlier detected for column [CPU_TIME_DELTA] at location [5286] with value [2058970198]
# Outlier detected for column [CPU_TIME_DELTA] at location [5287] with value [1546473216]
# Outlier detected for column [CPU_TIME_DELTA] at location [5485] with value [6409042615]
# Outlier detected for column [CPU_TIME_DELTA] at location [5486] with value [2089820010]
# Outlier detected for column [CPU_TIME_DELTA] at location [5487] with value [1840031857]
# Outlier detected for column [CPU_TIME_DELTA] at location [5488] with value [2996976804]
# Outlier detected for column [CPU_TIME_DELTA] at location [5489] with value [2241257013]
# Outlier detected for column [CPU_TIME_DELTA] at location [5490] with value [1834003362]
# Outlier detected for column [CPU_TIME_DELTA] at location [5642] with value [2534319989]
# Outlier detected for column [CPU_TIME_DELTA] at location [5643] with value [1878693422]
# Outlier detected for column [CPU_TIME_DELTA] at location [5644] with value [1940529941]
# Outlier detected for column [CPU_TIME_DELTA] at location [5646] with value [2760330135]
# Outlier detected for column [CPU_TIME_DELTA] at location [5647] with value [1645552684]
# Outlier detected for column [CPU_TIME_DELTA] at location [5873] with value [1540715433]
# Outlier detected for column [CPU_TIME_DELTA] at location [5876] with value [3250436769]
# Outlier detected for column [CPU_TIME_DELTA] at location [6042] with value [4499975918]
# Outlier detected for column [CPU_TIME_DELTA] at location [6043] with value [1630869083]
# Outlier detected for column [CPU_TIME_DELTA] at location [6044] with value [1919285148]
# Outlier detected for column [CPU_TIME_DELTA] at location [6055] with value [1625216476]
# Outlier detected for column [CPU_TIME_DELTA] at location [6231] with value [1933924123]
# Outlier detected for column [CPU_TIME_DELTA] at location [6232] with value [1913094467]
# Outlier detected for column [CPU_TIME_DELTA] at location [6235] with value [1610065958]
# Outlier detected for column [CPU_TIME_DELTA] at location [6236] with value [1918397511]
# Outlier detected for column [CPU_TIME_DELTA] at location [6418] with value [2211947646]
# Outlier detected for column [CPU_TIME_DELTA] at location [6419] with value [4110878251]
# Outlier detected for column [CPU_TIME_DELTA] at location [6421] with value [1608813875]
# Outlier detected for column [CPU_TIME_DELTA] at location [6602] with value [1719216493]
# Outlier detected for column [CPU_TIME_DELTA] at location [6608] with value [1993125631]
# Outlier detected for column [CPU_TIME_DELTA] at location [6610] with value [1946742614]
# Outlier detected for column [CPU_TIME_DELTA] at location [6614] with value [4460359463]
# Outlier detected for column [CPU_TIME_DELTA] at location [6615] with value [3387899690]
# Outlier detected for column [CPU_TIME_DELTA] at location [6773] with value [1589470964]
# Outlier detected for column [CPU_TIME_DELTA] at location [6777] with value [1834275168]
# Outlier detected for column [CPU_TIME_DELTA] at location [6779] with value [1738440735]
# Outlier detected for column [CPU_TIME_DELTA] at location [7036] with value [4094825524]
# Outlier detected for column [CPU_TIME_DELTA] at location [7046] with value [2205054305]
# Outlier detected for column [CPU_TIME_DELTA] at location [7047] with value [2522321065]
# Outlier detected for column [CPU_TIME_DELTA] at location [7049] with value [1608053574]
# Outlier detected for column [CPU_TIME_DELTA] at location [7050] with value [2277476624]
# Outlier detected for column [CPU_TIME_DELTA] at location [7053] with value [1539793037]
# Outlier detected for column [CPU_TIME_DELTA] at location [7199] with value [1534483520]
# Outlier detected for column [CPU_TIME_DELTA] at location [7201] with value [2566174582]
# Outlier detected for column [CPU_TIME_DELTA] at location [7202] with value [1781477921]
# Outlier detected for column [CPU_TIME_DELTA] at location [7208] with value [1935937857]
# Outlier detected for column [CPU_TIME_DELTA] at location [7211] with value [2458159416]
# Outlier detected for column [CPU_TIME_DELTA] at location [7434] with value [7777029608]
# Outlier detected for column [CPU_TIME_DELTA] at location [7435] with value [3739253805]
# Outlier detected for column [CPU_TIME_DELTA] at location [7436] with value [4901282583]
# Outlier detected for column [CPU_TIME_DELTA] at location [7437] with value [3497560087]
# Outlier detected for column [CPU_TIME_DELTA] at location [7562] with value [1853894629]
# Outlier detected for column [CPU_TIME_DELTA] at location [7565] with value [3909377912]
# Outlier detected for column [CPU_TIME_DELTA] at location [7568] with value [1656340533]
# Outlier detected for column [CPU_TIME_DELTA] at location [7571] with value [1608720202]
# Outlier detected for column [CPU_TIME_DELTA] at location [7573] with value [1639557650]
# Outlier detected for column [CPU_TIME_DELTA] at location [7574] with value [2157564677]
# Outlier detected for column [CPU_TIME_DELTA] at location [7577] with value [1785710547]
# Outlier detected for column [CPU_TIME_DELTA] at location [7779] with value [1997686235]
# Outlier detected for column [CPU_TIME_DELTA] at location [7794] with value [2037972786]
# Outlier detected for column [CPU_TIME_DELTA] at location [7947] with value [2860973766]
# Outlier detected for column [CPU_TIME_DELTA] at location [7948] with value [4739936937]
# Outlier detected for column [CPU_TIME_DELTA] at location [7949] with value [6573399273]
# Outlier detected for column [CPU_TIME_DELTA] at location [7950] with value [4423113189]
# Outlier detected for column [CPU_TIME_DELTA] at location [7951] with value [3556419744]
# Outlier detected for column [CPU_TIME_DELTA] at location [8139] with value [8700003444]
# Outlier detected for column [CPU_TIME_DELTA] at location [8141] with value [1713364023]
# Outlier detected for column [CPU_TIME_DELTA] at location [8143] with value [6311525916]
# Outlier detected for column [CPU_TIME_DELTA] at location [8295] with value [4574129964]
# Outlier detected for column [CPU_TIME_DELTA] at location [8296] with value [3839938156]
# Outlier detected for column [CPU_TIME_DELTA] at location [8297] with value [4003204853]
# Outlier detected for column [CPU_TIME_DELTA] at location [8298] with value [2873243699]
# Outlier detected for column [CPU_TIME_DELTA] at location [8302] with value [2080937142]
# Outlier detected for column [CPU_TIME_DELTA] at location [8303] with value [1535643077]
# Outlier detected for column [CPU_TIME_DELTA] at location [8304] with value [1743902123]
# Outlier detected for column [CPU_TIME_DELTA] at location [8479] with value [1606437798]
# Outlier detected for column [CPU_TIME_DELTA] at location [8501] with value [1820482973]
# Outlier detected for column [CPU_TIME_DELTA] at location [8506] with value [2070754837]
# Outlier detected for column [CPU_TIME_DELTA] at location [8658] with value [1545714561]
# Outlier detected for column [CPU_TIME_DELTA] at location [8678] with value [2235077009]
# Outlier detected for column [CPU_TIME_DELTA] at location [8858] with value [1950583328]
# Outlier detected for column [CPU_TIME_DELTA] at location [8866] with value [1715718705]
# Outlier detected for column [CPU_TIME_DELTA] at location [9003] with value [1898398189]
# Outlier detected for column [CPU_TIME_DELTA] at location [9006] with value [1734230011]
# Outlier detected for column [CPU_TIME_DELTA] at location [9007] with value [4832492775]
# Outlier detected for column [CPU_TIME_DELTA] at location [9232] with value [1779807076]
# Outlier detected for column [CPU_TIME_DELTA] at location [9235] with value [2815746374]
# Outlier detected for column [CPU_TIME_DELTA] at location [9246] with value [1979411733]
# Outlier detected for column [CPU_TIME_DELTA] at location [9248] with value [1715495026]
# Outlier detected for column [CPU_TIME_DELTA] at location [9399] with value [2085406950]
# Outlier detected for column [CPU_TIME_DELTA] at location [9400] with value [1533434186]
# Outlier detected for column [CPU_TIME_DELTA] at location [9411] with value [2814192981]
# Outlier detected for column [CPU_TIME_DELTA] at location [9412] with value [1766681534]
# Outlier detected for column [CPU_TIME_DELTA] at location [9602] with value [2691485405]
# Outlier detected for column [CPU_TIME_DELTA] at location [9610] with value [1956016072]
# Outlier detected for column [CPU_TIME_DELTA] at location [9611] with value [1767933259]
# Outlier detected for column [CPU_TIME_DELTA] at location [9615] with value [2068252405]
# Outlier detected for column [CPU_TIME_DELTA] at location [9770] with value [1774003280]
# Outlier detected for column [CPU_TIME_DELTA] at location [9780] with value [1529695185]
# Outlier detected for column [CPU_TIME_DELTA] at location [9781] with value [2390984706]
# Outlier detected for column [CPU_TIME_DELTA] at location [9975] with value [7132799279]
# Outlier detected for column [CPU_TIME_DELTA] at location [9976] with value [3658747731]
# Outlier detected for column [CPU_TIME_DELTA] at location [9977] with value [2016109277]
# Outlier detected for column [CPU_TIME_DELTA] at location [9978] with value [1609498772]
# Outlier detected for column [CPU_TIME_DELTA] at location [9983] with value [1601871603]
# Outlier detected for column [CPU_TIME_DELTA] at location [10123] with value [2243705479]
# Outlier detected for column [CPU_TIME_DELTA] at location [10124] with value [4576388180]
# Outlier detected for column [CPU_TIME_DELTA] at location [10125] with value [1851828943]
# Outlier detected for column [CPU_TIME_DELTA] at location [10134] with value [2134890865]
# Outlier detected for column [CPU_TIME_DELTA] at location [10137] with value [1559022628]
# Outlier detected for column [CPU_TIME_DELTA] at location [10331] with value [6034855979]
# Outlier detected for column [CPU_TIME_DELTA] at location [10332] with value [4125620039]
# Outlier detected for column [CPU_TIME_DELTA] at location [10333] with value [3377187174]
# Outlier detected for column [CPU_TIME_DELTA] at location [10334] with value [6051495452]
# Outlier detected for column [CPU_TIME_DELTA] at location [10335] with value [1954155443]
# Outlier detected for column [CPU_TIME_DELTA] at location [10425] with value [1674591965]
# Outlier detected for column [CPU_TIME_DELTA] at location [10428] with value [4679025427]
# Outlier detected for column [CPU_TIME_DELTA] at location [10429] with value [5688341578]
# Outlier detected for column [CPU_TIME_DELTA] at location [10431] with value [1925167235]
# Outlier detected for column [CPU_TIME_DELTA] at location [10623] with value [1673340420]
# Outlier detected for column [CPU_TIME_DELTA] at location [10634] with value [4229862719]
# Outlier detected for column [CPU_TIME_DELTA] at location [10635] with value [3194403708]
# Outlier detected for column [CPU_TIME_DELTA] at location [10636] with value [1655076820]
# Outlier detected for column [CPU_TIME_DELTA] at location [10761] with value [1806087552]
# Outlier detected for column [CPU_TIME_DELTA] at location [10763] with value [1826264632]
# Outlier detected for column [CPU_TIME_DELTA] at location [10768] with value [1647823043]
# Outlier detected for column [CPU_TIME_DELTA] at location [10986] with value [5330160788]
# Outlier detected for column [CPU_TIME_DELTA] at location [11153] with value [1595259006]
# Outlier detected for column [CPU_TIME_DELTA] at location [11154] with value [1544549253]
# Outlier detected for column [CPU_TIME_DELTA] at location [11156] with value [3711974924]
# Outlier detected for column [CPU_TIME_DELTA] at location [11157] with value [3891203811]
# Outlier detected for column [CPU_TIME_DELTA] at location [11158] with value [5571181438]
# Outlier detected for column [CPU_TIME_DELTA] at location [11159] with value [3965665710]
# Outlier detected for column [CPU_TIME_DELTA] at location [11328] with value [1584670637]
# Outlier detected for column [CPU_TIME_DELTA] at location [11332] with value [1730885566]
# Outlier detected for column [CPU_TIME_DELTA] at location [11334] with value [2654262279]
# Outlier detected for column [CPU_TIME_DELTA] at location [11343] with value [2832262053]
# Outlier detected for column [CPU_TIME_DELTA] at location [11344] with value [1750605589]
# Outlier detected for column [CPU_TIME_DELTA] at location [11345] with value [2570764336]
# Outlier detected for column [CPU_TIME_DELTA] at location [11667] with value [2143445387]
# Outlier detected for column [CPU_TIME_DELTA] at location [11697] with value [2160133790]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Outlier detected for column [IOWAIT_DELTA] at location [0] with value [2801905125.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1] with value [3789764238.0]
# Outlier detected for column [IOWAIT_DELTA] at location [2] with value [3565006264.0]
# Outlier detected for column [IOWAIT_DELTA] at location [3] with value [3001697458.0]
# Outlier detected for column [IOWAIT_DELTA] at location [4] with value [346677435.0]
# Outlier detected for column [IOWAIT_DELTA] at location [34] with value [1435301238.0]
# Outlier detected for column [IOWAIT_DELTA] at location [35] with value [8242475867.0]
# Outlier detected for column [IOWAIT_DELTA] at location [36] with value [3299714697.0]
# Outlier detected for column [IOWAIT_DELTA] at location [37] with value [1622023268.0]
# Outlier detected for column [IOWAIT_DELTA] at location [38] with value [2515722772.0]
# Outlier detected for column [IOWAIT_DELTA] at location [39] with value [2668082832.0]
# Outlier detected for column [IOWAIT_DELTA] at location [40] with value [1008946846.0]
# Outlier detected for column [IOWAIT_DELTA] at location [41] with value [816516890.0]
# Outlier detected for column [IOWAIT_DELTA] at location [42] with value [786783781.0]
# Outlier detected for column [IOWAIT_DELTA] at location [43] with value [694742865.0]
# Outlier detected for column [IOWAIT_DELTA] at location [44] with value [825431974.0]
# Outlier detected for column [IOWAIT_DELTA] at location [45] with value [3634317005.0]
# Outlier detected for column [IOWAIT_DELTA] at location [46] with value [2029076339.0]
# Outlier detected for column [IOWAIT_DELTA] at location [47] with value [1768874278.0]
# Outlier detected for column [IOWAIT_DELTA] at location [48] with value [1892613249.0]
# Outlier detected for column [IOWAIT_DELTA] at location [49] with value [1747751671.0]
# Outlier detected for column [IOWAIT_DELTA] at location [50] with value [2920409162.0]
# Outlier detected for column [IOWAIT_DELTA] at location [51] with value [2413156919.0]
# Outlier detected for column [IOWAIT_DELTA] at location [52] with value [2447535577.0]
# Outlier detected for column [IOWAIT_DELTA] at location [53] with value [1475999163.0]
# Outlier detected for column [IOWAIT_DELTA] at location [54] with value [1495290784.0]
# Outlier detected for column [IOWAIT_DELTA] at location [55] with value [2656156316.0]
# Outlier detected for column [IOWAIT_DELTA] at location [56] with value [3548914438.0]
# Outlier detected for column [IOWAIT_DELTA] at location [57] with value [6287906358.0]
# Outlier detected for column [IOWAIT_DELTA] at location [58] with value [515194833.0]
# Outlier detected for column [IOWAIT_DELTA] at location [59] with value [1038945223.0]
# Outlier detected for column [IOWAIT_DELTA] at location [187] with value [305999640.0]
# Outlier detected for column [IOWAIT_DELTA] at location [190] with value [331095181.0]
# Outlier detected for column [IOWAIT_DELTA] at location [191] with value [502433308.0]
# Outlier detected for column [IOWAIT_DELTA] at location [192] with value [455693948.0]
# Outlier detected for column [IOWAIT_DELTA] at location [194] with value [296570218.0]
# Outlier detected for column [IOWAIT_DELTA] at location [203] with value [338510539.0]
# Outlier detected for column [IOWAIT_DELTA] at location [204] with value [383503823.0]
# Outlier detected for column [IOWAIT_DELTA] at location [205] with value [366380855.0]
# Outlier detected for column [IOWAIT_DELTA] at location [206] with value [300002112.0]
# Outlier detected for column [IOWAIT_DELTA] at location [207] with value [340963636.0]
# Outlier detected for column [IOWAIT_DELTA] at location [208] with value [330480005.0]
# Outlier detected for column [IOWAIT_DELTA] at location [209] with value [360630353.0]
# Outlier detected for column [IOWAIT_DELTA] at location [216] with value [496091418.0]
# Outlier detected for column [IOWAIT_DELTA] at location [238] with value [623326435.0]
# Outlier detected for column [IOWAIT_DELTA] at location [239] with value [2201145115.0]
# Outlier detected for column [IOWAIT_DELTA] at location [240] with value [1668085918.0]
# Outlier detected for column [IOWAIT_DELTA] at location [241] with value [2075247833.0]
# Outlier detected for column [IOWAIT_DELTA] at location [242] with value [1980823323.0]
# Outlier detected for column [IOWAIT_DELTA] at location [243] with value [2358055223.0]
# Outlier detected for column [IOWAIT_DELTA] at location [244] with value [1499609801.0]
# Outlier detected for column [IOWAIT_DELTA] at location [245] with value [1865702750.0]
# Outlier detected for column [IOWAIT_DELTA] at location [246] with value [1809516720.0]
# Outlier detected for column [IOWAIT_DELTA] at location [247] with value [1116790413.0]
# Outlier detected for column [IOWAIT_DELTA] at location [248] with value [1162763942.0]
# Outlier detected for column [IOWAIT_DELTA] at location [249] with value [824151601.0]
# Outlier detected for column [IOWAIT_DELTA] at location [250] with value [2790955694.0]
# Outlier detected for column [IOWAIT_DELTA] at location [251] with value [1764167804.0]
# Outlier detected for column [IOWAIT_DELTA] at location [252] with value [2650624357.0]
# Outlier detected for column [IOWAIT_DELTA] at location [253] with value [3030802411.0]
# Outlier detected for column [IOWAIT_DELTA] at location [254] with value [3720059383.0]
# Outlier detected for column [IOWAIT_DELTA] at location [255] with value [3063345317.0]
# Outlier detected for column [IOWAIT_DELTA] at location [256] with value [2133122255.0]
# Outlier detected for column [IOWAIT_DELTA] at location [257] with value [895509261.0]
# Outlier detected for column [IOWAIT_DELTA] at location [258] with value [661843369.0]
# Outlier detected for column [IOWAIT_DELTA] at location [259] with value [662487417.0]
# Outlier detected for column [IOWAIT_DELTA] at location [260] with value [644442761.0]
# Outlier detected for column [IOWAIT_DELTA] at location [261] with value [3939156993.0]
# Outlier detected for column [IOWAIT_DELTA] at location [262] with value [3861955316.0]
# Outlier detected for column [IOWAIT_DELTA] at location [263] with value [2240932375.0]
# Outlier detected for column [IOWAIT_DELTA] at location [264] with value [1535277734.0]
# Outlier detected for column [IOWAIT_DELTA] at location [265] with value [1182878868.0]
# Outlier detected for column [IOWAIT_DELTA] at location [266] with value [1168876724.0]
# Outlier detected for column [IOWAIT_DELTA] at location [267] with value [1753288499.0]
# Outlier detected for column [IOWAIT_DELTA] at location [268] with value [11840956044.0]
# Outlier detected for column [IOWAIT_DELTA] at location [269] with value [4364128841.0]
# Outlier detected for column [IOWAIT_DELTA] at location [270] with value [2721748314.0]
# Outlier detected for column [IOWAIT_DELTA] at location [271] with value [1201717021.0]
# Outlier detected for column [IOWAIT_DELTA] at location [272] with value [1023960563.0]
# Outlier detected for column [IOWAIT_DELTA] at location [273] with value [1029594377.0]
# Outlier detected for column [IOWAIT_DELTA] at location [274] with value [784348145.0]
# Outlier detected for column [IOWAIT_DELTA] at location [275] with value [308873713.0]
# Outlier detected for column [IOWAIT_DELTA] at location [276] with value [334505133.0]
# Outlier detected for column [IOWAIT_DELTA] at location [277] with value [620297501.0]
# Outlier detected for column [IOWAIT_DELTA] at location [278] with value [614931355.0]
# Outlier detected for column [IOWAIT_DELTA] at location [280] with value [317680467.0]
# Outlier detected for column [IOWAIT_DELTA] at location [478] with value [1629098479.0]
# Outlier detected for column [IOWAIT_DELTA] at location [479] with value [2595158185.0]
# Outlier detected for column [IOWAIT_DELTA] at location [480] with value [3830211049.0]
# Outlier detected for column [IOWAIT_DELTA] at location [481] with value [3391032786.0]
# Outlier detected for column [IOWAIT_DELTA] at location [482] with value [2112382407.0]
# Outlier detected for column [IOWAIT_DELTA] at location [502] with value [327090354.0]
# Outlier detected for column [IOWAIT_DELTA] at location [503] with value [405226684.0]
# Outlier detected for column [IOWAIT_DELTA] at location [504] with value [427013264.0]
# Outlier detected for column [IOWAIT_DELTA] at location [505] with value [434731288.0]
# Outlier detected for column [IOWAIT_DELTA] at location [506] with value [369029018.0]
# Outlier detected for column [IOWAIT_DELTA] at location [507] with value [464726053.0]
# Outlier detected for column [IOWAIT_DELTA] at location [508] with value [439463268.0]
# Outlier detected for column [IOWAIT_DELTA] at location [509] with value [336196504.0]
# Outlier detected for column [IOWAIT_DELTA] at location [510] with value [862112554.0]
# Outlier detected for column [IOWAIT_DELTA] at location [511] with value [405440716.0]
# Outlier detected for column [IOWAIT_DELTA] at location [538] with value [862585884.0]
# Outlier detected for column [IOWAIT_DELTA] at location [539] with value [2654514646.0]
# Outlier detected for column [IOWAIT_DELTA] at location [540] with value [4371082941.0]
# Outlier detected for column [IOWAIT_DELTA] at location [541] with value [2528099987.0]
# Outlier detected for column [IOWAIT_DELTA] at location [542] with value [2482878672.0]
# Outlier detected for column [IOWAIT_DELTA] at location [543] with value [2868301721.0]
# Outlier detected for column [IOWAIT_DELTA] at location [544] with value [2569959591.0]
# Outlier detected for column [IOWAIT_DELTA] at location [545] with value [1505604629.0]
# Outlier detected for column [IOWAIT_DELTA] at location [546] with value [789839344.0]
# Outlier detected for column [IOWAIT_DELTA] at location [547] with value [794285310.0]
# Outlier detected for column [IOWAIT_DELTA] at location [548] with value [3409569907.0]
# Outlier detected for column [IOWAIT_DELTA] at location [549] with value [2250373257.0]
# Outlier detected for column [IOWAIT_DELTA] at location [550] with value [1622505843.0]
# Outlier detected for column [IOWAIT_DELTA] at location [551] with value [1314270301.0]
# Outlier detected for column [IOWAIT_DELTA] at location [552] with value [1003119015.0]
# Outlier detected for column [IOWAIT_DELTA] at location [553] with value [1622044799.0]
# Outlier detected for column [IOWAIT_DELTA] at location [554] with value [1230789864.0]
# Outlier detected for column [IOWAIT_DELTA] at location [555] with value [2040672030.0]
# Outlier detected for column [IOWAIT_DELTA] at location [556] with value [2300316777.0]
# Outlier detected for column [IOWAIT_DELTA] at location [557] with value [2200439626.0]
# Outlier detected for column [IOWAIT_DELTA] at location [558] with value [874760123.0]
# Outlier detected for column [IOWAIT_DELTA] at location [559] with value [885082985.0]
# Outlier detected for column [IOWAIT_DELTA] at location [560] with value [1367166896.0]
# Outlier detected for column [IOWAIT_DELTA] at location [561] with value [3999798282.0]
# Outlier detected for column [IOWAIT_DELTA] at location [562] with value [3924563093.0]
# Outlier detected for column [IOWAIT_DELTA] at location [563] with value [3036948569.0]
# Outlier detected for column [IOWAIT_DELTA] at location [564] with value [3662734159.0]
# Outlier detected for column [IOWAIT_DELTA] at location [565] with value [3868274887.0]
# Outlier detected for column [IOWAIT_DELTA] at location [566] with value [3609143355.0]
# Outlier detected for column [IOWAIT_DELTA] at location [567] with value [1574968600.0]
# Outlier detected for column [IOWAIT_DELTA] at location [568] with value [786353882.0]
# Outlier detected for column [IOWAIT_DELTA] at location [569] with value [907820692.0]
# Outlier detected for column [IOWAIT_DELTA] at location [570] with value [2291771189.0]
# Outlier detected for column [IOWAIT_DELTA] at location [571] with value [948325237.0]
# Outlier detected for column [IOWAIT_DELTA] at location [572] with value [460438943.0]
# Outlier detected for column [IOWAIT_DELTA] at location [681] with value [1605412575.0]
# Outlier detected for column [IOWAIT_DELTA] at location [684] with value [2624255018.0]
# Outlier detected for column [IOWAIT_DELTA] at location [685] with value [2911303745.0]
# Outlier detected for column [IOWAIT_DELTA] at location [686] with value [3744234164.0]
# Outlier detected for column [IOWAIT_DELTA] at location [687] with value [2954040647.0]
# Outlier detected for column [IOWAIT_DELTA] at location [688] with value [2383045351.0]
# Outlier detected for column [IOWAIT_DELTA] at location [689] with value [1813688124.0]
# Outlier detected for column [IOWAIT_DELTA] at location [690] with value [1705030448.0]
# Outlier detected for column [IOWAIT_DELTA] at location [691] with value [1377003747.0]
# Outlier detected for column [IOWAIT_DELTA] at location [692] with value [10710420973.0]
# Outlier detected for column [IOWAIT_DELTA] at location [693] with value [2826385236.0]
# Outlier detected for column [IOWAIT_DELTA] at location [694] with value [1018528084.0]
# Outlier detected for column [IOWAIT_DELTA] at location [695] with value [651257468.0]
# Outlier detected for column [IOWAIT_DELTA] at location [696] with value [1056660609.0]
# Outlier detected for column [IOWAIT_DELTA] at location [697] with value [1453429793.0]
# Outlier detected for column [IOWAIT_DELTA] at location [698] with value [1234087108.0]
# Outlier detected for column [IOWAIT_DELTA] at location [699] with value [2627263302.0]
# Outlier detected for column [IOWAIT_DELTA] at location [700] with value [3175718115.0]
# Outlier detected for column [IOWAIT_DELTA] at location [701] with value [1945387163.0]
# Outlier detected for column [IOWAIT_DELTA] at location [702] with value [1835650276.0]
# Outlier detected for column [IOWAIT_DELTA] at location [703] with value [2742298966.0]
# Outlier detected for column [IOWAIT_DELTA] at location [704] with value [5257121958.0]
# Outlier detected for column [IOWAIT_DELTA] at location [705] with value [2799147323.0]
# Outlier detected for column [IOWAIT_DELTA] at location [706] with value [2139110657.0]
# Outlier detected for column [IOWAIT_DELTA] at location [707] with value [2340937163.0]
# Outlier detected for column [IOWAIT_DELTA] at location [708] with value [1616049682.0]
# Outlier detected for column [IOWAIT_DELTA] at location [709] with value [2156668553.0]
# Outlier detected for column [IOWAIT_DELTA] at location [710] with value [1527387795.0]
# Outlier detected for column [IOWAIT_DELTA] at location [711] with value [1663980019.0]
# Outlier detected for column [IOWAIT_DELTA] at location [712] with value [1349831464.0]
# Outlier detected for column [IOWAIT_DELTA] at location [713] with value [1177489043.0]
# Outlier detected for column [IOWAIT_DELTA] at location [714] with value [3492184155.0]
# Outlier detected for column [IOWAIT_DELTA] at location [715] with value [3437525230.0]
# Outlier detected for column [IOWAIT_DELTA] at location [716] with value [1126214416.0]
# Outlier detected for column [IOWAIT_DELTA] at location [717] with value [1504601237.0]
# Outlier detected for column [IOWAIT_DELTA] at location [719] with value [338533345.0]
# Outlier detected for column [IOWAIT_DELTA] at location [791] with value [3207435618.0]
# Outlier detected for column [IOWAIT_DELTA] at location [792] with value [2744071949.0]
# Outlier detected for column [IOWAIT_DELTA] at location [793] with value [3390262585.0]
# Outlier detected for column [IOWAIT_DELTA] at location [794] with value [3097141988.0]
# Outlier detected for column [IOWAIT_DELTA] at location [795] with value [359673448.0]
# Outlier detected for column [IOWAIT_DELTA] at location [830] with value [1199823969.0]
# Outlier detected for column [IOWAIT_DELTA] at location [831] with value [4698166490.0]
# Outlier detected for column [IOWAIT_DELTA] at location [832] with value [6188285114.0]
# Outlier detected for column [IOWAIT_DELTA] at location [833] with value [3178370580.0]
# Outlier detected for column [IOWAIT_DELTA] at location [834] with value [1550724818.0]
# Outlier detected for column [IOWAIT_DELTA] at location [835] with value [1008176116.0]
# Outlier detected for column [IOWAIT_DELTA] at location [836] with value [830165352.0]
# Outlier detected for column [IOWAIT_DELTA] at location [837] with value [754292011.0]
# Outlier detected for column [IOWAIT_DELTA] at location [838] with value [739170191.0]
# Outlier detected for column [IOWAIT_DELTA] at location [839] with value [1495221130.0]
# Outlier detected for column [IOWAIT_DELTA] at location [840] with value [820339026.0]
# Outlier detected for column [IOWAIT_DELTA] at location [841] with value [586457728.0]
# Outlier detected for column [IOWAIT_DELTA] at location [842] with value [1017558982.0]
# Outlier detected for column [IOWAIT_DELTA] at location [843] with value [2915830312.0]
# Outlier detected for column [IOWAIT_DELTA] at location [844] with value [6196929401.0]
# Outlier detected for column [IOWAIT_DELTA] at location [845] with value [6320488787.0]
# Outlier detected for column [IOWAIT_DELTA] at location [846] with value [1585822143.0]
# Outlier detected for column [IOWAIT_DELTA] at location [847] with value [1582118432.0]
# Outlier detected for column [IOWAIT_DELTA] at location [848] with value [13047697294.0]
# Outlier detected for column [IOWAIT_DELTA] at location [849] with value [8269814117.0]
# Outlier detected for column [IOWAIT_DELTA] at location [850] with value [7337166449.0]
# Outlier detected for column [IOWAIT_DELTA] at location [851] with value [5284449623.0]
# Outlier detected for column [IOWAIT_DELTA] at location [852] with value [4224132938.0]
# Outlier detected for column [IOWAIT_DELTA] at location [853] with value [3495419225.0]
# Outlier detected for column [IOWAIT_DELTA] at location [854] with value [534872654.0]
# Outlier detected for column [IOWAIT_DELTA] at location [855] with value [376333298.0]
# Outlier detected for column [IOWAIT_DELTA] at location [967] with value [316169566.0]
# Outlier detected for column [IOWAIT_DELTA] at location [968] with value [402453193.0]
# Outlier detected for column [IOWAIT_DELTA] at location [969] with value [510718244.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1088] with value [1264531649.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1089] with value [16629867167.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1090] with value [3421317145.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1091] with value [1565107956.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1092] with value [1214988791.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1093] with value [1912118758.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1094] with value [1532662484.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1095] with value [973590112.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1096] with value [625536025.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1097] with value [492447504.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1098] with value [2698891712.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1099] with value [4715690403.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1100] with value [2866341153.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1101] with value [1259777903.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1102] with value [1506567879.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1103] with value [1482862822.0]
# Outlier detected for column [IOWAIT_DELTA] at location [1104] with value [1438485769.0]
# Outlier detected for column [IOWAIT_DELTA] at location [
0]
# Outlier detected for column [IOWAIT_DELTA] at location [11837] with value [5956925299.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11838] with value [3935101494.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11839] with value [6081817762.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11840] with value [5664724799.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11841] with value [5201990359.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11842] with value [2078159675.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11843] with value [1852587496.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11844] with value [1784195853.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11845] with value [3000623319.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11846] with value [1460294605.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11847] with value [6272886185.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11848] with value [7929979001.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11849] with value [4385329513.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11850] with value [5498309865.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11851] with value [5389597970.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11852] with value [3793715763.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11853] with value [5553730277.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11854] with value [4894781404.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11855] with value [2583345219.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11856] with value [6331945387.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11857] with value [4296734762.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11858] with value [4329020415.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11859] with value [4932167900.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11860] with value [5011598683.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11861] with value [5535909729.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11862] with value [4498182493.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11863] with value [4514968745.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11864] with value [2173156934.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11865] with value [2514709704.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11866] with value [3683239157.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11867] with value [2231445339.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11868] with value [2388988442.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11869] with value [1811197009.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11870] with value [915756012.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11871] with value [1354522498.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11872] with value [9500275016.0]
# Outlier detected for column [IOWAIT_DELTA] at location [11873] with value [1440193467.0]
# Outlier detected for column [IOWAIT_DELTA] at location [12006] with value [1630544314.0]
# Outlier detected for column [IOWAIT_DELTA] at location [12007] with value [2678010138.0]
# Outlier detected for column [IOWAIT_DELTA] at location [12008] with value [4291324617.0]
# Outlier detected for column [IOWAIT_DELTA] at location [12009] with value [2914528516.0]
# Outlier detected for column [IOWAIT_DELTA] at location [12010] with value [2057079504.0]
# ---------------------------------------------------------------
# ---------------------------------------------------------------

# %% [markdown]
# ### Normalization
#
# Relavent Sources:
#
# * http://jmlr.csail.mit.edu/papers/volume3/guyon03a/guyon03a.pdf
# * https://machinelearningmastery.com/rescaling-data-for-machine-learning-in-python-with-scikit-learn/
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/ recommends a normalization preprocessing technique for data distribution that can closely approximate minimum and maximum observable values per column:
#
# <i>"Normalization requires that you know or are able to accurately estimate the minimum and maximum observable values. You may be able to estimate these values from your available data. If your time series is trending up or down, estimating these expected values may be difficult and normalization may not be the best method to use on your problem."</i>
#
# Normalization formula is stated as follows: $$y=(x-min)/(max-min)$$
#
# ### Standardization
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/ recommends a standardization preprocessing technique for data distributions that observe a Gaussian spread, with a mean of 0 and a standard deviation of 1 (approximately close to these values):
#
# <i>"Standardization assumes that your observations fit a Gaussian distribution (bell curve) with a well behaved mean and standard deviation. You can still standardize your time series data if this expectation is not met, but you may not get reliable results."</i>
#
# Standardization formula is stated as follows: $$y=(x-mean)/StandardDeviation$$
# Mean defined as: $$mean=sum(x)/count(x)$$
# Standard Deviation defined as: $$StandardDeviation=sqrt(sum((x-mean)^2)/count(x))$$

# %%
# MINMAX SCALER
#df = Normalizer.minmax_scaler(dataframe=df)
train, test = train_test_split(df, test_size=0.5)
trainheaders = train.columns
testheaders = test.columns
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)
train = pd.DataFrame(train, columns=trainheaders)
test = pd.DataFrame(test, columns=testheaders)
df = train.append(test, ignore_index=True)
#
# NORMALIZER
#df = Normalizer.normalize(dataframe=df)

print('\n\n------------------AFTER------------------')
print('------------------df------------------')
print(df.shape)
print('\n\n')
print('\n\ndf')
print(df.head())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# ------------------AFTER------------------
# ------------------df------------------
# (12019, 526)
#
#
#
#
#
# df
#     SNAP_ID  OPTIMIZER_COST  SHARABLE_MEM  FETCHES_TOTAL  FETCHES_DELTA  \
# 0  0
#
#    WORKAREA MEMORY ALLOCATED  WRITE CLONES CREATED IN BACKGROUND  \
# 0                   0.000000                            0.745789
# 1                   0.514103                            0.679019
# 2                   0.000000                            0.004060
# 3                   0.000000                            0.765807
# 4                   0.513328                            0.082556
#
#    WRITE CLONES CREATED IN FOREGROUND
# 0                            0.849105
# 1                            0.799428
# 2                            0.006123
# 3                            0.864760
# 4                            0.148181
#
# [5 rows x 526 columns]

# %% [markdown]
# ### Discrete Training
#
# This section converts the established features from the continuous domain into the discrete domain. Continous values will be converted into discrete, and used to train the model using such values (Utilizes bucket function).
#
# https://machinelearningmastery.com/make-predictions-long-short-term-memory-models-keras/

# %%
class BinClass:
    """
    Takes data column, and scales them into discrete buckets. Parameter 'n' denotes number of buckets. This class needs
    to be defined before the LSTM class, since it is referenced during the prediction stage. Since Keras models output a
    continuous output (even when trained on discrete data), the 'BinClass' is required by the LSTM class.
    """
    
    @staticmethod
    def __bucket_val(val, avg):
        """
        Receives threshold value and buckets the val according to the passed threshold
        """
        return np.where(val > avg, 1, 0)

    @staticmethod
    def discretize_value(X, threshold):
        """
        param: X - Input data
        """
        try:
            myfunc_vec = np.vectorize(lambda x: BinClass.__bucket_val(x, threshold))
            return myfunc_vec(X)
        except:
            return BinClass.__bucket_val(X, threshold)

cpu_avg = y_df[y_label[0]].mean()
y_df_cpu = pd.DataFrame(BinClass.discretize_value(y_df[[y_label[0]]].values, cpu_avg), columns=[y_label[0]])
print('CPU y:')
print(np.unique(y_df_cpu.values))
print('Number of 0s: ' + str(np.count_nonzero(y_df_cpu == 0)))
print('Number of 1s: ' + str(np.count_nonzero(y_df_cpu == 1)))
#
io_avg = y_df[y_label[1]].mean()
y_df_io = pd.DataFrame(BinClass.discretize_value(y_df[[y_label[1]]].values, io_avg), columns=[y_label[1]])
print('I/O y:')
print(np.unique(y_df_io.values))
print('Number of 0s: ' + str(np.count_nonzero(y_df_io == 0)))
print('Number of 1s: ' + str(np.count_nonzero(y_df_io == 1)))
# Out:
# CPU y:
# [0 1]
# Number of 0s: 9600
# Number of 1s: 2419
# I/O y:
# [0 1]
# Number of 0s: 2431
# Number of 1s: 9588

# %% [markdown]
# ### Time Series Shifting
#
# Shifting the datasets N lag minutes, in order to transform the problem into a supervised dataset. Each Lag Shift equates to 60 seconds (due to the way design of the data capturing tool). For each denoted lag amount, the same number of feature vectors will be stripped away at the beginning.
#
# Features and Labels are separated into seperate dataframes at this point.
#
# https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = data
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    n_out += 1
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# Frame as supervised learning set
X_df = series_to_supervised(X_df, lag, 0)
y_df = series_to_supervised(y_df, 0, lag)

print('\n-------------\nFeatures')
print(X_df.columns)
print(X_df.shape)
print('\n-------------\nLabels')
print(y_df.columns)
print(y_df.shape)
# Out:
# -------------
# Features
# Index(['var1(t-12)', 'var2(t-12)', 'var3(t-12)', 'var4(t-12)', 'var5(t-12)',
#        'var6(t-12)', 'var7(t-12)', 'var8(t-12)', 'var9(t-12)', 'var10(t-12)',
#        ...
#        'var517(t)', 'var518(t)', 'var519(t)', 'var520(t)', 'var521(t)',
#        'var522(t)', 'var523(t)', 'var524(t)', 'var525(t)', 'var526(t)'],
#       dtype='object', length=6838)
# (12007, 6838)
#
# -------------
# Labels
# Index(['var1(t)', 'var2(t)', 'var1(t+1)', 'var2(t+1)', 'var1(t+2)',
#        'var2(t+2)', 'var1(t+3)', 'var2(t+3)', 'var1(t+4)', 'var2(t+4)',
#        'var1(t+5)', 'var2(t+5)', 'var1(t+6)', 'var2(t+6)', 'var1(t+7)',
#        'var2(t+7)', 'var1(t+8)', 'var2(t+8)', 'var1(t+9)', 'var2(t+9)',
#        'var1(t+10)', 'var2(t+10)', 'var1(t+11)', 'var2(t+11)', 'var1(t+12)',
#        'var2(t+12)'],
#       dtype='object')
# (12007, 26)

# %% [markdown]
# ### Feature Selection
#
# Implements a recursive solution, where in features are eliminated based on an ensemble evaluator.

# %%
class FeatureEliminator:
    """
    This class is dedicated to housing logic pertaining to feature selection - retaining only labels which are considered
    important.
    """
    def __init__(self, X_df, y_df):
        """
        Class constructor.
        :param X_df: (Pandas) Pandas feature matrix.
        :param y_df: (Pandas) Pandas label matrix.
        :return: None
        """
        self.__X_df = X_df
        self.__y_df = y_df
    
    def rfe_selector(self, test_split=.4, optimum_feature_count=0, parallel_degree=1, max_depth=None, max_features='sqrt', n_estimators=100):
        """
        Recursive Feature Elimination Function. Isolates and eliminated features one by one, up till the desired amount, starting
        by features which are considered less important.
        :param test_split:            (Float) Denotes training/testing data split.
        :param optimum_feature_count: (Integer) Denotes the best estimated number of features to retain before a performance drop
                                                is estimated.
        :param parallel_degree:       (Integer) Denotes model training parallel degree.
        :param max_depth:             (Integer) Denotes number of leaves to evaluate during decision tree pruning.
        :param max_features:          (Integer) Denotes number of features to consider during random subselection.
        :param n_estimators:          (Integer) Number of estimators (trees) to build for decision making.
        :return: (List) This list is composed of boolean values, which correspond to the input feature column headers. True List 
                        values denote columns which have been retained. False values denote eliminated feature headers.
        :return: (List) This list denotes feature rankings, which correspond to the input feature column headers. Values of '1',
                        denote that features have been retained.
        """
        X_df = self.__X_df.values
        y_df = self.__y_df[self.__y_df.columns[0]].values  # We can only use a single target column since RandomForests do not support multi target labels
        print(X_df.shape)
        print(y_df.shape)
        optimum_feature_count = int(optimum_feature_count)
        
        X_train, X_test, y_train, y_test = train_test_split(X_df, 
                                                            y_df, 
                                                            test_size=test_split)
        model = RandomForestRegressor(n_estimators=int(n_estimators), 
                                      n_jobs=parallel_degree,
                                      max_depth=max_depth,
                                      max_features='sqrt')

        # create the RFE model and select N attributes
        rfe_model = RFE(model, optimum_feature_count, step=1)
        rfe_model = rfe_model.fit(X_train, y_train)

        # summarize the selection of the attributes
        print(rfe_model.support_)
        print(rfe_model.ranking_)

        # evaluate the model on testing set
        pred_y = rfe_model.predict(X_test)
        predictions = [round(value) for value in pred_y]
        r2s = r2_score(y_test, predictions)
        
        return rfe_model.support_, rfe_model.ranking_
    
    def get_selected_features(self, column_mask):
        """
        Retrieves features which have not been eliminated from the RFE function.
        :param column_mask: (List) This list is composed of boolean values, which correspond to the input feature column headers. 
                                   True list values denote columns which have been retained. False values denote eliminated 
                                   feature headers. 
        :return: (Pandas) Pandas data matrix.
        """
        recommended_columns = []
        for i in range(len(self.__X_df.columns)):
            if (column_mask[i]):
                recommended_columns.append(self.__X_df.columns[i])
                
        return self.__X_df[recommended_columns]
    
# fe = FeatureEliminator(X_df=X_df,
#                        y_df=y_df)
# column_mask, column_rankings = fe.rfe_selector(test_split=test_split,
#                                                optimum_feature_count=int(X_df.shape[1]/8),
#                                                parallel_degree=2,
#                                                max_depth=1,
#                                                max_features='sqrt',
#                                                n_estimators=n_estimators)
# print(X_df.columns)
# X_df = fe.get_selected_features(column_mask=column_mask)
# print(X_df.columns)
 'var521(t-4)', 'var522(t-4)', 'var523(t-4)', 'var524(t-4)', 'var525(t-4)', 'var526(t-4)', 'var1(t-3)', 'var2(t-3)', 'var4(t-3)', 'var5(t-3)', 'var8(t-3)', 'var9(t-3)', 'var10(t-3)', 'var12(t-3)', 'var13(t-3)', 'var15(t-3)', 'var19(t-3)', 'var20(t-3)', 'var21(t-3)', 'var22(t-3)', 'var28(t-3)', 'var29(t-3)', 'var38(t-3)', 'var40(t-3)', 'var41(t-3)', 'var42(t-3)', 'var43(t-3)', 'var44(t-3)', 'var45(t-3)', 'var46(t-3)', 'var47(t-3)', 'var49(t-3)', 'var50(t-3)', 'var51(t-3)', 'var53(t-3)', 'var54(t-3)', 'var56(t-3)', 'var59(t-3)', 'var60(t-3)', 'var61(t-3)', 'var62(t-3)', 'var63(t-3)', 'var64(t-3)', 'var74(t-3)', 'var75(t-3)', 'var78(t-3)', 'var79(t-3)', 'var81(t-3)', 'var83(t-3)', 'var85(t-3)', 'var86(t-3)', 'var88(t-3)', 'var89(t-3)', 'var91(t-3)', 'var92(t-3)', 'var93(t-3)', 'var94(t-3)', 'var95(t-3)', 'var96(t-3)', 'var97(t-3)', 'var99(t-3)', 'var102(t-3)', 'var103(t-3)', 'var104(t-3)', 'var106(t-3)', 'var111(t-3)', 'var114(t-3)', 'var124(t-3)', 'var125(t-3)', 'var130(t-3)', 'var131(t-3)', 'var132(t-3)', 'var133(t-3)', 'var134(t-3)', 'var148(t-3)', 'var152(t-3)', 'var154(t-3)', 'var156(t-3)', 'var163(t-3)', 'var164(t-3)', 'var166(t-3)', 'var171(t-3)', 'var172(t-3)', 'var174(t-3)', 'var175(t-3)', 'var176(t-3)', 'var178(t-3)', 'var180(t-3)', 'var181(t-3)', 'var183(t-3)', 'var184(t-3)', 'var185(t-3)', 'var186(t-3)', 'var187(t-3)', 'var188(t-3)', 'var189(t-3)', 'var191(t-3)', 'var192(t-3)', 'var193(t-3)', 'var196(t-3)', 'var197(t-3)', 'var201(t-3)', 'var203(t-3)', 'var204(t-3)', 'var205(t-3)', 'var206(t-3)', 'var207(t-3)', 'var208(t-3)', 'var209(t-3)', 'var210(t-3)', 'var211(t-3)', 'var215(t-3)', 'var216(t-3)', 'var217(t-3)', 'var218(t-3)', 'var219(t-3)', 'var220(t-3)', 'var221(t-3)', 'var222(t-3)', 'var223(t-3)', 'var224(t-3)', 'var225(t-3)', 'var226(t-3)', 'var227(t-3)', 'var228(t-3)', 'var229(t-3)', 'var230(t-3)', 'var231(t-3)', 'var232(t-3)', 'var233(t-3)', 'var234(t-3)', 'var235(t-3)', 'var236(t-3)', 'var237(t-3)', 'var238(t-3)', 'var239(t-3)', 'var240(t-3)', 'var241(t-3)', 'var242(t-3)', 'var243(t-3)', 'var244(t-3)', 'var245(t-3)', 'var246(t-3)', 'var247(t-3)', 'var248(t-3)', 'var249(t-3)', 'var250(t-3)', 'var251(t-3)', 'var252(t-3)', 'var253(t-3)', 'var254(t-3)', 'var255(t-3)', 'var256
 'var492(t-1)', 'var493(t-1)', 'var494(t-1)', 'var495(t-1)', 'var496(t-1)', 'var497(t-1)', 'var498(t-1)', 'var499(t-1)', 'var500(t-1)', 'var501(t-1)', 'var502(t-1)', 'var503(t-1)', 'var504(t-1)', 'var505(t-1)', 'var506(t-1)', 'var507(t-1)', 'var508(t-1)', 'var509(t-1)', 'var510(t-1)', 'var511(t-1)', 'var512(t-1)', 'var513(t-1)', 'var514(t-1)', 'var515(t-1)', 'var516(t-1)', 'var517(t-1)', 'var518(t-1)', 'var519(t-1)', 'var520(t-1)', 'var521(t-1)', 'var522(t-1)', 'var523(t-1)', 'var524(t-1)', 'var525(t-1)', 'var526(t-1)', 'var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)', 'var9(t)', 'var10(t)', 'var11(t)', 'var12(t)', 'var13(t)', 'var14(t)', 'var15(t)', 'var16(t)', 'var17(t)', 'var18(t)', 'var19(t)', 'var20(t)', 'var21(t)', 'var22(t)', 'var23(t)', 'var24(t)', 'var25(t)', 'var26(t)', 'var27(t)', 'var28(t)', 'var29(t)', 'var30(t)', 'var31(t)', 'var32(t)', 'var33(t)', 'var34(t)', 'var35(t)', 'var36(t)', 'var37(t)', 'var38(t)', 'var39(t)', 'var40(t)', 'var41(t)', 'var42(t)', 'var43(t)', 'var44(t)', 'var45(t)', 'var46(t)', 'var47(t)', 'var48(t)', 'var49(t)', 'var50(t)', 'var51(t)', 'var52(t)', 'var53(t)', 'var54(t)', 'var55(t)', 'var56(t)', 'var57(t)', 'var58(t)', 'var59(t)', 'var60(t)', 'var61(t)', 'var62(t)', 'var63(t)', 'var64(t)', 'var65(t)', 'var66(t)', 'var67(t)', 'var68(t)', 'var69(t)', 'var70(t)', 'var71(t)', 'var72(t)', 'var73(t)', 'var74(t)', 'var75(t)', 'var76(t)', 'var77(t)', 'var78(t)', 'var79(t)', 'var80(t)', 'var81(t)', 'var82(t)', 'var83(t)', 'var84(t)', 'var85(t)', 'var86(t)', 'var87(t)', 'var88(t)', 'var89(t)', 'var90(t)', 'var91(t)', 'var92(t)', 'var93(t)', 'var94(t)', 'var95(t)', 'var96(t)', 'var97(t)', 'var98(t)', 'var99(t)', 'var100(t)', 'var101(t)', 'var102(t)', 'var103(t)', 'var104(t)', 'var105(t)', 'var106(t)', 'var107(t)', 'var108(t)', 'var109(t)', 'var110(t)', 'var111(t)', 'var112(t)', 'var113(t)', 'var114(t)', 'var115(t)', 'var116(t)', 'var117(t)', 'var118(t)', 'var119(t)', 'var120(t)', 'var121(t)', 'var122(t)', 'var123(t)', 'var124(t)', 'var125(t)', 'var126(t)', 'var127(t)', 'var128(t)', 'var129(t)', 'var130(t)', 'var131(t)', 'var132(t)', 'var133(t)', 'var134(t)', 'var135(t)', 'var136(t)', 'var137(t)', 'var138(t)', 'var139(t)', 'var140(t)', 'var141(t)', 'var142(t)', 'var143(t)', 'var144(t)', 'var145(t)', 'var146(t)', 'var147(t)', 'var148(t)', 'var149(t)', 'var150(t)', 'var151(t)', 'var152(t)', 'var153(t)', 'var155(t)', 'var156(t)', 'var157(t)', 'var158(t)', 'var159(t)', 'var160(t)', 'var161(t)', 'var162(t)', 'var163(t)', 'var164(t)', 'var165(t)', 'var166(t)', 'var167(t)', 'var168(t)', 'var169(t)', 'var170(t)', 'var171(t)', 'var172(t)', 'var173(t)', 'var174(t)', 'var175(t)', 'var176(t)', 'var177(t)', 'var178(t)', 'var179(t)', 'var180(t)', 'var181(t)', 'var182(t)', 'var183(t)', 'var184(t)', 'var185(t)', 'var186(t)', 'var187(t)', 'var188(t)', 'var189(t)', 'var190(t)', 'var191(t)', 'var192(t)', 'var193(t)', 'var194(t)', 'var195(t)', 'var196(t)', 'var197(t)', 'var198(t)', 'var199(t)', 'var200(t)', 'var201(t)', 'var202(t)', 'var203(t)', 'var204(t)', 'var205(t)', 'var206(t)', 'var207(t)', 'var208(t)', 'var209(t)', 'var210(t)', 'var211(t)', 'var212(t)', 'var213(t)', 'var214(t)', 'var215(t)', 'var216(t)', 'var217(t)', 'var218(t)', 'var219(t)', 'var220(t)', 'var221(t)', 'var222(t)', 'var223(t)', 'var224(t)', 'var225(t)', 'var226(t)', 'var227(t)', 'var228(t)', 'var229(t)', 'var230(t)', 'var231(t)', 'var232(t)', 'var233(t)', 'var234(t)', 'var235(t)', 'var236(t)', 'var237(t)', 'var238(t)', 'var239(t)', 'var240(t)', 'var241(t)', 'var243(t)', 'var244(t)', 'var245(t)', 'var246(t)', 'var247(t)', 'var248(t)', 'var249(t)', 'var250(t)', 'var251(t)', 'var252(t)', 'var253(t)', 'var254(t)', 'var255(t)', 'var256(t)', 'var257(t)', 'var258(t)', 'var259(t)', 'var260(t)', 'var261(t)', 'var262(t)', 'var263(t)', 'var264(t)', 'var265(t)', 'var266(t)', 'var267(t)', 'var268(t)', 'var269(t)', 'var270(t)', 'var271(t)', 'var272(t)', 'var273(t)', 'var274(t)', 'var275(t)', 'var276(t)', 'var277(t)', 'var278(t)', 'var279(t)', 'var280(t)', 'var281(t)', 'var282(t)', 'var283(t)', 'var284(t)', 'var285(t)', 'var286(t)', 'var287(t)', 'var288(t)', 'var289(t)', 'var290(t)', 'var291(t)', 'var292(t)', 'var293(t)', 'var294(t)', 'var295(t)', 'var296(t)', 'var297(t)', 'var298(t)', 'var299(t)', 'var300(t)', 'var301(t)', 'var302(t)', 'var303(t)', 'var304(t)', 'var305(t)', 'var306(t)', 'var307(t)', 'var308(t)', 'var309(t)', 'var310(t)', 'var311(t)', 'var312(t)', 'var313(t)', 'var314(t)', 'var315(t)', 'var316(t)', 'var317(t)', 'var318(t)', 'var320(t)', 'var321(t)', 'var322(t)', 'var323(t)', 'var324(t)', 'var325(t)', 'var326(t)', 'var327(t)', 'var328(t)', 'var329(t)', 'var330(t)', 'var331(t)', 'var333(t)', 'var334(t)', 'var335(t)', 'var336(t)', 'var337(t)', 'var338(t)', 'var339(t)', 'var340(t)', 'var341(t)', 'var342(t)', 'var343(t)', 'var344(t)', 'var345(t)', 'var346(t)', 'var347(t)', 'var348(t)', 'var349(t)', 'var350(t)', 'var351(t)', 'var352(t)', 'var353(t)', 'var354(t)', 'var355(t)', 'var356(t)', 'var357(t)', 'var358(t)', 'var359(t)', 'var360(t)', 'var361(t)', 'var362(t)', 'var363(t)', 'var364(t)', 'var365(t)', 'var366(t)', 'var367(t)', 'var368(t)', 'var369(t)', 'var370(t)', 'var371(t)', 'var372(t)', 'var373(t)', 'var374(t)', 'var375(t)', 'var376(t)', 'var377(t)', 'var378(t)', 'var379(t)', 'var380(t)', 'var381(t)', 'var382(t)', 'var383(t)', 'var384(t)', 'var385(t)', 'var386(t)', 'var387(t)', 'var388(t)', 'var389(t)', 'var390(t)', 'var391(t)', 'var392(t)', 'var393(t)', 'var394(t)', 'var395(t)', 'var396(t)', 'var397(t)', 'var398(t)', 'var399(t)', 'var400(t)', 'var401(t)', 'var402(t)', 'var403(t)', 'var404(t)', 'var405(t)', 'var406(t)', 'var407(t)', 'var408(t)', 'var409(t)', 'var410(t)', 'var411(t)', 'var412(t)', 'var413(t)', 'var414(t)', 'var415(t)', 'var416(t)']
X_df = X_df[recursively_eliminated_columns]

# %% [markdown]
# ### Value Decomposition
#
# Principal component analysis: Factor model in which the factors are based on summarizing the total variance. With PCA, unities are used in the diagonal of the correlation matrix computationally implying that all the variance is common or shared.
#
# https://towardsdatascience.com/an-approach-to-choosing-the-number-of-components-in-a-principal-component-analysis-pca-3b9f3d6e73fe

# %%
class PrincipalComponentAnalysisClass:
    """
    This class handles logic related to PCA data transformations.
    https://towardsdatascience.com/an-approach-to-choosing-the-number-of-components-in-a-principal-component-analysis-pca-3b9f3d6e73fe
    """
    def __init__(self, X_df):
        """
        Cosntructor method.
        :param X_df: (Pandas) Dataframe consisting of input features, which will be subject to PCA.
        :return: None
        """
        self.__X_df = X_df
        
    def get_default_component_variances(self):
        """
        Fitting the PCA algorithm with our Data.
        :return: (Numpy array) Array of feature variances.
        """
        pca = PCA().fit(self.__X_df.values)
        return np.cumsum(pca.explained_variance_ratio_)
        
    def get_default_component_count(self, threshold=.99):
        """
        Retrieves the recommended number of component decomposition, above which very little variance 
        gain is achieved. This treshold will be set at a 0.999 variance threshold.
        :param threshold: (Float) Threshold value between 0 and 1. Stops immediately as soon the number
                                  of required components exceeds the threshold value.
        :return: (Integer) Returns the number of recommended components.
        """
        variance_ratios = self.get_default_component_variances()
        n = 0
        for val in variance_ratios:
            if val < threshold:
                n += 1
        return n
    
    def plot_variance_per_reduction(self):
        """
        This method subjects the feature matrix to a PCA decomposition. The number of components is plot
        vs the amount of retained variance.
        :return: None
        """
        variance_ratios = self.get_default_component_variances()
        
        #Plotting the Cumulative Summation of the Explained Variance
        plt.figure()
        plt.plot(variance_ratios)
        plt.xlabel('Number of Components')
        plt.ylabel('Variance (%)') #for each component
        plt.title(tpcds + ' Dataset Explained Variance')
        plt.show()
        
    def apply_PCA(self, n_components):
        """
        Applies Principle Component Analysis on the constructor passed data matrix, on a number of components.
        A new pandas data matrix is returned, with renamed 'Principal Component' headers.
        :param n_components: (Integer) Denotes number of component breakdown.
        :return: (Pandas) Dataframe consisting of new decomposed components.
        """
        pca = PCA(n_components=n_components)
        dataset = pca.fit_transform(self.__X_df.values)
        header_list = []
        for i in range(dataset.shape[1]):
            header_list.append('Component_' + str(i))
        return pd.DataFrame(data=dataset, columns=header_list)

print(X_df.head())
print(X_df.shape)

pcac = PrincipalComponentAnalysisClass(X_df=X_df)
pcac.plot_variance_per_reduction()
component_count = pcac.get_default_component_count()
X_df = pcac.apply_PCA(n_components=component_count)

print('-'*30)
print(X_df.head())
print(X_df.shape)
# Out:
#     var120(t-4)  var121(t-4)  var122(t-4)  var128(t-4)  var129(t-4)  \
# 12     0.009142          1.0     0.030948          0.0     0.212896
# 13     0.000000          1.0     0.008401          0.0     0.000000
# 14     0.045774          1.0     0.390978          0.0     0.000000
# 15     0.000000          1.0     0.016694          0.0     0.000000
# 16     0.000000          1.0     0.013218          0.0     0.000000
#
#     var130(t-4)  var131(t-4)  var132(t-4)  var133(t-4)  var134(t-4)  \
# 12     0.220182     0.000680     0.000992     0.000650     0.001019
# 13     0.000000     0.000019     0.000004     0.000311     0.000317
# 14     0.000000     0.541828     0.343499     0.541805     0.343511
# 15     0.000000     0.000003     0.000005     0.000289     0.000313
# 16     0.000000     0.000003     0.000006     0.000275     0.000302
#
#       ...      var407(t)  var408(t)  var409(t)  var410(t)  var411(t)  \
# 12    ...       0.399565   0.563880   0.563885   0.423808   0.543408
# 13    ...       0.300747   0.492021   0.492010   0.338954   0.468134
# 14    ...       0.658513   0.751988   0.751861   0.836221   0.739728
# 15    ...       0.808941   0.861134   0.861078   0.893821   0.854125
# 16    ...       0.014278   0.185028   0.184991   0.106162   0.163683
#
#     var412(t)  var413(t)  var414(t)  var415(t)  var416(t)
# 12   0.862438   0.538045   0.533608   0.682375   0.563221
# 13   0.839453   0.456341   0.447403   0.606338   0.491253
# 14   0.921859   0.740830   0.741817   0.807799   0.751613
# 15   0.955892   0.854226   0.854621   0.865727   0.860924
# 16   0.498883   0.151272   0.141493   0.224097   0.184315
#
# [5 rows x 1841 columns]
# (12007, 1841)
# ------------------------------
#    Component_0  Component_1  Component_2  Component_3  Component_4  \
# 0    -5.327620     4.634134    -5.464902    -2.214899     5.483346
# 1    -1.524545    -6.976740     5.843292     0.504451    -3.621574
# 2    -0.388803     6.900329    -3.250152    -4.793635    -1.315283
# 3    -4.684911    -4.899750    -1.710270    -5.124639    -0.502784
# 4    -6.639191    -0.957471    -0.622240     4.305802    -3.553291
#
#    Component_5  Component_6  Component_7  Component_8  Component_9  \
# 0     0.029117    -0.088189     0.040171    -0.033500    -0.314847
# 1    -0.063376    -0.011005    -0.086008    -0.056766    -0.288135
# 2     0.017561     0.001208     0.024239     0.017931    -0.305247
# 3     0.005307     0.006356    -0.029057    -0.078121    -0.235886
# 4    -0.030643    -0.042353     0.004763    -0.004523    -0.170121
#
#        ...       Component_85  Component_86  Component_87  Component_88  \
# 0      ...          -0.041859     -0.078293     -0.081657     -0.022135
# 1      ...           0.062072      0.012902     -0.058394      0.046504
# 2      ...          -0.093277     -0.009884     -0.102202      0.030336
# 3      ...          -0.009466     -0.023848     -0.029964     -0.073076
# 4      ...           0.033861     -0.019099     -0.080323      0.126604
#
#    Component_89  Component_90  Component_91  Component_92  Component_93  \
# 0      0.032574      0.022151     -0.081204      0.071605      0.134662
# 1      0.076427      0.019827      0.054789     -0.003782     -0.013285
# 2     -0.164240     -0.332791      0.020519      0.240076     -0.339479
# 3      0.106308     -0.043504      0.104628      0.076872     -0.050436
# 4     -0.077671      0.071332     -0.042268     -0.127232      0.039826
#
#    Component_94
# 0     -0.172425
# 1     -0.017820
# 2      0.136663
# 3     -0.206979
# 4     -0.029188
#
# [5 rows x 95 columns]
# (12007, 95)

# %% [markdown]
# ## LSTM Classification (Many to Many)
# ### Designing the network
#
# - The first step is to define your network.
# - Neural networks are defined in Keras as a sequence of layers. The container for these layers is the **Sequential class**.
# - The first step is to create an instance of the Sequential class. Then you can create your layers and add them in the order that they should be connected.
# - The LSTM recurrent layer comprised of memory units is called LSTM().
# - A fully connected layer that often follows LSTM layers and is used for outputting a prediction is called Dense().
# - The first layer in the network must define the number of inputs to expect.
# - Input must be three-dimensional, comprised of samples, timesteps, and features.
#     - **Samples:** These are the rows in your data.
#     - **Timesteps:** These are the past observations for a feature, such as lag variables.
#     - **Features:** These are columns in your data.
# - Assuming your data is loaded as a NumPy array, you can convert a 2D dataset to a 3D dataset using the reshape() function in NumPy.
#
# ### Relavent Links
#
# Network structure pointers [https://www.heatonresearch.com/2017/06/01/hidden-layers.html]. Rough heuristics to start with:
#
# * The number of hidden neurons should be between the size of the input layer and the size of the output layer.
# * The number of hidden neurons should be 2/3 the size of the input layer, plus the size of the output layer.
# * The number of hidden neurons should be less than twice the size of the input layer.
#
# --------------------------------------------------------------------------------------------
#
# * https://machinelearningmastery.com/models-sequence-prediction-recurrent-neural-networks/
# * https://machinelearningmastery.com/reshape-input-data-long-short-term-memory-networks-keras/
# * https://machinelearningmastery.com/5-step-life-cycle-long-short-term-memory-models-keras/
# * https://machinelearningmastery.com/stacked-long-short-term-memory-networks/
# * https://arxiv.org/pdf/1312.6026.pdf
# * https://machinelearningmastery.com/backtest-machine-learning-models-time-series-forecasting/
# * https://machinelearningmastery.com/understanding-stateful-lstm-recurrent-neural-networks-python-keras/
# * http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
# LSTM Class
class LSTM:
    """
    Long Short Term Memory Neural Net Class
    """

    def __init__(self, X, y, lag, loss_func, activation, optimizer='sgd', lstm_layers=1, dropout=.0,
                 stateful=False, y_labels=None, initializer='uniform'):
        """
        Initiating the class creates a net with the established parameters
        :param X             - (Numpy 2D Array) Training data used to train the model (Features).
        :param y             - (Numpy 2D Array) Test data used to test the model (Labels
        :param lag           - (Integer) Denotes lag step value
        :param loss_function - (String)  Denotes mode of measure fitting of model (Fitting function).
        :param activation    - (String)  Neuron activation function used to activate/trigger neurons.
        :param optimizer     - (String)  Denotes which function to us to optimize the model build (eg: Gradient Descent).
        :param lstm_layers   - (Integer) Denotes the number of LSTM layers to be included in the model build.
        :param dropout       - (Float)   Denotes amount of dropout for model. This parameter must be a value between 0 and 1.
        :param stateful      - (Boolean) Denotes whether state is used as initial state for next training batch.
        :param: y_labels     - (List) List of target label names
        :param: initializer  - (String)  String initializer which denotes starting weights.
        """
        self.__lag = lag
        self.__model = ke.models.Sequential()
        self.__y_labels = y_labels

        if dropout > 1 and dropout < 0:
            raise ValueError('Dropout parameter exceeded! Must be a value between 0 and 1.')
        
        # self.__model.add(ke.layers.Embedding(2+1, 32, input_length=X.shape[1]))
        for i in range(0, lstm_layers - 1):  # If lstm_layers == 1, this for loop logic is skipped.
            if stateful:
                if i == 0:
                    self.__model.add(ke.layers.LSTM(X.shape[2],
                                                    batch_input_shape=(X.shape[0],
                                                                       X.shape[1],
                                                                       X.shape[2]),
                                                    return_sequences=True,
                                                    recurrent_dropout=dropout,
                                                    recurrent_initializer=initializer,
                                                    activation=activation,
                                                    stateful=stateful))
                else:
                    self.__model.add(ke.layers.LSTM(X.shape[2],
                                                    input_shape=(X.shape[1],
                                                                 X.shape[2]),
                                                    return_sequences=True,
                                                    recurrent_dropout=dropout,
                                                    recurrent_initializer=initializer,
                                                    activation=activation,
                                                    stateful=stateful))
            else:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                input_shape=(X.shape[1],
                                                             X.shape[2]),
                                                return_sequences=True,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                stateful=stateful))
            self.__model.add(ke.layers.Dropout(dropout))
        if lstm_layers > 1:
            self.__model.add(ke.layers.LSTM(X.shape[2],
                                            input_shape=(X.shape[1],
                                                         X.shape[2]),
                                            stateful=stateful,
                                            recurrent_dropout=dropout,
                                            recurrent_initializer=initializer,
                                            activation=activation,
                                            return_sequences=False))
        else:
            if stateful:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                batch_input_shape=(X.shape[0],
                                                                   X.shape[1],
                                                                   X.shape[2]),
                                                stateful=stateful,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                return_sequences=False))
            else:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                input_shape=(X.shape[1],
                                                             X.shape[2]),
                                                stateful=stateful,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                return_sequences=False))
        self.__model.add(ke.layers.Dropout(dropout))
        # self.__model.add(ke.layers.TimeDistributed(ke.layers.Dense(self.__lag * len(self.__y_labels), kernel_initializer=initializer)))
        self.__model.add(ke.layers.Dense(y.shape[1],
                                         kernel_initializer=initializer,
                                         activation='sigmoid'))
        self.__model.compile(loss=loss_func, optimizer=optimizer, metrics=['mse','mae'])
        print(self.__model.summary())

    def fit_model(self, X_train=None, X_test=None, y_train=None, y_test=None, epochs=50, batch_size=50, verbose=2,
                  shuffle=False, plot=False):
        """
        Fit data to model & validate. Trains a number of epochs.

        :param: X_train    - (Numpy 2D Array) Numpy matrix consisting of input training features
        :param: X_test     - (Numpy 2D Array) Numpy matrix consisting of input validation/testing features
        :param: y_train    - (Numpy 2D Array) Numpy matrix consisting of output training labels
        :param: y_test     - (Numpy 2D Array) Numpy matrix consisting of output validation/testing labels
        :param: epochs     - (Integer) Integer value denoting number of trained epochs
        :param: batch_size - (Integer) Integer value denoting LSTM training batch_size
        :param: verbose    - (Integer) Integer value denoting net verbosity (Amount of information shown to user during LSTM training)
        :param: shuffle    - (Bool) Boolean value denoting whether or not to shuffle data. This parameter must always remain 'False' for time series datasets.
        :param: plot       - (Bool) Boolean value denoting whether this function should plot out it's evaluation

        :return: None
        """
        if X_test is not None and y_test is not None:
            history = self.__model.fit(x=X_train,
                                       y=y_train,
                                       epochs=epochs,
                                       batch_size=batch_size,
                                       validation_data=(X_test, y_test),
                                       verbose=verbose,
                                       shuffle=shuffle)
        else:
            history = self.__model.fit(x=X_train,
                                       y=y_train,
                                       epochs=epochs,
                                       batch_size=batch_size,
                                       verbose=verbose,
                                       shuffle=shuffle)

        if plot:
            plt.rcParams['figure.figsize'] = [20, 15]
            plt.plot(history.history['mean_squared_error'], label='mean_squared_error')
            plt.plot(history.history['mean_absolute_error'], label='mean_absolute_error')
            plt.ylabel('loss')
            plt.xlabel('epoch')
            plt.legend(['train', 'validation'], loc='upper left')
            plt.show()

    def predict(self, X, batch_size):
        """
        Predicts label/s from input feature 'X'
        :param: X - Numpy matrix consisting of a single feature vector
        :param: batch_size - (Integer) Denotes prediction batch size
        :return: Numpy matrix of predicted label output
        """
        yhat = self.__model.predict(X, batch_size=batch_size)
        return yhat

    @staticmethod
    def write_results_to_disk(path, iteration, lag, test_split, batch, dropout, epoch, layer, activation, initializer,
                              stateful, rmse, accuracy, f_score, time_train):
        """
        Static method which is used for test harness utilities. This method attempts a grid search across many
        trained LSTM models, each denoted with different configurations.

        Attempted configurations:
        * Varied data test split
        * Varied batch sizes
        * Varied epoch counts

        Each configuration is denoted with a score, and used to identify the most optimal configuration.

        :param: path       - (String) String denoting result csv output.
        :param: iteration  - (Integer) Integer denoting test iteration (Unique per test configuration).
        :param: lag        - (Integer) Denotes lag time shift
        :param: test_split - (Float) Float denoting data sample sizes.
        :param: batch      - (Integer) Integer denoting LSTM batch size.
        :param: epoch      - (Integer) Integer denoting number of LSTM training iterations.
        :param: layer      - (Integer) Integer denoting number of LSTM layers
        :param: activation - (String) String denoting activation for LSTM layers.
        :param: initializer- (String) String denoting LSTM initializing weights.
        :param: stateful   - (Bool) Boolean flag which denotes whether LSTM model is trained in stateful mode or not.
        :param: dropout    - (Float) Float denoting model dropout layer.
        :param: rmse       - (Float) Float denoting experiment configuration RSME score.
        :param: accuracy   - (Float) Float denoting experiment accuracy score.
        :param: fscore     - (Float) Float denoting experiment fscore score.
        :param: time_train - (Integer) Integer denoting number of seconds taken by LSTM training iteration.

        :return: None
        """
        file_exists = os.path.isfile(path)
        with open(path, 'a+') as csvfile:
            headers = ['iteration', 'test_split', 'batch', 'epoch', 'layer', 'stateful', 'dropout', 'activation',
                       'initializer', 'rmse', 'accuracy', 'f_score', 'time_train', 'lag']
            writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n', fieldnames=headers)
            if not file_exists:
                writer.writeheader()  # file doesn't exist yet, write a header
            writer.writerow({'iteration': iteration,
                             'test_split': test_split,
                             'batch': batch,
                             'epoch': epoch,
                             'layer': layer,
                             'stateful': stateful,
                             'dropout': dropout,
                             'activation': activation,
                             'initializer': initializer,
                             'rmse': rmse,
                             'accuracy': accuracy,
                             'f_score': f_score,
                             'time_train': time_train,
                             'lag': lag})

    @staticmethod
    def lag_multiple(X, lag):
        """
        Divides the total number of rows by the lag value, until a perfect multiple amount is retrieved.
        :param X: (Numpy) 2D array consisting of input.
        :param lag: (Integer) Denotes time shift value.
        :return: (Numpy) 2D array consisting of a perfect lag multiple rows.
        """
        n_rows = X.shape[0]
        multiple = int(n_rows/lag)
        max_new_rows = multiple * lag
        return X[0:max_new_rows, :]

# %% [markdown]
# ### Time Step (1) - Training (CPU)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
y_labels2 = []
for label in y_df.columns:
    if 'var1' in label:
        y_labels2.append(label)
y_df2 = y_df[y_labels2]
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df2, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(6003, 1, 95)] Type - <class 'numpy.ndarray'>
# y_train shape [(6003, 13)] Type - <class 'numpy.ndarray'>
# X_validate shape [(6004, 1, 95)] Type - <class 'numpy.ndarray'>
# y_validate shape [(6004, 13)] Type - <class 'numpy.ndarray'>
# INFO:plaidml:Opening device "opencl_amd_tonga.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 95)             72580
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 95)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 95)                72580
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 95)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                1248
# =================================================================
# Total params: 146,408
# Trainable params: 146,408
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 6003 samples, validate on 6004 samples
# Epoch 1/300
#  - 10s - loss: 0.1190 - mean_squared_error: 0.1190 - mean_absolute_error: 0.3014 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.0931
# Epoch 2/300
#  - 3s - loss: 0.0284 - mean_squared_error: 0.0284 - mean_absolute_error: 0.0958 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0939
# Epoch 3/300
#  - 3s - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.0983 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0943
# Epoch 4/300
#  - 3s - loss: 0.0278 - mean_squared_error: 0.0278 - mean_absolute_error: 0.0981 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0940
# Epoch 5/300
#  - 3s - loss: 0.0277 - mean_squared_error: 0.0277 - mean_absolute_error: 0.0981 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0947
# Epoch 6/300
#  - 3s - loss: 0.0276 - mean_squared_error: 0.0276 - mean_absolute_error: 0.0982 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0948
# Epoch 7/300
#  - 3s - loss: 0.0275 - mean_squared_error: 0.0275 - mean_absolute_error: 0.0984 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0954
# Epoch 8/300
#  - 3s - loss: 0.0271 - mean_squared_error: 0.0271 - mean_absolute_error: 0.0984 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0956
# Epoch 9/300
#  - 3s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.0976 - val_loss: 0.0260 - val_mean_squared_error: 0.0260 - val_mean_absolute_error: 0.0936
# Epoch 10/300
#  - 3s - loss: 0.0260 - mean_squared_error: 0.0260 - mean_absolute_error: 0.0962 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - val_mean_absolute_error: 0.0922
# Epoch 11/300
#  - 3s - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.0943 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0907
# Epoch 12/300
#  - 3s - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.0931 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - val_mean_absolute_error: 0.0886
# Epoch 13/300
#  - 3s - loss: 0.0242 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0916 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.0858
# Epoch 14/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0890 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.0836
# Epoch 15/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0864 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0810
# Epoch 16/300
#  - 3s - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0842 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0791
# Epoch 17/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0826 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0772
# Epoch 18/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0820 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0768
# Epoch 19/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0811 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0764
# Epoch 20/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0806 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0762
# Epoch 21/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0800 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0761
# Epoch 22/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0798 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0756
# Epoch 23/300
#  - 3s - loss: 0.0204 - mean_squared_error: 0.0204 - mean_absolute_error: 0.0796 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0752
# Epoch 24/300
#  - 3s - loss: 0.0202 - mean_squared_error: 0.0202 - mean_absolute_error: 0.0790 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0755
# Epoch 25/300
#  - 3s - loss: 0.0202 - mean_squared_error: 0.0202 - mean_absolute_error: 0.0789 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0753
# Epoch 26/300
#  - 3s - loss: 0.0201 - mean_squared_error: 0.0201 - mean_absolute_error: 0.0786 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0749
# Epoch 27/300
#  - 3s - loss: 0.0201 - mean_squared_error: 0.0201 - mean_absolute_error: 0.0783 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0753
# Epoch 28/300
#  - 3s - loss: 0.0199 - mean_squared_error: 0.0199 - mean_absolute_error: 0.0780 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0750
# Epoch 29/300
#  - 3s - loss: 0.0199 - mean_squared_error: 0.0199 - mean_absolute_error: 0.0778 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 30/300
#  - 3s - loss: 0.0199 - mean_squared_error: 0.0199 - mean_absolute_error: 0.0778 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0749
# Epoch 31/300
#  - 3s - loss: 0.0198 - mean_squared_error: 0.0198 - mean_absolute_error: 0.0777 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0744
# Epoch 32/300
#  - 3s - loss: 0.0198 - mean_squared_error: 0.0198 - mean_absolute_error: 0.0776 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0744
# Epoch 33/300
#  - 3s - loss: 0.0197 - mean_squared_error: 0.0197 - mean_absolute_error: 0.0773 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0744
# Epoch 34/300
#  - 3s - loss: 0.0197 - mean_squared_error: 0.0197 - mean_absolute_error: 0.0773 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0743
# Epoch 35/300
#  - 3s - loss: 0.0197 - mean_squared_error: 0.0197 - mean_absolute_error: 0.0771 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 36/300
#  - 3s - loss: 0.0197 - mean_squared_error: 0.0197 - mean_absolute_error: 0.0770 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 37/300
#  - 3s - loss: 0.0196 - mean_squared_error: 0.0196 - mean_absolute_error: 0.0771 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0743
# Epoch 38/300
#  - 3s - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.0768 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0743
# Epoch 39/300
#  - 3s - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.0766 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0746
# Epoch 40/300
#  - 3s - loss: 0.0195 - mean_squared_error: 0.0195 - mean_absolute_error: 0.0767 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0740
# Epoch 41/300
#  - 3s - loss: 0.0194 - mean_squared_error: 0.0194 - mean_absolute_error: 0.0766 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0740
# Epoch 42/300
#  - 3s - loss: 0.0194 - mean_squared_error: 0.0194 - mean_absolute_error: 0.0766 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0740
# Epoch 43/300
#  - 3s - loss: 0.0194 - mean_squared_error: 0.0194 - mean_absolute_error: 0.0764 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 44/300
#  - 3s - loss: 0.0193 - mean_squared_error: 0.0193 - mean_absolute_error: 0.0763 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0740
# Epoch 45/300
#  - 3s - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.0760 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0742
# Epoch 46/300
#  - 3s - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.0759 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 47/300
#  - 3s - loss: 0.0193 - mean_squared_error: 0.0193 - mean_absolute_error: 0.0762 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0741
# Epoch 48/300
#  - 3s - loss: 0.0192 - mean_squared_error: 0.0192 - mean_absolute_error: 0.0759 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0743
# Epoch 49/300
#  - 3s - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0758 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0743
# Epoch 50/300
#  - 3s - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0758 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0740
# Epoch 51/300
#  - 3s - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0757 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0740
# Epoch 52/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0754 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 53/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0755 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 54/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0755 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 55/300
#  - 3s - loss: 0.0191 - mean_squared_error: 0.0191 - mean_absolute_error: 0.0757 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0741
# Epoch 56/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0755 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0742
# Epoch 57/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0755 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0743
# Epoch 58/300
#  - 3s - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.0754 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 59/300
#  - 3s - loss: 0.0189 - mean_squared_error: 0.0189 - mean_absolute_error: 0.0752 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0741
# Epoch 60/300
#  - 3s - loss: 0.0189 - mean_squared_error: 0.0189 - mean_absolute_error: 0.0752 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 61/300
#  - 3s - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0749 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0746
# Epoch 62/300
#  - 3s - loss: 0.0189 - mean_squared_error: 0.0189 - mean_absolute_error: 0.0751 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0748
# Epoch 63/300
#  - 3s - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0750 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0747
# Epoch 64/300
#  - 3s - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0748 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 65/300
#  - 3s - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0749 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0742
# Epoch 66/300
#  - 3s - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0749 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0742
# Epoch 67/300
#  - 3s - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0748 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0743
# Epoch 68/300
#  - 3s - loss: 0.0187 - mean_squared_error: 0.0187 - mean_absolute_error: 0.0747 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0746
# Epoch 69/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0745 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 70/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0746 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 71/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0746 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0744
# Epoch 72/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0744 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0743
# Epoch 73/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0744 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 74/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0744 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0746
# Epoch 75/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0744 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 76/300
#  - 3s - loss: 0.0186 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0745 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0745
# Epoch 77/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0743 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0747
# Epoch 78/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0744 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0744
# Epoch 79/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0742 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0740
# Epoch 80/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0742 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 81/300
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0184 - mean_absolute_error: 0.0741 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0749
# Epoch 82/300
#  - 3s - loss: 0.0185 - mean_squared_error: 0.0185 - mean_absolute_error: 0.0744 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 83/300
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0184 - mean_absolute_error: 0.0740 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 84/300
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0184 - mean_absolute_error: 0.0740 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 85/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0738 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 86/300
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0184 - mean_absolute_error: 0.0740 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 87/300
#  - 3s - loss: 0.0184 - mean_squared_error: 0.0184 - mean_absolute_error: 0.0739 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 88/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0740 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 89/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0738 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0747
# Epoch 90/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0738 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0748
# Epoch 91/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0737 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0746
# Epoch 92/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0737 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0746
# Epoch 93/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0735 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0750
# Epoch 94/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0738 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0748
# Epoch 95/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0735 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0749
# Epoch 96/300
#  - 3s - loss: 0.0183 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0737 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0745
# Epoch 97/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0734 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 98/300
#  - 3s - loss: 0.0182 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0734 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 99/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0735 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 100/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0732 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0746
# Epoch 101/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0733 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0747
# Epoch 102/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0734 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0751
# Epoch 103/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0733 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0751
# Epoch 104/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0733 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 105/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0730 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 106/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0732 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 107/300
#  - 3s - loss: 0.0181 - mean_squared_error: 0.0181 - mean_absolute_error: 0.0733 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0750
# Epoch 108/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0732 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0746
# Epoch 109/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0730 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0752
# Epoch 110/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0731 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0743
# Epoch 111/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0729 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 112/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0733 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 113/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0729 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 114/300
#  - 3s - loss: 0.0180 - mean_squared_error: 0.0180 - mean_absolute_error: 0.0730 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0746
# Epoch 115/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0730 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0751
# Epoch 116/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0730 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 117/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0729 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0751
# Epoch 118/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0727 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0750
# Epoch 119/300
#  - 3s - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0728 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0751
# Epoch 120/300
#  - 3s - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0727 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0752
# Epoch 121/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0729 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0753
# Epoch 122/300
#  - 3s - loss: 0.0179 - mean_squared_error: 0.0179 - mean_absolute_error: 0.0729 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0747
# Epoch 123/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0726 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0746
# Epoch 124/300
#  - 3s - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0725 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0750
# Epoch 125/300
#  - 3s - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0725 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 126/300
#  - 3s - loss: 0.0178 - mean_squared_error: 0.0178 - mean_absolute_error: 0.0726 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0750
# Epoch 127/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0753
# Epoch 128/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0753
# Epoch 129/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0723 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0754
# Epoch 130/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0725 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 131/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0750
# Epoch 132/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 133/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0723 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0748
# Epoch 134/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0749
# Epoch 135/300
#  - 3s - loss: 0.0177 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0724 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0748
# Epoch 136/300
#  - 3s - loss: 0.0176 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0721 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0752
# Epoch 137/300
#  - 3s - loss: 0.0176 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0720 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0755
# Epoch 138/300
#  - 3s - loss: 0.0176 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0724 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0749
# Epoch 139/300
#  - 3s - loss: 0.0176 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0719 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0752
# Epoch 140/300
#  - 3s - loss: 0.0176 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0723 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0747
# Epoch 141/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0720 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 142/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0718 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0749
# Epoch 143/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0721 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 144/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0719 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 145/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0720 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 146/300
#  - 3s - loss: 0.0175 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0719 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0752
# Epoch 147/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0720 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0752
# Epoch 148/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0717 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0752
# Epoch 149/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0719 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0753
# Epoch 150/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0716 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0750
# Epoch 151/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0717 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0753
# Epoch 152/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0717 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0751
# Epoch 153/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0716 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0749
# Epoch 154/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0716 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 155/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0716 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0749
# Epoch 156/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0715 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0746
# Epoch 157/300
#  - 3s - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0715 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0754
# Epoch 158/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0716 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0751
# Epoch 159/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0713 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0753
# Epoch 160/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0715 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0751
# Epoch 161/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0713 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0753
# Epoch 162/300
#  - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0713 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0751
# Epoch 163/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0713 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0750
# Epoch 164/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0711 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0752
# Epoch 165/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0713 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0753
# Epoch 166/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0712 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0747
# Epoch 167/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0712 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0748
# Epoch 168/300
#  - 3s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0710 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0753
# Epoch 169/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0710 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0748
# Epoch 170/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0711 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0749
# Epoch 171/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0711 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0750
# Epoch 172/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0709 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0750
# Epoch 173/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0709 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0748
# Epoch 174/300
#  - 3s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0706 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0753
# Epoch 175/300
#  - 3s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0709 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0747
# Epoch 176/300
#  - 3s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0707 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0748
# Epoch 177/300
#  - 3s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0707 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0753
# Epoch 178/300
#  - 3s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0707 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0748
# Epoch 179/300
#  - 3s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0706 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0750
# Epoch 180/300
#  - 3s - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0705 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0751
# Epoch 181/300
#  - 3s - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0706 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0747
# Epoch 182/300
#  - 3s - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0704 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0750
# Epoch 183/300
#  - 3s - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0704 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0749
# Epoch 184/300
#  - 3s - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0704 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0747
# Epoch 185/300
#  - 3s - loss: 0.0169 - mean_squared_error: 0.0169 - mean_absolute_error: 0.0703 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0751
# Epoch 186/300
#  - 3s - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0706 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0748
# Epoch 187/300
#  - 3s - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0702 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0743
# Epoch 188/300
#  - 3s - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0703 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0750
# Epoch 189/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0700 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0748
# Epoch 190/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0702 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0748
# Epoch 191/300
#  - 3s - loss: 0.0168 - mean_squared_error: 0.0168 - mean_absolute_error: 0.0700 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0752
# Epoch 192/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0701 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0748
# Epoch 193/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0702 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0746
# Epoch 194/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0698 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0747
# Epoch 195/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0700 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0744
# Epoch 196/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0699 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0745
# Epoch 197/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0699 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0748
# Epoch 198/300
#  - 3s - loss: 0.0167 - mean_squared_error: 0.0167 - mean_absolute_error: 0.0697 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0747
# Epoch 199/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0700 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0740
# Epoch 200/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0696 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0744
# Epoch 201/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0695 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0749
# Epoch 202/300
#  - 3s - loss: 0.0165 - mean_squared_error: 0.0165 - mean_absolute_error: 0.0697 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0744
# Epoch 203/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0695 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0744
# Epoch 204/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0697 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0744
# Epoch 205/300
#  - 3s - loss: 0.0166 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0696 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0744
# Epoch 206/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0693 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0748
# Epoch 207/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0695 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0742
# Epoch 208/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0692 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0747
# Epoch 209/300
#  - 3s - loss: 0.0165 - mean_squared_error: 0.0165 - mean_absolute_error: 0.0693 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0742
# Epoch 210/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0692 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0745
# Epoch 211/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0694 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0747
# Epoch 212/300
#  - 3s - loss: 0.0165 - mean_squared_error: 0.0165 - mean_absolute_error: 0.0693 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0745
# Epoch 213/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0694 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0744
# Epoch 214/300
#  - 3s - loss: 0.0164 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0689 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0745
# Epoch 215/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0692 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0744
# Epoch 216/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0689 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.0740
# Epoch 217/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0692 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0746
# Epoch 218/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0689 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0742
# Epoch 219/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0689 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0742
# Epoch 220/300
#  - 3s - loss: 0.0163 - mean_squared_error: 0.0163 - mean_absolute_error: 0.0688 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0747
# Epoch 221/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0688 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0743
# Epoch 222/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0687 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0744
# Epoch 223/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0688 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0745
# Epoch 224/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0689 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0742
# Epoch 225/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0685 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0742
# Epoch 226/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0685 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0739
# Epoch 227/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0685 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0742
# Epoch 228/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0686 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0738
# Epoch 229/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0685 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0743
# Epoch 230/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0683 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0742
# Epoch 231/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0684 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0738
# Epoch 232/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0684 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0738
# Epoch 233/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0682 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0745
# Epoch 234/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0684 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0738
# Epoch 235/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0683 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0746
# Epoch 236/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0683 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0738
# Epoch 237/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0682 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0740
# Epoch 238/300
#  - 3s - loss: 0.0159 - mean_squared_error: 0.0159 - mean_absolute_error: 0.0680 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0737
# Epoch 239/300
#  - 3s - loss: 0.0159 - mean_squared_error: 0.0159 - mean_absolute_error: 0.0680 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0737
# Epoch 240/300
#  - 3s - loss: 0.0159 - mean_squared_error: 0.0159 - mean_absolute_error: 0.0679 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0737
# Epoch 241/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0680 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0739
# Epoch 242/300
#  - 3s - loss: 0.0158 - mean_squared_error: 0.0158 - mean_absolute_error: 0.0679 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0745
# Epoch 243/300
#  - 3s - loss: 0.0159 - mean_squared_error: 0.0159 - mean_absolute_error: 0.0681 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0739
# Epoch 244/300
#  - 3s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0680 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0741
# Epoch 245/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0676 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0738
# Epoch 246/300
#  - 3s - loss: 0.0158 - mean_squared_error: 0.0158 - mean_absolute_error: 0.0680 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0736
# Epoch 247/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0675 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0736
# Epoch 248/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0678 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0740
# Epoch 249/300
#  - 3s - loss: 0.0158 - mean_squared_error: 0.0158 - mean_absolute_error: 0.0678 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0735
# Epoch 250/300
#  - 3s - loss: 0.0158 - mean_squared_error: 0.0158 - mean_absolute_error: 0.0677 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0736
# Epoch 251/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0674 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0738
# Epoch 252/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0676 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0736
# Epoch 253/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0675 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0737
# Epoch 254/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0678 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0737
# Epoch 255/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0675 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0738
# Epoch 256/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0674 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0738
# Epoch 257/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0675 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0732
# Epoch 258/300
#  - 3s - loss: 0.0156 - mean_squared_error: 0.0156 - mean_absolute_error: 0.0670 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0737
# Epoch 259/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0677 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0742
# Epoch 260/300
#  - 3s - loss: 0.0156 - mean_squared_error: 0.0156 - mean_absolute_error: 0.0674 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0733
# Epoch 261/300
#  - 3s - loss: 0.0156 - mean_squared_error: 0.0156 - mean_absolute_error: 0.0673 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0735
# Epoch 262/300
#  - 3s - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0672 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.0734
# Epoch 263/300
#  - 3s - loss: 0.0155 - mean_squared_error: 0.0155 - mean_absolute_error: 0.0672 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0736
# Epoch 264/300
#  - 3s - loss: 0.0155 - mean_squared_error: 0.0155 - mean_absolute_error: 0.0671 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0736
# Epoch 265/300
#  - 3s - loss: 0.0155 - mean_squared_error: 0.0155 - mean_absolute_error: 0.0670 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0735
# Epoch 266/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0668 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0737
# Epoch 267/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0671 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0730
# Epoch 268/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0668 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0735
# Epoch 269/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0668 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0739
# Epoch 270/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0670 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0735
# Epoch 271/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0671 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0736
# Epoch 272/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0668 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0736
# Epoch 273/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0669 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0738
# Epoch 274/300
#  - 3s - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0666 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0739
# Epoch 275/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0665 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0731
# Epoch 276/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0667 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0735
# Epoch 277/300
#  - 3s - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0664 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0733
# Epoch 278/300
#  - 3s - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0665 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0738
# Epoch 279/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0664 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0733
# Epoch 280/300
#  - 3s - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0666 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0734
# Epoch 281/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0663 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0733
# Epoch 282/300
#  - 3s - loss: 0.0151 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0662 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0734
# Epoch 283/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0665 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0730
# Epoch 284/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0663 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0734
# Epoch 285/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0663 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0731
# Epoch 286/300
#  - 3s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0663 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Epoch 287/300
#  - 3s - loss: 0.0151 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0661 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0736
# Epoch 288/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0660 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0734
# Epoch 289/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0660 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Epoch 290/300
#  - 3s - loss: 0.0149 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0658 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0736
# Epoch 291/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0661 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0737
# Epoch 292/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0661 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Epoch 293/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0659 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0733
# Epoch 294/300
#  - 3s - loss: 0.0149 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0660 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Epoch 295/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0658 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0731
# Epoch 296/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0655 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0731
# Epoch 297/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0659 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0734
# Epoch 298/300
#  - 3s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0657 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Epoch 299/300
#  - 3s - loss: 0.0148 - mean_squared_error: 0.0148 - mean_absolute_error: 0.0655 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0731
# Epoch 300/300
#  - 3s - loss: 0.0149 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0657 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0731
# Wall time: 14min 25s

# %% [markdown]
# ### Timestep (1) - Evaluation  (CPU)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
#NEW
y_actual, y_predicted = [],[]
#NEW
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        #NEW
        y_actual.append(y[0])
        y_predicted.append(yhat[0])
        #NEW
        
        for z in range(yhat.shape[0]):
            y[z] = BinClass.discretize_value(y[z], cpu_avg)
            yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(len(y_labels2)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
    
#NEW
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual, label='y_actual')
plt.plot(y_predicted, label='y_predicted')
plt.title('Predicted vs Actual')
plt.show()

plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[0:100], label='y_actual')
plt.plot(y_predicted[0:100], label='y_predicted')
plt.title('Predicted vs Actual (0-100)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[200:300], label='y_actual')
plt.plot(y_predicted[200:300], label='y_predicted')
plt.title('Predicted vs Actual (200-300)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[400:500], label='y_actual')
plt.plot(y_predicted[400:500], label='y_predicted')
plt.title('Predicted vs Actual (400-500)')
plt.show()
#NEW
# Out:
# Day 1
# Feature vectors: (857, 1, 95)
# Label vectors: (857, 13)
# Label: 0
# Accuracy: 0.662777129521587
# F1Score: 0.2608695652173913
# --------------------------
# Label: 1
# Accuracy: 0.6721120186697783
# F1Score: 0.1710914454277286
# --------------------------
# Label: 2
# Accuracy: 0.7269544924154026
# F1Score: 0.1333333333333333
# --------------------------
# Label: 3
# Accuracy: 0.6207701283547258
# F1Score: 0.22802850356294535
# --------------------------
# Label: 4
# Accuracy: 0.6546091015169195
# F1Score: 0.19999999999999998
# --------------------------
# Label: 5
# Accuracy: 0.7141190198366394
# F1Score: 0.1218637992831541
# --------------------------
# Label: 6
# Accuracy: 0.7246207701283547
# F1Score: 0.1386861313868613
# --------------------------
# Label: 7
# Accuracy: 0.6814469078179697
# F1Score: 0.1702127659574468
# --------------------------
# Label: 8
# Accuracy: 0.9381563593932322
# F1Score: 0.8454810495626821
# --------------------------
# Label: 9
# Accuracy: 0.9451575262543758
# F1Score: 0.8478964401294498
# --------------------------
# Label: 10
# Accuracy: 0.9299883313885647
# F1Score: 0.8013245033112583
# --------------------------
# Label: 11
# Accuracy: 0.9276546091015169
# F1Score: 0.8050314465408805
# --------------------------
# Label: 12
# Accuracy: 0.9381563593932322
# F1Score: 0.8408408408408408
# --------------------------
# Averaged Day 13 Accuracy: 0.7797325195224846
# F1Score: 0.4280507557349209
# --------------------------
# ----------------------------------------
# Day 2
# Feature vectors: (857, 1, 95)
# Label vectors: (857, 13)
# Label: 0
# Accuracy: 0.49941656942823803
# F1Score: 0.3024390243902439
# --------------------------
# Label: 1
# Accuracy: 0.6826137689614936
# F1Score: 0.13375796178343946
# --------------------------
# Label: 2
# Accuracy: 0.5460910151691949
# F1Score: 0.2965641952983725
# --------------------------
# Label: 3
# Accuracy: 0.6441073512252042
# F1Score: 0.19947506561679793
# --------------------------
# Label: 4
# Accuracy: 0.6417736289381564
# F1Score: 0.25304136253041365
# --------------------------
# Label: 5
# Accuracy: 0.691948658109685
# F1Score: 0.2457142857142857
# --------------------------
# ----------------------------------------
# Day 7
# Feature vectors: (857, 1, 95)
# Label vectors: (857, 13)
# Label: 0
# Accuracy: 0.6219369894982497
# F1Score: 0.25688073394495414
# --------------------------
# Label: 1
# Accuracy: 0.5822637106184364
# F1Score: 0.2183406113537118
# --------------------------
# Label: 2
# Accuracy: 0.5810968494749125
# F1Score: 0.28628230616302186
# --------------------------
# Label: 3
# Accuracy: 0.45507584597432904
# F1Score: 0.289193302891933
# --------------------------
# Label: 4
# Accuracy: 0.5519253208868145
# F1Score: 0.2529182879377432
# --------------------------
# Label: 5
# Accuracy: 0.46091015169194866
# F1Score: 0.29141104294478526
# --------------------------
# Label: 6
# Accuracy: 0.5332555425904317
# F1Score: 0.2779783393501805
# --------------------------
# Label: 7
# Accuracy: 0.5682613768961493
# F1Score: 0.24796747967479674
# --------------------------
# Label: 8
# Accuracy: 0.9451575262543758
# F1Score: 0.853582554517134
# --------------------------
# Label: 9
# Accuracy: 0.9544924154025671
# F1Score: 0.8745980707395498
# --------------------------
# Label: 10
# Accuracy: 0.9439906651108518
# F1Score: 0.8536585365853658
# --------------------------
# Label: 11
# Accuracy: 0.9591598599766628
# F1Score: 0.8736462093862815
# --------------------------
# Label: 12
# Accuracy: 0.9521586931155193
# F1Score: 0.862876254180602
# --------------------------
# Averaged Day 13 Accuracy: 0.7303396719966148
# F1Score: 0.47283260471838656
# --------------------------
# ----------------------------------------
# Wall time: 5min 12s

# %% [markdown]
# ### Scoring per day  (CPU)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (1) - Training (IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
y_labels2 = []
for label in y_df.columns:
    if 'var2' in label:
        y_labels2.append(label)
y_df2 = y_df[y_labels2]
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df2, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(6003, 1, 95)] Type - <class 'numpy.ndarray'>
# y_train shape [(6003, 13)] Type - <class 'numpy.ndarray'>
# X_validate shape [(6004, 1, 95)] Type - <class 'numpy.ndarray'>
# y_validate shape [(6004, 13)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 1, 95)             72580
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 95)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 95)                72580
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 95)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                1248
# =================================================================
# Total params: 146,408
# Trainable params: 146,408
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 6003 samples, validate on 6004 samples
# Epoch 1/300
#  - 3s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1582 - val_loss: 0.0371 - val_mean_squared_error: 0.0371 - val_mean_absolute_error: 0.1285
# Epoch 2/300
#  - 3s - loss: 0.0373 - mean_squared_error: 0.0373 - mean_absolute_error: 0.1322 - val_loss: 0.0364 - val_mean_squared_error: 0.0364 - val_mean_absolute_error: 0.1302
# Epoch 3/300
#  - 3s - loss: 0.0362 - mean_squared_error: 0.0362 - mean_absolute_error: 0.1298 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - val_mean_absolute_error: 0.1249
# Epoch 4/300
#  - 3s - loss: 0.0337 - mean_squared_error: 0.0337 - mean_absolute_error: 0.1244 - val_loss: 0.0317 - val_mean_squared_error: 0.0317 - val_mean_absolute_error: 0.1168
# Epoch 5/300
#  - 3s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1201 - val_loss: 0.0298 - val_mean_squared_error: 0.0298 - val_mean_absolute_error: 0.1103
# Epoch 6/300
#  - 3s - loss: 0.0305 - mean_squared_error: 0.0305 - mean_absolute_error: 0.1171 - val_loss: 0.0286 - val_mean_squared_error: 0.0286 - val_mean_absolute_error: 0.1074
# Epoch 7/300
#  - 3s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1153 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1059
# Epoch 8/300
#  - 3s - loss: 0.0291 - mean_squared_error: 0.0291 - mean_absolute_error: 0.1142 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.1054
# Epoch 9/300
#  - 3s - loss: 0.0288 - mean_squared_error: 0.0288 - mean_absolute_error: 0.1132 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.1046
# Epoch 10/300
#  - 3s - loss: 0.0285 - mean_squared_error: 0.0285 - mean_absolute_error: 0.1124 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.1044
# Epoch 11/300
#  - 3s - loss: 0.0283 - mean_squared_error: 0.0283 - mean_absolute_error: 0.1116 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.1042
# Epoch 12/300
#  - 3s - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1112 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.1034
# Epoch 13/300
#  - 3s - loss: 0.0280 - mean_squared_error: 0.0280 - mean_absolute_error: 0.1107 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.1037
# Epoch 14/300
#  - 3s - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1103 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.1031
# Epoch 15/300
#  - 3s - loss: 0.0278 - mean_squared_error: 0.0278 - mean_absolute_error: 0.1097 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.1033
# Epoch 16/300
#  - 3s - loss: 0.0275 - mean_squared_error: 0.0275 - mean_absolute_error: 0.1090 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.1029
# Epoch 17/300
#  - 3s - loss: 0.0276 - mean_squared_error: 0.0276 - mean_absolute_error: 0.1090 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.1024
# Epoch 18/300
#  - 3s - loss: 0.0273 - mean_squared_error: 0.0273 - mean_absolute_error: 0.1081 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.1026
# Epoch 19/300
#  - 3s - loss: 0.0273 - mean_squared_error: 0.0273 - mean_absolute_error: 0.1078 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.1024
# Epoch 20/300
#  - 3s - loss: 0.0273 - mean_squared_error: 0.0273 - mean_absolute_error: 0.1076 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.1019
# Epoch 21/300
#  - 3s - loss: 0.0271 - mean_squared_error: 0.0271 - mean_absolute_error: 0.1069 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.1021
# Epoch 22/300
#  - 3s - loss: 0.0271 - mean_squared_error: 0.0271 - mean_absolute_error: 0.1067 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.1016
# Epoch 23/300
#  - 3s - loss: 0.0270 - mean_squared_error: 0.0270 - mean_absolute_error: 0.1063 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.1013
# Epoch 24/300
#  - 3s - loss: 0.0269 - mean_squared_error: 0.0269 - mean_absolute_error: 0.1059 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.1011
# Epoch 25/300
#  - 3s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1054 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.1009
# Epoch 26/300
#  - 3s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1049 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.1012
# Epoch 27/300
#  - 3s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1047 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.1006
# Epoch 28/300
#  - 3s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1043 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.1006
# Epoch 29/300
#  - 3s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1039 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.1003
# Epoch 30/300
#  - 3s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1037 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.1003
# Epoch 31/300
#  - 3s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1035 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0999
# Epoch 32/300
#  - 3s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1030 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0999
# Epoch 33/300
#  - 3s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1028 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0999
# Epoch 34/300
#  - 3s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1025 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0997
# Epoch 35/300
#  - 3s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1022 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0995
# Epoch 36/300
#  - 3s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1022 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0997
# Epoch 37/300
#  - 3s - loss: 0.0260 - mean_squared_error: 0.0260 - mean_absolute_error: 0.1018 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0990
# Epoch 38/300
#  - 3s - loss: 0.0259 - mean_squared_error: 0.0259 - mean_absolute_error: 0.1014 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0995
# Epoch 39/300
#  - 3s - loss: 0.0258 - mean_squared_error: 0.0258 - mean_absolute_error: 0.1012 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0993
# Epoch 40/300
#  - 3s - loss: 0.0258 - mean_squared_error: 0.0258 - mean_absolute_error: 0.1011 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0994
# Epoch 41/300
#  - 3s - loss: 0.0257 - mean_squared_error: 0.0257 - mean_absolute_error: 0.1008 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0988
# Epoch 42/300
#  - 3s - loss: 0.0257 - mean_squared_error: 0.0257 - mean_absolute_error: 0.1006 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0988
# Epoch 43/300
#  - 3s - loss: 0.0257 - mean_squared_error: 0.0257 - mean_absolute_error: 0.1004 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0987
# Epoch 44/300
#  - 3s - loss: 0.0256 - mean_squared_error: 0.0256 - mean_absolute_error: 0.1002 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0986
# Epoch 45/300
#  - 3s - loss: 0.0255 - mean_squared_error: 0.0255 - mean_absolute_error: 0.0999 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0986
# Epoch 46/300
#  - 3s - loss: 0.0255 - mean_squared_error: 0.0255 - mean_absolute_error: 0.0998 - val_loss: 0.0262 - val_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0985
# Epoch 47/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0996 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0986
# Epoch 48/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0996 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0985
# Epoch 49/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0994 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0983
# Epoch 50/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0992 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0984
# Epoch 51/300
#  - 3s - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.0986 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0984
# Epoch 52/300
#  - 3s - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.0986 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0986
# Epoch 53/300
#  - 3s - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.0989 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0980
# Epoch 54/300
#  - 3s - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.0984 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0979
# Epoch 55/300
#  - 3s - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.0982 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0980
# Epoch 56/300
#  - 3s - loss: 0.0250 - mean_squared_error: 0.0250 - mean_absolute_error: 0.0980 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0975
# Epoch 57/300
#  - 3s - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.0980 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0978
# Epoch 58/300
#  - 3s - loss: 0.0250 - mean_squared_error: 0.0250 - mean_absolute_error: 0.0977 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0979
# Epoch 59/300
#  - 3s - loss: 0.0249 - mean_squared_error: 0.0249 - mean_absolute_error: 0.0978 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0978
# Epoch 60/300
#  - 3s - loss: 0.0249 - mean_squared_error: 0.0249 - mean_absolute_error: 0.0976 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0979
# Epoch 61/300
#  - 3s - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.0974 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0973
# Epoch 62/300
#  - 3s - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.0975 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0979
# Epoch 63/300
#  - 3s - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.0974 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0973
# Epoch 64/300
#  - 3s - loss: 0.0247 - mean_squared_error: 0.0247 - mean_absolute_error: 0.0970 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0973
# Epoch 65/300
#  - 3s - loss: 0.0247 - mean_squared_error: 0.0247 - mean_absolute_error: 0.0971 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0976
# Epoch 66/300
#  - 3s - loss: 0.0247 - mean_squared_error: 0.0247 - mean_absolute_error: 0.0969 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0975
# Epoch 67/300
#  - 3s - loss: 0.0246 - mean_squared_error: 0.0246 - mean_absolute_error: 0.0967 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0976
# Epoch 68/300
#  - 3s - loss: 0.0246 - mean_squared_error: 0.0246 - mean_absolute_error: 0.0967 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0976
# Epoch 69/300
#  - 3s - loss: 0.0246 - mean_squared_error: 0.0246 - mean_absolute_error: 0.0966 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0974
# Epoch 70/300
#  - 3s - loss: 0.0244 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0963 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0975
# Epoch 71/300
#  - 3s - loss: 0.0245 - mean_squared_error: 0.0245 - mean_absolute_error: 0.0964 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0976
# Epoch 72/300
#  - 3s - loss: 0.0244 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0962 - val_loss: 0.0264 - val_mean_squared_error: 0.0264 - val_mean_absolute_error: 0.0975
# Epoch 73/300
#  - 3s - loss: 0.0244 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0961 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0974
# Epoch 74/300
#  - 3s - loss: 0.0244 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0961 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0975
# Epoch 75/300
#  - 3s - loss: 0.0244 - mean_squared_error: 0.0244 - mean_absolute_error: 0.0960 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0974
# Epoch 76/300
#  - 3s - loss: 0.0243 - mean_squared_error: 0.0243 - mean_absolute_error: 0.0960 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0973
# Epoch 77/300
#  - 3s - loss: 0.0242 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0958 - val_loss: 0.0265 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.0975
# Epoch 78/300
#  - 3s - loss: 0.0242 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0959 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0975
# Epoch 79/300
#  - 3s - loss: 0.0242 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0955 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0974
# Epoch 80/300
#  - 3s - loss: 0.0241 - mean_squared_error: 0.0241 - mean_absolute_error: 0.0954 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0976
# Epoch 81/300
#  - 3s - loss: 0.0242 - mean_squared_error: 0.0242 - mean_absolute_error: 0.0957 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0973
# Epoch 82/300
#  - 3s - loss: 0.0240 - mean_squared_error: 0.0240 - mean_absolute_error: 0.0954 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0980
# Epoch 83/300
#  - 3s - loss: 0.0241 - mean_squared_error: 0.0241 - mean_absolute_error: 0.0955 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0977
# Epoch 84/300
#  - 3s - loss: 0.0241 - mean_squared_error: 0.0241 - mean_absolute_error: 0.0956 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0973
# Epoch 85/300
#  - 3s - loss: 0.0240 - mean_squared_error: 0.0240 - mean_absolute_error: 0.0952 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0975
# Epoch 86/300
#  - 3s - loss: 0.0239 - mean_squared_error: 0.0239 - mean_absolute_error: 0.0952 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0975
# Epoch 87/300
#  - 3s - loss: 0.0239 - mean_squared_error: 0.0239 - mean_absolute_error: 0.0951 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0977
# Epoch 88/300
#  - 3s - loss: 0.0240 - mean_squared_error: 0.0240 - mean_absolute_error: 0.0953 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0974
# Epoch 89/300
#  - 3s - loss: 0.0240 - mean_squared_error: 0.0240 - mean_absolute_error: 0.0953 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0976
# Epoch 90/300
#  - 3s - loss: 0.0238 - mean_squared_error: 0.0238 - mean_absolute_error: 0.0951 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0974
# Epoch 91/300
#  - 3s - loss: 0.0239 - mean_squared_error: 0.0239 - mean_absolute_error: 0.0952 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0972
# Epoch 92/300
#  - 3s - loss: 0.0238 - mean_squared_error: 0.0238 - mean_absolute_error: 0.0948 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0976
# Epoch 93/300
#  - 3s - loss: 0.0238 - mean_squared_error: 0.0238 - mean_absolute_error: 0.0950 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0974
# Epoch 94/300
#  - 3s - loss: 0.0238 - mean_squared_error: 0.0238 - mean_absolute_error: 0.0949 - val_loss: 0.0267 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0974
# Epoch 95/300
#  - 3s - loss: 0.0238 - mean_squared_error: 0.0238 - mean_absolute_error: 0.0947 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0979
# Epoch 96/300
#  - 3s - loss: 0.0237 - mean_squared_error: 0.0237 - mean_absolute_error: 0.0948 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0977
# Epoch 97/300
#  - 3s - loss: 0.0237 - mean_squared_error: 0.0237 - mean_absolute_error: 0.0948 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0974
# Epoch 98/300
#  - 3s - loss: 0.0236 - mean_squared_error: 0.0236 - mean_absolute_error: 0.0946 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0977
# Epoch 99/300
#  - 3s - loss: 0.0236 - mean_squared_error: 0.0236 - mean_absolute_error: 0.0947 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0972
# Epoch 100/300
#  - 3s - loss: 0.0236 - mean_squared_error: 0.0236 - mean_absolute_error: 0.0946 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0974
# Epoch 101/300
#  - 3s - loss: 0.0236 - mean_squared_error: 0.0236 - mean_absolute_error: 0.0946 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0979
# Epoch 102/300
#  - 3s - loss: 0.0236 - mean_squared_error: 0.0236 - mean_absolute_error: 0.0946 - val_loss: 0.0268 - val_mean_squared_error: 0.0268 - val_mean_absolute_error: 0.0979
# Epoch 103/300
#  - 3s - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.0943 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0976
# Epoch 104/300
#  - 3s - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.0945 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0974
# Epoch 105/300
#  - 3s - loss: 0.0235 - mean_squared_error: 0.0235 - mean_absolute_error: 0.0944 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0978
# Epoch 106/300
#  - 3s - loss: 0.0235 - mean_squared_error: 0.0235 - mean_absolute_error: 0.0947 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0977
# Epoch 107/300
#  - 3s - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.0943 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0978
# Epoch 108/300
#  - 3s - loss: 0.0234 - mean_squared_error: 0.0234 - mean_absolute_error: 0.0941 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0978
# Epoch 109/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0942 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0979
# Epoch 110/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0942 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0975
# Epoch 111/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0942 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0976
# Epoch 112/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0942 - val_loss: 0.0269 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0979
# Epoch 113/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0944 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0975
# Epoch 114/300
#  - 3s - loss: 0.0232 - mean_squared_error: 0.0232 - mean_absolute_error: 0.0939 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0980
# Epoch 115/300
#  - 3s - loss: 0.0233 - mean_squared_error: 0.0233 - mean_absolute_error: 0.0940 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0979
# Epoch 116/300
#  - 3s - loss: 0.0232 - mean_squared_error: 0.0232 - mean_absolute_error: 0.0940 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0979
# Epoch 117/300
#  - 3s - loss: 0.0232 - mean_squared_error: 0.0232 - mean_absolute_error: 0.0942 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0981
# Epoch 118/300
#  - 3s - loss: 0.0231 - mean_squared_error: 0.0231 - mean_absolute_error: 0.0940 - val_loss: 0.0270 - val_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0979
# Epoch 119/300
#  - 3s - loss: 0.0231 - mean_squared_error: 0.0231 - mean_absolute_error: 0.0939 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0979
# Epoch 120/300
#  - 3s - loss: 0.0231 - mean_squared_error: 0.0231 - mean_absolute_error: 0.0939 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0980
# Epoch 121/300
#  - 3s - loss: 0.0230 - mean_squared_error: 0.0230 - mean_absolute_error: 0.0937 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0982
# Epoch 122/300
#  - 4s - loss: 0.0230 - mean_squared_error: 0.0230 - mean_absolute_error: 0.0939 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0983
# Epoch 123/300
#  - 4s - loss: 0.0231 - mean_squared_error: 0.0231 - mean_absolute_error: 0.0941 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0982
# Epoch 124/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0938 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0981
# Epoch 125/300
#  - 3s - loss: 0.0230 - mean_squared_error: 0.0230 - mean_absolute_error: 0.0937 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0983
# Epoch 126/300
#  - 3s - loss: 0.0230 - mean_squared_error: 0.0230 - mean_absolute_error: 0.0940 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0981
# Epoch 127/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0938 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0980
# Epoch 128/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0938 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0983
# Epoch 129/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0937 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0981
# Epoch 130/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0938 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0985
# Epoch 131/300
#  - 3s - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.0936 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0982
# Epoch 132/300
#  - 3s - loss: 0.0228 - mean_squared_error: 0.0228 - mean_absolute_error: 0.0938 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0980
# Epoch 133/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0932 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0982
# Epoch 134/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0935 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0986
# Epoch 135/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0936 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0987
# Epoch 136/300
#  - 3s - loss: 0.0228 - mean_squared_error: 0.0228 - mean_absolute_error: 0.0935 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0978
# Epoch 137/300
#  - 3s - loss: 0.0228 - mean_squared_error: 0.0228 - mean_absolute_error: 0.0934 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0983
# Epoch 138/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0935 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0985
# Epoch 139/300
#  - 3s - loss: 0.0226 - mean_squared_error: 0.0226 - mean_absolute_error: 0.0933 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0986
# Epoch 140/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0937 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0985
# Epoch 141/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0934 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0985
# Epoch 142/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0937 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.0985
# Epoch 143/300
#  - 3s - loss: 0.0226 - mean_squared_error: 0.0226 - mean_absolute_error: 0.0934 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0985
# Epoch 144/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0935 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0988
# Epoch 145/300
#  - 3s - loss: 0.0226 - mean_squared_error: 0.0226 - mean_absolute_error: 0.0935 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0982
# Epoch 146/300
#  - 3s - loss: 0.0227 - mean_squared_error: 0.0227 - mean_absolute_error: 0.0936 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0986
# Epoch 147/300
#  - 3s - loss: 0.0225 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0931 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0987
# Epoch 148/300
#  - 3s - loss: 0.0225 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0931 - val_loss: 0.0273 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.0984
# Epoch 149/300
#  - 3s - loss: 0.0225 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0931 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0987
# Epoch 150/300
#  - 3s - loss: 0.0225 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0932 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0989
# Epoch 151/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0932 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0988
# Epoch 152/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0931 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0989
# Epoch 153/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0933 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0987
# Epoch 154/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0931 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0988
# Epoch 155/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0931 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0990
# Epoch 156/300
#  - 3s - loss: 0.0225 - mean_squared_error: 0.0225 - mean_absolute_error: 0.0932 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0988
# Epoch 157/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0933 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0987
# Epoch 158/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0929 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0992
# Epoch 159/300
#  - 3s - loss: 0.0224 - mean_squared_error: 0.0224 - mean_absolute_error: 0.0931 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0991
# Epoch 160/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0930 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0991
# Epoch 161/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0930 - val_loss: 0.0274 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0990
# Epoch 162/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0931 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0991
# Epoch 163/300
#  - 3s - loss: 0.0222 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0928 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0990
# Epoch 164/300
#  - 3s - loss: 0.0222 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0928 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0989
# Epoch 165/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0928 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0990
# Epoch 166/300
#  - 3s - loss: 0.0223 - mean_squared_error: 0.0223 - mean_absolute_error: 0.0931 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0988
# Epoch 167/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0927 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0993
# Epoch 168/300
#  - 3s - loss: 0.0222 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0930 - val_loss: 0.0275 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0991
# Epoch 169/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0927 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0992
# Epoch 170/300
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.0927 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0991
# Epoch 171/300
#  - 4s - loss: 0.0222 - mean_squared_error: 0.0222 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0995
# Epoch 172/300
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0994
# Epoch 173/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0989
# Epoch 174/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0994
# Epoch 175/300
#  - 3s - loss: 0.0221 - mean_squared_error: 0.0221 - mean_absolute_error: 0.0929 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0992
# Epoch 176/300
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.0926 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0991
# Epoch 177/300
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0991
# Epoch 178/300
#  - 3s - loss: 0.0220 - mean_squared_error: 0.0220 - mean_absolute_error: 0.0928 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0994
# Epoch 179/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0924 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0993
# Epoch 180/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0926 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0993
# Epoch 181/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0924 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - val_mean_absolute_error: 0.0994
# Epoch 182/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0922 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0992
# Epoch 183/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0926 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0995
# Epoch 184/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0923 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0993
# Epoch 185/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0925 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 186/300
#  - 3s - loss: 0.0219 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0928 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 187/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0924 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0995
# Epoch 188/300
#  - 3s - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0922 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 189/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0922 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0997
# Epoch 190/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0924 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0994
# Epoch 191/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0925 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 192/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0925 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 193/300
#  - 3s - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0924 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0997
# Epoch 194/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0926 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0996
# Epoch 195/300
#  - 3s - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0922 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0992
# Epoch 196/300
#  - 3s - loss: 0.0218 - mean_squared_error: 0.0218 - mean_absolute_error: 0.0924 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0998
# Epoch 197/300
#  - 3s - loss: 0.0217 - mean_squared_error: 0.0217 - mean_absolute_error: 0.0924 - val_loss: 0.0277 - val_mean_squared_error: 0.0277 - val_mean_absolute_error: 0.0998
# Epoch 198/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0921 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0996
# Epoch 199/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0923 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0998
# Epoch 200/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0924 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0997
# Epoch 201/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0920 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0998
# Epoch 202/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0921 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.1000
# Epoch 203/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0921 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0997
# Epoch 204/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0921 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0996
# Epoch 205/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0923 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0996
# Epoch 206/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1000
# Epoch 207/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0923 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0999
# Epoch 208/300
#  - 3s - loss: 0.0216 - mean_squared_error: 0.0216 - mean_absolute_error: 0.0921 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.1000
# Epoch 209/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0919 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.1001
# Epoch 210/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0923 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.0999
# Epoch 211/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1001
# Epoch 212/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1001
# Epoch 213/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1002
# Epoch 214/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0921 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1002
# Epoch 215/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0922 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.0999
# Epoch 216/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1001
# Epoch 217/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0918 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.0999
# Epoch 218/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.0999
# Epoch 219/300
#  - 3s - loss: 0.0215 - mean_squared_error: 0.0215 - mean_absolute_error: 0.0922 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1002
# Epoch 220/300
#  - 3s - loss: 0.0214 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0920 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1002
# Epoch 221/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0917 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1003
# Epoch 222/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0918 - val_loss: 0.0279 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1004
# Epoch 223/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0919 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1000
# Epoch 224/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0916 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1005
# Epoch 225/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0917 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1002
# Epoch 226/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0916 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1001
# Epoch 227/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0917 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1002
# Epoch 228/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0918 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1002
# Epoch 229/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0917 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.0998
# Epoch 230/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0917 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1003
# Epoch 231/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0918 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1003
# Epoch 232/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0916 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1002
# Epoch 233/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0917 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1002
# Epoch 234/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0915 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1003
# Epoch 235/300
#  - 3s - loss: 0.0213 - mean_squared_error: 0.0213 - mean_absolute_error: 0.0918 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1004
# Epoch 236/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0916 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.1002
# Epoch 237/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0913 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1004
# Epoch 238/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0916 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1002
# Epoch 239/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0913 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1008
# Epoch 240/300
#  - 3s - loss: 0.0212 - mean_squared_error: 0.0212 - mean_absolute_error: 0.0919 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.0999
# Epoch 241/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0913 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1004
# Epoch 242/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0915 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1003
# Epoch 243/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0915 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1004
# Epoch 244/300
#  - 3s - loss: 0.0211 - mean_squared_error: 0.0211 - mean_absolute_error: 0.0914 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1003
# Epoch 245/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1005
# Epoch 246/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0914 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1006
# Epoch 247/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0912 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1005
# Epoch 248/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0914 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1007
# Epoch 249/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1004
# Epoch 250/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0912 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1007
# Epoch 251/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1005
# Epoch 252/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1008
# Epoch 253/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0913 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1007
# Epoch 254/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1006
# Epoch 255/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0910 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1008
# Epoch 256/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0912 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1009
# Epoch 257/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1005
# Epoch 258/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0909 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 259/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1005
# Epoch 260/300
#  - 3s - loss: 0.0210 - mean_squared_error: 0.0210 - mean_absolute_error: 0.0915 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 261/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0913 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1009
# Epoch 262/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0913 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1006
# Epoch 263/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0912 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1006
# Epoch 264/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0912 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1005
# Epoch 265/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 266/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1009
# Epoch 267/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1010
# Epoch 268/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0913 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1009
# Epoch 269/300
#  - 3s - loss: 0.0209 - mean_squared_error: 0.0209 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1009
# Epoch 270/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0909 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1011
# Epoch 271/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0911 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1010
# Epoch 272/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0911 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1011
# Epoch 273/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0911 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1011
# Epoch 274/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 275/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1007
# Epoch 276/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0909 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1010
# Epoch 277/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0912 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1012
# Epoch 278/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0909 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1007
# Epoch 279/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0909 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1012
# Epoch 280/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0911 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1010
# Epoch 281/300
#  - 3s - loss: 0.0208 - mean_squared_error: 0.0208 - mean_absolute_error: 0.0912 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1009
# Epoch 282/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0910 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1010
# Epoch 283/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0909 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1011
# Epoch 284/300
#  - 3s - loss: 0.0207 - mean_squared_error: 0.0207 - mean_absolute_error: 0.0911 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1011
# Epoch 285/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0908 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1008
# Epoch 286/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0910 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1009
# Epoch 287/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0908 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 288/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0908 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1008
# Epoch 289/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0907 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1009
# Epoch 290/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0909 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1011
# Epoch 291/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0910 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1009
# Epoch 292/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0904 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1012
# Epoch 293/300
#  - 3s - loss: 0.0206 - mean_squared_error: 0.0206 - mean_absolute_error: 0.0907 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1012
# Epoch 294/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0906 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1013
# Epoch 295/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0908 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1010
# Epoch 296/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0907 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1010
# Epoch 297/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0906 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1010
# Epoch 298/300
#  - 3s - loss: 0.0205 - mean_squared_error: 0.0205 - mean_absolute_error: 0.0907 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1013
# Epoch 299/300
#  - 3s - loss: 0.0204 - mean_squared_error: 0.0204 - mean_absolute_error: 0.0905 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1010
# Epoch 300/300
#  - 3s - loss: 0.0204 - mean_squared_error: 0.0204 - mean_absolute_error: 0.0906 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1015
# Wall time: 14min 37s

# %% [markdown]
# ### Timestep (1) - Evaluation  (IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
#NEW
y_actual, y_predicted = [],[]
#NEW
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        #NEW
        y_actual.append(y[0])
        y_predicted.append(yhat[0])
        #NEW
        
        for z in range(yhat.shape[0]):
            y[i] = BinClass.discretize_value(y[z], io_avg)
            yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(len(y_labels2)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
    
#NEW
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual, label='y_actual')
plt.plot(y_predicted, label='y_predicted')
plt.title('Predicted vs Actual')
plt.show()

plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[0:100], label='y_actual')
plt.plot(y_predicted[0:100], label='y_predicted')
plt.title('Predicted vs Actual (0-100)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[200:300], label='y_actual')
plt.plot(y_predicted[200:300], label='y_predicted')
plt.title('Predicted vs Actual (200-300)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[400:500], label='y_actual')
plt.plot(y_predicted[400:500], label='y_predicted')
plt.title('Predicted vs Actual (400-500)')
plt.show()
#NEW
# Out:
# Day 1
# Feature vectors: (857, 1, 95)
# Label vectors: (857, 13)
# Label: 0
# Accuracy: 0.5670945157526255
# F1Score: 0.6599450045829515
# --------------------------
# Label: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of continuous and binary targets

# %% [markdown]
# ### Scoring per day  (IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (1) - Training (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(6003, 1, 95)] Type - <class 'numpy.ndarray'>
# y_train shape [(6003, 26)] Type - <class 'numpy.ndarray'>
# X_validate shape [(6004, 1, 95)] Type - <class 'numpy.ndarray'>
# y_validate shape [(6004, 26)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 1, 95)             72580
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 95)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 95)                72580
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 95)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 26)                2496
# =================================================================
# Total params: 147,656
# Trainable params: 147,656
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 6003 samples, validate on 6004 samples
# Epoch 1/300
#  - 11s - loss: 0.0845 - mean_squared_error: 0.0845 - mean_absolute_error: 0.2349 - val_loss: 0.0331 - val_mean_squared_error: 0.0331 - val_mean_absolute_error: 0.1188
# Epoch 2/300
#  - 3s - loss: 0.0335 - mean_squared_error: 0.0335 - mean_absolute_error: 0.1181 - val_loss: 0.0328 - val_mean_squared_error: 0.0328 - val_mean_absolute_error: 0.1155
# Epoch 3/300
#  - 3s - loss: 0.0333 - mean_squared_error: 0.0333 - mean_absolute_error: 0.1177 - val_loss: 0.0327 - val_mean_squared_error: 0.0327 - val_mean_absolute_error: 0.1157
# Epoch 4/300
#  - 3s - loss: 0.0330 - mean_squared_error: 0.0330 - mean_absolute_error: 0.1174 - val_loss: 0.0325 - val_mean_squared_error: 0.0325 - val_mean_absolute_error: 0.1157
# Epoch 5/300
#  - 3s - loss: 0.0327 - mean_squared_error: 0.0327 - mean_absolute_error: 0.1169 - val_loss: 0.0321 - val_mean_squared_error: 0.0321 - val_mean_absolute_error: 0.1152
# Epoch 6/300
#  - 3s - loss: 0.0320 - mean_squared_error: 0.0320 - mean_absolute_error: 0.1157 - val_loss: 0.0309 - val_mean_squared_error: 0.0309 - val_mean_absolute_error: 0.1127
# Epoch 7/300
#  - 3s - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1140 - val_loss: 0.0295 - val_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.1093
# Epoch 8/300
#  - 3s - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1119 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.1062
# Epoch 9/300
#  - 3s - loss: 0.0292 - mean_squared_error: 0.0292 - mean_absolute_error: 0.1102 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - val_mean_absolute_error: 0.1039
# Epoch 10/300
#  - 3s - loss: 0.0287 - mean_squared_error: 0.0287 - mean_absolute_error: 0.1085 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - val_mean_absolute_error: 0.1021
# Epoch 11/300
#  - 3s - loss: 0.0282 - mean_squared_error: 0.0282 - mean_absolute_error: 0.1071 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.1008
# Epoch 12/300
#  - 3s - loss: 0.0276 - mean_squared_error: 0.0276 - mean_absolute_error: 0.1058 - val_loss: 0.0258 - val_mean_squared_error: 0.0258 - val_mean_absolute_error: 0.0987
# Epoch 13/300
#  - 3s - loss: 0.0270 - mean_squared_error: 0.0270 - mean_absolute_error: 0.1045 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.0963
# Epoch 14/300
#  - 3s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1027 - val_loss: 0.0247 - val_mean_squared_error: 0.0247 - val_mean_absolute_error: 0.0946
# Epoch 15/300
#  - 3s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1014 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0940
# Epoch 16/300
#  - 3s - loss: 0.0259 - mean_squared_error: 0.0259 - mean_absolute_error: 0.1006 - val_loss: 0.0244 - val_mean_squared_error: 0.0244 - val_mean_absolute_error: 0.0935
# Epoch 17/300
#  - 3s - loss: 0.0257 - mean_squared_error: 0.0257 - mean_absolute_error: 0.0999 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - val_mean_absolute_error: 0.0929
# Epoch 18/300
#  - 3s - loss: 0.0257 - mean_squared_error: 0.0257 - mean_absolute_error: 0.0997 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.0925
# Epoch 19/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0990 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.0923
# Epoch 20/300
#  - 3s - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.0986 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - val_mean_absolute_error: 0.0922
# Epoch 21/300
#  - 3s - loss: 0.0252 - mean_squared_error: 0.0252 - mean_absolute_error: 0.0982 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - val_mean_absolute_error: 0.0916
# Epoch 22/300
#  - 3s - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.0977 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - val_mean_absolute_error: 0.0916
# Epoch 23/300
#  - 3s - loss: 0.0250 - mean_squared_error: 0.0250 - mean_absolute_error: 0.0975 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - val_mean_absolute_error: 0.0916
# Epoch 24/300
#  - 3s - loss: 0.0249 - mean_squared_error: 0.0249 - mean_absolute_error: 0.0972 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.0915
# Epoch 25/300
#  - 3s - loss: 0.0249 - mean_squared_error: 0.0249 - mean_absolute_error: 0.0970 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.0910
# Epoch 26/300

# %% [markdown]
# ### Timestep (1) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (2) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 2
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)

# %% [markdown]
# ### Timestep (2) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (3) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 3
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)

# %% [markdown]
# ### Timestep (3) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if i % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (Equal to Lag) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = lag
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)

# %% [markdown]
# ### Timestep (Equal to Lag) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()
