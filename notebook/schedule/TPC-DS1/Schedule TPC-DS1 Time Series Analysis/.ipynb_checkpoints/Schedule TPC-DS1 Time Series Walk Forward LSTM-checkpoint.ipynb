# %% [markdown]
# # Walk Foward Evaluation
#
# This section mimics a real-life like approach, where a model is trained on a week worth of data, and then used to predict 7 days worth of predictions.

# %% [markdown]
# ### Module Installation and Importing Libraries
#
# * https://machinelearningmastery.com/setup-python-environment-machine-learning-deep-learning-anaconda/
# * https://vertexai-plaidml.readthedocs-hosted.com/en/latest/installing.html

# %%
# scipy
import scipy as sc
print('scipy: %s' % sc.__version__)
# numpy
import numpy as np
print('numpy: %s' % np.__version__)
# matplotlib
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot
from statsmodels.graphics.tsaplots import plot_acf
# pandas
import pandas as pd
from pandas.plotting import lag_plot
print('pandas: %s' % pd.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn import preprocessing
from sklearn.metrics import r2_score
import sklearn as sk
print('sklearn: %s' % sk.__version__)
# theano
import theano
print('theano: %s' % theano.__version__)
# tensorflow
import tensorflow
print('tensorflow: %s' % tensorflow.__version__)
# plaidml keras
import plaidml.keras
plaidml.keras.install_backend()
# keras
import keras as ke
print('keras: %s' % ke.__version__)
# math
import math
import csv
import os.path
import time
# Out:
# scipy: 1.1.0
# numpy: 1.15.4
# pandas: 0.23.4
# statsmodels: 0.9.0
# sklearn: 0.20.2
# theano: 1.0.3
# tensorflow: 1.11.0
# keras: 2.2.4

# %% [markdown]
# ### Configuration Cell
#
# Tweak parametric changes from this cell to influence outcome of experiment.
# NB: This experiment demonstrates at time  step = 1 (1 minute in advance). Further down in experiment, other timestep results are also featured and evaluated.

# %%
# Experiment Config
tpcds='TPCDS1' # Schema upon which to operate test
lag=12 # Time Series shift / Lag Step. Each lag value equates to 1 minute. Cannot be less than 1
if lag < 1:
    raise ValueError('Lag value must be greater than 1!')
nrows=None
test_split=.5 # Denotes which Data Split to operate under when it comes to training / validation
sub_sample_start=350 # Denotes frist 0..n samples (Used for plotting purposes)
y_label = ['CPU_TIME_DELTA', 'IOWAIT_DELTA']# Denotes which label to use for time series experiments

# Feature Selection
parallel_degree = -1
n_estimators=100

# LSTM Network Structure
epochs=300
batch=64
activation='tanh'
initializer='normal'
dropout=0.4
layer=2
state=False

# %% [markdown]
# ### Read data from file into Pandas Dataframes

# %%
# Root path
#root_dir = 'C:/Users/gabriel.sammut/University/Data_ICS5200/Schedule/' + tpcds
root_dir = 'D:/Projects/Datagenerated_ICS5200/Schedule/' + tpcds

# Open Data
rep_hist_snapshot_path = root_dir + '/rep_hist_snapshot.csv'
rep_hist_sysmetric_summary_path = root_dir + '/rep_hist_sysmetric_summary.csv'
rep_hist_sysstat_path = root_dir + '/rep_hist_sysstat.csv'

rep_hist_snapshot_df = pd.read_csv(rep_hist_snapshot_path, nrows=nrows)
rep_hist_sysmetric_summary_df = pd.read_csv(rep_hist_sysmetric_summary_path, nrows=nrows)
rep_hist_sysstat_df = pd.read_csv(rep_hist_sysstat_path, nrows=nrows)

def prettify_header(headers):
    """
    Cleans header list from unwated character strings
    """
    header_list = []
    [header_list.append(header.replace("(","").replace(")","").replace("'","").replace(",","")) for header in headers]
    return header_list

rep_hist_snapshot_df.columns = prettify_header(rep_hist_snapshot_df.columns.values)
rep_hist_sysmetric_summary_df.columns = prettify_header(rep_hist_sysmetric_summary_df.columns.values)
rep_hist_sysstat_df.columns = prettify_header(rep_hist_sysstat_df.columns.values)

print(rep_hist_snapshot_df.columns.values)
print(rep_hist_sysmetric_summary_df.columns.values)
print(rep_hist_sysstat_df.columns.values)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'SQL_ID' 'PLAN_HASH_VALUE'
#  'OPTIMIZER_COST' 'OPTIMIZER_MODE' 'OPTIMIZER_ENV_HASH_VALUE'
#  'SHARABLE_MEM' 'LOADED_VERSIONS' 'VERSION_COUNT' 'MODULE' 'ACTION'
#  'SQL_PROFILE' 'FORCE_MATCHING_SIGNATURE' 'PARSING_SCHEMA_ID'
#  'PARSING_SCHEMA_NAME' 'PARSING_USER_ID' 'FETCHES_TOTAL' 'FETCHES_DELTA'
#  'END_OF_FETCH_COUNT_TOTAL' 'END_OF_FETCH_COUNT_DELTA' 'SORTS_TOTAL'
#  'SORTS_DELTA' 'EXECUTIONS_TOTAL' 'EXECUTIONS_DELTA'
#  'PX_SERVERS_EXECS_TOTAL' 'PX_SERVERS_EXECS_DELTA' 'LOADS_TOTAL'
#  'LOADS_DELTA' 'INVALIDATIONS_TOTAL' 'INVALIDATIONS_DELTA'
#  'PARSE_CALLS_TOTAL' 'PARSE_CALLS_DELTA' 'DISK_READS_TOTAL'
#  'DISK_READS_DELTA' 'BUFFER_GETS_TOTAL' 'BUFFER_GETS_DELTA'
#  'ROWS_PROCESSED_TOTAL' 'ROWS_PROCESSED_DELTA' 'CPU_TIME_TOTAL'
#  'CPU_TIME_DELTA' 'ELAPSED_TIME_TOTAL' 'ELAPSED_TIME_DELTA' 'IOWAIT_TOTAL'
#  'IOWAIT_DELTA' 'CLWAIT_TOTAL' 'CLWAIT_DELTA' 'APWAIT_TOTAL'
#  'APWAIT_DELTA' 'CCWAIT_TOTAL' 'CCWAIT_DELTA' 'DIRECT_WRITES_TOTAL'
#  'DIRECT_WRITES_DELTA' 'PLSEXEC_TIME_TOTAL' 'PLSEXEC_TIME_DELTA'
#  'JAVEXEC_TIME_TOTAL' 'JAVEXEC_TIME_DELTA' 'IO_OFFLOAD_ELIG_BYTES_TOTAL'
#  'IO_OFFLOAD_ELIG_BYTES_DELTA' 'IO_INTERCONNECT_BYTES_TOTAL'
#  'IO_INTERCONNECT_BYTES_DELTA' 'PHYSICAL_READ_REQUESTS_TOTAL'
#  'PHYSICAL_READ_REQUESTS_DELTA' 'PHYSICAL_READ_BYTES_TOTAL'
#  'PHYSICAL_READ_BYTES_DELTA' 'PHYSICAL_WRITE_REQUESTS_TOTAL'
#  'PHYSICAL_WRITE_REQUESTS_DELTA' 'PHYSICAL_WRITE_BYTES_TOTAL'
#  'PHYSICAL_WRITE_BYTES_DELTA' 'OPTIMIZED_PHYSICAL_READS_TOTAL'
#  'OPTIMIZED_PHYSICAL_READS_DELTA' 'CELL_UNCOMPRESSED_BYTES_TOTAL'
#  'CELL_UNCOMPRESSED_BYTES_DELTA' 'IO_OFFLOAD_RETURN_BYTES_TOTAL'
#  'IO_OFFLOAD_RETURN_BYTES_DELTA' 'BIND_DATA' 'FLAG' 'CON_DBID' 'CON_ID'
#  'SQL_TEXT' 'COMMAND_TYPE' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME'
#  'END_INTERVAL_TIME' 'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT'
#  'SNAP_FLAG' 'SNAP_TIMEZONE']
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'BEGIN_TIME' 'END_TIME' 'INTSIZE'
#  'GROUP_ID' 'METRIC_ID' 'METRIC_NAME' 'METRIC_UNIT' 'NUM_INTERVAL'
#  'MINVAL' 'MAXVAL' 'AVERAGE' 'STANDARD_DEVIATION' 'SUM_SQUARES' 'CON_DBID'
#  'CON_ID' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME' 'END_INTERVAL_TIME'
#  'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT' 'SNAP_FLAG' 'SNAP_TIMEZONE']
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'STAT_ID' 'STAT_NAME' 'VALUE'
#  'CON_DBID' 'CON_ID' 'STARTUP_TIME' 'BEGIN_INTERVAL_TIME'
#  'END_INTERVAL_TIME' 'FLUSH_ELAPSED' 'SNAP_LEVEL' 'ERROR_COUNT'
#  'SNAP_FLAG' 'SNAP_TIMEZONE']

# %% [markdown]
# ### Pivoting Tables and Changing Matrix Shapes
#
# Changes all dataframe shapes to be similar to each other, where in a number of snap_id timestamps are cojoined with instance metrics.

# %%
print('Header Lengths [Before Pivot]')
print('REP_HIST_SNAPSHOT: ' + str(len(rep_hist_snapshot_df.columns)))
print('REP_HIST_SYSMETRIC_SUMMARY: ' + str(len(rep_hist_sysmetric_summary_df.columns)))
print('REP_HIST_SYSSTAT: ' + str(len(rep_hist_sysstat_df.columns)))

# Table REP_HIST_SYSMETRIC_SUMMARY
rep_hist_sysmetric_summary_df = rep_hist_sysmetric_summary_df.pivot(index='SNAP_ID', columns='METRIC_NAME', values='AVERAGE')
rep_hist_sysmetric_summary_df.reset_index(inplace=True)
rep_hist_sysmetric_summary_df[['SNAP_ID']] = rep_hist_sysmetric_summary_df[['SNAP_ID']].astype(int)
#rep_hist_sysmetric_summary_df = rep_hist_sysstat_df.groupby(['SNAP_ID']).sum()
rep_hist_sysmetric_summary_df.reset_index(inplace=True)
rep_hist_sysmetric_summary_df.sort_values(by=['SNAP_ID'],inplace=True,ascending=True)

# Table REP_HIST_SYSSTAT
rep_hist_sysstat_df = rep_hist_sysstat_df.pivot(index='SNAP_ID', columns='STAT_NAME', values='VALUE')
rep_hist_sysstat_df.reset_index(inplace=True)
rep_hist_sysstat_df[['SNAP_ID']] = rep_hist_sysstat_df[['SNAP_ID']].astype(int)
#rep_hist_sysstat_df = rep_hist_sysstat_df.groupby(['SNAP_ID']).sum()
rep_hist_sysstat_df.reset_index(inplace=True)
rep_hist_sysstat_df.sort_values(by=['SNAP_ID'],inplace=True,ascending=True)

rep_hist_sysmetric_summary_df.rename(str.upper, inplace=True, axis='columns')
rep_hist_sysstat_df.rename(str.upper, inplace=True, axis='columns')

# Group By Values by SNAP_ID , sum all metrics (for table REP_HIST_SNAPSHOT)
rep_hist_snapshot_df = rep_hist_snapshot_df.groupby(['SNAP_ID','DBID','INSTANCE_NUMBER']).sum()
rep_hist_snapshot_df.reset_index(inplace=True)

print('\nHeader Lengths [After Pivot]')
print('REP_HIST_SNAPSHOT: ' + str(len(rep_hist_snapshot_df.columns)))
print('REP_HIST_SYSMETRIC_SUMMARY: ' + str(len(rep_hist_sysmetric_summary_df.columns)))
print('REP_HIST_SYSSTAT: ' + str(len(rep_hist_sysstat_df.columns)))

# DF Shape
print('\nDataframe shapes:\nTable [REP_HIST_SNAPSHOT] - ' + str(rep_hist_snapshot_df.shape))
print('Table [REP_HIST_SYSMETRIC_SUMMARY] - ' + str(rep_hist_sysmetric_summary_df.shape))
print('Table [REP_HIST_SYSSTAT] - ' + str(rep_hist_sysstat_df.shape) + '\n')

print(rep_hist_snapshot_df.columns.values)
print(rep_hist_sysmetric_summary_df.columns.values)
print(rep_hist_sysstat_df.columns.values)
print(rep_hist_snapshot_df.shape)
print(rep_hist_sysmetric_summary_df.shape)
print(rep_hist_sysstat_df.shape)
# Out:
# Header Lengths [Before Pivot]
# REP_HIST_SNAPSHOT: 90
# REP_HIST_SYSMETRIC_SUMMARY: 26
# REP_HIST_SYSSTAT: 16
#
# Header Lengths [After Pivot]
# REP_HIST_SNAPSHOT: 77
# REP_HIST_SYSMETRIC_SUMMARY: 163
# REP_HIST_SYSSTAT: 1180
#
# Dataframe shapes:
# Table [REP_HIST_SNAPSHOT] - (19831, 77)
# Table [REP_HIST_SYSMETRIC_SUMMARY] - (19831, 163)
# Table [REP_HIST_SYSSTAT] - (19831, 1180)
#
# ['SNAP_ID' 'DBID' 'INSTANCE_NUMBER' 'PLAN_HASH_VALUE' 'OPTIMIZER_COST'
#  'OPTIMIZER_ENV_HASH_VALUE' 'SHARABLE_MEM' 'LOADED_VERSIONS'
#  'VERSION_COUNT' 'SQL_PROFILE' 'PARSING_SCHEMA_ID' 'PARSING_USER_ID'
#  'FETCHES_TOTAL' 'FETCHES_DELTA' 'END_OF_FETCH_COUNT_TOTAL'
#  'END_OF_FETCH_COUNT_DELTA' 'SORTS_TOTAL' 'SORTS_DELTA' 'EXECUTIONS_TOTAL'
#  'EXECUTIONS_DELTA' 'PX_SERVERS_EXECS_TOTAL' 'PX_SERVERS_EXECS_DELTA'
#  'LOADS_TOTAL' 'LOADS_DELTA' 'INVALIDATIONS_TOTAL' 'INVALIDATIONS_DELTA'
#  'PARSE_CALLS_TOTAL' 'PARSE_CALLS_DELTA' 'DISK_READS_TOTAL'
#  'DISK_READS_DELTA' 'BUFFER_GETS_TOTAL' 'BUFFER_GETS_DELTA'
#  'ROWS_PROCESSED_TOTAL' 'ROWS_PROCESSED_DELTA' 'CPU_TIME_TOTAL'
#  'CPU_TIME_DELTA' 'ELAPSED_TIME_TOTAL' 'ELAPSED_TIME_DELTA' 'IOWAIT_TOTAL'
#  'IOWAIT_DELTA' 'CLWAIT_TOTAL' 'CLWAIT_DELTA' 'APWAIT_TOTAL'
#  'APWAIT_DELTA' 'CCWAIT_TOTAL' 'CCWAIT_DELTA' 'DIRECT_WRITES_TOTAL'
#  'DIRECT_WRITES_DELTA' 'PLSEXEC_TIME_TOTAL' 'PLSEXEC_TIME_DELTA'
#  'JAVEXEC_TIME_TOTAL' 'JAVEXEC_TIME_DELTA' 'IO_OFFLOAD_ELIG_BYTES_TOTAL'
#  'IO_OFFLOAD_ELIG_BYTES_DELTA' 'IO_INTERCONNECT_BYTES_TOTAL'
#  'IO_INTERCONNECT_BYTES_DELTA' 'PHYSICAL_READ_REQUESTS_TOTAL'
#  'PHYSICAL_READ_REQUESTS_DELTA' 'PHYSICAL_READ_BYTES_TOTAL'
#  'PHYSICAL_READ_BYTES_DELTA' 'PHYSICAL_WRITE_REQUESTS_TOTAL'
#  'PHYSICAL_WRITE_REQUESTS_DELTA' 'PHYSICAL_WRITE_BYTES_TOTAL'
#  'PHYSICAL_WRITE_BYTES_DELTA' 'OPTIMIZED_PHYSICAL_READS_TOTAL'
#  'OPTIMIZED_PHYSICAL_READS_DELTA' 'CELL_UNCOMPRESSED_BYTES_TOTAL'
#  'CELL_UNCOMPRESSED_BYTES_DELTA' 'IO_OFFLOAD_RETURN_BYTES_TOTAL'
#  'IO_OFFLOAD_RETURN_BYTES_DELTA' 'FLAG' 'CON_DBID' 'CON_ID' 'COMMAND_TYPE'
#  'SNAP_LEVEL' 'ERROR_COUNT' 'SNAP_FLAG']
# ['INDEX' 'SNAP_ID' 'ACTIVE PARALLEL SESSIONS' 'ACTIVE SERIAL SESSIONS'
#  'AVERAGE ACTIVE SESSIONS' 'AVERAGE SYNCHRONOUS SINGLE-BLOCK READ LATENCY'
#  'BACKGROUND CPU USAGE PER SEC' 'BACKGROUND CHECKPOINTS PER SEC'
#  'BACKGROUND TIME PER SEC' 'BRANCH NODE SPLITS PER SEC'
#  'BRANCH NODE SPLITS PER TXN' 'BUFFER CACHE HIT RATIO' 'CPU USAGE PER SEC'
#  'CPU USAGE PER TXN' 'CR BLOCKS CREATED PER SEC'
#  'CR BLOCKS CREATED PER TXN' 'CR UNDO RECORDS APPLIED PER SEC'
#  'CR UNDO RECORDS APPLIED PER TXN' 'CAPTURED USER CALLS'
#  'CELL PHYSICAL IO INTERCONNECT BYTES' 'CONSISTENT READ CHANGES PER SEC'
#  'CONSISTENT READ CHANGES PER TXN' 'CONSISTENT READ GETS PER SEC'
#  'CONSISTENT READ GETS PER TXN' 'CURRENT LOGONS COUNT' 'CURRENT OS LOAD'
#  'CURRENT OPEN CURSORS COUNT' 'CURSOR CACHE HIT RATIO'
#  'DB BLOCK CHANGES PER SEC' 'DB BLOCK CHANGES PER TXN'
#  'DB BLOCK CHANGES PER USER CALL' 'DB BLOCK GETS PER SEC'
#  'DB BLOCK GETS PER TXN' 'DB BLOCK GETS PER USER CALL'
#  'DBWR CHECKPOINTS PER SEC' 'DDL STATEMENTS PARALLELIZED PER SEC'
#  'DML STATEMENTS PARALLELIZED PER SEC' 'DATABASE CPU TIME RATIO'
#  'DATABASE TIME PER SEC' 'DATABASE WAIT TIME RATIO' 'DISK SORT PER SEC'
#  'DISK SORT PER TXN' 'ENQUEUE DEADLOCKS PER SEC'
#  'ENQUEUE DEADLOCKS PER TXN' 'ENQUEUE REQUESTS PER SEC'
#  'ENQUEUE REQUESTS PER TXN' 'ENQUEUE TIMEOUTS PER SEC'
#  'ENQUEUE TIMEOUTS PER TXN' 'ENQUEUE WAITS PER SEC'
#  'ENQUEUE WAITS PER TXN' 'EXECUTE WITHOUT PARSE RATIO'
#  'EXECUTIONS PER SEC' 'EXECUTIONS PER TXN' 'EXECUTIONS PER USER CALL'
#  'FULL INDEX SCANS PER SEC' 'FULL INDEX SCANS PER TXN'
#  'GC CR BLOCK RECEIVED PER SECOND' 'GC CR BLOCK RECEIVED PER TXN'
#  'GC CURRENT BLOCK RECEIVED PER SECOND'
#  'GC CURRENT BLOCK RECEIVED PER TXN' 'GLOBAL CACHE AVERAGE CR GET TIME'
#  'GLOBAL CACHE AVERAGE CURRENT GET TIME' 'GLOBAL CACHE BLOCKS CORRUPTED'
#  'GLOBAL CACHE BLOCKS LOST' 'HARD PARSE COUNT PER SEC'
#  'HARD PARSE COUNT PER TXN' 'HOST CPU USAGE PER SEC'
#  'HOST CPU UTILIZATION (%)' 'I/O MEGABYTES PER SECOND'
#  'I/O REQUESTS PER SECOND' 'LEAF NODE SPLITS PER SEC'
#  'LEAF NODE SPLITS PER TXN' 'LIBRARY CACHE HIT RATIO'
#  'LIBRARY CACHE MISS RATIO' 'LOGICAL READS PER SEC'
#  'LOGICAL READS PER TXN' 'LOGICAL READS PER USER CALL' 'LOGONS PER SEC'
#  'LOGONS PER TXN' 'LONG TABLE SCANS PER SEC' 'LONG TABLE SCANS PER TXN'
#  'MEMORY SORTS RATIO' 'NETWORK TRAFFIC VOLUME PER SEC'
#  'OPEN CURSORS PER SEC' 'OPEN CURSORS PER TXN' 'PGA CACHE HIT %'
#  'PQ QC SESSION COUNT' 'PQ SLAVE SESSION COUNT'
#  'PX DOWNGRADED 1 TO 25% PER SEC' 'PX DOWNGRADED 25 TO 50% PER SEC'
#  'PX DOWNGRADED 50 TO 75% PER SEC' 'PX DOWNGRADED 75 TO 99% PER SEC'
#  'PX DOWNGRADED TO SERIAL PER SEC' 'PX OPERATIONS NOT DOWNGRADED PER SEC'
#  'PARSE FAILURE COUNT PER SEC' 'PARSE FAILURE COUNT PER TXN'
#  'PHYSICAL READ BYTES PER SEC' 'PHYSICAL READ IO REQUESTS PER SEC'
#  'PHYSICAL READ TOTAL BYTES PER SEC'
#  'PHYSICAL READ TOTAL IO REQUESTS PER SEC'
#  'PHYSICAL READS DIRECT LOBS PER SEC' 'PHYSICAL READS DIRECT LOBS PER TXN'
#  'PHYSICAL READS DIRECT PER SEC' 'PHYSICAL READS DIRECT PER TXN'
#  'PHYSICAL READS PER SEC' 'PHYSICAL READS PER TXN'
#  'PHYSICAL WRITE BYTES PER SEC' 'PHYSICAL WRITE IO REQUESTS PER SEC'
#  'PHYSICAL WRITE TOTAL BYTES PER SEC'
#  'PHYSICAL WRITE TOTAL IO REQUESTS PER SEC'
#  'PHYSICAL WRITES DIRECT LOBS  PER TXN'
#  'PHYSICAL WRITES DIRECT LOBS PER SEC' 'PHYSICAL WRITES DIRECT PER SEC'
#  'PHYSICAL WRITES DIRECT PER TXN' 'PHYSICAL WRITES PER SEC'
#  'PHYSICAL WRITES PER TXN' 'PROCESS LIMIT %'
#  'QUERIES PARALLELIZED PER SEC' 'RECURSIVE CALLS PER SEC'
#  'RECURSIVE CALLS PER TXN' 'REDO ALLOCATION HIT RATIO'
#  'REDO GENERATED PER SEC' 'REDO GENERATED PER TXN' 'REDO WRITES PER SEC'
#  'REDO WRITES PER TXN' 'REPLAYED USER CALLS' 'RESPONSE TIME PER TXN'
#  'ROW CACHE HIT RATIO' 'ROW CACHE MISS RATIO' 'ROWS PER SORT'
#  'RUN QUEUE PER SEC' 'SQL SERVICE RESPONSE TIME' 'SESSION COUNT'
#  'SESSION LIMIT %' 'SHARED POOL FREE %' 'SOFT PARSE RATIO'
#  'STREAMS POOL USAGE PERCENTAGE' 'TEMP SPACE USED'
#  'TOTAL INDEX SCANS PER SEC' 'TOTAL INDEX SCANS PER TXN'
#  'TOTAL PGA ALLOCATED' 'TOTAL PGA USED BY SQL WORKAREAS'
#  'TOTAL PARSE COUNT PER SEC' 'TOTAL PARSE COUNT PER TXN'
#  'TOTAL SORTS PER USER CALL' 'TOTAL TABLE SCANS PER SEC'
#  'TOTAL TABLE SCANS PER TXN' 'TOTAL TABLE SCANS PER USER CALL'
#  'TXNS PER LOGON' 'USER CALLS PER SEC' 'USER CALLS PER TXN'
#  'USER CALLS RATIO' 'USER COMMITS PER SEC' 'USER COMMITS PERCENTAGE'
#  'USER LIMIT %' 'USER ROLLBACK UNDO RECORDS APPLIED PER TXN'
#  'USER ROLLBACK UNDOREC APPLIED PER SEC' 'USER ROLLBACKS PER SEC'
#  'USER ROLLBACKS PERCENTAGE' 'USER TRANSACTION PER SEC'
#  'VM IN BYTES PER SEC' 'VM OUT BYTES PER SEC'
#  'WORKLOAD CAPTURE AND REPLAY STATUS']
# ['INDEX' 'SNAP_ID' 'ADG GLOBAL FLUSH' ...
#  'WRITE CLONES CREATED FOR RECOVERY' 'WRITE CLONES CREATED IN BACKGROUND'
#  'WRITE CLONES CREATED IN FOREGROUND']
# (19831, 77)
# (19831, 163)
# (19831, 1180)

# %% [markdown]
# ### Dealing with Empty Values

# %%
def get_na_columns(df, headers):
    """
    Return columns which consist of NAN values
    """
    na_list = []
    for head in headers:
        if df[head].isnull().values.any():
            na_list.append(head)
    return na_list

print('N/A Columns\n')
print('\n REP_HIST_SNAPSHOT Features ' + str(len(rep_hist_snapshot_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_snapshot_df,headers=rep_hist_snapshot_df.columns)) + "\n")
print('REP_HIST_SYSMETRIC_SUMMARY Features ' + str(len(rep_hist_sysmetric_summary_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_sysmetric_summary_df,headers=rep_hist_sysmetric_summary_df.columns)) + "\n")
print('REP_HIST_SYSSTAT Features ' + str(len(rep_hist_sysstat_df.columns)) + ': ' + str(get_na_columns(df=rep_hist_sysstat_df,headers=rep_hist_sysstat_df.columns)) + "\n")

def fill_na(df):
    """
    Replaces NA columns with 0s
    """
    return df.fillna(0)

# Populating NaN values with amount '0'
rep_hist_snapshot_df.fillna(0, inplace=True)
rep_hist_sysmetric_summary_df.fillna(0, inplace=True)
rep_hist_sysstat_df.fillna(0, inplace=True)
# Out:
# N/A Columns
#
#
#  REP_HIST_SNAPSHOT Features 77: []
#
# REP_HIST_SYSMETRIC_SUMMARY Features 163: ['ACTIVE PARALLEL SESSIONS', 'ACTIVE SERIAL SESSIONS', 'AVERAGE ACTIVE SESSIONS', 'AVERAGE SYNCHRONOUS SINGLE-BLOCK READ LATENCY', 'BACKGROUND CPU USAGE PER SEC', 'BACKGROUND TIME PER SEC', 'CAPTURED USER CALLS', 'CELL PHYSICAL IO INTERCONNECT BYTES', 'HOST CPU USAGE PER SEC', 'I/O MEGABYTES PER SECOND', 'I/O REQUESTS PER SECOND', 'PX OPERATIONS NOT DOWNGRADED PER SEC', 'REPLAYED USER CALLS', 'RUN QUEUE PER SEC', 'SESSION COUNT', 'TEMP SPACE USED', 'TOTAL PGA ALLOCATED', 'TOTAL PGA USED BY SQL WORKAREAS', 'VM IN BYTES PER SEC', 'VM OUT BYTES PER SEC', 'WORKLOAD CAPTURE AND REPLAY STATUS']
#
# REP_HIST_SYSSTAT Features 1180: ['BA SPARE STATISTIC 9', 'CLI FLSTASK CREATE', 'EHCC COMPRESSED LENGTH COMPRESSED', 'EFFECTIVE IO TIME', 'FORWARDED 2PC COMMANDS ACROSS RAC NODES', 'IM POPULATE (FASTSTART) CUS READ ATTEMPTS', 'IM POPULATE CUS MEMCOMPRESS FOR CAPACITY LOW', 'IM REPOPULATE (TRICKLE) CUS MEMCOMPRESS FOR QUERY LOW', 'IM REPOPULATE (TRICKLE) CUS REQUESTED', 'IM SCAN ROWS JOURNAL', 'IM SCAN ROWS PROJECTED', 'IM SPACE SMU BYTES ALLOCATED', 'IM SPACE SMU CREATIONS COMMITTED', 'IM SPACE PRIVATE JOURNAL EXTENTS ALLOCATED', 'IPC CPU USED BY THIS SESSION', 'PARALLEL OPERATIONS DOWNGRADED TO SERIAL', 'WORKLOAD REPLAY: THINK TIME', 'BACKUP DATA COMPRESSED REMOTELY', 'CALLS TO KCMGRS', 'CELL CUS SENT UNCOMPRESSED', 'CONSISTENT GETS', 'DATA WAREHOUSING SCANNED BLOCKS', 'FLASH CACHE INSERT SKIP: MODIFICATION', 'KA LOCAL MESSAGE WAITS', 'KA MESSAGES SENT', 'LOB WRITES UNALIGNED', 'PHYSICAL READS CACHE', 'REDO SYNCH TIME', 'REDO WRITE SIZE COUNT (   4KB)', 'REDO WRITE SIZE COUNT (INF)', 'SESSION PGA MEMORY', 'TRACKED TRANSACTIONS', 'WRITE CLONES CREATED IN FOREGROUND']

# %% [markdown]
# ### Merging Frames
#
# This part merges the following pandas data frame into a single frame:
# * REP_HIST_SNAPSHOT
# * REP_HIST_SYSMETRIC_SUMMARY
# * REP_HIST_SYSSTAT

# %%
print
df = pd.merge(rep_hist_snapshot_df, rep_hist_sysmetric_summary_df,how='inner',on ='SNAP_ID')
df = pd.merge(df, rep_hist_sysstat_df,how='inner',on ='SNAP_ID')
print(df.shape)
print('----------------------------------')
print(df.columns.tolist())
# Out:
# (19831, 1418)
# ----------------------------------
# ['SNAP_ID', 'DBID', 'INSTANCE_NUMBER', 'PLAN_HASH_VALUE', 'OPTIMIZER_COST', 'OPTIMIZER_ENV_HASH_VALUE', 'SHARABLE_MEM', 'LOADED_VERSIONS', 'VERSION_COUNT', 'SQL_PROFILE', 'PARSING_SCHEMA_ID', 'PARSING_USER_ID', 'FETCHES_TOTAL', 'FETCHES_DELTA', 'END_OF_FETCH_COUNT_TOTAL', 'END_OF_FETCH_COUNT_DELTA', 'SORTS_TOTAL', 'SORTS_DELTA', 'EXECUTIONS_TOTAL', 'EXECUTIONS_DELTA', 'PX_SERVERS_EXECS_TOTAL', 'PX_SERVERS_EXECS_DELTA', 'LOADS_TOTAL', 'LOADS_DELTA', 'INVALIDATIONS_TOTAL', 'INVALIDATIONS_DELTA', 'PARSE_CALLS_TOTAL', 'PARSE_CALLS_DELTA', 'DISK_READS_TOTAL', 'DISK_READS_DELTA', 'BUFFER_GETS_TOTAL', 'BUFFER_GETS_DELTA', 'ROWS_PROCESSED_TOTAL', 'ROWS_PROCESSED_DELTA', 'CPU_TIME_TOTAL', 'CPU_TIME_DELTA', 'ELAPSED_TIME_TOTAL', 'ELAPSED_TIME_DELTA', 'IOWAIT_TOTAL', 'IOWAIT_DELTA', 'CLWAIT_TOTAL', 'CLWAIT_DELTA', 'APWAIT_TOTAL', 'APWAIT_DELTA', 'CCWAIT_TOTAL', 'CCWAIT_DELTA', 'DIRECT_WRITES_TOTAL', 'DIRECT_WRITES_DELTA', 'PLSEXEC_TIME_TOTAL', 'PLSEXEC_TIME_DELTA', 'JAVEXEC_TIME_TOTAL', 'JAVEXEC_TIME_DELTA', 'IO_OFFLOAD_ELIG_BYTES_TOTAL', 'IO_OFFLOAD_ELIG_BYTES_DELTA', 'IO_INTERCONNECT_BYTES_TOTAL', 'IO_INTERCONNECT_BYTES_DELTA', 'PHYSICAL_READ_REQUESTS_TOTAL', 'PHYSICAL_READ_REQUESTS_DELTA', 'PHYSICAL_READ_BYTES_TOTAL', 'PHYSICAL_READ_BYTES_DELTA', 'PHYSICAL_WRITE_REQUESTS_TOTAL', 'PHYSICAL_WRITE_REQUESTS_DELTA', 'PHYSICAL_WRITE_BYTES_TOTAL', 'PHYSICAL_WRITE_BYTES_DELTA', 'OPTIMIZED_PHYSICAL_READS_TOTAL', 'OPTIMIZED_PHYSICAL_READS_DELTA', 'CELL_UNCOMPRESSED_BYTES_TOTAL', 'CELL_UNCOMPRESSED_BYTES_DELTA', 'IO_OFFLOAD_RETURN_BYTES_TOTAL', 'IO_OFFLOAD_RETURN_BYTES_DELTA', 'FLAG', 'CON_DBID', 'CON_ID', 'COMMAND_TYPE', 'SNAP_LEVEL', 'ERROR_COUNT', 'SNAP_FLAG', 'INDEX_x', 'ACTIVE PARALLEL SESSIONS', 'ACTIVE SERIAL SESSIONS', 'AVERAGE ACTIVE SESSIONS', 'AVERAGE SYNCHRONOUS SINGLE-BLOCK READ LATENCY', 'BACKGROUND CPU USAGE PER SEC', 'BACKGROUND CHECKPOINTS PER SEC', 'BACKGROUND TIME PER SEC', 'BRANCH NODE SPLITS PER SEC', 'BRANCH NODE SPLITS PER TXN', 'BUFFER CACHE HIT RATIO', 'CPU USAGE PER SEC', 'CPU USAGE PER TXN', 'CR BLOCKS CREATED PER SEC', 'CR BLOCKS CREATED PER TXN', 'CR UNDO RECORDS APPLIED PER SEC', 'CR UNDO RECORDS APPLIED PER TXN', 'CAPTURED USER CALLS', 'CELL PHYSICAL IO INTERCONNECT BYTES_x', 'CONSISTENT READ CHANGES PER SEC', 'CONSISTENT READ CHANGES PER TXN', 'CONSISTENT READ GETS PER SEC', 'CONSISTENT READ GETS PER TXN', 'CURRENT LOGONS COUNT', 'CURRENT OS LOAD', 'CURRENT OPEN CURSORS COUNT', 'CURSOR CACHE HIT RATIO', 'DB BLOCK CHANGES PER SEC', 'DB BLOCK CHANGES PER TXN', 'DB BLOCK CHANGES PER USER CALL', 'DB BLOCK GETS PER SEC', 'DB BLOCK GETS PER TXN', 'DB BLOCK GETS PER USER CALL', 'DBWR CHECKPOINTS PER SEC', 'DDL STATEMENTS PARALLELIZED PER SEC', 'DML STATEMENTS PARALLELIZED PER SEC', 'DATABASE CPU TIME RATIO', 'DATABASE TIME PER SEC', 'DATABASE WAIT TIME RATIO', 'DISK SORT PER SEC', 'DISK SORT PER TXN', 'ENQUEUE DEADLOCKS PER SEC', 'ENQUEUE DEADLOCKS PER TXN', 'ENQUEUE REQUESTS PER SEC', 'ENQUEUE REQUESTS PER TXN', 'ENQUEUE TIMEOUTS PER SEC', 'ENQUEUE TIMEOUTS PER TXN', 'ENQUEUE WAITS PER SEC', 'ENQUEUE WAITS PER TXN', 'EXECUTE WITHOUT PARSE RATIO', 'EXECUTIONS PER SEC', 'EXECUTIONS PER TXN', 'EXECUTIONS PER USER CALL', 'FULL INDEX SCANS PER SEC', 'FULL INDEX SCANS PER TXN', 'GC CR BLOCK RECEIVED PER SECOND', 'GC CR BLOCK RECEIVED PER TXN', 'GC CURRENT BLOCK RECEIVED PER SECOND', 'GC CURRENT BLOCK RECEIVED PER TXN', 'GLOBAL CACHE AVERAGE CR GET TIME', 'GLOBAL CACHE AVERAGE CURRENT GET TIME', 'GLOBAL CACHE BLOCKS CORRUPTED', 'GLOBAL CACHE BLOCKS LOST', 'HARD PARSE COUNT PER SEC', 'HARD PARSE COUNT PER TXN', 'HOST CPU USAGE PER SEC', 'HOST CPU UTILIZATION (%)', 'I/O MEGABYTES PER SECOND', 'I/O REQUESTS PER SECOND', 'LEAF NODE SPLITS PER SEC', 'LEAF NODE SPLITS PER TXN', 'LIBRARY CACHE HIT RATIO', 'LIBRARY CACHE MISS RATIO', 'LOGICAL READS PER SEC', 'LOGICAL READS PER TXN', 'LOGICAL READS PER USER CALL', 'LOGONS PER SEC', 'LOGONS PER TXN', 'LONG TABLE SCANS PER SEC', 'LONG TABLE SCANS PER TXN', 'MEMORY SORTS RATIO', 'NETWORK  ...

# %% [markdown]
# ### Data Ordering
#
# Sorting of datasets in order of SNAP_ID.

# %%
df.sort_values(by=['SNAP_ID'], ascending=True, inplace=True)
print(df.shape)
# Out:
# (19831, 1418)

# %% [markdown]
# ### Floating point precision conversion
#
# Each column is converted into a column of type values which are floating point for higher precision.

# %%
df.astype('float32', inplace=True)
df = np.round(df, 3) # rounds to 3 dp
print(df.shape)
# Out:
# (19831, 1418)

# %% [markdown]
# ### Redundant Feature Removal
#
# In this step, redundant features are dropped. Features are considered redundant if exhibit a standard devaition of 0 (meaning no change in value).

# %%
def drop_flatline_columns(df):
    columns = df.columns
    flatline_features = []
    for i in range(len(columns)):
        try:
            std = df[columns[i]].std()
            if std == 0:
                flatline_features.append(columns[i])
        except:
            pass
    
    print('\nShape before changes: [' + str(df.shape) + ']')
    df = df.drop(columns=flatline_features)
    print('Shape after changes: [' + str(df.shape) + ']')
    print('Dropped a total [' + str(len(flatline_features)) + ']')
    return df

print('Before column drop:')
print(df.shape)
df = drop_flatline_columns(df=df)
print('\nAfter flatline column drop:')
print(df.shape)
dropped_columns_df = [ 'PLAN_HASH_VALUE',
                       'OPTIMIZER_ENV_HASH_VALUE',
                       'LOADED_VERSIONS',
                       'VERSION_COUNT',
                       'PARSING_SCHEMA_ID',
                       'PARSING_USER_ID',
                       'CON_DBID',
                       'SNAP_LEVEL',
                       'SNAP_FLAG',
                       'COMMAND_TYPE']
df.drop(columns=dropped_columns_df, inplace=True)
print('\nAfter additional column drop:')
print(df.shape)
# Out:
# Before column drop:
# (19831, 1418)
#
# Shape before changes: [(19831, 1418)]
# Shape after changes: [(19831, 521)]
# Dropped a total [897]
#
# After flatline column drop:
# (19831, 521)
#
# After additional column drop:
# (19831, 511)

# %% [markdown]
# ### Outlier Detection - Standard Deviation Method
#
# Detection and transformation of outliers, categorized as more than 3 standard deviations away.
#
# If we know that the distribution of values in the sample is Gaussian or Gaussian-like, we can use the standard deviation of the sample as a cut-off for identifying outliers.
#
# The Gaussian distribution has the property that the standard deviation from the mean can be used to reliably summarize the percentage of values in the sample.
#
# For example, within one standard deviation of the mean will cover 68% of the data.
#
# So, if the mean is 50 and the standard deviation is 5, as in the test dataset above, then all data in the sample between 45 and 55 will account for about 68% of the data sample. We can cover more of the data sample if we expand the range as follows:
#
# * 1 Standard Deviation from the Mean: 68%
# * 2 Standard Deviations from the Mean: 95%
# * 3 Standard Deviations from the Mean: 99.7%
#
# A value that falls outside of 3 standard deviations is part of the distribution, but it is an unlikely or rare event at approximately 1 in 370 samples.
#
# Three standard deviations from the mean is a common cut-off in practice for identifying outliers in a Gaussian or Gaussian-like distribution. For smaller samples of data, perhaps a value of 2 standard deviations (95%) can be used, and for larger samples, perhaps a value of 4 standard deviations (99.9%) can be used.
#
# More infor here: https://machinelearningmastery.com/how-to-use-statistics-to-identify-outliers-in-data/

# %%
def detect_and_transform_outliers_zscore(df, threshold=3):
    """
    Iterates over input dataframe and transforms outliers (greater then 3 std threshold) into mean value
    
    :param: (Pandas 2D Matrix) Input dataframe
    :param: (Integer) Input standard deviation threshold - 3 equates to the .99% threshold
    """
    for col in df.columns:
        mean = np.mean(df[col])
        std = np.std(df[col])
        
        counter = 0
        for val in df[col]:
            z_score = (val - mean) / std
            if np.abs(z_score) > threshold:
                df[col].iloc[counter] = mean
                print('Outlier detected for column [' + col + '] at location [' + str(counter) + '] with value [' + str(val) + ']')
            counter += 1
                
    return df

def detect_and_transform_outliers_iqr(df):
    """
    Iterates over input dataframe and transforms outliers (greater then 3 std threshold) into mean value
    
    :param: (Pandas 2D Matrix) Input dataframe
    :param: (Integer) Input standard deviation threshold - 3 equates to the .99% threshold
    """
    for col in df.columns:
        quartile_1, quartile_3 = np.percentile(df.values, [25, 75])
        iqr = quartile_3 - quartile_1
        lower_bound = quartile_1 - (iqr * 1.5)
        upper_bound = quartile_3 + (iqr * 1.5)
        
        counter = 0
        for val in df[col]:
            if (val > upper_bound) or (val < lower_bound):
                df[col].iloc[counter] = lower_bound
                print('Outlier detected for column [' + col + '] at location [' + str(counter) + '] with value [' + str(val) + ']')
            counter += 1
                
    return df

df[[y_label[0]]] = detect_and_transform_outliers_zscore(df=df[[y_label[0]]])
df[[y_label[1]]] = detect_and_transform_outliers_iqr(df=df[[y_label[1]]])

for label in y_label:
    
    df.plot.scatter(x='SNAP_ID',
                    y=label,
                    c='DarkBlue')
    plt.title(label + " over time (SNAP_ID)")
    plt.show()
    
    df[label].hist(bins=10)
    plt.title(label + ' value distribution')
    plt.show()
    
    qqplot(df[label], line='s')
    plt.show()
    
    df[label].plot.line()
    plt.title(label + ' over time')
    plt.show()
    print('---------------------------------------------------------------')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Outlier detected for column [IOWAIT_DELTA] at location [0] with value [30637665.0]
# Outlier detected for column [IOWAIT_DELTA] at location [7] with value [45906216.0]
# Outlier detected for column [IOWAIT_DELTA] at location [8] with value [54738912.0]
# Outlier detected for column [IOWAIT_DELTA] at location [9] with value [38384072.0]
# Outlier detected for column [IOWAIT_DELTA] at location [15] with value [23097556.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19] with value [25811806.0]
# Outlier detected for column [IOWAIT_DELTA] at location [20] with value [54155590.0]
# Outlier detected for column [IOWAIT_DELTA] at location [21] with value [45285285.0]
# Outlier detected for column [IOWAIT_DELTA] at location [27] with value [26206268.0]
# Outlier detected for column [IOWAIT_DELTA] at location [28] with value [23831069.0]
# Outlier detected for column [IOWAIT_DELTA] at location [32] with value [54160781.0]
# Outlier detected for column [IOWAIT_DELTA] at location [33] with value [45329000.0]
# Outlier detected for column [IOWAIT_DELTA] at location [39] with value [24740853.0]
# Outlier detected for column [IOWAIT_DELTA] at location [40] with value [27650721.0]
# Outlier detected for column [IOWAIT_DELTA] at location [44] with value [45636547.0]
# Outlier detected for column [IOWAIT_DELTA] at location [45] with value [48079360.0]
# Outlier detected for column [IOWAIT_DELTA] at location [46] with value [28525100.0]
# Outlier detected for column [IOWAIT_DELTA] at location [52] with value [27353744.0]
# Outlier detected for column [IOWAIT_DELTA] at location [56] with value [36417586.0]
# Outlier detected for column [IOWAIT_DELTA] at location [57] with value [58425620.0]
# Outlier detected for column [IOWAIT_DELTA] at location [58] with value [49882228.0]
# Outlier detected for column [IOWAIT_DELTA] at location [65] with value [25061816.0]
# Outlier detected for column [IOWAIT_DELTA] at location [69] with value [27033749.0]
# Outlier detected for column [IOWAIT_DELTA] at location [70] with value [56309175.0]
# Outlier detected for column [IOWAIT_DELTA] at location [71] with value [49417064.0]
# Outlier detected for column [IOWAIT_DELTA] at location [77] with value [26105382.0]
# Outlier detected for column [IOWAIT_DELTA] at location [78] with value [24272449.0]
# Outlier detected for column [IOWAIT_DELTA] at location [82] with value [55378450.0]
# Outlier detected for column [IOWAIT_DELTA] at location [83] with value [45910281.0]
# Outlier detected for column [IOWAIT_DELTA] at location [90] with value [27617917.0]
# Outlier detected for column [IOWAIT_DELTA] at location [94] with value [51281943.0]
# Outlier detected for column [IOWAIT_DELTA] at location [95] with value [54127789.0]
# Outlier detected for column [IOWAIT_DELTA] at location [96] with value [35513094.0]
# Outlier detected for column [IOWAIT_DELTA] at location [102] with value [31558327.0]
# Outlier detected for column [IOWAIT_DELTA] at location [103] with value [24908746.0]
# Outlier detected for column [IOWAIT_DELTA] at location [106] with value [27720614.0]
# Outlier detected for column [IOWAIT_DELTA] at location [107] with value [56869697.0]
# Outlier detected for column [IOWAIT_DELTA] at location [108] with value [47334678.0]
# Outlier detected for column [IOWAIT_DELTA] at location [114] with value [26895846.0]
# Outlier detected for column [IOWAIT_DELTA] at location [115] with value [23332255.0]
# Outlier detected for column [IOWAIT_DELTA] at location [119] with value [59386611.0]
# Outlier detected for column [IOWAIT_DELTA] at location [120] with value [47067587.0]
# Outlier detected for column [IOWAIT_DELTA] at location [126] with value [24159658.0]
# Outlier detected for column [IOWAIT_DELTA] at location [127] with value [24268654.0]
# Outlier detected for column [IOWAIT_DELTA] at location [131] with value [58276309.0]
# Outlier detected for column [IOWAIT_DELTA] at location [132] with value [49852747.0]
# Outlier detected for column [IOWAIT_DELTA] at location [133] with value [33195966.0]
# Outlier detected for column [IOWAIT_DELTA] at location [139] with value [28307179.0]
# Outlier detected for column [IOWAIT_DELTA] at location [143] with value [41709135.0]
# Outlier detected for column [IOWAIT_DELTA] at location [144] with value [58565041.0]
# Outlier detected for column [IOWAIT_DELTA] at location [145] with value [47620267.0]
# Outlier detected for column [IOWAIT_DELTA] at location [151] with value [30236797.0]
# Outlier detected for column [IOWAIT_DELTA] at location [152] with value [25280686.0]
# Outlier detected for column [IOWAIT_DELTA] at location [156] with value [51997979.0]
# Outlier detected for column [IOWAIT_DELTA] at location [157] with value [46472110.0]
# Outlier detected for column [IOWAIT_DELTA] at location [163] with value [25880832.0]
# Outlier detected for column [IOWAIT_DELTA] at location [164] with value [24065677.0]
# Outlier detected for column [IOWAIT_DELTA] at location [168] with value [47236107.0]
# Outlier detected for column [IOWAIT_DELTA] at location [169] with value [42400805.0]
# Outlier detected for column [IOWAIT_DELTA] at location [175] with value [27998403.0]
# Outlier detected for column [IOWAIT_DELTA] at location [176] with value [28945110.0]
# Outlier detected for column [IOWAIT_DELTA] at location [180] with value [43333207.0]
# Outlier detected for column [IOWAIT_DELTA] at location [181] with value [47481288.0]
# Outlier detected for column [IOWAIT_DELTA] at location [182] with value [27231988.0]
# Outlier detected for column [IOWAIT_DELTA] at location [188] with value [30934120.0]
# Outlier detected for column [IOWAIT_DELTA] at location [189] with value [24289352.0]
# Outlier detected for column [IOWAIT_DELTA] at location [192] with value [24880782.0]
# Outlier detected for column [IOWAIT_DELTA] at location [193] with value [50073543.0]
# Outlier detected for column [IOWAIT_DELTA] at location [194] with value [41057055.0]
# Outlier detected for column [IOWAIT_DELTA] at location [200] with value [26797404.0]
# Outlier detected for column [IOWAIT_DELTA] at location [201] with value [24644775.0]
# Outlier detected for column [IOWAIT_DELTA] at location [205] with value [47183742.0]
# Outlier detected for column [IOWAIT_DELTA] at location [206] with value [36212256.0]
# Outlier detected for column [IOWAIT_DELTA] at location [212] with value [25949562.0]
# Outlier detected for column [IOWAIT_DELTA] at location [213] with value [27003743.0]
# Outlier detected for column [IOWAIT_DELTA] at location [217] with value [39085815.0]
# Outlier detected for column [IOWAIT_DELTA] at location [218] with value [39640333.0]
# Outlier detected for column [IOWAIT_DELTA] at location [225] with value [27431383.0]
# Outlier detected for column [IOWAIT_DELTA] at location [229] with value [43655491.0]
# Outlier detected for column [IOWAIT_DELTA] at location [230] with value [61103766.0]
# Outlier detected for column [IOWAIT_DELTA] at location [231] with value [54900431.0]
# Outlier detected for column [IOWAIT_DELTA] at location [237] with value [26124434.0]
# Outlier detected for column [IOWAIT_DELTA] at location [242] with value [48665511.0]
# Outlier detected for column [IOWAIT_DELTA] at location [243] with value [39747533.0]
# Outlier detected for column [IOWAIT_DELTA] at location [249] with value [25733656.0]
# Outlier detected for column [IOWAIT_DELTA] at location [250] with value [24568676.0]
# Outlier detected for column [IOWAIT_DELTA] at location [254] with value [43428800.0]
# Outlier detected for column [IOWAIT_DELTA] at location [255] with value [38613339.0]
# Outlier detected for column [IOWAIT_DELTA] at location [262] with value [219069013.0]
# Outlier detected for column [IOWAIT_DELTA] at location [263] with value [126565907.0]
# Outlier detected for column [IOWAIT_DELTA] at location [264] with value [86043092.0]
# Outlier detected for column [IOWAIT_DELTA] at location [265] with value [91495060.0]
# Outlier detected for column [IOWAIT_DELTA] at location [266] with value [250939238.0]
# Outlier detected for column [IOWAIT_DELTA] at location [267] with value [233448646.0]
# Outlier detected for column [IOWAIT_DELTA] at location [268] with value [185316631.0]
# Outlier detected for column [IOWAIT_DELTA] at location [269] with value [90790583.0]
# Outlier detected for column [IOWAIT_DELTA] at location [270] with value [85405054.0]
# Outlier detected for column [IOWAIT_DELTA] at location [271] with value [797638567.0]
# Outlier detected for column [IOWAIT_DELTA] at location [272] with value [527098817.0]
# Outlier detected for column [IOWAIT_DELTA] at location [273] with value [113649673.0]
# Outlier detected for column [IOWAIT_DELTA] at location [274] with value [42053846.0]
# Outlier detected for column [IOWAIT_DELTA] at location [280] with value [24691307.0]
# Outlier detected for column [IOWAIT_DELTA] at location [284] with value [219027741.0]
# Outlier detected for column [IOWAIT_DELTA] at location [292] with value [42564981.0]
# Outlier detected for column [IOWAIT_DELTA] at location [293] with value [35615606.0]
# Outlier detected for column [IOWAIT_DELTA] at location [297] with value [39828311.0]
# Outlier detected for column [IOWAIT_DELTA] at location [304] with value [31852770.0]
# Outlier detected for column [IOWAIT_DELTA] at location [305] with value [33503446.0]
# Outlier detected for column [IOWAIT_DELTA] at location [316] with value [23138767.0]
# Outlier detected for column [IOWAIT_DELTA] at location [317] with value [38521031.0]
# Outlier detected for column [IOWAIT_DELTA] at location [329] with value [45264203.0]
# Outlier detected for column [IOWAIT_DELTA] at location [342] with value [52807177.0]
# Outlier detected for column [IOWAIT_DELTA] at location [343] with value [118122485.0]
# Outlier detected for column [IOWAIT_DELTA] at location [344] with value [81433382.0]
# Outlier detected for column [IOWAIT_DELTA] at location [354] with value [33691463.0]
# Outlier detected for column [IOWAIT_DELTA] at location [355] with value [49563592.0]
# Outlier detected for column [IOWAIT_DELTA] at location [356] with value [31145340.0]
# Outlier detected for column [IOWAIT_DELTA] at location [359] with value [32352518.0]
# Outlier detected for column [IOWAIT_DELTA] at location [367] with value [32352987.0]
# Outlier detected for column [IOWAIT_DELTA] at location [368] with value [27208790.0]
# Outlier detected for column [IOWAIT_DELTA] at location [379] with value [53543612.0]
# Outlier detected for column [IOWAIT_DELTA] at location [380] with value [50635046.0]
# Outlier detected for column [IOWAIT_DELTA] at location [381] with value [28291734.0]
# Outlier detected for column [IOWAIT_DELTA] at location [391] with value [28293540.0]
# Outlier detected for column [IOWAIT_DELTA] at location [392] with value [42554215.0]
# Outlier detected for column [IOWAIT_DELTA] at location [393] with value [24151184.0]
# Outlier detected for column [IOWAIT_DELTA] at location [400] with value [24673782.0]
# Outlier detected for column [IOWAIT_DELTA] at location [405] with value [38352588.0]
# Outlier detected for column [IOWAIT_DELTA] at location [406] with value [26242878.0]
# Outlier detected for column [IOWAIT_DELTA] at location [417] with value [54412082.0]
# Outlier detected for column [IOWAIT_DELTA] at location [418] with value [44094053.0]
# Outlier detected for column [IOWAIT_DELTA] at location [430] with value [43230317.0]
# Outlier detected for column [IOWAIT_DELTA] at location [431] with value [38418621.0]
# Outlier detected for column [IOWAIT_DELTA] at location [442] with value [36590170.0]
# Outlier detected for column [IOWAIT_DELTA] at location [443] with value [35537350.0]
# Outlier detected for column [IOWAIT_DELTA] at location [454] with value [28918023.0]
# Outlier detected for column [IOWAIT_DELTA] at location [455] with value [52641337.0]
# Outlier detected for column [IOWAIT_DELTA] at location [456] with value [41146701.0]
# Outlier detected for column [IOWAIT_DELTA] at location [467] with value [42933638.0]
# Outlier detected for column [IOWAIT_DELTA] at location [468] with value [33930132.0]
# Outlier detected for column [IOWAIT_DELTA] at location [479] with value [41789233.0]
# Outlier detected for column [IOWAIT_DELTA] at location [480] with value [35086198.0]
# Outlier detected for column [IOWAIT_DELTA] at location [491] with value [39967479.0]
# Outlier detected for column [IOWAIT_DELTA] at location [492] with value [51364752.0]
# Outlier detected for column [IOWAIT_DELTA] at location [493] with value [33448594.0]
# Outlier detected for column [IOWAIT_DELTA] at location [498] with value [27395778.0]
# Outlier detected for column [IOWAIT_DELTA] at location [504] with value [44126749.0]
# Outlier detected for column [IOWAIT_DELTA] at location [505] with value [31503036.0]
# Outlier detected for column [IOWAIT_DELTA] at location [516] with value [29834721.0]
# Outlier detected for column [IOWAIT_DELTA] at location [529] with value [44329546.0]
# Outlier detected for column [IOWAIT_DELTA] at location [530] with value [44545668.0]
# Outlier detected for column [IOWAIT_DELTA] at location [531] with value [24608742.0]
# Outlier detected for column [IOWAIT_DELTA] at location [542] with value [33583651.0]
# Outlier detected for column [IOWAIT_DELTA] at location [553] with value [24136803.0]
# Outlier detected for column [IOWAIT_DELTA] at location [554] with value [44383975.0]
# Outlier detected for column [IOWAIT_DELTA] at location [555] with value [33665976.0]
# Outlier detected for column [IOWAIT_DELTA] at location [566] with value [26749689.0]
# Outlier detected for column [IOWAIT_DELTA] at location [578] with value [38807558.0]
# Outlier detected for column [IOWAIT_DELTA] at location [579] with value [34542938.0]
# Outlier detected for column [IOWAIT_DELTA] at location [590] with value [29766205.0]
# Outlier detected for column [IOWAIT_DELTA] at location [591] with value [27628828.0]
# Outlier detected for column [IOWAIT_DELTA] at location [602] with value [35597551.0]
# Outlier detected for column [IOWAIT_DELTA] at location [603] with value [37216520.0]
# Outlier detected for column [IOWAIT_DELTA] at location [614] with value [26726628.0]
# Outlier detected for column [IOWAIT_DELTA] at location [615] with value [43376985.0]
# Outlier detected for column [IOWAIT_DELTA] at location [616] with value [26771112.0]
# Outlier detected for column [IOWAIT_DELTA] at location [625] with value [32858415.0]
# Outlier detected for column [IOWAIT_DELTA] at location [626] with value [43544148.0]
# Outlier detected for column [IOWAIT_DELTA] at location [627] with value [43823571.0]
# Outlier detected for column [IOWAIT_DELTA] at location [628] with value [32367853.0]
# Outlier detected for column [IOWAIT_DELTA] at location [639] with value [38094490.0]
# Outlier detected for column [IOWAIT_DELTA] at location [640] with value [32085255.0]
# Outlier detected for column [IOWAIT_DELTA] at location [651] with value [36080312.0]
# Outlier detected for column [IOWAIT_DELTA] at location [652] with value [31768262.0]
# Outlier detected for column [IOWAIT_DELTA] at location [663] with value [30522307.0]
# Outlier detected for column [IOWAIT_DELTA] at location [664] with value [32579429.0]
# Outlier detected for column [IOWAIT_DELTA] at location [676] with value [37928458.0]
# Outlier detected for column [IOWAIT_DELTA] at location [677] with value [23642224.0]
# Outlier detected for column [IOWAIT_DELTA] at location [680] with value [64950074.0]
# Outlier detected for column [IOWAIT_DELTA] at location [681] with value [969154123.0]
# Outlier detected for column [IOWAIT_DELTA] at location [682] with value [25747626.0]
# Outlier detected for column [IOWAIT_DELTA] at location [689] with value [37238876.0]
# Outlier detected for column [IOWAIT_DELTA] at location [690] with value [32388877.0]
# Outlier detected for column [IOWAIT_DELTA] at location [693] with value [39932312.0]
# Outlier detected for column [IOWAIT_DELTA] at location [694] with value [472389506.0]
# Outlier detected for column [IOWAIT_DELTA] at location [707] with value [30068670.0]
# Outlier detected for column [IOWAIT_DELTA] at location [715] with value [63350448.0]
# Outlier detected for column [IOWAIT_DELTA] at location [728] with value [23796711.0]
# Outlier detected for column [IOWAIT_DELTA] at location [729] with value [31262418.0]
# Outlier detected for column [IOWAIT_DELTA] at location [734] with value [168811004.0]
# Outlier detected for column [IOWAIT_DELTA] at location [735] with value [174976544.0]
# Outlier detected for column [IOWAIT_DELTA] at location [736] with value [538354039.0]
# Outlier detected for column [IOWAIT_DELTA] at location [737] with value [182112178.0]
# Outlier detected for column [IOWAIT_DELTA] at location [738] with value [106959214.0]
# Outlier detected for column [IOWAIT_DELTA] at location [739] with value [75298807.0]
# Outlier detected for column [IOWAIT_DELTA] at location [740] with value [30714277.0]
# Outlier detected for column [IOWAIT_DELTA] at location [750] with value [39053189.0]
# Outlier detected for column [IOWAIT_DELTA] at location [758] with value [371912577.0]
# Outlier detected for column [IOWAIT_DELTA] at location [779] with value [96625586.0]
# Outlier detected for column [IOWAIT_DELTA] at location [792] with value [26042664.0]
# Outlier detected for column [IOWAIT_DELTA] at location [793] with value [49125651.0]
# Outlier detected for column [IOWAIT_DELTA] at location [794] with value [37707025.0]
# Outlier detected for column [IOWAIT_DELTA] at location [797] with value [23259754.0]
# Outlier detected for column [IOWAIT_DELTA] at location [810] with value [26992562.0]
# Outlier detected for column [IOWAIT_DELTA] at location [818] with value [29430675.0]
# Outlier detected for column [IOWAIT_DELTA] at location [819] with value [23372921.0]
# Outlier detected for column [IOWAIT_DELTA] at location [822] with value [26413818.0]
# Outlier detected for column [IOWAIT_DELTA] at location [830] with value [45850399.0]
# Outlier detected for column [IOWAIT_DELTA] at location [831] with value [42564118.0]
# Outlier detected for column [IOWAIT_DELTA] at location [835] with value [33775548.0]
# Outlier detected for column [IOWAIT_DELTA] at location [843] with value [36307392.0]
# Outlier detected for column [IOWAIT_DELTA] at location [855] with value [47909865.0]
# Outlier detected for column [IOWAIT_DELTA] at location [856] with value [36331548.0]
# Outlier detected for column [IOWAIT_DELTA] at location [867] with value [57681336.0]
# Outlier detected for column [IOWAIT_DELTA] at location [879] with value [33657737.0]
# Outlier detected for column [IOWAIT_DELTA] at location [891] with value [26164363.0]
# Outlier detected for column [IOWAIT_DELTA] at location [903] with value [40229738.0]
# Outlier detected for column [IOWAIT_DELTA] at location [904] with value [29897976.0]
0]
# Outlier detected for column [IOWAIT_DELTA] at location [18802] with value [39143152.0]
# Outlier detected for column [IOWAIT_DELTA] at location [18803] with value [74542668.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19080] with value [59405709.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19081] with value [31897362.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19140] with value [155947155.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19142] with value [36445636.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19143] with value [35034137.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19144] with value [35507811.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19146] with value [74335464.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19152] with value [26610581.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19153] with value [492728444.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19154] with value [121481347.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19161] with value [33979060.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19166] with value [675466855.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19167] with value [24654059.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19179] with value [573798706.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19180] with value [199946685.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19191] with value [79376370.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19227] with value [49959071.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19317] with value [143907168.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19318] with value [74813016.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19322] with value [255478893.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19323] with value [24258174.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19335] with value [40713072.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19384] with value [24635163.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19396] with value [25562076.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19432] with value [29956477.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19434] with value [61318059.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19435] with value [45991670.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19436] with value [27210049.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19444] with value [50824194.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19468] with value [50770470.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19609] with value [207518073.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19630] with value [57290988.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19685] with value [39051437.0]
# Outlier detected for column [IOWAIT_DELTA] at location [19788] with value [79731632.0]
# ---------------------------------------------------------------
# ---------------------------------------------------------------

# %% [markdown]
# ### Normalization
#
# Relavent Sources:
#
# * http://jmlr.csail.mit.edu/papers/volume3/guyon03a/guyon03a.pdf
# * https://machinelearningmastery.com/rescaling-data-for-machine-learning-in-python-with-scikit-learn/
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/ recommends a normalization preprocessing technique for data distribution that can closely approximate minimum and maximum observable values per column:
#
# <i>"Normalization requires that you know or are able to accurately estimate the minimum and maximum observable values. You may be able to estimate these values from your available data. If your time series is trending up or down, estimating these expected values may be difficult and normalization may not be the best method to use on your problem."</i>
#
# Normalization formula is stated as follows: $$y=(x-min)/(max-min)$$
#
# ### Standardization
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/ recommends a standardization preprocessing technique for data distributions that observe a Gaussian spread, with a mean of 0 and a standard deviation of 1 (approximately close to these values):
#
# <i>"Standardization assumes that your observations fit a Gaussian distribution (bell curve) with a well behaved mean and standard deviation. You can still standardize your time series data if this expectation is not met, but you may not get reliable results."</i>
#
# Standardization formula is stated as follows: $$y=(x-mean)/StandardDeviation$$
# Mean defined as: $$mean=sum(x)/count(x)$$
# Standard Deviation defined as: $$StandardDeviation=sqrt(sum((x-mean)^2)/count(x))$$

# %%
# MINMAX SCALER
#df = Normalizer.minmax_scaler(dataframe=df)
train, test = train_test_split(df, test_size=0.5)
trainheaders = train.columns
testheaders = test.columns
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)
train = pd.DataFrame(train, columns=trainheaders)
test = pd.DataFrame(test, columns=testheaders)
df = train.append(test, ignore_index=True)
#
# NORMALIZER
#df = Normalizer.normalize(dataframe=df)

print('\n\n------------------AFTER------------------')
print('------------------df------------------')
print(df.shape)
print('\n\n')
print('\n\ndf')
print(df.head())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# ------------------AFTER------------------
# ------------------df------------------
# (19831, 511)
#
#
#
#
#
# df
#     SNAP_ID  OPTIMIZER_COST  SHARABLE_MEM  FETCHES_TOTAL  FETCHES_DELTA  \
# 0  0.767877    1.763487e-09      0.001144       0.013160       0.001123
# 1  0.254665    4.077102e-02      0.355561       0.434423       0.144279
# 2  0.247655    4.118033e-02      0.331129       0.426159       0.280317
# 3  0.643873    2.670293e-10      0.521807       0.719960       0.016684
# 4  0.697832    3.724991e-02      0.403418       0.796189       0.304103
#
#    END_OF_FETCH_COUNT_TOTAL  END_OF_FETCH_COUNT_DELTA  SORTS_TOTAL  \
# 0                  0.013026                  0.001373     0.011977
# 1                  0.501928                  0.261871     0.428879
# 2                  0.480718                  0.497121     0.419924
# 3                  0.453088                  0.119368     0.708147
# 4                  0.906628                  0.530291     0.758818
#
#    SORTS_DELTA  EXECUTIONS_TOTAL                 ...                  \
# 0     0.001635          0.010237                 ...
# 1     0.224493          0.508004                 ...
# 2     0.424787          0.488855                 ...
# 3     0.050033          0.547454                 ...
# 4     0.434107          0.916269                 ...
#
#    USER CALLS  USER COMMITS  USER LOGONS CUMULATIVE  USER LOGOUTS CUMULATIVE  \
# 0    0.788206      0.785655                0.788498                 0.788495
# 1    0.282320      0.278994                0.282948                 0.282948
# 2    0.273612      0.271554                0.274079                 0.274076
# 3    0.661049      0.661198                0.660909                 0.660909
# 4    0.718190      0.717395                0.718100                 0.718099
#
#    USER ROLLBACKS  WORKAREA EXECUTIONS - ONEPASS  \
# 0        0.788514                       0.788603
# 1        0.282968                       0.282988
# 2        0.274073                       0.274142
# 3        0.661125                       0.661038
# 4        0.718136                       0.718191
#
#    WORKAREA EXECUTIONS - OPTIMAL  WORKAREA MEMORY ALLOCATED  \
# 0                       0.787967                   0.326259
# 1                       0.282474                   0.000000
# 2                       0.273781                   0.486595
# 3                       0.660559                   0.000000
# 4                       0.717803                   0.202165
#
#    WRITE CLONES CREATED IN BACKGROUND  WRITE CLONES CREATED IN FOREGROUND
# 0                            0.802817                            0.999696
# 1                            0.312676                            0.998907
# 2                            0.301408                            0.998896
# 3                            0.684507                            0.999536
# 4                            0.743662                            0.999609
#
# [5 rows x 511 columns]

# %% [markdown]
# ### Split Train Test
#
# Splits dataset into training and validation subsets

# %%
y_df = df[y_label]
X_df = df
print("Label " + str(y_label) + " shape: " + str(y_df.shape))
print("Feature matrix shape: " + str(X_df.shape))
print(X_df.head())
# Out:
# Label ['CPU_TIME_DELTA', 'IOWAIT_DELTA'] shape: (19831, 2)
# Feature matrix shape: (19831, 511)
#     SNAP_ID  OPTIMIZER_COST  SHARABLE_MEM  FETCHES_TOTAL  FETCHES_DELTA  \
# 0  0.767877    1.763487e-09      0.001144       0.013160       0.001123
# 1  0.254665    4.077102e-02      0.355561       0.434423       0.144279
# 2  0.247655    4.118033e-02      0.331129       0.426159       0.280317
# 3  0.643873    2.670293e-10      0.521807       0.719960       0.016684
# 4  0.697832    3.724991e-02      0.403418       0.796189       0.304103
#
#    END_OF_FETCH_COUNT_TOTAL  END_OF_FETCH_COUNT_DELTA  SORTS_TOTAL  \
# 0                  0.013026                  0.001373     0.011977
# 1                  0.501928                  0.261871     0.428879
# 2                  0.480718                  0.497121     0.419924
# 3                  0.453088                  0.119368     0.708147
# 4                  0.906628                  0.530291     0.758818
#
#    SORTS_DELTA  EXECUTIONS_TOTAL                 ...                  \
# 0     0.001635          0.010237                 ...
# 1     0.224493          0.508004                 ...
# 2     0.424787          0.488855                 ...
# 3     0.050033          0.547454                 ...
# 4     0.434107          0.916269                 ...
#
#    USER CALLS  USER COMMITS  USER LOGONS CUMULATIVE  USER LOGOUTS CUMULATIVE  \
# 0    0.788206      0.785655                0.788498                 0.788495
# 1    0.282320      0.278994                0.282948                 0.282948
# 2    0.273612      0.271554                0.274079                 0.274076
# 3    0.661049      0.661198                0.660909                 0.660909
# 4    0.718190      0.717395                0.718100                 0.718099
#
#    USER ROLLBACKS  WORKAREA EXECUTIONS - ONEPASS  \
# 0        0.788514                       0.788603
# 1        0.282968                       0.282988
# 2        0.274073                       0.274142
# 3        0.661125                       0.661038
# 4        0.718136                       0.718191
#
#    WORKAREA EXECUTIONS - OPTIMAL  WORKAREA MEMORY ALLOCATED  \
# 0                       0.787967                   0.326259
# 1                       0.282474                   0.000000
# 2                       0.273781                   0.486595
# 3                       0.660559                   0.000000
# 4                       0.717803                   0.202165
#
#    WRITE CLONES CREATED IN BACKGROUND  WRITE CLONES CREATED IN FOREGROUND
# 0                            0.802817                            0.999696
# 1                            0.312676                            0.998907
# 2                            0.301408                            0.998896
# 3                            0.684507                            0.999536
# 4                            0.743662                            0.999609
#
# [5 rows x 511 columns]

# %% [markdown]
# ### Discrete Training
#
# This section converts the established features from the continuous domain into the discrete domain. Continous values will be converted into discrete, and used to train the model using such values (Utilizes bucket function).
#
# https://machinelearningmastery.com/make-predictions-long-short-term-memory-models-keras/

# %%
class BinClass:
    """
    Takes data column, and scales them into discrete buckets. Parameter 'n' denotes number of buckets. This class needs
    to be defined before the LSTM class, since it is referenced during the prediction stage. Since Keras models output a
    continuous output (even when trained on discrete data), the 'BinClass' is required by the LSTM class.
    """
    
    @staticmethod
    def __bucket_val(val, avg):
        """
        Receives threshold value and buckets the val according to the passed threshold
        """
        return np.where(val > avg, 1, 0)

    @staticmethod
    def discretize_value(X, threshold):
        """
        param: X - Input data
        """
        try:
            myfunc_vec = np.vectorize(lambda x: BinClass.__bucket_val(x, threshold))
            return myfunc_vec(X)
        except:
            return BinClass.__bucket_val(X, threshold)

cpu_avg = y_df[y_label[0]].mean()
y_df_cpu = pd.DataFrame(BinClass.discretize_value(y_df[[y_label[0]]].values, cpu_avg), columns=[y_label[0]])
print('CPU y:')
print(np.unique(y_df_cpu.values))
print('Number of 0s: ' + str(np.count_nonzero(y_df_cpu == 0)))
print('Number of 1s: ' + str(np.count_nonzero(y_df_cpu == 1)))
#
io_avg = y_df[y_label[1]].mean()
y_df_io = pd.DataFrame(BinClass.discretize_value(y_df[[y_label[1]]].values, io_avg), columns=[y_label[1]])
print('I/O y:')
print(np.unique(y_df_io.values))
print('Number of 0s: ' + str(np.count_nonzero(y_df_io == 0)))
print('Number of 1s: ' + str(np.count_nonzero(y_df_io == 1)))
# Out:
# CPU y:
# [0 1]
# Number of 0s: 10804
# Number of 1s: 9027
# I/O y:
# [0 1]
# Number of 0s: 11673
# Number of 1s: 8158

# %% [markdown]
# ### Time Series Shifting
#
# Shifting the datasets N lag minutes, in order to transform the problem into a supervised dataset. Each Lag Shift equates to 60 seconds (due to the way design of the data capturing tool). For each denoted lag amount, the same number of feature vectors will be stripped away at the beginning.
#
# Features and Labels are separated into seperate dataframes at this point.
#
# https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = data
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    n_out += 1
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# Frame as supervised learning set
X_df = series_to_supervised(X_df, lag, 0)
y_df = series_to_supervised(y_df, 0, lag)

print('\n-------------\nFeatures')
print(X_df.columns)
print(X_df.shape)
print('\n-------------\nLabels')
print(y_df.columns)
print(y_df.shape)
# Out:
# -------------
# Features
# Index(['var1(t-12)', 'var2(t-12)', 'var3(t-12)', 'var4(t-12)', 'var5(t-12)',
#        'var6(t-12)', 'var7(t-12)', 'var8(t-12)', 'var9(t-12)', 'var10(t-12)',
#        ...
#        'var502(t)', 'var503(t)', 'var504(t)', 'var505(t)', 'var506(t)',
#        'var507(t)', 'var508(t)', 'var509(t)', 'var510(t)', 'var511(t)'],
#       dtype='object', length=6643)
# (19819, 6643)
#
# -------------
# Labels
# Index(['var1(t)', 'var2(t)', 'var1(t+1)', 'var2(t+1)', 'var1(t+2)',
#        'var2(t+2)', 'var1(t+3)', 'var2(t+3)', 'var1(t+4)', 'var2(t+4)',
#        'var1(t+5)', 'var2(t+5)', 'var1(t+6)', 'var2(t+6)', 'var1(t+7)',
#        'var2(t+7)', 'var1(t+8)', 'var2(t+8)', 'var1(t+9)', 'var2(t+9)',
#        'var1(t+10)', 'var2(t+10)', 'var1(t+11)', 'var2(t+11)', 'var1(t+12)',
#        'var2(t+12)'],
#       dtype='object')
# (19819, 26)

# %% [markdown]
# ### Feature Selection
#
# Implements a recursive solution, where in features are eliminated based on an ensemble evaluator.

# %%
class FeatureEliminator:
    """
    This class is dedicated to housing logic pertaining to feature selection - retaining only labels which are considered
    important.
    """
    def __init__(self, X_df, y_df):
        """
        Class constructor.
        :param X_df: (Pandas) Pandas feature matrix.
        :param y_df: (Pandas) Pandas label matrix.
        :return: None
        """
        self.__X_df = X_df
        self.__y_df = y_df
    
    def rfe_selector(self, test_split=.4, optimum_feature_count=0, parallel_degree=1, max_depth=None, max_features='sqrt', n_estimators=100):
        """
        Recursive Feature Elimination Function. Isolates and eliminated features one by one, up till the desired amount, starting
        by features which are considered less important.
        :param test_split:            (Float) Denotes training/testing data split.
        :param optimum_feature_count: (Integer) Denotes the best estimated number of features to retain before a performance drop
                                                is estimated.
        :param parallel_degree:       (Integer) Denotes model training parallel degree.
        :param max_depth:             (Integer) Denotes number of leaves to evaluate during decision tree pruning.
        :param max_features:          (Integer) Denotes number of features to consider during random subselection.
        :param n_estimators:          (Integer) Number of estimators (trees) to build for decision making.
        :return: (List) This list is composed of boolean values, which correspond to the input feature column headers. True List 
                        values denote columns which have been retained. False values denote eliminated feature headers.
        :return: (List) This list denotes feature rankings, which correspond to the input feature column headers. Values of '1',
                        denote that features have been retained.
        """
        X_df = self.__X_df.values
        y_df = self.__y_df[self.__y_df.columns[0]].values  # We can only use a single target column since RandomForests do not support multi target labels
        print(X_df.shape)
        print(y_df.shape)
        optimum_feature_count = int(optimum_feature_count)
        
        X_train, X_test, y_train, y_test = train_test_split(X_df, 
                                                            y_df, 
                                                            test_size=test_split)
        model = RandomForestRegressor(n_estimators=int(n_estimators), 
                                      n_jobs=parallel_degree,
                                      max_depth=max_depth,
                                      max_features='sqrt')

        # create the RFE model and select N attributes
        rfe_model = RFE(model, optimum_feature_count, step=1)
        rfe_model = rfe_model.fit(X_train, y_train)

        # summarize the selection of the attributes
        print(rfe_model.support_)
        print(rfe_model.ranking_)

        # evaluate the model on testing set
        pred_y = rfe_model.predict(X_test)
        predictions = [round(value) for value in pred_y]
        r2s = r2_score(y_test, predictions)
        
        return rfe_model.support_, rfe_model.ranking_
    
    def get_selected_features(self, column_mask):
        """
        Retrieves features which have not been eliminated from the RFE function.
        :param column_mask: (List) This list is composed of boolean values, which correspond to the input feature column headers. 
                                   True list values denote columns which have been retained. False values denote eliminated 
                                   feature headers. 
        :return: (Pandas) Pandas data matrix.
        """
        recommended_columns = []
        for i in range(len(self.__X_df.columns)):
            if (column_mask[i]):
                recommended_columns.append(self.__X_df.columns[i])
                
        return self.__X_df[recommended_columns]
    
# fe = FeatureEliminator(X_df=X_df,
#                        y_df=y_df)
# column_mask, column_rankings = fe.rfe_selector(test_split=test_split,
#                                                optimum_feature_count=int(X_df.shape[1]/8),
#                                                parallel_degree=2,
#                                                max_depth=1,
#                                                max_features='sqrt',
#                                                n_estimators=n_estimators)
# print(X_df.columns)
# X_df = fe.get_selected_features(column_mask=column_mask)
# print(X_df.columns)
recursively_eliminated_columns = ['var175(t-4)', 'var176(t-4)', 'var177(t-4)', 'var178(t-4)', 'var179(t-4)', 'var180(t-4)', 'var181(t-4)', 'var182(t-4)', 'var183(t-4)', 'var184(t-4)', 'var185(t-4)', 'var186(t-4)', 'var187(t-4)', 'var188(t-4)', 'var189(t-4)', 'var190(t-4)', 'var191(t-4)', 'var192(t-4)', 'var193(t-4)', 'var195(t-4)', 'var196(t-4)', 'var197(t-4)', 'var198(t-4)', 'var199(t-4)', 'var200(t-4)', 'var201(t-4)', 'var202(t-4)', 'var203(t-4)', 'var204(t-4)', 'var205(t-4)', 'var206(t-4)', 'var207(t-4)', 'var208(t-4)', 'var209(t-4)', 'var210(t-4)', 'var211(t-4)', 'var212(t-4)', 'var213(t-4)', 'var214(t-4)', 'var215(t-4)', 'var217(t-4)', 'var218(t-4)', 'var219(t-4)', 'var220(t-4)', 'var221(t-4)', 'var222(t-4)', 'var223(t-4)', 'var224(t-4)', 'var225(t-4)', 'var226(t-4)', 'var227(t-4)', 'var228(t-4)', 'var229(t-4)', 'var230(t-4)', 'var235(t-4)', 'var238(t-4)', 'var240(t-4)', 'var241(t-4)', 'var243(t-4)', 'var244(t-4)', 'var245(t-4)', 'var246(t-4)', 'var247(t-4)', 'var248(t-4)', 'var250(t-4)', 'var252(t-4)', 'var253(t-4)', 'var254(t-4)', 'var255(t-4)', 'var256(t-4)', 'var258(t-4)', 'var259(t-4)', 'var260(t-4)', 'var261(t-4)', 'var266(t-4)', 'var267(
var466(t-4)', 'var468(t-4)', 'var469(t-4)', 'var470(t-4)', 'var471(t-4)', 'var472(t-4)', 'var473(t-4)', 'var474(t-4)', 'var475(t-4)', 'var476(t-4)', 'var477(t-4)', 'var478(t-4)', 'var479(t-4)', 'var480(t-4)', 'var481(t-4)', 'var482(t-4)', 'var483(t-4)', 'var484(t-4)', 'var485(t-4)', 'var486(t-4)', 'var487(t-4)', 'var488(t-4)', 'var489(t-4)', 'var490(t-4)', 'var491(t-4)', 'var492(t-4)', 'var493(t-4)', 'var494(t-4)', 'var495(t-4)', 'var496(t-4)', 'var497(t-4)', 'var498(t-4)', 'var499(t-4)', 'var500(t-4)', 'var501(t-4)', 'var502(t-4)', 'var503(t-4)', 'var504(t-4)', 'var506(t-4)', 'var507(t-4)', 'var511(t-4)', 'var1(t-3)', 'var2(t-3)', 'var3(t-3)', 'var4(t-3)', 'var5(t-3)', 'var7(t-3)', 'var8(t-3)', 'var11(t-3)', 'var12(t-3)', 'var13(t-3)', 'var14(t-3)', 'var16(t-3)', 'var19(t-3)', 'var20(t-3)', 'var22(t-3)', 'var23(t-3)', 'var25(t-3)', 'var28(t-3)', 'var30(t-3)', 'var31(t-3)', 'var37(t-3)', 'var39(t-3)', 'var41(t-3)', 'var42(t-3)', 'var45(t-3)', 'var47(t-3)', 'var48(t-3)', 'var50(t-3)', 'var52(t-3)', 'var53(t-3)', 'var54(t-3)', 'var58(t-3)', 'var59(t-3)', 'var61(t-3)', 'var62(t-3)', 'var63(t-3)', 'var66(t-3)', 'var67(t-3)', 'var68(t-3)', 'var70(t-3)', 'var72(t-3)', 'var75(t-3)', 'var77(t-3)', 'var78(t-3)', 'var79(t-3)', 'var80(t-3)', 'var86(t-3)', 'var88(t-3)', 'var89(t-3)', 'var91(t-3)', 'var92(t-3)', 'var94(t-3)', 'var95(t-3)', 'var96(t-3)', 'var98(t-3)', 'var99(t-3)', 'var100(t-3)', 'var101(t-3)', 'var102(t-3)', 'var103(t-3)', 'var106(t-3)', 'var108(t-3)', 'var109(t-3)', 'var114(t-3)', 'var115(t-3)', 'var116(t-3)', 'var117(t-3)', 'var119(t-3)', 'var120(t-3)', 'var121(t-3)', 'var122(t-3)', 'var123(t-3)', 'var124(t-3)', 'var126(t-3)', 'var127(t-3)', 'var132(t-3)', 'var133(t-3)', 'var138(t-3)', 'var144(t-3)', 'var145(t-3)', 'var148(t-3)', 'var150(t-3)', 'var154(t-3)', 'var155(t-3)', 'var158(t-3)', 'var160(t-3)', 'var162(t-3)', 'var163(t-3)', 'var164(t-3)', 'var170(t-3)', 'var171(t-3)', 'var172(t-3)', 'var173(t-3)', 'var176(t-3)', 'var177(t-3)', 'var180(t-3)', 'var181(t-3)', 'var190(t-3)', 'var191(t-3)', 'var192(t-3)', 'var193(t-3)', 'var195(t-3)', 'var196(t-3)', 'var197(t-3)', 'var198(t-3)', 'var199(t-3)', 'var200(t-3)', 'var201(t-3)', 'var202(t-3)', 'var203(t-3)', 'var204(t-3)', 'var205(t-3)', 'var206(t-3)', 'var207(t-3)', 'var208(t-3)', 'var209(t-3)', 'var210(t-3)', 'var211(t-3)', 'var212(t-3)', 'var213(t-3)', 'var214(t-3)', 'var215(t-3)', 'var216(t-3)', 'var217(t-3)', 'var218(t-3)', 'var219(t-3)', 'var220(t-3)', 'var221(t-3)', 'var222(t-3)', 'var223(t-3)', 'var224(t-3)', 'var225(t-3)', 'var226(t-3)', 'var227(t-3)', 'var228(t-3)', 'var229(t-3)', 'var230(t-3)', 'var231(t-3)', 'var232(t-3)', 'var233(t-3)', 'var234(t-3)', 'var235(t-3)', 'var236(t-3)', 'var237(t-3)', 'var238(t-3)', 'var240(t-3)', 'var241(t-3)', 'var242(t-3)', 'var243(t-3)', 'var244(t-3)', 'var245(t-3)', 'var246(t-3)', 'var247(t-3)', 'var248(t-3)', 'var249(t-3)', 'var250(t-3)', 'var251(t-3)', 'var252(t-3)', 'var253(t-3)', 'var254(t-3)', 'var256(t-3)', 'var257(t-3)', 'var258(t-3)', 'var259(t-3)', 'var261(t-3)', 'var262(t-3)', 'var264(t-3)', 'var265(t-3)', 'var266(t-3)', 'var267(t-3)', 'var268(t-3)', 'var269(t-3)', 'var270(t-3)', 'var271(t-3)', 'var272(t-3)', 'var273(t-3)', 'var274(t-3)', 'var276(t-3)', 'var277(t-3)', 'var278(t-3)', 'var279(t-3)', 'var280(t-3)', 'var281(t-3)', 'var282(t-3)', 'var283(t-3)', 'var284(t-3)', 'var285(t-3)', 'var286(t-3)', 'var287(t-3)', 'var288(t-3)', 'var289(t-3)', 'var290(t-3)', 'var291(t-3)', 'var292(t-3)', 'var293(t-3)', 'var294(t-3)', 'var295(t-3)', 'var300(t-3)', 'var301(t-3)', 'var305(t-3)', 'var306(t-3)', 'var307(t-3)', 'var309(t-3)', 'var310(t-3)', 'var311(t-3)', 'var313(t-3)', 'var314(t-3)', 'var315(t-3)', 'var317(t-3)', 'var318(t-3)', 'var319(t-3)', 'var321(t-3)', 'var327(t-3)', 'var329(t-3)', 'var330(t-3)', 'var331(t-3)', 'var335(t-3)', 'var336(t-3)', 'var337(t-3)', 'var338(t-3)', 'var339(t-3)', 'var342(t-3)', 'var344(t-3)', 'var345(t-3)', 'var347(t-3)', 'var349(t-3)', 'var351(t-3)', 'var352(t-3)', 'var354(t-3)', 'var355(t-3)', 'var356(t-3)', 'var357(t-3)', 'var363(t-3)', 'var365(t-3)', 'var366(t-3)', 'var367(t-3)', 'var369(t-3)', 'var370(t-3)', 'var371(t-3)', 'var373(t-3)', 'var374(t-3)', 'var375(t-3)', 'var376(t-3)', 'var378(t-3)', 'var379(t-3)', 'var380(t-3)', 'var382(t-3)', 'var383(t-3)', 'var384(t-3)', 'var385(t-3)', 'var386(t-3)', 'var388(t-3)', 'var391(t-3)', 'var398(t-3)', 'var403(t-3)', 'var404(t-3)', 'var405(t-3)', 'var406(t-3)', 'var407(t-3)', 'var408(t-3)', 'var409(t-3)', 'var410(t-3)', 'var411(t-3)', 'var413(t-3)', 'var414(t-3)', 'var415(t-3)', 'var417(
'var74(t)', 'var75(t)', 'var76(t)', 'var77(t)', 'var78(t)', 'var79(t)', 'var80(t)', 'var81(t)', 'var82(t)', 'var83(t)', 'var84(t)', 'var85(t)', 'var86(t)', 'var87(t)', 'var88(t)', 'var89(t)', 'var90(t)', 'var91(t)', 'var92(t)', 'var93(t)', 'var94(t)', 'var95(t)', 'var96(t)', 'var97(t)', 'var98(t)', 'var99(t)', 'var100(t)', 'var101(t)', 'var102(t)', 'var103(t)', 'var104(t)', 'var105(t)', 'var106(t)', 'var107(t)', 'var108(t)', 'var109(t)', 'var110(t)', 'var111(t)', 'var112(t)', 'var113(t)', 'var114(t)', 'var115(t)', 'var116(t)', 'var117(t)', 'var118(t)', 'var119(t)', 'var120(t)', 'var121(t)', 'var122(t)', 'var123(t)', 'var124(t)', 'var125(t)', 'var126(t)', 'var127(t)', 'var128(t)', 'var129(t)', 'var130(t)', 'var131(t)', 'var132(t)', 'var133(t)', 'var134(t)', 'var135(t)', 'var136(t)', 'var137(t)', 'var138(t)', 'var139(t)', 'var141(t)', 'var142(t)', 'var143(t)', 'var144(t)', 'var145(t)', 'var146(t)', 'var147(t)', 'var148(t)', 'var149(t)', 'var150(t)', 'var151(t)', 'var152(t)', 'var153(t)', 'var154(t)', 'var155(t)', 'var156(t)', 'var157(t)', 'var158(t)', 'var159(t)', 'var160(t)', 'var161(t)', 'var162(t)', 'var163(t)', 'var164(t)', 'var165(t)', 'var166(t)', 'var167(t)', 'var168(t)', 'var169(t)', 'var170(t)', 'var171(t)', 'var172(t)', 'var173(t)', 'var174(t)', 'var176(t)', 'var177(t)', 'var178(t)', 'var179(t)', 'var180(t)', 'var182(t)', 'var183(t)', 'var184(t)', 'var185(t)', 'var186(t)', 'var187(t)', 'var188(t)', 'var189(t)', 'var190(t)', 'var191(t)', 'var192(t)', 'var193(t)', 'var194(t)', 'var195(t)', 'var196(t)', 'var197(t)', 'var198(t)', 'var199(t)', 'var200(t)', 'var201(t)', 'var202(t)', 'var203(t)', 'var204(t)', 'var205(t)', 'var206(t)', 'var207(t)', 'var208(t)', 'var209(t)', 'var210(t)', 'var211(t)', 'var212(t)', 'var213(t)', 'var214(t)', 'var215(t)', 'var216(t)', 'var217(t)', 'var218(t)', 'var219(t)', 'var220(t)', 'var221(t)', 'var222(t)', 'var223(t)', 'var224(t)', 'var225(t)', 'var226(t)', 'var227(t)', 'var228(t)', 'var229(t)', 'var230(t)', 'var231(t)', 'var232(t)', 'var233(t)', 'var234(t)', 'var235(t)', 'var236(t)', 'var237(t)', 'var238(t)', 'var239(t)', 'var240(t)', 'var241(t)', 'var242(t)', 'var243(t)', 'var244(t)', 'var245(t)', 'var246(t)', 'var247(t)', 'var248(t)', 'var249(t)', 'var250(t)', 'var251(t)', 'var252(t)', 'var253(t)', 'var254(t)', 'var255(t)', 'var256(t)', 'var257(t)', 'var259(t)', 'var260(t)', 'var261(t)', 'var262(t)', 'var263(t)', 'var265(t)', 'var266(t)', 'var267(t)', 'var268(t)', 'var270(t)', 'var271(t)', 'var272(t)', 'var273(t)', 'var274(t)', 'var275(t)', 'var276(t)', 'var277(t)', 'var278(t)', 'var279(t)', 'var280(t)', 'var281(t)', 'var282(t)', 'var283(t)', 'var284(t)', 'var285(t)', 'var286(t)', 'var287(t)', 'var288(t)', 'var289(t)', 'var290(t)', 'var291(t)', 'var292(t)', 'var293(t)', 'var294(t)', 'var295(t)', 'var296(t)', 'var297(t)', 'var298(t)', 'var299(t)', 'var300(t)', 'var301(t)', 'var302(t)', 'var303(t)', 'var304(t)', 'var305(t)', 'var306(t)', 'var307(t)', 'var308(t)', 'var309(t)', 'var310(t)', 'var311(t)', 'var312(t)', 'var313(t)', 'var314(t)', 'var315(t)', 'var316(t)', 'var317(t)', 'var319(t)', 'var320(t)', 'var321(t)', 'var322(t)', 'var323(t)', 'var324(t)', 'var325(t)', 'var326(t)', 'var328(t)', 'var330(t)', 'var331(t)', 'var332(t)', 'var333(t)', 'var334(t)', 'var336(t)', 'var337(t)', 'var338(t)', 'var339(t)', 'var340(t)', 'var341(t)', 'var342(t)', 'var343(t)', 'var344(t)', 'var345(t)', 'var346(t)', 'var347(t)', 'var348(t)', 'var349(t)', 'var350(t)', 'var351(t)', 'var352(t)', 'var353(t)', 'var354(t)', 'var355(t)', 'var356(t)', 'var357(t)', 'var358(t)', 'var359(t)', 'var360(t)', 'var361(t)', 'var362(t)', 'var363(t)', 'var364(t)', 'var365(t)', 'var366(t)', 'var367(t)', 'var368(t)', 'var369(t)', 'var371(t)', 'var372(t)', 'var373(t)', 'var374(t)', 'var375(t)', 'var376(t)', 'var377(t)', 'var378(t)', 'var379(t)', 'var380(t)', 'var381(t)', 'var382(t)', 'var383(t)', 'var384(t)', 'var385(t)', 'var386(t)', 'var387(t)', 'var388(t)', 'var389(t)', 'var390(t)', 'var391(t)', 'var392(t)', 'var393(t)']
X_df = X_df[recursively_eliminated_columns]

# %% [markdown]
# ### Value Decomposition
#
# Principal component analysis: Factor model in which the factors are based on summarizing the total variance. With PCA, unities are used in the diagonal of the correlation matrix computationally implying that all the variance is common or shared.
#
# https://towardsdatascience.com/an-approach-to-choosing-the-number-of-components-in-a-principal-component-analysis-pca-3b9f3d6e73fe

# %%
class PrincipalComponentAnalysisClass:
    """
    This class handles logic related to PCA data transformations.
    https://towardsdatascience.com/an-approach-to-choosing-the-number-of-components-in-a-principal-component-analysis-pca-3b9f3d6e73fe
    """
    def __init__(self, X_df):
        """
        Cosntructor method.
        :param X_df: (Pandas) Dataframe consisting of input features, which will be subject to PCA.
        :return: None
        """
        self.__X_df = X_df
        
    def get_default_component_variances(self):
        """
        Fitting the PCA algorithm with our Data.
        :return: (Numpy array) Array of feature variances.
        """
        pca = PCA().fit(self.__X_df.values)
        return np.cumsum(pca.explained_variance_ratio_)
        
    def get_default_component_count(self, threshold=.99):
        """
        Retrieves the recommended number of component decomposition, above which very little variance 
        gain is achieved. This treshold will be set at a 0.999 variance threshold.
        :param threshold: (Float) Threshold value between 0 and 1. Stops immediately as soon the number
                                  of required components exceeds the threshold value.
        :return: (Integer) Returns the number of recommended components.
        """
        variance_ratios = self.get_default_component_variances()
        n = 0
        for val in variance_ratios:
            if val < threshold:
                n += 1
        return n
    
    def plot_variance_per_reduction(self):
        """
        This method subjects the feature matrix to a PCA decomposition. The number of components is plot
        vs the amount of retained variance.
        :return: None
        """
        variance_ratios = self.get_default_component_variances()
        
        #Plotting the Cumulative Summation of the Explained Variance
        plt.figure()
        plt.plot(variance_ratios)
        plt.xlabel('Number of Components')
        plt.ylabel('Variance (%)') #for each component
        plt.title(tpcds + ' Dataset Explained Variance')
        plt.show()
        
    def apply_PCA(self, n_components):
        """
        Applies Principle Component Analysis on the constructor passed data matrix, on a number of components.
        A new pandas data matrix is returned, with renamed 'Principal Component' headers.
        :param n_components: (Integer) Denotes number of component breakdown.
        :return: (Pandas) Dataframe consisting of new decomposed components.
        """
        pca = PCA(n_components=n_components)
        dataset = pca.fit_transform(self.__X_df.values)
        header_list = []
        for i in range(dataset.shape[1]):
            header_list.append('Component_' + str(i))
        return pd.DataFrame(data=dataset, columns=header_list)

print(X_df.head())
print(X_df.shape)

pcac = PrincipalComponentAnalysisClass(X_df=X_df)
pcac.plot_variance_per_reduction()
component_count = pcac.get_default_component_count()
X_df = pcac.apply_PCA(n_components=component_count)

print('-'*30)
print(X_df.head())
print(X_df.shape)
# Out:
#     var175(t-4)  var176(t-4)  var177(t-4)  var178(t-4)  var179(t-4)  \
# 12     0.033151     0.060661     0.008347     0.033565     0.005953
# 13     0.026007     0.092172     0.016403     0.052033     0.004734
# 14     0.007144     0.024741     0.019637     0.002967     0.000796
# 15     0.006375     0.298768     0.240981     0.003258     0.000034
# 16     0.012279     0.003373     0.002234     0.002037     0.005969
#
#     var180(t-4)  var181(t-4)  var182(t-4)  var183(t-4)  var184(t-4)  \
# 12     0.009906     0.000974     0.052338     0.039506     0.304846
# 13     0.009689     0.001191     0.081229     0.027030     0.209716
# 14     0.045329     0.021874     0.455376     0.009731     1.000000
# 15     0.511614     0.238103     0.509626     0.009689     1.000000
# 16     0.008460     0.004570     0.328421     0.010396     1.000000
#
#       ...      var384(t)  var385(t)  var386(t)  var387(t)  var388(t)  \
# 12    ...       0.615679   0.634632   0.627330   0.634548   0.718995
# 13    ...       0.635755   0.651254   0.646319   0.651199   0.740926
# 14    ...       0.822730   0.841209   0.834232   0.841121   0.902716
# 15    ...       0.961523   0.962426   0.963318   0.962442   0.978222
# 16    ...       0.448569   0.471761   0.457778   0.471578   0.440337
#
#     var389(t)  var390(t)  var391(t)  var392(t)  var393(t)
# 12   0.132075   0.047619   0.726470   0.603886   0.635125
# 13   0.276730   0.952381   0.760755   0.627784   0.651155
# 14   0.226415   0.190476   0.900177   0.816027   0.841230
# 15   0.238994   0.190476   0.990651   0.961257   0.962597
# 16   0.169811   0.000000   0.573236   0.427775   0.471748
#
# [5 rows x 1788 columns]
# (19819, 1788)
# ------------------------------
#    Component_0  Component_1  Component_2  Component_3  Component_4  \
# 0    -0.158386     0.008742    -7.651313     6.088315     6.099712
# 1    -0.104080    -0.043808    -2.220541     7.231353     4.988485
# 2    -0.106060    -0.026731    -2.602293     5.895514    -7.084241
# 3    -0.097299    -0.056754    -5.757948    -6.511144    -1.284303
# 4    -0.132911     0.005316    -7.770164    -2.117686    -2.223772
#
#    Component_5  Component_6  Component_7  Component_8  Component_9  \
# 0     5.597299    -0.045511     1.940163    -1.205987    -0.174992
# 1    -5.969432    -2.762774    -1.267013     0.191880     1.017109
# 2    -0.169693    -4.285752     0.173441     2.148013    -0.741499
# 3    -0.631342    -6.586875     2.193994     1.480701     0.121894
# 4    -4.383386     0.043610     1.517139     2.451879     1.399142
#
#        ...       Component_49  Component_50  Component_51  Component_52  \
# 0      ...          -0.049445      0.040157      0.136738      0.311118
# 1      ...          -0.125001     -0.292859     -0.080360      0.284698
# 2      ...           0.019574     -0.422058      0.401411     -0.359485
# 3      ...          -0.102018      0.661393     -0.318167     -0.307016
# 4      ...           0.456304     -0.004688     -0.347496      0.445224
#
#    Component_53  Component_54  Component_55  Component_56  Component_57  \
# 0      0.550862      0.130162     -0.047184     -0.449029     -0.267813
# 1      0.253824      0.276429     -0.517020      0.374780      0.324887
# 2     -0.186234     -0.248399      0.063159      0.490163     -0.085543
# 3     -0.280846     -0.062871      0.304244      0.245161      0.119427
# 4     -0.041384     -0.378165      0.110510     -0.199301      0.466708
#
#    Component_58
# 0     -0.015185
# 1      0.597577
# 2      0.028272
# 3     -0.339246
# 4     -0.138377
#
# [5 rows x 59 columns]
# (19819, 59)

# %% [markdown]
# ## LSTM Classification (Many to Many)
# ### Designing the network
#
# - The first step is to define your network.
# - Neural networks are defined in Keras as a sequence of layers. The container for these layers is the **Sequential class**.
# - The first step is to create an instance of the Sequential class. Then you can create your layers and add them in the order that they should be connected.
# - The LSTM recurrent layer comprised of memory units is called LSTM().
# - A fully connected layer that often follows LSTM layers and is used for outputting a prediction is called Dense().
# - The first layer in the network must define the number of inputs to expect.
# - Input must be three-dimensional, comprised of samples, timesteps, and features.
#     - **Samples:** These are the rows in your data.
#     - **Timesteps:** These are the past observations for a feature, such as lag variables.
#     - **Features:** These are columns in your data.
# - Assuming your data is loaded as a NumPy array, you can convert a 2D dataset to a 3D dataset using the reshape() function in NumPy.
#
# ### Relavent Links
#
# Network structure pointers [https://www.heatonresearch.com/2017/06/01/hidden-layers.html]. Rough heuristics to start with:
#
# * The number of hidden neurons should be between the size of the input layer and the size of the output layer.
# * The number of hidden neurons should be 2/3 the size of the input layer, plus the size of the output layer.
# * The number of hidden neurons should be less than twice the size of the input layer.
#
# --------------------------------------------------------------------------------------------
#
# * https://machinelearningmastery.com/models-sequence-prediction-recurrent-neural-networks/
# * https://machinelearningmastery.com/reshape-input-data-long-short-term-memory-networks-keras/
# * https://machinelearningmastery.com/5-step-life-cycle-long-short-term-memory-models-keras/
# * https://machinelearningmastery.com/stacked-long-short-term-memory-networks/
# * https://arxiv.org/pdf/1312.6026.pdf
# * https://machinelearningmastery.com/backtest-machine-learning-models-time-series-forecasting/
# * https://machinelearningmastery.com/understanding-stateful-lstm-recurrent-neural-networks-python-keras/
# * http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %%
# LSTM Class
class LSTM:
    """
    Long Short Term Memory Neural Net Class
    """

    def __init__(self, X, y, lag, loss_func, activation, optimizer='sgd', lstm_layers=1, dropout=.0,
                 stateful=False, y_labels=None, initializer='uniform'):
        """
        Initiating the class creates a net with the established parameters
        :param X             - (Numpy 2D Array) Training data used to train the model (Features).
        :param y             - (Numpy 2D Array) Test data used to test the model (Labels
        :param lag           - (Integer) Denotes lag step value
        :param loss_function - (String)  Denotes mode of measure fitting of model (Fitting function).
        :param activation    - (String)  Neuron activation function used to activate/trigger neurons.
        :param optimizer     - (String)  Denotes which function to us to optimize the model build (eg: Gradient Descent).
        :param lstm_layers   - (Integer) Denotes the number of LSTM layers to be included in the model build.
        :param dropout       - (Float)   Denotes amount of dropout for model. This parameter must be a value between 0 and 1.
        :param stateful      - (Boolean) Denotes whether state is used as initial state for next training batch.
        :param: y_labels     - (List) List of target label names
        :param: initializer  - (String)  String initializer which denotes starting weights.
        """
        self.__lag = lag
        self.__model = ke.models.Sequential()
        self.__y_labels = y_labels

        if dropout > 1 and dropout < 0:
            raise ValueError('Dropout parameter exceeded! Must be a value between 0 and 1.')
        
        # self.__model.add(ke.layers.Embedding(2+1, 32, input_length=X.shape[1]))
        for i in range(0, lstm_layers - 1):  # If lstm_layers == 1, this for loop logic is skipped.
            if stateful:
                if i == 0:
                    self.__model.add(ke.layers.LSTM(X.shape[2],
                                                    batch_input_shape=(X.shape[0],
                                                                       X.shape[1],
                                                                       X.shape[2]),
                                                    return_sequences=True,
                                                    recurrent_dropout=dropout,
                                                    recurrent_initializer=initializer,
                                                    activation=activation,
                                                    stateful=stateful))
                else:
                    self.__model.add(ke.layers.LSTM(X.shape[2],
                                                    input_shape=(X.shape[1],
                                                                 X.shape[2]),
                                                    return_sequences=True,
                                                    recurrent_dropout=dropout,
                                                    recurrent_initializer=initializer,
                                                    activation=activation,
                                                    stateful=stateful))
            else:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                input_shape=(X.shape[1],
                                                             X.shape[2]),
                                                return_sequences=True,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                stateful=stateful))
            self.__model.add(ke.layers.Dropout(dropout))
        if lstm_layers > 1:
            self.__model.add(ke.layers.LSTM(X.shape[2],
                                            input_shape=(X.shape[1],
                                                         X.shape[2]),
                                            stateful=stateful,
                                            recurrent_dropout=dropout,
                                            recurrent_initializer=initializer,
                                            activation=activation,
                                            return_sequences=False))
        else:
            if stateful:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                batch_input_shape=(X.shape[0],
                                                                   X.shape[1],
                                                                   X.shape[2]),
                                                stateful=stateful,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                return_sequences=False))
            else:
                self.__model.add(ke.layers.LSTM(X.shape[2],
                                                input_shape=(X.shape[1],
                                                             X.shape[2]),
                                                stateful=stateful,
                                                recurrent_dropout=dropout,
                                                recurrent_initializer=initializer,
                                                activation=activation,
                                                return_sequences=False))
        self.__model.add(ke.layers.Dropout(dropout))
        # self.__model.add(ke.layers.TimeDistributed(ke.layers.Dense(self.__lag * len(self.__y_labels), kernel_initializer=initializer)))
        self.__model.add(ke.layers.Dense(y.shape[1],
                                         kernel_initializer=initializer,
                                         activation='sigmoid'))
        self.__model.compile(loss=loss_func, optimizer=optimizer, metrics=['mse','mae'])
        print(self.__model.summary())

    def fit_model(self, X_train=None, X_test=None, y_train=None, y_test=None, epochs=50, batch_size=50, verbose=2,
                  shuffle=False, plot=False):
        """
        Fit data to model & validate. Trains a number of epochs.

        :param: X_train    - (Numpy 2D Array) Numpy matrix consisting of input training features
        :param: X_test     - (Numpy 2D Array) Numpy matrix consisting of input validation/testing features
        :param: y_train    - (Numpy 2D Array) Numpy matrix consisting of output training labels
        :param: y_test     - (Numpy 2D Array) Numpy matrix consisting of output validation/testing labels
        :param: epochs     - (Integer) Integer value denoting number of trained epochs
        :param: batch_size - (Integer) Integer value denoting LSTM training batch_size
        :param: verbose    - (Integer) Integer value denoting net verbosity (Amount of information shown to user during LSTM training)
        :param: shuffle    - (Bool) Boolean value denoting whether or not to shuffle data. This parameter must always remain 'False' for time series datasets.
        :param: plot       - (Bool) Boolean value denoting whether this function should plot out it's evaluation

        :return: None
        """
        if X_test is not None and y_test is not None:
            history = self.__model.fit(x=X_train,
                                       y=y_train,
                                       epochs=epochs,
                                       batch_size=batch_size,
                                       validation_data=(X_test, y_test),
                                       verbose=verbose,
                                       shuffle=shuffle)
        else:
            history = self.__model.fit(x=X_train,
                                       y=y_train,
                                       epochs=epochs,
                                       batch_size=batch_size,
                                       verbose=verbose,
                                       shuffle=shuffle)

        if plot:
            plt.rcParams['figure.figsize'] = [20, 15]
            plt.plot(history.history['mean_squared_error'], label='mean_squared_error')
            plt.plot(history.history['mean_absolute_error'], label='mean_absolute_error')
            plt.ylabel('loss')
            plt.xlabel('epoch')
            plt.legend(['train', 'validation'], loc='upper left')
            plt.show()

    def predict(self, X, batch_size):
        """
        Predicts label/s from input feature 'X'
        :param: X - Numpy matrix consisting of a single feature vector
        :param: batch_size - (Integer) Denotes prediction batch size
        :return: Numpy matrix of predicted label output
        """
        yhat = self.__model.predict(X, batch_size=batch_size)
        return yhat

    @staticmethod
    def write_results_to_disk(path, iteration, lag, test_split, batch, dropout, epoch, layer, activation, initializer,
                              stateful, rmse, accuracy, f_score, time_train):
        """
        Static method which is used for test harness utilities. This method attempts a grid search across many
        trained LSTM models, each denoted with different configurations.

        Attempted configurations:
        * Varied data test split
        * Varied batch sizes
        * Varied epoch counts

        Each configuration is denoted with a score, and used to identify the most optimal configuration.

        :param: path       - (String) String denoting result csv output.
        :param: iteration  - (Integer) Integer denoting test iteration (Unique per test configuration).
        :param: lag        - (Integer) Denotes lag time shift
        :param: test_split - (Float) Float denoting data sample sizes.
        :param: batch      - (Integer) Integer denoting LSTM batch size.
        :param: epoch      - (Integer) Integer denoting number of LSTM training iterations.
        :param: layer      - (Integer) Integer denoting number of LSTM layers
        :param: activation - (String) String denoting activation for LSTM layers.
        :param: initializer- (String) String denoting LSTM initializing weights.
        :param: stateful   - (Bool) Boolean flag which denotes whether LSTM model is trained in stateful mode or not.
        :param: dropout    - (Float) Float denoting model dropout layer.
        :param: rmse       - (Float) Float denoting experiment configuration RSME score.
        :param: accuracy   - (Float) Float denoting experiment accuracy score.
        :param: fscore     - (Float) Float denoting experiment fscore score.
        :param: time_train - (Integer) Integer denoting number of seconds taken by LSTM training iteration.

        :return: None
        """
        file_exists = os.path.isfile(path)
        with open(path, 'a+') as csvfile:
            headers = ['iteration', 'test_split', 'batch', 'epoch', 'layer', 'stateful', 'dropout', 'activation',
                       'initializer', 'rmse', 'accuracy', 'f_score', 'time_train', 'lag']
            writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n', fieldnames=headers)
            if not file_exists:
                writer.writeheader()  # file doesn't exist yet, write a header
            writer.writerow({'iteration': iteration,
                             'test_split': test_split,
                             'batch': batch,
                             'epoch': epoch,
                             'layer': layer,
                             'stateful': stateful,
                             'dropout': dropout,
                             'activation': activation,
                             'initializer': initializer,
                             'rmse': rmse,
                             'accuracy': accuracy,
                             'f_score': f_score,
                             'time_train': time_train,
                             'lag': lag})

    @staticmethod
    def lag_multiple(X, lag):
        """
        Divides the total number of rows by the lag value, until a perfect multiple amount is retrieved.
        :param X: (Numpy) 2D array consisting of input.
        :param lag: (Integer) Denotes time shift value.
        :return: (Numpy) 2D array consisting of a perfect lag multiple rows.
        """
        n_rows = X.shape[0]
        multiple = int(n_rows/lag)
        max_new_rows = multiple * lag
        return X[0:max_new_rows, :]

# %% [markdown]
# ### Time Step (1) - Training (CPU)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
y_labels2 = []
for label in y_df.columns:
    if 'var1' in label:
        y_labels2.append(label)
y_df2 = y_df[y_labels2]
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df2, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(9909, 1, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(9909, 13)] Type - <class 'numpy.ndarray'>
# X_validate shape [(9910, 1, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(9910, 13)] Type - <class 'numpy.ndarray'>
# INFO:plaidml:Opening device "opencl_amd_tonga.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 1, 59)             28084
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 59)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 59)                28084
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 59)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                780
# =================================================================
# Total params: 56,948
# Trainable params: 56,948
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 9909 samples, validate on 9910 samples
# Epoch 1/300
#  - 12s - loss: 0.0900 - mean_squared_error: 0.0900 - mean_absolute_error: 0.2727 - val_loss: 0.0763 - val_mean_squared_error: 0.0763 - val_mean_absolute_error: 0.2572
# Epoch 2/300
#  - 3s - loss: 0.0743 - mean_squared_error: 0.0743 - mean_absolute_error: 0.2511 - val_loss: 0.0674 - val_mean_squared_error: 0.0674 - val_mean_absolute_error: 0.2366
# Epoch 3/300
#  - 3s - loss: 0.0661 - mean_squared_error: 0.0661 - mean_absolute_error: 0.2296 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2164
# Epoch 4/300
#  - 3s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.2176 - val_loss: 0.0569 - val_mean_squared_error: 0.0569 - val_mean_absolute_error: 0.2048
# Epoch 5/300
#  - 3s - loss: 0.0591 - mean_squared_error: 0.0591 - mean_absolute_error: 0.2099 - val_loss: 0.0544 - val_mean_squared_error: 0.0544 - val_mean_absolute_error: 0.1976
# Epoch 6/300
#  - 4s - loss: 0.0574 - mean_squared_error: 0.0574 - mean_absolute_error: 0.2049 - val_loss: 0.0532 - val_mean_squared_error: 0.0532 - val_mean_absolute_error: 0.1933
# Epoch 7/300
#  - 3s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.2021 - val_loss: 0.0528 - val_mean_squared_error: 0.0528 - val_mean_absolute_error: 0.1913
# Epoch 8/300
#  - 4s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.2000 - val_loss: 0.0527 - val_mean_squared_error: 0.0527 - val_mean_absolute_error: 0.1904
# Epoch 9/300
#  - 4s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1990 - val_loss: 0.0525 - val_mean_squared_error: 0.0525 - val_mean_absolute_error: 0.1893
# Epoch 10/300
#  - 4s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1976 - val_loss: 0.0524 - val_mean_squared_error: 0.0524 - val_mean_absolute_error: 0.1888
# Epoch 11/300
#  - 4s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1967 - val_loss: 0.0524 - val_mean_squared_error: 0.0524 - val_mean_absolute_error: 0.1879
# Epoch 12/300
#  - 4s - loss: 0.0547 - mean_squared_error: 0.0547 - mean_absolute_error: 0.1960 - val_loss: 0.0523 - val_mean_squared_error: 0.0523 - val_mean_absolute_error: 0.1877
# Epoch 13/300
#  - 4s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1952 - val_loss: 0.0523 - val_mean_squared_error: 0.0523 - val_mean_absolute_error: 0.1873
# Epoch 14/300
#  - 4s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1946 - val_loss: 0.0522 - val_mean_squared_error: 0.0522 - val_mean_absolute_error: 0.1870
# Epoch 15/300
#  - 4s - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1939 - val_loss: 0.0522 - val_mean_squared_error: 0.0522 - val_mean_absolute_error: 0.1867
# Epoch 16/300
#  - 4s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1935 - val_loss: 0.0521 - val_mean_squared_error: 0.0521 - val_mean_absolute_error: 0.1863
# Epoch 17/300
#  - 4s - loss: 0.0538 - mean_squared_error: 0.0538 - mean_absolute_error: 0.1929 - val_loss: 0.0521 - val_mean_squared_error: 0.0521 - val_mean_absolute_error: 0.1859
# Epoch 18/300
#  - 4s - loss: 0.0537 - mean_squared_error: 0.0537 - mean_absolute_error: 0.1926 - val_loss: 0.0521 - val_mean_squared_error: 0.0521 - val_mean_absolute_error: 0.1859
# Epoch 19/300
#  - 4s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1922 - val_loss: 0.0520 - val_mean_squared_error: 0.0520 - val_mean_absolute_error: 0.1856
# Epoch 20/300
#  - 4s - loss: 0.0534 - mean_squared_error: 0.0534 - mean_absolute_error: 0.1917 - val_loss: 0.0520 - val_mean_squared_error: 0.0520 - val_mean_absolute_error: 0.1854
# Epoch 21/300
#  - 4s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1915 - val_loss: 0.0519 - val_mean_squared_error: 0.0519 - val_mean_absolute_error: 0.1852
# Epoch 22/300
#  - 4s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1912 - val_loss: 0.0519 - val_mean_squared_error: 0.0519 - val_mean_absolute_error: 0.1850
# Epoch 23/300
#  - 4s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1907 - val_loss: 0.0519 - val_mean_squared_error: 0.0519 - val_mean_absolute_error: 0.1848
# Epoch 24/300
#  - 4s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1906 - val_loss: 0.0518 - val_mean_squared_error: 0.0518 - val_mean_absolute_error: 0.1846
# Epoch 25/300
#  - 4s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1902 - val_loss: 0.0518 - val_mean_squared_error: 0.0518 - val_mean_absolute_error: 0.1845
# Epoch 26/300
#  - 4s - loss: 0.0528 - mean_squared_error: 0.0528 - mean_absolute_error: 0.1899 - val_loss: 0.0517 - val_mean_squared_error: 0.0517 - val_mean_absolute_error: 0.1843
# Epoch 27/300
#  - 4s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1896 - val_loss: 0.0517 - val_mean_squared_error: 0.0517 - val_mean_absolute_error: 0.1842
# Epoch 28/300
#  - 4s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1898 - val_loss: 0.0517 - val_mean_squared_error: 0.0517 - val_mean_absolute_error: 0.1841
# Epoch 29/300
#  - 4s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1894 - val_loss: 0.0516 - val_mean_squared_error: 0.0516 - val_mean_absolute_error: 0.1839
# Epoch 30/300
#  - 4s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1892 - val_loss: 0.0516 - val_mean_squared_error: 0.0516 - val_mean_absolute_error: 0.1838
# Epoch 31/300
#  - 4s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1891 - val_loss: 0.0516 - val_mean_squared_error: 0.0516 - val_mean_absolute_error: 0.1838
# Epoch 32/300
#  - 4s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1887 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1836
# Epoch 33/300
#  - 4s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1887 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1835
# Epoch 34/300
#  - 4s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1885 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1834
# Epoch 35/300
#  - 4s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1881 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1834
# Epoch 36/300
#  - 4s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1881 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1834
# Epoch 37/300
#  - 4s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1880 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1832
# Epoch 38/300
#  - 4s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1881 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1833
# Epoch 39/300
#  - 4s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1878 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1833
# Epoch 40/300
#  - 4s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1876 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1832
# Epoch 41/300
#  - 4s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1876 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1831
# Epoch 42/300
#  - 4s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1873 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1831
# Epoch 43/300
#  - 4s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1875 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1831
# Epoch 44/300
#  - 4s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1874 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1830
# Epoch 45/300
#  - 4s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1872 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1831
# Epoch 46/300
#  - 4s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1870 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1831
# Epoch 47/300
#  - 4s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1870 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1830
# Epoch 48/300
#  - 4s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1870 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1830
# Epoch 49/300
#  - 4s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1869 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1830
# Epoch 50/300
#  - 4s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1869 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1829
# Epoch 51/300
#  - 4s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1868 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1828
# Epoch 52/300
#  - 4s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1867 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1829
# Epoch 53/300
#  - 4s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1866 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 54/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1865 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1829
# Epoch 55/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1864 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 56/300
#  - 4s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1864 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1828
# Epoch 57/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1864 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1828
# Epoch 58/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1862 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1829
# Epoch 59/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1863 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 60/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1862 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 61/300
#  - 4s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1861 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 62/300
#  - 4s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1862 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 63/300
#  - 4s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1861 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 64/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1858 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1827
# Epoch 65/300
#  - 4s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1859 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 66/300
#  - 4s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1861 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 67/300
#  - 4s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1860 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 68/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1858 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 69/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 70/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 71/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1857 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 72/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1857 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 73/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1856 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 74/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1826
# Epoch 75/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1856 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 76/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 77/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1854 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 78/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 79/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1856 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 80/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1852 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 81/300
#  - 4s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1855 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 82/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1853 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 83/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1851 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 84/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1851 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 85/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1852 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 86/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1851 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 87/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1851 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 88/300
#  - 4s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1852 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 89/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 90/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 91/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 92/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1848 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 93/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 94/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 95/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1848 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1824
# Epoch 96/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1850 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 97/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1848 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 98/300
#  - 4s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1849 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1825
# Epoch 99/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 100/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 101/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 102/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1824
# Epoch 103/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 104/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1844 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 105/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1846 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 106/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1846 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 107/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1847 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1823
# Epoch 108/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1845 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1823
# Epoch 109/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1845 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 110/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1845 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 111/300
#  - 4s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1846 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1822
# Epoch 112/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1844 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1822
# Epoch 113/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1843 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 114/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1844 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 115/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1843 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 116/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1845 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1822
# Epoch 117/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1843 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1823
# Epoch 118/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1842 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 119/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1841 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1822
# Epoch 120/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1841 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1823
# Epoch 121/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1843 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1822
# Epoch 122/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1842 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1820
# Epoch 123/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1842 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 124/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1841 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1820
# Epoch 125/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1842 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1821
# Epoch 126/300
#  - 4s - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1839 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1821
# Epoch 127/300
#  - 4s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1842 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1822
# Epoch 128/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1841 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1820
# Epoch 129/300
#  - 4s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1841 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.
- val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1813
# Epoch 261/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1816 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 262/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1815 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 263/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1816 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1812
# Epoch 264/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1817 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1812
# Epoch 265/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1816 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1814
# Epoch 266/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1815 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1813
# Epoch 267/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1817 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1812
# Epoch 268/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1815 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 269/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1815 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 270/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1816 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1813
# Epoch 271/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1814 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1811
# Epoch 272/300
#  - 5s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 273/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1815 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1811
# Epoch 274/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1814 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1812
# Epoch 275/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 276/300
#  - 4s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1815 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 277/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1814 - val_loss: 0.0514 - val_mean_squared_error: 0.0514 - val_mean_absolute_error: 0.1812
# Epoch 278/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1813 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 279/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1811 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 280/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1813 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1810
# Epoch 281/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 282/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 283/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1813 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 284/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1813
# Epoch 285/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1811 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 286/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1811 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 287/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1811 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 288/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 289/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1813 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 290/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1813 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 291/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 292/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1811
# Epoch 293/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1810 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 294/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 295/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1810 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1810
# Epoch 296/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 297/300
#  - 4s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1812 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 298/300
#  - 4s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1810 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1810
# Epoch 299/300
#  - 4s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1808 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Epoch 300/300
#  - 4s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1809 - val_loss: 0.0515 - val_mean_squared_error: 0.0515 - val_mean_absolute_error: 0.1812
# Wall time: 20min 32s

# %% [markdown]
# ### Timestep (1) - Evaluation  (CPU)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
#NEW
y_actual, y_predicted = [],[]
#NEW
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        #NEW
        y_actual.append(y[0])
        y_predicted.append(yhat[0])
        #NEW
        
        for z in range(yhat.shape[0]):
            y[z] = BinClass.discretize_value(y[z], cpu_avg)
            yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(len(y_labels2)):
        print('Label: ' + str(i))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
    
#NEW
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual, label='y_actual')
plt.plot(y_predicted, label='y_predicted')
plt.title('Predicted vs Actual')
plt.show()

plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[0:100], label='y_actual')
plt.plot(y_predicted[0:100], label='y_predicted')
plt.title('Predicted vs Actual (0-100)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[200:300], label='y_actual')
plt.plot(y_predicted[200:300], label='y_predicted')
plt.title('Predicted vs Actual (200-300)')
plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(y_actual[400:500], label='y_actual')
plt.plot(y_predicted[400:500], label='y_predicted')
plt.title('Predicted vs Actual (400-500)')
plt.show()
#NEW
# Out:
# Day 1
# Feature vectors: (1415, 1, 59)
# Label vectors: (1415, 13)
# Label: 0
# Accuracy: 0.4911660777385159
# F1Score: 0.5141700404858299
# --------------------------
# Label: 0
# Accuracy: 0.5024734982332155
# F1Score: 0.495702005730659
# --------------------------
# Label: 0
# Accuracy: 0.5003533568904593
# F1Score: 0.4366533864541833
# --------------------------
# Label: 0
# Accuracy: 0.5328621908127208
# F1Score: 0.38281979458450044
# --------------------------
# Label: 0
# Accuracy: 0.545583038869258
# F1Score: 0.3391572456320658
# --------------------------
# Label: 0
# Accuracy: 0.508833922261484
# F1Score: 0.4354183590576767
# --------------------------
# Label: 0
# Accuracy: 0.511660777385159
# F1Score: 0.4058469475494411
# --------------------------
# Label: 0
# Accuracy: 0.49045936395759715
# F1Score: 0.38005159071367156
# --------------------------
# Label: 0
# Accuracy: 0.8784452296819788
# F1Score: 0.8660436137071651
# --------------------------
# Label: 0
# Accuracy: 0.9477031802120142
# F1Score: 0.9431643625192012
# --------------------------
# Label: 0
# Accuracy: 0.9717314487632509
# F1Score: 0.9692307692307692
# --------------------------
# Label: 0
# Accuracy: 0.9604240282685512
# F1Score: 0.95679012345679
# --------------------------
# Label: 0
# Accuracy: 0.9625441696113074
# F1Score: 0.960060286360211
# --------------------------
# Averaged Day 13 Accuracy: 0.67724925251427
# F1Score: 0.6219314250370898
# --------------------------
# ----------------------------------------
# Day 2
# Feature vectors: (1415, 1, 59)
# Label vectors: (1415, 13)
# Label:
# Label: 5
# Accuracy: 0.901060070671378
# F1Score: 0.8894154818325434
# --------------------------
# Label: 5
# Accuracy: 0.9604240282685512
# F1Score: 0.9566563467492261
# --------------------------
# Label: 5
# Accuracy: 0.9696113074204947
# F1Score: 0.9662215239591516
# --------------------------
# Label: 5
# Accuracy: 0.9618374558303887
# F1Score: 0.958966565349544
# --------------------------
# Label: 5
# Accuracy: 0.9653710247349824
# F1Score: 0.9615686274509804
# --------------------------
# Averaged Day 13 Accuracy: 0.6746036060523694
# F1Score: 0.6424316169263592
# --------------------------
# ----------------------------------------
# Day 7
# Feature vectors: (1415, 1, 59)
# Label vectors: (1415, 13)
# Label: 6
# Accuracy: 0.4742049469964664
# F1Score: 0.5308953341740228
# --------------------------
# Label: 6
# Accuracy: 0.4975265017667845
# F1Score: 0.5059068797776234
# --------------------------
# Label: 6
# Accuracy: 0.4939929328621908
# F1Score: 0.5
# --------------------------
# Label: 6
# Accuracy: 0.5095406360424029
# F1Score: 0.5373333333333333
# --------------------------
# Label: 6
# Accuracy: 0.5180212014134276
# F1Score: 0.5021897810218978
# --------------------------
# Label: 6
# Accuracy: 0.4989399293286219
# F1Score: 0.5399091499026606
# --------------------------
# Label: 6
# Accuracy: 0.49823321554770317
# F1Score: 0.48920863309352525
# --------------------------
# Label: 6
# Accuracy: 0.5286219081272084
# F1Score: 0.384118190212373
# --------------------------
# Label: 6
# Accuracy: 0.8876325088339223
# F1Score: 0.8747044917257683
# --------------------------
# Label: 6
# Accuracy: 0.9491166077738515
# F1Score: 0.9455370650529501
# --------------------------
# Label: 6
# Accuracy: 0.9681978798586572
# F1Score: 0.9661399548532732
# --------------------------
# Label: 6
# Accuracy: 0.9590106007067137
# F1Score: 0.9518272425249169
# --------------------------
# Label: 6
# Accuracy: 0.9632508833922262
# F1Score: 0.9590551181102362
# --------------------------
# Averaged Day 13 Accuracy: 0.6743447365355493
# F1Score: 0.6461152889454791
# --------------------------
# ----------------------------------------
# Wall time: 7min 26s

# %% [markdown]
# ### Scoring per day  (CPU)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (1) - Training (IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
y_labels2 = []
for label in y_df.columns:
    if 'var2' in label:
        y_labels2.append(label)
y_df2 = y_df[y_labels2]
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df2, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(9909, 1, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(9909, 13)] Type - <class 'numpy.ndarray'>
# X_validate shape [(9910, 1, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(9910, 13)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 1, 59)             28084
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 59)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 59)                28084
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 59)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                780
# =================================================================
# Total params: 56,948
# Trainable params: 56,948
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 9909 samples, validate on 9910 samples
# Epoch 1/300
#  - 4s - loss: 0.0359 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1409 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.1364
# Epoch 2/300
#  - 4s - loss: 0.0343 - mean_squared_error: 0.0343 - mean_absolute_error: 0.1328 - val_loss: 0.0335 - val_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.1287
# Epoch 3/300
#  - 4s - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1262 - val_loss: 0.0318 - val_mean_squared_error: 0.0318 - val_mean_absolute_error: 0.1230
# Epoch 4/300
#  - 4s - loss: 0.0315 - mean_squared_error: 0.0315 - mean_absolute_error: 0.1242 - val_loss: 0.0313 - val_mean_squared_error: 0.0313 - val_mean_absolute_error: 0.1222
# Epoch 5/300
#  - 4s - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1236 - val_loss: 0.0310 - val_mean_squared_error: 0.0310 - val_mean_absolute_error: 0.1216
# Epoch 6/300
#  - 4s - loss: 0.0309 - mean_squared_error: 0.0309 - mean_absolute_error: 0.1229 - val_loss: 0.0308 - val_mean_squared_error: 0.0308 - val_mean_absolute_error: 0.1208
# Epoch 7/300
#  - 5s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1219 - val_loss: 0.0305 - val_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.1200
# Epoch 8/300
#  - 4s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1211 - val_loss: 0.0303 - val_mean_squared_error: 0.0303 - val_mean_absolute_error: 0.1188
# Epoch 9/300
#  - 4s - loss: 0.0301 - mean_squared_error: 0.0301 - mean_absolute_error: 0.1202 - val_loss: 0.0301 - val_mean_squared_error: 0.0301 - val_mean_absolute_error: 0.1180
# Epoch 10/300
#  - 4s - loss: 0.0300 - mean_squared_error: 0.0300 - mean_absolute_error: 0.1197 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - val_mean_absolute_error: 0.1173
# Epoch 11/300
#  - 4s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1190 - val_loss: 0.0298 - val_mean_squared_error: 0.0298 - val_mean_absolute_error: 0.1166
# Epoch 12/300
#  - 5s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1182 - val_loss: 0.0296 - val_mean_squared_error: 0.0296 - val_mean_absolute_error: 0.1159
# Epoch 13/300
#  - 4s - loss: 0.0295 - mean_squared_error: 0.0295 - mean_absolute_error: 0.1178 - val_loss: 0.0295 - val_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.1153
# Epoch 14/300
#  - 5s - loss: 0.0294 - mean_squared_error: 0.0294 - mean_absolute_error: 0.1172 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.1147
# Epoch 15/300
#  - 4s - loss: 0.0293 - mean_squared_error: 0.0293 - mean_absolute_error: 0.1168 - val_loss: 0.0293 - val_mean_squared_error: 0.0293 - val_mean_absolute_error: 0.1143
# Epoch 16/300
#  - 4s - loss: 0.0292 - mean_squared_error: 0.0292 - mean_absolute_error: 0.1165 - val_loss: 0.0292 - val_mean_squared_error: 0.0292 - val_mean_absolute_error: 0.1139
# Epoch 17/300
#  - 4s - loss: 0.0291 - mean_squared_error: 0.0291 - mean_absolute_error: 0.1160 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.1135
# Epoch 18/300
#  - 4s - loss: 0.0290 - mean_squared_error: 0.0290 - mean_absolute_error: 0.1158 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.1132
# Epoch 19/300
#  - 4s - loss: 0.0289 - mean_squared_error: 0.0289 - mean_absolute_error: 0.1153 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 
300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 135/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 136/300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 137/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 138/300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1091
# Epoch 139/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 140/300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 141/300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 142/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 143/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1091
# Epoch 144/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 145/300
#  - 5s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 146/300
#  - 5s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 147/300
#  - 5s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 148/300
#  - 5s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 149/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 150/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1097 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 151/300
#  - 5s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 152/300
#  - 4s - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1098 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 153/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 154/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 155/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1098 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 156/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 157/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 158/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 159/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 160/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 161/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 162/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 163/300
#  - 5s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 164/300
#  - 4s - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1096 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 165/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 166/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 167/300
#  - 5s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 168/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 169/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 170/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1096 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 171/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 172/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 173/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 174/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 175/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 176/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 177/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 178/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 179/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 180/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 181/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 182/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 183/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 184/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 185/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 186/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 187/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 188/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 189/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 190/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 191/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 192/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 193/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 194/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 195/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1092 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1090
# Epoch 196/300
#  - 4s - loss: 0.0266 - mean_squared_error: 0.0266 - mean_absolute_error: 0.1095 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1089
# Epoch 197/300
#  - 5s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 198/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1094 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 199/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 200/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1092 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1091
# Epoch 201/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 202/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 203/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 204/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 205/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 206/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 207/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 208/300
#  - 4s - loss: 0.0265 - mean_squared_error: 0.0265 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 209/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 210/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 211/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 212/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 213/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 214/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1093 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1091
# Epoch 215/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 216/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 217/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 218/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 219/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 220/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1093 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 221/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 222/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 223/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 224/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 225/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 226/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 227/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 228/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 229/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 230/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 231/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 232/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1092 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 233/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 234/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 235/300
#  - 4s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1091 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 236/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 237/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 238/300
#  - 5s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 239/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 240/300
#  - 5s - loss: 0.0264 - mean_squared_error: 0.0264 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 241/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 242/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 243/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 244/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1092
# Epoch 245/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 246/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 247/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 248/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 249/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 250/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 251/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1090
# Epoch 252/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 253/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 254/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 255/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 256/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 257/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 258/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 259/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 260/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1092
# Epoch 261/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 262/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1089 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1092
# Epoch 263/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 264/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 265/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 266/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 267/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 268/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1092
# Epoch 269/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 270/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 271/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 272/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 273/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1090 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 274/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 275/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 276/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 277/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 278/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1093
# Epoch 279/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 280/300
#  - 4s - loss: 0.0263 - mean_squared_error: 0.0263 - mean_absolute_error: 0.1089 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 281/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 282/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1086 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1089
# Epoch 283/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 284/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 285/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 286/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1086 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 287/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 288/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1089 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 289/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 290/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1088 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 291/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1086 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 292/300
#  - 5s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1085 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1090
# Epoch 293/300
#  - 5s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1092
# Epoch 294/300
#  - 5s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1087 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 295/300
#  - 5s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1088 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 296/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1085 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 297/300
#  - 4s - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1086 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1092
# Epoch 298/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Epoch 299/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1086 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.1091
# Epoch 300/300
#  - 4s - loss: 0.0261 - mean_squared_error: 0.0261 - mean_absolute_error: 0.1087 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1091
# Wall time: 21min 2s

# %% [markdown]
# ### Timestep (1) - Evaluation  (IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
#NEW
y_actual, y_predicted = [],[]
#NEW
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        #NEW
        y_actual.append(y[0])
        y_predicted.append(yhat[0])
        #NEW
        
        for z in range(yhat.shape[0]):
            y[z] = BinClass.discretize_value(y[z], io_avg)
            yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(len(y_labels2)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
    
#NEW
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot
# F1Score: 0.8612612612612611
# --------------------------
# Label: 10
# Accuracy: 0.9095406360424029
# F1Score: 0.8917089678510998
# --------------------------
# Label: 11
# Accuracy: 0.9074204946996467
# F1Score: 0.8896377422072453
# --------------------------
# Label: 12
# Accuracy: 0.9159010600706714
# F1Score: 0.896251089799477
# --------------------------
# Averaged Day 13 Accuracy: 0.6343959926998796
# F1Score: 0.5994280613946078
# --------------------------
# ----------------------------------------
# Wall time: 7min 20s

# %% [markdown]
# ### Scoring per day  (IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (1) - Training (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 1
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(9909, 1, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(9909, 26)] Type - <class 'numpy.ndarray'>
# X_validate shape [(9910, 1, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(9910, 26)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 1, 59)             28084
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 59)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 59)                28084
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 59)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 26)                1560
# =================================================================
# Total params: 57,728
# Trainable params: 57,728
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 9909 samples, validate on 9910 samples
# Epoch 1/300
#  - 14s - loss: 0.0636 - mean_squared_error: 0.0636 - mean_absolute_error: 0.2074 - val_loss: 0.0556 - val_mean_squared_error: 0.0556 - val_mean_absolute_error: 0.1961
# Epoch 2/300
#  - 4s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1935 - val_loss: 0.0513 - val_mean_squared_error: 0.0513 - val_mean_absolute_error: 0.1852
# Epoch 3/300
#  - 4s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1820 - val_loss: 0.0471 - val_mean_squared_error: 0.0471 - val_mean_absolute_error: 0.1725
# Epoch 4/300
#  - 4s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1746 - val_loss: 0.0453 - val_mean_squared_error: 0.0453 - val_mean_absolute_error: 0.1666
# Epoch 5/300
#  - 4s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1708 - val_loss: 0.0441 - val_mean_squared_error: 0.0441 - val_mean_absolute_error: 0.1631
# Epoch 6/300
#  - 4s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1685 - val_loss: 0.0437 - val_mean_squared_error: 0.0437 - val_mean_absolute_error: 0.1614
# Epoch 7/300
#  - 4s - loss: 0.0457 - mean_squared_error: 0.0457 - mean_absolute_error: 0.1673 - val_loss: 0.0435 - val_mean_squared_error: 0.0435 - val_mean_absolute_error: 0.1606
# Epoch 8/300
#  - 4s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1665 - val_loss: 0.0434 - val_mean_squared_error: 0.0434 - val_mean_absolute_error: 0.1600
# Epoch 9/300
#  - 4s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1658 - val_loss: 0.0433 - val_mean_squared_error: 0.0433 - val_mean_absolute_error: 0.1595
# Epoch 10/300
#  - 4s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1651 - val_loss: 0.0432 - val_mean_squared_error: 0.0432 - val_mean_absolute_error: 0.1589
# Epoch 11/300
#  - 4s - loss: 0.0449 - mean_squared_error: 0.0449 - mean_absolute_error: 0.1646 - val_loss: 0.0432 - val_mean_squared_error: 0.0432 - val_mean_absolute_error: 0.1586
# Epoch 12/300
#  - 4s - loss: 0.0448 - mean_squared_error: 0.0448 - mean_absolute_error: 0.1642 - val_loss: 0.0432 - val_mean_squared_error: 0.0432 - val_mean_absolute_error: 0.1582
# Epoch 13/300
#  - 4s - loss: 0.0447 - mean_squared_error: 0.0447 - mean_absolute_error: 0.1639 - val_loss: 0.0431 - val_mean_squared_error: 0.0431 - val_mean_absolute_error: 0.1580
# Epoch 14/300
#  - 4s - loss: 0.0445 - mean_squared_error: 0.0445 - mean_absolute_error: 0.1634 - val_loss: 0.0431 - val_mean_squared_error: 0.0431 - val_mean_absolute_error: 0.1576
# Epoch 15/300
#  - 4s - loss: 0.0445 - mean_squared_error: 0.0445 - mean_absolute_error: 0.1631 - val_loss: 0.0430 - val_mean_squared_error: 0.0430 - val_mean_absolute_error: 0.1574
# Epoch 16/300
#  - 4s - loss: 0.0444 - mean_squared_error: 0.0444 - mean_absolute_error: 0.1629 - val_loss: 0.0430 - val_mean_squared_error: 0.0430 - val_mean_absolute_error: 0.1571
# Epoch 17/300
#  - 4s - loss: 0.0442 - mean_squared_error: 0.0442 - mean_absolute_error: 0.1624 - val_loss: 0.0429 - val_mean_squared_error: 0.0429 - val_mean_absolute_error: 0.1568
# Epoch 18/300
#  - 4s - loss: 0.0442 - mean_squared_error: 0.0442 - mean_absolute_error: 0.1622 - val_loss: 0.0428 - val_mean_squared_error: 0.0428 - val_mean_absolute_error: 0.1564
# Epoch 19/300
#  - 4s - loss: 0.0440 - mean_squared_error: 0.0440 - mean_absolute_error: 0.1618 - val_loss: 0.0426 - val_mean_squared_error: 0.0426 - val_mean_absolute_error: 0.1559
# Epoch 20/300
#  - 4s - loss: 0.0438 - mean_squared_error: 0.0438 - mean_absolute_error: 0.1613 - val_loss: 0.0424 - val_mean_squared_error: 0.0424 - val_mean_absolute_error: 0.1551
# Epoch 21/300
#  - 4s - loss: 0.0436 - mean_squared_error: 0.0436 - mean_absolute_error: 0.1608 - val_loss: 0.0421 - val_mean_squared_error: 0.0421 - val_mean_absolute_error: 0.1544
# Epoch 22/300
#  - 4s - loss: 0.0434 - mean_squared_error: 0.0434 - mean_absolute_error: 0.1604 - val_loss: 0.0419 - val_mean_squared_error: 0.0419 - val_mean_absolute_error: 0.1538
# Epoch 23/300
#  - 4s - loss: 0.0433 - mean_squared_error: 0.0433 - mean_absolute_error: 0.1600 - val_loss: 0.0418 - val_mean_squared_error: 0.0418 - val_mean_absolute_error: 0.1532
# Epoch 24/300
#  - 4s - loss: 0.0432 - mean_squared_error: 0.0432 - mean_absolute_error: 0.1599 - val_loss: 0.0416 - val_mean_squared_error: 0.0416 - val_mean_absolute_error: 0.1527
# Epoch 25/300
#  - 4s - loss: 0.0430 - mean_squared_error: 0.0430 - mean_absolute_error: 0.1594 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - val_mean_absolute_error: 0.1522
# Epoch 26/300
#  - 4s - loss: 0.0429 - mean_squared_error: 0.0429 - mean_absolute_error: 0.1590 - val_loss: 0.0413 - val_mean_squared_error: 0.0413 - val_mean_absolute_error: 0.1518
# Epoch 27/300
#  - 4s - loss: 0.0427 - mean_squared_error: 0.0427 - mean_absolute_error: 0.1588 - val_loss: 0.0411 - val_mean_squared_error: 0.0411 - val_mean_absolute_error: 0.1515
# Epoch 28/300
#  - 4s - loss: 0.0427 - mean_squared_error: 0.0427 - mean_absolute_error: 0.1586 - val_loss: 0.0410 - val_mean_squared_error: 0.0410 - val_mean_absolute_error: 0.1511
# Epoch 29/300
#  - 4s - loss: 0.0426 - mean_squared_error: 0.0426 - mean_absolute_error: 0.1584 - val_loss: 0.0410 - val_mean_squared_error: 0.0410 - val_mean_absolute_error: 0.1509
# Epoch 30/300
#  - 4s - loss: 0.0425 - mean_squared_error: 0.0425 - mean_absolute_error: 0.1581 - val_loss: 0.0409 - val_mean_squared_error: 0.0409 - val_mean_absolute_error: 0.1507
# Epoch 31/300
#  - 4s - loss: 0.0423 - mean_squared_error: 0.0423 - mean_absolute_error: 0.1578 - val_loss: 0.0408 - val_mean_squared_error: 0.0408 - val_mean_absolute_error: 0.1506
# Epoch 32/300
#  - 4s - loss: 0.0423 - mean_squared_error: 0.0423 - mean_absolute_error: 0.1577 - val_loss: 0.0407 - val_mean_squared_error: 0.0407 - val_mean_absolute_error: 0.1502
# Epoch 33/300
#  - 4s - loss: 0.0423 - mean_squared_error: 0.0423 - mean_absolute_error: 0.1576 - val_loss: 0.0407 - val_mean_squared_error: 0.0407 - val_mean_absolute_error: 0.1501
# Epoch 34/300
#  - 4s - loss: 0.0421 - mean_squared_error: 0.0421 - mean_absolute_error: 0.1572 - val_loss: 0.0406 - val_mean_squared_error: 0.0406 - val_mean_absolute_error: 0.1499
# Epoch 35/300
#  - 4s - loss: 0.0421 - mean_squared_error: 0.0421 - mean_absolute_error: 0.1570 - val_loss: 0.0406 - val_mean_squared_error: 0.0406 - val_mean_absolute_error: 0.1497
# Epoch 36/300
#  - 4s - loss: 0.0421 - mean_squared_error: 0.0421 - mean_absolute_error: 0.1569 - val_loss: 0.0405 - val_mean_squared_error: 0.0405 - val_mean_absolute_error: 0.1496
# Epoch 37/300
#  - 4s - loss: 0.0420 - mean_squared_error: 0.0420 - mean_absolute_error: 0.1568 - val_loss: 0.0405 - val_mean_squared_error: 0.0405 - val_mean_absolute_error: 0.1495
# Epoch 38/300
#  - 4s - loss: 0.0419 - mean_squared_error: 0.0419 - mean_absolute_error: 0.1566 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.1493
# Epoch 39/300
#  - 4s - loss: 0.0418 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1563 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.1492
# Epoch 40/300
#  - 4s - loss: 0.0418 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1563 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.1490
# Epoch 41/300
#  - 4s - loss: 0.0418 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1563 - val_loss: 0.0403 - val_mean_squared_error: 0.0403 - val_mean_absolute_error: 0.1489
# Epoch 42/300
#  - 4s - loss: 0.0417 - mean_squared_error: 0.0417 - mean_absolute_error: 0.1560 - val_loss: 0.0403 - val_mean_squared_error: 0.0403 - val_mean_absolute_error: 0.1488
# Epoch 43/300
#  - 4s - loss: 0.0417 - mean_squared_error: 0.0417 - mean_absolute_error: 0.1559 - val_loss: 0.0403 - val_mean_squared_error: 0.0403 - val_mean_absolute_error: 0.1489
# Epoch 44/300
- val_loss: 0.0399 - val_mean_squared_error: 0.0399 - val_mean_absolute_error: 0.1475
# Epoch 64/300
#  - 4s - loss: 0.0412 - mean_squared_error: 0.0412 - mean_absolute_error: 0.1541 - val_loss: 0.0399 - val_mean_squared_error: 0.0399 - val_mean_absolute_error: 0.1474
# Epoch 65/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1540 - val_loss: 0.0399 - val_mean_squared_error: 0.0399 - val_mean_absolute_error: 0.1474
# Epoch 66/300
#  - 4s - loss: 0.0412 - mean_squared_error: 0.0412 - mean_absolute_error: 0.1541 - val_loss: 0.0399 - val_mean_squared_error: 0.0399 - val_mean_absolute_error: 0.1474
# Epoch 67/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1539 - val_loss: 0.0399 - val_mean_squared_error: 0.0399 - val_mean_absolute_error: 0.1474
# Epoch 68/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1538 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1473
# Epoch 69/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1539 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1473
# Epoch 70/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1538 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1472
# Epoch 71/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1537 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1472
# Epoch 72/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1538 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1472
# Epoch 73/300
#  - 4s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1537 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1472
# Epoch 74/300
#  - 4s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1537 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1471
# Epoch 75/300
#  - 4s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1534 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1471
# Epoch 76/300
#  - 4s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1535 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1470
# Epoch 77/300
#  - 4s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1535 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1471
# Epoch 78/300
#  - 4s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1533 - val_loss: 0.0398 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1470
# Epoch 79/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1533 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1470
# Epoch 80/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1533 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1469
# Epoch 81/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1533 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1469
# Epoch 82/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1533 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1469
# Epoch 83/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1533 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1468
# Epoch 84/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1531 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1468
# Epoch 85/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1532 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1468
# Epoch 86/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1531 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1468
# Epoch 87/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1531 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1469
# Epoch 88/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1531 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1467
# Epoch 89/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1530 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1467
# Epoch 90/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1531 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1467
# Epoch 91/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1530 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1466
# Epoch 92/300
#  - 4s - loss: 0.0409 - mean_squared_error: 0.0409 - mean_absolute_error: 0.1530 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1467
# Epoch 93/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1528 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1466
# Epoch 94/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1527 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - val_mean_absolute_error: 0.1466
# Epoch 95/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1527 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 96/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1528 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1466
# Epoch 97/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1527 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 98/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1527 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 99/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1527 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 100/300
#  - 4s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1528 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 101/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1527 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 102/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1526 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1464
# Epoch 103/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1525 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1465
# Epoch 104/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1526 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1464
# Epoch 105/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1525 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1464
# Epoch 106/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1526 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1464
# Epoch 107/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1525 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1463
# Epoch 108/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1525 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1462
# Epoch 109/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1525 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1463
# Epoch 110/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1524 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1462
# Epoch 111/300
#  - 4s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1524 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1464
# Epoch 112/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1523 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1463
# Epoch 113/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1523 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1462
# Epoch 114/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1523 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1462
# Epoch 115/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1524 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1462
# Epoch 116/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1523 - val_loss: 0.0396 - val_mean_squared_error: 0.0396 - val_mean_absolute_error: 0.1461
# Epoch 117/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1523 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1462
# Epoch 118/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1522 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1460
# Epoch 119/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1521 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1461
# Epoch 120/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1524 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1461
# Epoch 121/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1522 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1461
# Epoch 122/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.1521 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1461
# Epoch 123/300
#  - 4s - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1520 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1460
# Epoch 124/300
#  - 4s - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1520 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1461
# Epoch 125/300
#  - 4s - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1519 - val_loss: 0.0395 - val_mean_squared_error: 0.0395 - val_mean_absolute_error: 0.1459
# Epoch 126/300
#  - 4s - loss: 0.0406 - mean_squared_error: 0.0406 - mean_absolute_error: 0.
# F1Score: 0.3661417322834646
# --------------------------
# Label: 9
# Accuracy: 0.5328621908127208
# F1Score: 0.4247171453437772
# --------------------------
# Label: 10
# Accuracy: 0.48975265017667846
# F1Score: 0.4972144846796657
# --------------------------
# Label: 11
# Accuracy: 0.4826855123674912
# F1Score: 0.5
# --------------------------
# Label: 12
# Accuracy: 0.519434628975265
# F1Score: 0.4720496894409938
# --------------------------
# Label: 13
# Accuracy: 0.49540636042402825
# F1Score: 0.5102880658436214
# --------------------------
# Label: 14
# Accuracy: 0.488339222614841
# F1Score: 0.539440203562341
# --------------------------
# Label: 15
# Accuracy: 0.5130742049469965
# F1Score: 0.45186953062848056
# --------------------------
# Label: 16
# Accuracy: 0.8833922261484098
# F1Score: 0.8773234200743495
# --------------------------
# Label: 17
# Accuracy: 0.7151943462897526
# F1Score: 0.7155963302752294
# --------------------------
# Label: 18
# Accuracy: 0.9462897526501767
# F1Score: 0.9405320813771519
# --------------------------
# Label: 19
# Accuracy: 0.8713780918727915
# F1Score: 0.8409090909090909
# --------------------------
# Label: 20
# Accuracy: 0.9802120141342756
# F1Score: 0.9782608695652175
# --------------------------
# Label: 21
# Accuracy: 0.893286219081272
# F1Score: 0.8655387355298307
# --------------------------
# Label: 22
# Accuracy: 0.9590106007067137
# F1Score: 0.9573529411764705
# --------------------------
# Label: 23
# Accuracy: 0.8996466431095407
# F1Score: 0.8802698145025294
# --------------------------
# Averaged Day 24 Accuracy: 0.6302961467272422
# F1Score: 0.5912640644787533
# --------------------------
# ----------------------------------------
# Wall time: 7min 28s

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (2) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 2
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(4954, 2, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(4954, 26)] Type - <class 'numpy.ndarray'>
# X_validate shape [(4955, 2, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(4955, 26)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 2, 59)             28084
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 59)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 59)                28084
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 59)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 26)                1560
# =================================================================
# Total params: 57,728
# Trainable params: 57,728
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 4954 samples, validate on 4955 samples
# Epoch 1/300
#  - 14s - loss: 0.0665 - mean_squared_error: 0.0665 - mean_absolute_error: 0.2113 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1999
# Epoch 2/300
#  - 2s - loss: 0.0575 - mean_squared_error: 0.0575 - mean_absolute_error: 0.2004 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1996
# Epoch 3/300
#  - 2s - loss: 0.0573 - mean_squared_error: 0.0573 - mean_absolute_error: 0.2000 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1994
# Epoch 4/300
#  - 2s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1999 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1995
# Epoch 5/300
#  - 2s - loss: 0.0571 - mean_squared_error: 0.0571 - mean_absolute_error: 0.1997 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1994
# Epoch 6/300
#  - 2s - loss: 0.0571 - mean_squared_error: 0.0571 - mean_absolute_error: 0.1995 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1995
# Epoch 7/300
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1996 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1994
# Epoch 8/300
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1994 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1994
# Epoch 9/300
#  - 2s - loss: 0.0569 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1993 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1995
# Epoch 10/300
#  - 2s - loss: 0.0569 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1993 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1995
# Epoch 11/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1991 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1994
# Epoch 12/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1989 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1994
# Epoch 13/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1988 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1995
# Epoch 14/300
#  - 2s - loss: 0.0567 - mean_squared_error: 0.0567 - mean_absolute_error: 0.1987 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1995
# Epoch 15/300
#  - 2s - loss: 0.0566 - mean_squared_error: 0.0566 - mean_absolute_error: 0.1985 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1995
# Epoch 16/300
#  - 2s - loss: 0.0567 - mean_squared_error: 0.0567 - mean_absolute_error: 0.1985 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1995
# Epoch 17/300
#  - 2s - loss: 0.0566 - mean_squared_error: 0.0566 - mean_absolute_error: 0.1984 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1995
# Epoch 18/300
#  - 2s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1982 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1995
# Epoch 19/300
#  - 2s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1980 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1995
# Epoch 20/300
#  - 2s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1979 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1995
# Epoch 21/300
#  - 2s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1977 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.1995
# Epoch 22/300
#  - 2s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1976 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.1997
# Epoch 23/300
#  - 2s - loss: 0.0563 - mean_squared_error: 0.0563 - mean_absolute_error: 0.1976 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.1996
# Epoch 24/300
#  - 2s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1973 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.1997
# Epoch 25/300
#  - 2s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1971 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.1996
# Epoch 26/300
#  - 2s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1970 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.1994
# Epoch 27/300
#  - 2s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1969 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.1996
# Epoch 28/300
#  - 2s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1968 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.1997
# Epoch 29/300
#  - 2s - loss: 0.0560 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1967 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.1996
# Epoch 30/300
#  - 2s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1965 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.1997
# Epoch 31/300
#  - 2s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1964 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1997
# Epoch 32/300
#  - 2s - loss: 0.0558 - mean_squared_error: 0.0558 - mean_absolute_error: 0.1962 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.1997
# Epoch 33/300
#  - 2s - loss: 0.0557 - mean_squared_error: 0.0557 - mean_absolute_error: 0.1960 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1997
# Epoch 34/300
#  - 2s - loss: 0.0557 - mean_squared_error: 0.0557 - mean_absolute_error: 0.1959 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1996
# Epoch 35/300
#  - 2s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1956 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1995
# Epoch 36/300
#  - 2s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1956 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.1996
# Epoch 37/300
#  - 2s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1953 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.1996
# Epoch 38/300
#  - 2s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1952 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.1997
# Epoch 39/300
#  - 2s - loss: 0.0554 - mean_squared_error: 0.0554 - mean_absolute_error: 0.1951 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.1997
# Epoch 40/300
#  - 2s - loss: 0.0553 - mean_squared_error: 0.0553 - mean_absolute_error: 0.1946 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.1997
# Epoch 41/300
#  - 2s - loss: 0.0553 - mean_squared_error: 0.0553 - mean_absolute_error: 0.1945 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.1999
# Epoch 42/300
#  - 2s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1944 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.1997
# Epoch 43/300
#  - 2s - loss: 0.0553 - mean_squared_error: 0.0553 - mean_absolute_error: 0.1945 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.1998
# Epoch 44/300
#  - 2s - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1942 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.1997
# Epoch 45/300
#  - 2s - loss: 0.0550 - mean_squared_error: 0.0550 - mean_absolute_error: 0.1939 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.1999
# Epoch 46/300
#  - 2s - loss: 0.0550 - mean_squared_error: 0.0550 - mean_absolute_error: 0.1938 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.1999
# Epoch 47/300
#  - 2s - loss: 0.0550 - mean_squared_error: 0.0550 - mean_absolute_error: 0.1937 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.1998
# Epoch 48/300
#  - 2s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1934 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.1999
# Epoch 49/300
#  - 2s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1935 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.1999
# Epoch 50/300
#  - 2s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1934 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.1998
# Epoch 51/300
#  - 2s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1932 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - val_mean_absolute_error: 0.1999
# Epoch 52/300
#  - 2s - loss: 0.0547 - mean_squared_error: 0.0547 - mean_absolute_error: 0.1930 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - val_mean_absolute_error: 0.2000
# Epoch 53/300
#  - 2s - loss: 0.0547 - mean_squared_error: 0.0547 - mean_absolute_error: 0.1929 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - val_mean_absolute_error: 0.2000
# Epoch 54/300
#  - 2s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1926 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.1998
# Epoch 55/300
#  - 2s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1926 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.2001
# Epoch 56/300
#  - 2s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1924 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.2001
# Epoch 57/300
#  - 2s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1923 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.2001
# Epoch 58/300
#  - 2s - loss: 0.0544 - mean_squared_error: 0.0544 - mean_absolute_error: 0.1920 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.2000
# Epoch 59/300
#  - 2s - loss: 0.0544 - mean_squared_error: 0.0544 - mean_absolute_error: 0.1920 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.2000
# Epoch 60/300
#  - 2s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1917 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.2001
# Epoch 61/300
#  - 2s - loss: 0.0542 - mean_squared_error: 0.0542 - mean_absolute_error: 0.1914 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2000
# Epoch 62/300
#  - 2s - loss: 0.0542 - mean_squared_error: 0.0542 - mean_absolute_error: 0.1915 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2003
# Epoch 63/300
#  - 2s - loss: 0.0542 - mean_squared_error: 0.0542 - mean_absolute_error: 0.1915 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2000
# Epoch 64/300
#  - 2s - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1913 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2000
# Epoch 65/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1910 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2002
# Epoch 66/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1909 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - val_mean_absolute_error: 0.2002
# Epoch 67/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1908 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - val_mean_absolute_error: 0.2000
# Epoch 68/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1908 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - val_mean_absolute_error: 0.2001
# Epoch 69/300
#  - 2s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1906 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2002
# Epoch 70/300
#  - 2s - loss: 0.0537 - mean_squared_error: 0.0537 - mean_absolute_error: 0.1902 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2003
# Epoch 71/300
#  - 2s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1899 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2002
# Epoch 72/300
#  - 2s - loss: 0.0537 - mean_squared_error: 0.0537 - mean_absolute_error: 0.1900 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2002
# Epoch 73/300
#  - 2s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1898 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2002
# Epoch 74/300
#  - 2s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1894 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2003
# Epoch 75/300
#  - 2s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1895 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2005
# Epoch 76/300
#  - 2s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1894 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.2003
# Epoch 77/300
#  - 2s - loss: 0.0534 - mean_squared_error: 0.0534 - mean_absolute_error: 0.1892 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.2003
# Epoch 78/300
#  - 2s - loss: 0.0534 - mean_squared_error: 0.0534 - mean_absolute_error: 0.1890 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.2005
# Epoch 79/300
#  - 2s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1890 - val_loss: 0.0590 - val_mean_squared_error: 0.0590 - val_mean_absolute_error: 0.2005
# Epoch 80/300
#  - 2s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1889 - val_loss: 0.0590 - val_mean_squared_error: 0.0590 - val_mean_absolute_error: 0.2004
# Epoch 81/300
#  - 2s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1887 - val_loss: 0.0590 - val_mean_squared_error: 0.0590 - val_mean_absolute_error: 0.2003
# Epoch 82/300
#  - 2s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1883 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2005
# Epoch 83/300
#  - 2s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1884 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2005
# Epoch 84/300
#  - 2s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1884 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2007
# Epoch 85/300
#  - 3s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1883 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2005
# Epoch 86/300
#  - 2s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1881 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2006
# Epoch 87/300
#  - 2s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1881 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2005
# Epoch 88/300
#  - 2s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1878 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2006
# Epoch 89/300
#  - 2s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1876 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2006
# Epoch 90/300
#  - 2s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1878 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2007
# Epoch 91/300
#  - 2s - loss: 0.0528 - mean_squared_error: 0.0528 - mean_absolute_error: 0.1874 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2005
# Epoch 92/300
#  - 2s - loss: 0.0528 - mean_squared_error: 0.0528 - mean_absolute_error: 0.1874 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2006
# Epoch 93/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1869 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2007
# Epoch 94/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1870 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2007
# Epoch 95/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1870 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2008
# Epoch 96/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1869 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2007
# Epoch 97/300
#  - 2s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1866 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2006
# Epoch 98/300
#  - 2s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1867 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2007
# Epoch 99/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1867 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2007
# Epoch 100/300
#  - 2s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1865 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2007
# Epoch 101/300
#  - 2s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1861 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2008
# Epoch 102/300
#  - 2s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1863 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2007
# Epoch 103/300
#  - 2s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1862 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2008
# Epoch 104/300
#  - 2s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1862 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2007
# Epoch 105/300
#  - 3s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1859 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2008
# Epoch 106/300
#  - 3s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1859 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2009
# Epoch 107/300
#  - 2s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1857 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2007
# Epoch 108/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1854 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2009
# Epoch 109/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1855 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2009
# Epoch 110/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1855 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2010
# Epoch 111/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1854 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2009
# Epoch 112/300
#  - 3s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1853 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2008
# Epoch 113/300
#  - 2s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1852 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2009
# Epoch 114/300
#  - 2s - loss: 0.0520 - mean_squared_error: 0.0520 - mean_absolute_error: 0.1851 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2010
# Epoch 115/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1852 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2008
# Epoch 116/300
#  - 3s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1851 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2009
# Epoch 117/300
#  - 3s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1846 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2009
# Epoch 118/300
#  - 3s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1845 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2009
# Epoch 119/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1846 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2009
# Epoch 120/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1846 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2009
# Epoch 121/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1845 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2009
# Epoch 122/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1845 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2009
# Epoch 123/300
#  - 2s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1842 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2009
# Epoch 124/300
#  - 3s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1842 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2010
# Epoch 125/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1841 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2010
# Epoch 126/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1843 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2010
# Epoch 127/300
#  - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1838 - val_loss: 0.0599 - val_mean_squared_error: 0.0599 - val_mean_absolute_error: 0.2011
# Epoch 128/300
#  - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1837 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2010
# Epoch 129/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1838 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2012
# Epoch 130/300
#  - 2s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1837 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2011
# Epoch 131/300
#  - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1837 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2012
# Epoch 132/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1837 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2011
# Epoch 133/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1834 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2012
# Epoch 134/300
#  - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1836 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2010
# Epoch 135/300
#  - 2s - loss: 0.0515 - mean_squared_error: 0.0515 - mean_absolute_error: 0.1835 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2010
# Epoch 136/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1832 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2010
# Epoch 137/300
#  - 2s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1834 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 138/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1830 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 139/300
#  - 2s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1834 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 140/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1828 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 141/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1829 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 142/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1829 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2011
# Epoch 143/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1827 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2011
# Epoch 144/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1825 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2012
# Epoch 145/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1828 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2011
# Epoch 146/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1826 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2012
# Epoch 147/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1826 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2012
# Epoch 148/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1823 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2011
# Epoch 149/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1823 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2011
# Epoch 150/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1824 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2011
# Epoch 151/300
#  - 3s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1824 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2012
# Epoch 152/300
#  - 3s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1822 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2012
# Epoch 153/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1822 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2012
# Epoch 154/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1823 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2012
# Epoch 155/300
#  - 2s - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1820 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2012
# Epoch 156/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1820 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2011
# Epoch 157/300
#  - 2s - loss: 0.0509 - mean_squared_error: 0.0509 - mean_absolute_error: 0.1819 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2013
# Epoch 158/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1816 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2012
# Epoch 159/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1816 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2013
# Epoch 160/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1817 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2012
# Epoch 161/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1817 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2012
# Epoch 162/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1815 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2013
# Epoch 163/300
#  - 3s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1815 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2011
# Epoch 164/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1815 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2012
# Epoch 165/300
#  - 2s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1811 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 166/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1815 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2011
# Epoch 167/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1813 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2012
# Epoch 168/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1814 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2012
# Epoch 169/300
#  - 2s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1811 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 170/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1810 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 171/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1810 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2012
# Epoch 172/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1811 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 173/300
#  - 2s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1810 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 174/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1808 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 175/300
#  - 2s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1807 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2014
# Epoch 176/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1807 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2014
# Epoch 177/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1808 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2013
# Epoch 178/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1807 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2014
# Epoch 179/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1805 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2013
# Epoch 180/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1808 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2013
# Epoch 181/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1806 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2014
# Epoch 182/300
#  - 2s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1806 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2013
# Epoch 183/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1808 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2012
# Epoch 184/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1807 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2012
# Epoch 185/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1804 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2013
# Epoch 186/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1802 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2013
# Epoch 187/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1801 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2015
# Epoch 188/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1804 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 189/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1801 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2013
# Epoch 190/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1800 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 191/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1801 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 192/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1800 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2015
# Epoch 193/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1800 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 194/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1799 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 195/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1799 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 196/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1796 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 197/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1797 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2013
# Epoch 198/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1798 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 199/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1798 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2014
# Epoch 200/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1798 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 201/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1798 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2014
# Epoch 202/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1798 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2013
# Epoch 203/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1794 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 204/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1795 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 205/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1795 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 206/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1793 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2014
# Epoch 207/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1790 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 208/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1793 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 209/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1794 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2014
# Epoch 210/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1794 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2014
# Epoch 211/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1792 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 212/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1788 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 213/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1791 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2014
# Epoch 214/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1792 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 215/300
#  - 2s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1788 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 216/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1790 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 217/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1789 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 218/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1792 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2014
# Epoch 219/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1787 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 220/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1786 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2016
# Epoch 221/300
#  - 2s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1787 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 222/300
#  - 2s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1786 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 223/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1788 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 224/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1786 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2016
# Epoch 225/300
#  - 3s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1788 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 226/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1783 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 227/300
#  - 2s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1787 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 228/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1783 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2015
# Epoch 229/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1785 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 230/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1784 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 231/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1780 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 232/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1782 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 233/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1783 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 234/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1782 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 235/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1785 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 236/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1781 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 237/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1783 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 238/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1783 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 239/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1781 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 240/300
#  - 3s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1781 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 241/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1783 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 242/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1778 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 243/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1777 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2015
# Epoch 244/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1779 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2016
# Epoch 245/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1778 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 246/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1780 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 247/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1778 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 248/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1777 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2017
# Epoch 249/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1778 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 250/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1776 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 251/300
#  - 3s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1778 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 252/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1777 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 253/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1776 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 254/300
#  - 3s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1778 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2017
# Epoch 255/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1775 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 256/300
#  - 3s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1779 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 257/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1774 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 258/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 259/300
#  - 3s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1775 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 260/300
#  - 3s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1779 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2015
# Epoch 261/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1776 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 262/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1774 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2017
# Epoch 263/300
#  - 3s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1777 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 264/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1775 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2017
# Epoch 265/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1773 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 266/300
#  - 3s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 267/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1772 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 268/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 269/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1769 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 270/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 271/300
#  - 3s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1772 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 272/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1773 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 273/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1770 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 274/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 275/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1773 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 276/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1770 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 277/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1772 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 278/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1774 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 279/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1769 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 280/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1773 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 281/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1768 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2016
# Epoch 282/300
#  - 3s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1768 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 283/300
#  - 3s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1769 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2016
# Epoch 284/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 285/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1768 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 286/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1766 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 287/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1766 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 288/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1764 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2018
# Epoch 289/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1765 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 290/300
#  - 3s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1765 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 291/300
#  - 3s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1767 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 292/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1765 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2018
# Epoch 293/300
#  - 3s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1765 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 294/300
#  - 3s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1762 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 295/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1766 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 296/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1763 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2018
# Epoch 297/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1763 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Epoch 298/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1767 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2017
# Epoch 299/300
#  - 3s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1765 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2018
# Epoch 300/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1767 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2017
# Wall time: 11min 40s

# %% [markdown]
# ### Timestep (2) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
# Out:
# Day 1
# Feature vectors: (707, 2, 59)
# Label vectors: (707, 26)
# Label: 0
# Accuracy: 0.5247524752475248
# F1Score: 0.4473684210526316
# --------------------------
# Label: 1
# Accuracy: 0.4837340876944837
# F1Score: 0.5397225725094578
# --------------------------
# Label: 2
# Accuracy: 0.5091937765205092
# F1Score: 0.41483979763912315
# --------------------------
# Label: 3
# Accuracy: 0.49222065063649223
# F1Score: 0.48345323741007196
# --------------------------
# Label: 4
# Accuracy: 0.4611032531824611
# F1Score: 0.4486251808972504
# --------------------------
# Label: 5
# Accuracy: 0.48514851485148514
# F1Score: 0.5517241379310345
# --------------------------
# Label: 6
# Accuracy: 0.5106082036775106
# F1Score: 0.3731884057971015
# --------------------------
# Label: 7
# Accuracy: 0.5374823196605375
# F1Score: 0.3524752475247525
# --------------------------
# Label: 8
# Accuracy: 0.5148514851485149
# F1Score: 0.37294332723948814
# --------------------------
# Label: 9
# Accuracy: 0.4681753889674682
# F1Score: 0.3993610223642173
# --------------------------
# Label: 10
# Accuracy: 0.5035360678925035
# F1Score: 0.2880324543610548
# --------------------------
# Label: 11
# Accuracy: 0.5077793493635078
# F1Score: 0.37634408602150543
# --------------------------
# Label: 12
O)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (3) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = 3
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(3303, 3, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(3303, 26)] Type - <class 'numpy.ndarray'>
# X_validate shape [(3303, 3, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(3303, 26)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 3, 59)             28084
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 59)             0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 59)                28084
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 59)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 26)                1560
# =================================================================
# Total params: 57,728
# Trainable params: 57,728
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3303 samples, validate on 3303 samples
# Epoch 1/300
#  - 19s - loss: 0.0693 - mean_squared_error: 0.0693 - mean_absolute_error: 0.2147 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1987
# Epoch 2/300
#  - 2s - loss: 0.0576 - mean_squared_error: 0.0576 - mean_absolute_error: 0.2000 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1997
# Epoch 3/300
#  - 2s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1998 - val_loss: 0.0570 - val_mean_squared_error: 0.0570 - val_mean_absolute_error: 0.1998
# Epoch 4/300
#  - 2s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1998 - val_loss: 0.0570 - val_mean_squared_error: 0.0570 - val_mean_absolute_error: 0.1999
# Epoch 5/300
#  - 2s - loss: 0.0571 - mean_squared_error: 0.0571 - mean_absolute_error: 0.1995 - val_loss: 0.0570 - val_mean_squared_error: 0.0570 - val_mean_absolute_error: 0.1999
# Epoch 6/300
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1994 - val_loss: 0.0570 - val_mean_squared_error: 0.0570 - val_mean_absolute_error: 0.1999
# Epoch 7/300
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0570 - mean_absolute_error: 0.1993 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1999
# Epoch 8/300
#  - 2s - loss: 0.0569 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1991 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1999
# Epoch 9/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1991 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1998
# Epoch 10/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1989 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1998
# Epoch 11/300
#  - 2s - loss: 0.0568 - mean_squared_error: 0.0568 - mean_absolute_error: 0.1988 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.2000
# Epoch 12/300
#  - 2s - loss: 0.0567 - mean_squared_error: 0.0567 - mean_absolute_error: 0.1986 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1999
# Epoch 13/300
#  - 2s - loss: 0.0566 - mean_squared_error: 0.0566 - mean_absolute_error: 0.1984 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.2000
# Epoch 14/300
#  - 2s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1983 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.2000
# Epoch 15/300
#  - 2s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1983 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.2000
# Epoch 16/300
#  - 2s - loss: 0.0564 - mean_squared_error: 0.0564 - mean_absolute_error: 0.1979 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.2000
# Epoch 17/300
#  - 2s - loss: 0.0563 - mean_squared_error: 0.0563 - mean_absolute_error: 0.1977 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.2000
# Epoch 18/300
#  - 2s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1974 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.2001
# Epoch 19/300
#  - 2s - loss: 0.0562 - mean_squared_error: 0.0562 - mean_absolute_error: 0.1972 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.2001
# Epoch 20/300
#  - 2s - loss: 0.0560 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1968 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.2003
# Epoch 21/300
#  - 2s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1967 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - val_mean_absolute_error: 0.2001
# Epoch 22/300
#  - 2s - loss: 0.0558 - mean_squared_error: 0.0558 - mean_absolute_error: 0.1963 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.2002
# Epoch 23/300
#  - 2s - loss: 0.0558 - mean_squared_error: 0.0558 - mean_absolute_error: 0.1962 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.1999
# Epoch 24/300
#  - 2s - loss: 0.0557 - mean_squared_error: 0.0557 - mean_absolute_error: 0.1959 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.2003
# Epoch 25/300
#  - 2s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1957 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.2004
# Epoch 26/300
#  - 2s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1953 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - val_mean_absolute_error: 0.2001
# Epoch 27/300
#  - 2s - loss: 0.0555 - mean_squared_error: 0.0555 - mean_absolute_error: 0.1953 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.2002
# Epoch 28/300
#  - 2s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1946 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.2004
# Epoch 29/300
#  - 2s - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1943 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.2002
# Epoch 30/300
#  - 2s - loss: 0.0551 - mean_squared_error: 0.0551 - mean_absolute_error: 0.1942 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.2007
# Epoch 31/300
#  - 2s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1938 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.2003
# Epoch 32/300
#  - 2s - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1936 - val_loss: 0.0581 - val_mean_squared_error: 0.0581 - val_mean_absolute_error: 0.2004
# Epoch 33/300
#  - 2s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1933 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - val_mean_absolute_error: 0.2003
# Epoch 34/300
#  - 2s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1932 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.2004
# Epoch 35/300
#  - 2s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1929 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - val_mean_absolute_error: 0.2003
# Epoch 36/300
#  - 2s - loss: 0.0545 - mean_squared_error: 0.0545 - mean_absolute_error: 0.1925 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.2005
# Epoch 37/300
#  - 2s - loss: 0.0544 - mean_squared_error: 0.0544 - mean_absolute_error: 0.1923 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2005
# Epoch 38/300
#  - 2s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1918 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2009
# Epoch 39/300
#  - 2s - loss: 0.0543 - mean_squared_error: 0.0543 - mean_absolute_error: 0.1920 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.2005
# Epoch 40/300
#  - 2s - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1913 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - val_mean_absolute_error: 0.2007
# Epoch 41/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1912 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2005
# Epoch 42/300
#  - 2s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1910 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2008
# Epoch 43/300
#  - 2s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1907 - val_loss: 0.0587 - val_mean_squared_error: 0.0587 - val_mean_absolute_error: 0.2006
# Epoch 44/300
#  - 2s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1906 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2008
# Epoch 45/300
#  - 2s - loss: 0.0539 - mean_squared_error: 0.0539 - mean_absolute_error: 0.1906 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - val_mean_absolute_error: 0.2007
# Epoch 46/300
#  - 2s - loss: 0.0537 - mean_squared_error: 0.0537 - mean_absolute_error: 0.1900 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.2009
# Epoch 47/300
#  - 2s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1897 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.2010
# Epoch 48/300
#  - 2s - loss: 0.0535 - mean_squared_error: 0.0535 - mean_absolute_error: 0.1896 - val_loss: 0.0590 - val_mean_squared_error: 0.0590 - val_mean_absolute_error: 0.2009
# Epoch 49/300
#  - 2s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1890 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2008
# Epoch 50/300
#  - 2s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1889 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2009
# Epoch 51/300
#  - 2s - loss: 0.0532 - mean_squared_error: 0.0532 - mean_absolute_error: 0.1887 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2007
# Epoch 52/300
#  - 2s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1884 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - val_mean_absolute_error: 0.2009
# Epoch 53/300
#  - 2s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1880 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2009
# Epoch 54/300
#  - 2s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1877 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2011
# Epoch 55/300
#  - 2s - loss: 0.0530 - mean_squared_error: 0.0530 - mean_absolute_error: 0.1879 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.2010
# Epoch 56/300
#  - 2s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1873 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.2010
# Epoch 57/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1871 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2011
# Epoch 58/300
#  - 2s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1872 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2010
# Epoch 59/300
#  - 2s - loss: 0.0526 - mean_squared_error: 0.0526 - mean_absolute_error: 0.1870 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2010
# Epoch 60/300
#  - 2s - loss: 0.0525 - mean_squared_error: 0.0525 - mean_absolute_error: 0.1865 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2012
# Epoch 61/300
#  - 2s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1864 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2011
# Epoch 62/300
#  - 2s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1863 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2011
# Epoch 63/300
#  - 2s - loss: 0.0523 - mean_squared_error: 0.0523 - mean_absolute_error: 0.1860 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - val_mean_absolute_error: 0.2011
# Epoch 64/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1856 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2013
# Epoch 65/300
#  - 2s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1856 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2011
# Epoch 66/300
#  - 2s - loss: 0.0521 - mean_squared_error: 0.0521 - mean_absolute_error: 0.1854 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2013
# Epoch 67/300
#  - 2s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1849 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2011
# Epoch 68/300
#  - 2s - loss: 0.0519 - mean_squared_error: 0.0519 - mean_absolute_error: 0.1848 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2012
# Epoch 69/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1843 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2011
# Epoch 70/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1841 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2012
# Epoch 71/300
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0516 - mean_absolute_error: 0.1842 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2013
# Epoch 72/300
#  - 2s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1842 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2012
# Epoch 73/300
#  - 2s - loss: 0.0518 - mean_squared_error: 0.0518 - mean_absolute_error: 0.1843 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2013
# Epoch 74/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1834 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - val_mean_absolute_error: 0.2015
# Epoch 75/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1833 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2014
# Epoch 76/300
#  - 2s - loss: 0.0514 - mean_squared_error: 0.0514 - mean_absolute_error: 0.1833 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - val_mean_absolute_error: 0.2015
# Epoch 77/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1833 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2013
# Epoch 78/300
#  - 2s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1830 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2015
# Epoch 79/300
#  - 2s - loss: 0.0512 - mean_squared_error: 0.0512 - mean_absolute_error: 0.1829 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2013
# Epoch 80/300
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1826 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2016
# Epoch 81/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1825 - val_loss: 0.0605 - val_mean_squared_error: 0.0605 - val_mean_absolute_error: 0.2014
# Epoch 82/300
#  - 2s - loss: 0.0510 - mean_squared_error: 0.0510 - mean_absolute_error: 0.1821 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2016
# Epoch 83/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1818 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2016
# Epoch 84/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1815 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2017
# Epoch 85/300
#  - 2s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1817 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2015
# Epoch 86/300
#  - 2s - loss: 0.0505 - mean_squared_error: 0.0505 - mean_absolute_error: 0.1810 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 87/300
#  - 2s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1813 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2017
# Epoch 88/300
#  - 2s - loss: 0.0506 - mean_squared_error: 0.0506 - mean_absolute_error: 0.1811 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2015
# Epoch 89/300
#  - 2s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1806 - val_loss: 0.0608 - val_mean_squared_error: 0.0608 - val_mean_absolute_error: 0.2017
# Epoch 90/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1804 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2017
# Epoch 91/300
#  - 2s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1807 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2018
# Epoch 92/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1802 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2018
# Epoch 93/300
#  - 2s - loss: 0.0502 - mean_squared_error: 0.0502 - mean_absolute_error: 0.1800 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2018
# Epoch 94/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1798 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2018
# Epoch 95/300
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1804 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2017
# Epoch 96/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1796 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - val_mean_absolute_error: 0.2019
# Epoch 97/300
#  - 2s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1796 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2018
# Epoch 98/300
#  - 2s - loss: 0.0501 - mean_squared_error: 0.0501 - mean_absolute_error: 0.1796 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2019
# Epoch 99/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1791 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2019
# Epoch 100/300
#  - 2s - loss: 0.0499 - mean_squared_error: 0.0499 - mean_absolute_error: 0.1791 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2018
# Epoch 101/300
#  - 2s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1791 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2019
# Epoch 102/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1787 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2019
# Epoch 103/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1787 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2019
# Epoch 104/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1783 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2020
# Epoch 105/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1782 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2020
# Epoch 106/300
#  - 2s - loss: 0.0496 - mean_squared_error: 0.0496 - mean_absolute_error: 0.1783 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2019
# Epoch 107/300
#  - 2s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1785 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2019
# Epoch 108/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1783 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2020
# Epoch 109/300
#  - 2s - loss: 0.0495 - mean_squared_error: 0.0495 - mean_absolute_error: 0.1780 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2018
# Epoch 110/300
#  - 2s - loss: 0.0494 - mean_squared_error: 0.0494 - mean_absolute_error: 0.1777 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - val_mean_absolute_error: 0.2020
# Epoch 111/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1776 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - val_mean_absolute_error: 0.2022
# Epoch 112/300
#  - 2s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1776 - val_loss: 0.0616 - val_mean_squared_error: 0.0616 - val_mean_absolute_error: 0.2021
# Epoch 113/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1772 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - val_mean_absolute_error: 0.2023
# Epoch 114/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1775 - val_loss: 0.0616 - val_mean_squared_error: 0.0616 - val_mean_absolute_error: 0.2022
# Epoch 115/300
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0492 - mean_absolute_error: 0.1771 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - val_mean_absolute_error: 0.2021
# Epoch 116/300
#  - 2s - loss: 0.0491 - mean_squared_error: 0.0491 - mean_absolute_error: 0.1769 - val_loss: 0.0616 - val_mean_squared_error: 0.0616 - val_mean_absolute_error: 0.2019
# Epoch 117/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1768 - val_loss: 0.0616 - val_mean_squared_error: 0.0616 - val_mean_absolute_error: 0.2021
# Epoch 118/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1765 - val_loss: 0.0617 - val_mean_squared_error: 0.0617 - val_mean_absolute_error: 0.2021
# Epoch 119/300
#  - 2s - loss: 0.0490 - mean_squared_error: 0.0490 - mean_absolute_error: 0.1766 - val_loss: 0.0617 - val_mean_squared_error: 0.0617 - val_mean_absolute_error: 0.2021
# Epoch 120/300
#  - 2s - loss: 0.0488 - mean_squared_error: 0.0488 - mean_absolute_error: 0.1763 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2023
# Epoch 121/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1765 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2022
# Epoch 122/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1764 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2022
# Epoch 123/300
#  - 2s - loss: 0.0488 - mean_squared_error: 0.0488 - mean_absolute_error: 0.1762 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2023
# Epoch 124/300
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1762 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2025
# Epoch 125/300
#  - 2s - loss: 0.0487 - mean_squared_error: 0.0487 - mean_absolute_error: 0.1759 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - val_mean_absolute_error: 0.2022
# Epoch 126/300
#  - 2s - loss: 0.0485 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1755 - val_loss: 0.0619 - val_mean_squared_error: 0.0619 - val_mean_absolute_error: 0.2023
# Epoch 127/300
#  - 2s - loss: 0.0486 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1755 - val_loss: 0.0619 - val_mean_squared_error: 0.0619 - val_mean_absolute_error: 0.2023
# Epoch 128/300
#  - 2s - loss: 0.0486 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1757 - val_loss: 0.0620 - val_mean_squared_error: 0.0620 - val_mean_absolute_error: 0.2024
# Epoch 129/300
#  - 2s - loss: 0.0485 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1754 - val_loss: 0.0619 - val_mean_squared_error: 0.0619 - val_mean_absolute_error: 0.2024
# Epoch 130/300
#  - 2s - loss: 0.0485 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1754 - val_loss: 0.0621 - val_mean_squared_error: 0.0621 - val_mean_absolute_error: 0.2024
# Epoch 131/300
#  - 2s - loss: 0.0486 - mean_squared_error: 0.0486 - mean_absolute_error: 0.1756 - val_loss: 0.0621 - val_mean_squared_error: 0.0621 - val_mean_absolute_error: 0.2024
# Epoch 132/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1749 - val_loss: 0.0620 - val_mean_squared_error: 0.0620 - val_mean_absolute_error: 0.2024
# Epoch 133/300
#  - 2s - loss: 0.0484 - mean_squared_error: 0.0484 - mean_absolute_error: 0.1751 - val_loss: 0.0620 - val_mean_squared_error: 0.0620 - val_mean_absolute_error: 0.2023
# Epoch 134/300
#  - 2s - loss: 0.0482 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1746 - val_loss: 0.0620 - val_mean_squared_error: 0.0620 - val_mean_absolute_error: 0.2023
# Epoch 135/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1749 - val_loss: 0.0621 - val_mean_squared_error: 0.0621 - val_mean_absolute_error: 0.2023
# Epoch 136/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1747 - val_loss: 0.0621 - val_mean_squared_error: 0.0621 - val_mean_absolute_error: 0.2026
# Epoch 137/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1748 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2027
# Epoch 138/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1746 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2024
# Epoch 139/300
#  - 2s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1743 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2026
# Epoch 140/300
#  - 2s - loss: 0.0483 - mean_squared_error: 0.0483 - mean_absolute_error: 0.1747 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2025
# Epoch 141/300
#  - 2s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1743 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2025
# Epoch 142/300
#  - 2s - loss: 0.0479 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1739 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2025
# Epoch 143/300
#  - 2s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1740 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2026
# Epoch 144/300
#  - 2s - loss: 0.0480 - mean_squared_error: 0.0480 - mean_absolute_error: 0.1737 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2026
# Epoch 145/300
#  - 2s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1741 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2027
# Epoch 146/300
#  - 2s - loss: 0.0479 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1738 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2025
# Epoch 147/300
#  - 2s - loss: 0.0481 - mean_squared_error: 0.0481 - mean_absolute_error: 0.1740 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2026
# Epoch 148/300
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1734 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2026
# Epoch 149/300
#  - 2s - loss: 0.0479 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1735 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2026
# Epoch 150/300
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1733 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2026
# Epoch 151/300
#  - 2s - loss: 0.0479 - mean_squared_error: 0.0479 - mean_absolute_error: 0.1735 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2026
# Epoch 152/300
#  - 2s - loss: 0.0478 - mean_squared_error: 0.0478 - mean_absolute_error: 0.1735 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2026
# Epoch 153/300
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1730 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - val_mean_absolute_error: 0.2026
# Epoch 154/300
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1732 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - val_mean_absolute_error: 0.2028
# Epoch 155/300
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1732 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2026
# Epoch 156/300
#  - 2s - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1729 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - val_mean_absolute_error: 0.2026
# Epoch 157/300
#  - 2s - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1729 - val_loss: 0.0624 - val_mean_squared_error: 0.0624 - val_mean_absolute_error: 0.2027
# Epoch 158/300
#  - 2s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1729 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - val_mean_absolute_error: 0.2027
# Epoch 159/300
#  - 2s - loss: 0.0476 - mean_squared_error: 0.0476 - mean_absolute_error: 0.1729 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2025
# Epoch 160/300
#  - 2s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1725 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2026
# Epoch 161/300
#  - 2s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1725 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2026
# Epoch 162/300
#  - 2s - loss: 0.0478 - mean_squared_error: 0.0478 - mean_absolute_error: 0.1732 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2027
# Epoch 163/300
#  - 2s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1726 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2027
# Epoch 164/300
#  - 2s - loss: 0.0473 - mean_squared_error: 0.0473 - mean_absolute_error: 0.1722 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2027
# Epoch 165/300
#  - 2s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1723 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2027
# Epoch 166/300
#  - 2s - loss: 0.0473 - mean_squared_error: 0.0473 - mean_absolute_error: 0.1720 - val_loss: 0.0627 - val_mean_squared_error: 0.0627 - val_mean_absolute_error: 0.2027
# Epoch 167/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1714 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2029
# Epoch 168/300
#  - 2s - loss: 0.0473 - mean_squared_error: 0.0473 - mean_absolute_error: 0.1718 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2028
# Epoch 169/300
#  - 2s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1715 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2028
# Epoch 170/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1714 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2030
# Epoch 171/300
#  - 2s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1720 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2028
# Epoch 172/300
#  - 2s - loss: 0.0475 - mean_squared_error: 0.0475 - mean_absolute_error: 0.1723 - val_loss: 0.0627 - val_mean_squared_error: 0.0627 - val_mean_absolute_error: 0.2028
# Epoch 173/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1716 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2028
# Epoch 174/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1715 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2029
# Epoch 175/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1715 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2028
# Epoch 176/300
#  - 2s - loss: 0.0471 - mean_squared_error: 0.0471 - mean_absolute_error: 0.1714 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2029
# Epoch 177/300
#  - 2s - loss: 0.0469 - mean_squared_error: 0.0469 - mean_absolute_error: 0.1711 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2030
# Epoch 178/300
#  - 2s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1713 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2030
# Epoch 179/300
#  - 2s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1713 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2029
# Epoch 180/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1707 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2028
# Epoch 181/300
#  - 2s - loss: 0.0469 - mean_squared_error: 0.0469 - mean_absolute_error: 0.1711 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2028
# Epoch 182/300
#  - 2s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1711 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2030
# Epoch 183/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1707 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - val_mean_absolute_error: 0.2028
# Epoch 184/300
#  - 2s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1711 - val_loss: 0.0630 - val_mean_squared_error: 0.0630 - val_mean_absolute_error: 0.2029
# Epoch 185/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1709 - val_loss: 0.0630 - val_mean_squared_error: 0.0630 - val_mean_absolute_error: 0.2030
# Epoch 186/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1706 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2029
# Epoch 187/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1706 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 188/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1707 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2028
# Epoch 189/300
#  - 2s - loss: 0.0467 - mean_squared_error: 0.0467 - mean_absolute_error: 0.1705 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2031
# Epoch 190/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1706 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 191/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1704 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 192/300
#  - 2s - loss: 0.0466 - mean_squared_error: 0.0466 - mean_absolute_error: 0.1702 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2029
# Epoch 193/300
#  - 2s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1704 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 194/300
#  - 2s - loss: 0.0467 - mean_squared_error: 0.0467 - mean_absolute_error: 0.1704 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 195/300
#  - 2s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1700 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2031
# Epoch 196/300
#  - 2s - loss: 0.0467 - mean_squared_error: 0.0467 - mean_absolute_error: 0.1704 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2029
# Epoch 197/300
#  - 3s - loss: 0.0468 - mean_squared_error: 0.0468 - mean_absolute_error: 0.1705 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2030
# Epoch 198/300
#  - 2s - loss: 0.0466 - mean_squared_error: 0.0466 - mean_absolute_error: 0.1699 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2031
# Epoch 199/300
#  - 2s - loss: 0.0464 - mean_squared_error: 0.0464 - mean_absolute_error: 0.1699 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - val_mean_absolute_error: 0.2028
# Epoch 200/300
#  - 2s - loss: 0.0466 - mean_squared_error: 0.0466 - mean_absolute_error: 0.1700 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2030
# Epoch 201/300
#  - 2s - loss: 0.0464 - mean_squared_error: 0.0464 - mean_absolute_error: 0.1698 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2031
# Epoch 202/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1696 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2031
# Epoch 203/300
#  - 2s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1700 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 204/300
#  - 2s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1697 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2031
# Epoch 205/300
#  - 2s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1699 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2030
# Epoch 206/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1692 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2033
# Epoch 207/300
#  - 2s - loss: 0.0464 - mean_squared_error: 0.0464 - mean_absolute_error: 0.1695 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2033
# Epoch 208/300
#  - 2s - loss: 0.0466 - mean_squared_error: 0.0466 - mean_absolute_error: 0.1697 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2030
# Epoch 209/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1690 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 210/300
#  - 2s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1695 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 211/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1693 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2032
# Epoch 212/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1694 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 213/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1692 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2030
# Epoch 214/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1695 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2030
# Epoch 215/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1691 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 216/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1689 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2031
# Epoch 217/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1693 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 218/300
#  - 2s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1692 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2030
# Epoch 219/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1691 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2031
# Epoch 220/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1689 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2031
# Epoch 221/300
#  - 2s - loss: 0.0460 - mean_squared_error: 0.0460 - mean_absolute_error: 0.1687 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2030
# Epoch 222/300
#  - 2s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1691 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2031
# Epoch 223/300
#  - 2s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1687 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2032
# Epoch 224/300
#  - 2s - loss: 0.0460 - mean_squared_error: 0.0460 - mean_absolute_error: 0.1687 - val_loss: 0.0634 - val_mean_squared_error: 0.0634 - val_mean_absolute_error: 0.2030
# Epoch 225/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1689 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 226/300
#  - 2s - loss: 0.0463 - mean_squared_error: 0.0463 - mean_absolute_error: 0.1689 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2033
# Epoch 227/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1685 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 228/300
#  - 2s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1689 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2033
# Epoch 229/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1685 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 230/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1682 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 231/300
#  - 2s - loss: 0.0460 - mean_squared_error: 0.0460 - mean_absolute_error: 0.1683 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2032
# Epoch 232/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1682 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2031
# Epoch 233/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1683 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 234/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1686 - val_loss: 0.0635 - val_mean_squared_error: 0.0635 - val_mean_absolute_error: 0.2032
# Epoch 235/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1681 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2033
# Epoch 236/300
#  - 2s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1687 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2032
# Epoch 237/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1679 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2034
# Epoch 238/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1679 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2034
# Epoch 239/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1681 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2031
# Epoch 240/300
#  - 2s - loss: 0.0460 - mean_squared_error: 0.0460 - mean_absolute_error: 0.1684 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2031
# Epoch 241/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1679 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2033
# Epoch 242/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1681 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2032
# Epoch 243/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1682 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2032
# Epoch 244/300
#  - 2s - loss: 0.0457 - mean_squared_error: 0.0457 - mean_absolute_error: 0.1677 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2033
# Epoch 245/300
#  - 2s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1679 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2033
# Epoch 246/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1680 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2033
# Epoch 247/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1675 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2035
# Epoch 248/300
#  - 2s - loss: 0.0457 - mean_squared_error: 0.0457 - mean_absolute_error: 0.1677 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2035
# Epoch 249/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1675 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 250/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1672 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2035
# Epoch 251/300
#  - 2s - loss: 0.0458 - mean_squared_error: 0.0458 - mean_absolute_error: 0.1677 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - val_mean_absolute_error: 0.2034
# Epoch 252/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1676 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 253/300
#  - 2s - loss: 0.0457 - mean_squared_error: 0.0457 - mean_absolute_error: 0.1675 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 254/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1674 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2035
# Epoch 255/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1669 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 256/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1675 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 257/300
#  - 2s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1670 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 258/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1672 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 259/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1673 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2034
# Epoch 260/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1674 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 261/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1671 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2036
# Epoch 262/300
#  - 2s - loss: 0.0457 - mean_squared_error: 0.0457 - mean_absolute_error: 0.1676 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 263/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1669 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 264/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1672 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 265/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1669 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2034
# Epoch 266/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1669 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2036
# Epoch 267/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1667 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2034
# Epoch 268/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1667 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 269/300
#  - 2s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1670 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 270/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1668 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2035
# Epoch 271/300
#  - 2s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1674 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 272/300
#  - 2s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1670 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2035
# Epoch 273/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1663 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 274/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1667 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2034
# Epoch 275/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1666 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2035
# Epoch 276/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1667 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 277/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1668 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 278/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1665 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 279/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1663 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 280/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1664 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 281/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1666 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 282/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1665 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2036
# Epoch 283/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1665 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2035
# Epoch 284/300
#  - 2s - loss: 0.0454 - mean_squared_error: 0.0454 - mean_absolute_error: 0.1667 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 285/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1661 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2037
# Epoch 286/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1663 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 287/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1661 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2037
# Epoch 288/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1658 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 289/300
#  - 2s - loss: 0.0452 - mean_squared_error: 0.0452 - mean_absolute_error: 0.1663 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 290/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1662 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 291/300
#  - 2s - loss: 0.0449 - mean_squared_error: 0.0449 - mean_absolute_error: 0.1656 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2036
# Epoch 292/300
#  - 2s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1665 - val_loss: 0.0640 - val_mean_squared_error: 0.0640 - val_mean_absolute_error: 0.2034
# Epoch 293/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1660 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2035
# Epoch 294/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1660 - val_loss: 0.0641 - val_mean_squared_error: 0.0641 - val_mean_absolute_error: 0.2035
# Epoch 295/300
#  - 2s - loss: 0.0449 - mean_squared_error: 0.0449 - mean_absolute_error: 0.1658 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - val_mean_absolute_error: 0.2035
# Epoch 296/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1660 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - val_mean_absolute_error: 0.2037
# Epoch 297/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1661 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - val_mean_absolute_error: 0.2036
# Epoch 298/300
#  - 2s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1659 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - val_mean_absolute_error: 0.2036
# Epoch 299/300
#  - 2s - loss: 0.0450 - mean_squared_error: 0.0450 - mean_absolute_error: 0.1658 - val_loss: 0.0643 - val_mean_squared_error: 0.0643 - val_mean_absolute_error: 0.2037
# Epoch 300/300
#  - 2s - loss: 0.0450 - mean_squared_error: 0.0450 - mean_absolute_error: 0.1658 - val_loss: 0.0643 - val_mean_squared_error: 0.0643 - val_mean_absolute_error: 0.2037
# Wall time: 8min 57s

# %% [markdown]
# ### Timestep (3) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(j+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
# Out:
# Day 1
# Feature vectors: (471, 3, 59)
# Label vectors: (471, 26)
# Label: 0
# Accuracy: 0.535031847133758
# F1Score: 0.42819843342036557
# --------------------------
# Label: 1
# Accuracy: 0.47770700636942676
# F1Score: 0.5214007782101168
# --------------------------
# Label: 2
# Accuracy: 0.5286624203821656
# F1Score: 0.4477611940298507
# --------------------------
# Label: 3
# Accuracy: 0.5286624203821656
# F1Score: 0.47393364928909953
# --------------------------
# Label: 4
# Accuracy: 0.5371549893842887
# F1Score: 0.4656862745098039
# --------------------------
# Label: 5
# Accuracy: 0.5074309978768577
# F1Score: 0.5084745762711865
# --------------------------
# Label: 6
# Accuracy: 0.505307855626327
# F1Score: 0.3545706371191135
# --------------------------
# Label: 7
# Accuracy: 0.4989384288747346
# F1Score: 0.5021097046413502
# --------------------------
# Label: 8
# Accuracy: 0.4692144373673036
# F1Score: 0.3055555555555555
# --------------------------
# Label: 9
# Accuracy: 0.46496815286624205
# F1Score: 0.5547703180212015
# --------------------------
# Label: 10
# Accuracy: 0.46496815286624205
# F1Score: 0.411214953271028
# --------------------------
# Label: 11
# Accuracy: 0.4883227176220807
# F1Score: 0.5561694290976059
# --------------------------
# Label: 12
# Accuracy: 0.5159235668789809
# F1Score: 0.39682539682539686
# --------------------------
# Label: 13
# Accuracy: 0.5498938428874734
# F1Score: 0.3872832369942197
# --------------------------
# Label: 14
# Accuracy: 0.49256900212314225
# F1Score: 0.38242894056847554
# --------------------------
# Label: 15
# Accuracy: 0.4819532908704883
# F1Score: 0.42180094786729855
# --------------------------
# Label: 16
# Accuracy: 0.5520169851380042
# F1Score: 0.2214022140221402
# --------------------------
# Label: 17
# Accuracy: 0.4713375796178344
# F1Score: 0.4575163398692811
# --------------------------
# Label: 18
# Accuracy: 0.49044585987261147
# F1Score: 0.3582887700534759
# --------------------------
# Label: 19
# Accuracy: 0.5180467091295117
# F1Score: 0.453012048192771
# --------------------------
# Label: 20
# Accuracy: 0.4883227176220807
# F1Score: 0.35388739946380693
# --------------------------
# Label: 21
# Accuracy: 0.4883227176220807
# F1Score: 0.41927710843373495
# --------------------------
# Label: 22
# Accuracy: 0.4692144373673036
# F1Score: 0.43946188340807174
# --------------------------
# Label: 23
# Accuracy: 0.5095541401273885
# F1Score: 0.5157232704402516
# --------------------------
# Averaged Day 24 Accuracy: 0.5014154281670207
# F1Score: 0.4306980441489667
# --------------------------
# ----------------------------------------
# Day 2
# Feature vectors:
# F1Score: 0.5960061443932412
# --------------------------
# Label: 5
# Accuracy: 0.45222929936305734
# F1Score: 0.5551724137931034
# --------------------------
# Label: 6
# Accuracy: 0.4883227176220807
# F1Score: 0.43559718969555034
# --------------------------
# Label: 7
# Accuracy: 0.5498938428874734
# F1Score: 0.41111111111111104
# --------------------------
# Label: 8
# Accuracy: 0.49044585987261147
# F1Score: 0.441860465116279
# --------------------------
# Label: 9
# Accuracy: 0.4713375796178344
# F1Score: 0.5464480874316939
# --------------------------
# Label: 10
# Accuracy: 0.5498938428874734
# F1Score: 0.2535211267605634
# --------------------------
# Label: 11
# Accuracy: 0.42038216560509556
# F1Score: 0.3837471783295711
# --------------------------
# Label: 12
# Accuracy: 0.4968152866242038
# F1Score: 0.5536723163841808
# --------------------------
# Label: 13
# Accuracy: 0.46709129511677283
# F1Score: 0.6108527131782946
# --------------------------
# Label: 14
# Accuracy: 0.4713375796178344
# F1Score: 0.5146198830409356
# --------------------------
# Label: 15
# Accuracy: 0.5286624203821656
# F1Score: 0.13953488372093026
# --------------------------
# Label: 16
# Accuracy: 0.5010615711252654
# F1Score: 0.6063651591289783
# --------------------------
# Label: 17
# Accuracy: 0.45222929936305734
# F1Score: 0.6114457831325301
# --------------------------
# Label: 18
# Accuracy: 0.4564755838641189
# F1Score: 0.5095785440613028
# --------------------------
# Label: 19
# Accuracy: 0.4607218683651805
# F1Score: 0.5398550724637682
# --------------------------
# Label: 20
# Accuracy: 0.5201698513800425
# F1Score: 0.39893617021276595
# --------------------------
# Label: 21
# Accuracy: 0.40976645435244163
# F1Score: 0.446215139442231
# --------------------------
# Label: 22
# Accuracy: 0.505307855626327
# F1Score: 0.33994334277620397
# --------------------------
# Label: 23
# Accuracy: 0.5626326963906582
# F1Score: 0.09649122807017543
# --------------------------
# Averaged Day 24 Accuracy: 0.5001895662723689
# F1Score: 0.43247164990087256
# --------------------------
# ----------------------------------------
# Wall time: 3min 2s

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()

# %% [markdown]
# ### Time Step (Equal to Lag) - Training  (CPU + IO)
#
# Timestep unrolls the LSTM model N steps during the training phase. This means that the model is influenced from prior data points during training. Training is carried out on half the trace dataset, which equates to about 7 days. The rest is left out, so as to validate the model's accuracy and f1 score.

# %%
# %%time
timestep = lag
X_train, X_validate, y_train, y_validate = train_test_split(X_df, y_df, test_size=test_split)
X_train = X_train.values
y_train = y_train.values
X_validate = X_validate.values
y_validate = y_validate.values

# Lag Multiples
X_train = LSTM.lag_multiple(X=X_train, lag=timestep)
y_train = LSTM.lag_multiple(X=y_train, lag=timestep)
X_validate = LSTM.lag_multiple(X=X_validate, lag=timestep)
y_validate = LSTM.lag_multiple(X=y_validate, lag=timestep)

# Reshape for fitting in LSTM
X_train = X_train.reshape((int(X_train.shape[0] / timestep), timestep, X_train.shape[1]))
y_train = y_train[0:int(y_train.shape[0] / timestep),:]
X_validate = X_validate.reshape((int(X_validate.shape[0] / timestep), timestep, X_validate.shape[1]))
y_validate = y_validate[0:int(y_validate.shape[0] / timestep),:]             

print('\nReshaping Training Frames')
print("X_train shape [" + str(X_train.shape) + "] Type - " + str(type(X_train)))
print("y_train shape [" + str(y_train.shape) + "] Type - " + str(type(y_train)))
print("X_validate shape [" + str(X_validate.shape) + "] Type - " + str(type(X_validate)))
print("y_validate shape [" + str(y_validate.shape) + "] Type - " + str(type(y_validate)))
   
model = LSTM(X=X_train,
             y=y_train,
             lag=lag,
             loss_func='mean_squared_error',
             activation=activation,
             optimizer='adam',
             lstm_layers=layer,
             dropout=dropout,
             stateful=state,
             y_labels=y_label,
             initializer=initializer)

model.fit_model(X_train=X_train,
                X_test=X_validate,
                y_train=y_train,
                y_test=y_validate,
                epochs=epochs,
                batch_size=batch,
                verbose=2,
                shuffle=False,
                plot=True)
# Out:
# Reshaping Training Frames
# X_train shape [(825, 12, 59)] Type - <class 'numpy.ndarray'>
# y_train shape [(825, 26)] Type - <class 'numpy.ndarray'>
# X_validate shape [(825, 12, 59)] Type - <class 'numpy.ndarray'>
# y_validate shape [(825, 26)] Type - <class 'numpy.ndarray'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 12, 59)            28084
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 12, 59)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 59)                28084
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 59)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 26)                1560
# =================================================================
# Total params: 57,728
# Trainable params: 57,728
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 825 samples, validate on 825 samples
# Epoch 1/300
# INFO:plaidml:Analyzing Ops: 1585 of 2778 operations complete
# INFO:plaidml:Analyzing Ops: 2511 of 2778 operations complete
#  - 29s - loss: 0.0748 - mean_squared_error: 0.0748 - mean_absolute_error: 0.2224 - val_loss: 0.0700 - val_mean_squared_error: 0.0700 - val_mean_absolute_error: 0.2152
# Epoch 2/300
#  - 1s - loss: 0.0664 - mean_squared_error: 0.0664 - mean_absolute_error: 0.2125 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1990
# Epoch 3/300
#  - 1s - loss: 0.0598 - mean_squared_error: 0.0598 - mean_absolute_error: 0.2021 - val_loss: 0.0564 - val_mean_squared_error: 0.0564 - val_mean_absolute_error: 0.1984
# Epoch 4/300
#  - 1s - loss: 0.0589 - mean_squared_error: 0.0589 - mean_absolute_error: 0.2035 - val_loss: 0.0563 - val_mean_squared_error: 0.0563 - val_mean_absolute_error: 0.1996
# Epoch 5/300
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0586 - mean_absolute_error: 0.2026 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1981
# Epoch 6/300
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.2017 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1981
# Epoch 7/300
#  - 1s - loss: 0.0584 - mean_squared_error: 0.0584 - mean_absolute_error: 0.2020 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1983
# Epoch 8/300
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0582 - mean_absolute_error: 0.2015 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1982
# Epoch 9/300
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0582 - mean_absolute_error: 0.2015 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1984
# Epoch 10/300
#  - 1s - loss: 0.0581 - mean_squared_error: 0.0581 - mean_absolute_error: 0.2018 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1982
# Epoch 11/300
#  - 1s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.2013 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1982
# Epoch 12/300
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0579 - mean_absolute_error: 0.2012 - val_loss: 0.0562 - val_mean_squared_error: 0.0562 - val_mean_absolute_error: 0.1982
# Epoch 13/300
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0577 - mean_absolute_error: 0.2007 - val_loss: 0.0563 - val_mean_squared_error: 0.0563 - val_mean_absolute_error: 0.1985
# Epoch 14/300
#  - 1s - loss: 0.0575 - mean_squared_error: 0.0575 - mean_absolute_error: 0.2002 - val_loss: 0.0564 - val_mean_squared_error: 0.0564 - val_mean_absolute_error: 0.1983
# Epoch 15/300
#  - 1s - loss: 0.0573 - mean_squared_error: 0.0573 - mean_absolute_error: 0.1997 - val_loss: 0.0565 - val_mean_squared_error: 0.0565 - val_mean_absolute_error: 0.1983
# Epoch 16/300
#  - 1s - loss: 0.0572 - mean_squared_error: 0.0572 - mean_absolute_error: 0.1993 - val_loss: 0.0566 - val_mean_squared_error: 0.0566 - val_mean_absolute_error: 0.1985
# Epoch 17/300
#  - 1s - loss: 0.0569 - mean_squared_error: 0.0569 - mean_absolute_error: 0.1986 - val_loss: 0.0567 - val_mean_squared_error: 0.0567 - val_mean_absolute_error: 0.1982
# Epoch 18/300
#  - 1s - loss: 0.0566 - mean_squared_error: 0.0566 - mean_absolute_error: 0.1978 - val_loss: 0.0569 - val_mean_squared_error: 0.0569 - val_mean_absolute_error: 0.1987
# Epoch 19/300
#  - 1s - loss: 0.0565 - mean_squared_error: 0.0565 - mean_absolute_error: 0.1975 - val_loss: 0.0571 - val_mean_squared_error: 0.0571 - val_mean_absolute_error: 0.1991
# Epoch 20/300
#  - 1s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1968 - val_loss: 0.0572 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1991
# Epoch 21/300
#  - 1s - loss: 0.0559 - mean_squared_error: 0.0559 - mean_absolute_error: 0.1962 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - val_mean_absolute_error: 0.1988
# Epoch 22/300
#  - 1s - loss: 0.0561 - mean_squared_error: 0.0561 - mean_absolute_error: 0.1964 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.1990
# Epoch 23/300
#  - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - mean_absolute_error: 0.1953 - val_loss: 0.0576 - val_mean_squared_error: 0.0576 - val_mean_absolute_error: 0.1994
# Epoch 24/300
#  - 1s - loss: 0.0554 - mean_squared_error: 0.0554 - mean_absolute_error: 0.1946 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - val_mean_absolute_error: 0.1990
# Epoch 25/300
#  - 1s - loss: 0.0552 - mean_squared_error: 0.0552 - mean_absolute_error: 0.1942 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - val_mean_absolute_error: 0.1992
# Epoch 26/300
#  - 1s - loss: 0.0548 - mean_squared_error: 0.0548 - mean_absolute_error: 0.1930 - val_loss: 0.0580 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.1995
# Epoch 27/300
#  - 1s - loss: 0.0544 - mean_squared_error: 0.0544 - mean_absolute_error: 0.1921 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - val_mean_absolute_error: 0.1998
# Epoch 28/300
#  - 1s - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1924 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.2000
# Epoch 29/300
#  - 1s - loss: 0.0541 - mean_squared_error: 0.0541 - mean_absolute_error: 0.1911 - val_loss: 0.0584 - val_mean_squared_error: 0.0584 - val_mean_absolute_error: 0.1998
# Epoch 30/300
#  - 1s - loss: 0.0540 - mean_squared_error: 0.0540 - mean_absolute_error: 0.1910 - val_loss: 0.0585 - val_mean_squared_error: 0.0585 - val_mean_absolute_error: 0.1999
# Epoch 31/300
#  - 1s - loss: 0.0536 - mean_squared_error: 0.0536 - mean_absolute_error: 0.1900 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - val_mean_absolute_error: 0.1996
# Epoch 32/300
#  - 1s - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1895 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - val_mean_absolute_error: 0.1999
# Epoch 33/300
#  - 1s - loss: 0.0531 - mean_squared_error: 0.0531 - mean_absolute_error: 0.1885 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - val_mean_absolute_error: 0.2003
# Epoch 34/300
#  - 1s - loss: 0.0527 - mean_squared_error: 0.0527 - mean_absolute_error: 0.1878 - val_loss: 0.0593 - val_mean_squared_error: 0.0593 - val_mean_absolute_error: 0.1999
# Epoch 35/300
#  - 1s - loss: 0.0529 - mean_squared_error: 0.0529 - mean_absolute_error: 0.1883 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - val_mean_absolute_error: 0.1998
# Epoch 36/300
#  - 1s - loss: 0.0524 - mean_squared_error: 0.0524 - mean_absolute_error: 0.1868 - val_loss: 0.0595 - val_mean_squared_error: 0.0595 - val_mean_absolute_error: 0.2004
# Epoch 37/300
#  - 1s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1860 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - val_mean_absolute_error: 0.2007
# Epoch 38/300
#  - 1s - loss: 0.0522 - mean_squared_error: 0.0522 - mean_absolute_error: 0.1860 - val_loss: 0.0598 - val_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.2014
# Epoch 39/300
#  - 1s - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1846 - val_loss: 0.0601 - val_mean_squared_error: 0.0601 - val_mean_absolute_error: 0.2022
# Epoch 40/300
#  - 1s - loss: 0.0513 - mean_squared_error: 0.0513 - mean_absolute_error: 0.1838 - val_loss: 0.0600 - val_mean_squared_error: 0.0600 - val_mean_absolute_error: 0.2013
# Epoch 41/300
#  - 1s - loss: 0.0511 - mean_squared_error: 0.0511 - mean_absolute_error: 0.1835 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - val_mean_absolute_error: 0.2003
# Epoch 42/300
#  - 1s - loss: 0.0508 - mean_squared_error: 0.0508 - mean_absolute_error: 0.1825 - val_loss: 0.0606 - val_mean_squared_error: 0.0606 - val_mean_absolute_error: 0.2005
# Epoch 43/300
#  - 1s - loss: 0.0507 - mean_squared_error: 0.0507 - mean_absolute_error: 0.1824 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2004
# Epoch 44/300
#  - 1s - loss: 0.0504 - mean_squared_error: 0.0504 - mean_absolute_error: 0.1815 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - val_mean_absolute_error: 0.2010
# Epoch 45/300
#  - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - mean_absolute_error: 0.1803 - val_loss: 0.0609 - val_mean_squared_error: 0.0609 - val_mean_absolute_error: 0.2016
# Epoch 46/300
#  - 1s - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1799 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - val_mean_absolute_error: 0.2018
# Epoch 47/300
#  - 1s - loss: 0.0497 - mean_squared_error: 0.0497 - mean_absolute_error: 0.1791 - val_loss: 0.0611 - val_mean_squared_error: 0.0611 - val_mean_absolute_error: 0.2016
# Epoch 48/300
#  - 1s - loss: 0.0493 - mean_squared_error: 0.0493 - mean_absolute_error: 0.1788 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - val_mean_absolute_error: 0.2019
# Epoch 49/300
#  - 1s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1774 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - val_mean_absolute_error: 0.2017
# Epoch 50/300
#  - 1s - loss: 0.0489 - mean_squared_error: 0.0489 - mean_absolute_error: 0.1773 - val_loss: 0.0620 - val_mean_squared_error: 0.0620 - val_mean_absolute_error: 0.2018
# Epoch 51/300
#  - 1s - loss: 0.0485 - mean_squared_error: 0.0485 - mean_absolute_error: 0.1765 - val_loss: 0.0621 - val_mean_squared_error: 0.0621 - val_mean_absolute_error: 0.2018
# Epoch 52/300
#  - 1s - loss: 0.0484 - mean_squared_error: 0.0484 - mean_absolute_error: 0.1763 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - val_mean_absolute_error: 0.2019
# Epoch 53/300
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0480 - mean_absolute_error: 0.1748 - val_loss: 0.0623 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2022
# Epoch 54/300
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1753 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - val_mean_absolute_error: 0.2021
# Epoch 55/300
#  - 1s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1743 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2024
# Epoch 56/300
#  - 1s - loss: 0.0477 - mean_squared_error: 0.0477 - mean_absolute_error: 0.1739 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - val_mean_absolute_error: 0.2030
# Epoch 57/300
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0470 - mean_absolute_error: 0.1725 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2025
# Epoch 58/300
#  - 1s - loss: 0.0474 - mean_squared_error: 0.0474 - mean_absolute_error: 0.1732 - val_loss: 0.0632 - val_mean_squared_error: 0.0632 - val_mean_absolute_error: 0.2024
# Epoch 59/300
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0469 - mean_absolute_error: 0.1720 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2025
# Epoch 60/300
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0465 - mean_absolute_error: 0.1710 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - val_mean_absolute_error: 0.2032
# Epoch 61/300
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1701 - val_loss: 0.0636 - val_mean_squared_error: 0.0636 - val_mean_absolute_error: 0.2031
# Epoch 62/300
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0461 - mean_absolute_error: 0.1701 - val_loss: 0.0638 - val_mean_squared_error: 0.0638 - val_mean_absolute_error: 0.2028
# Epoch 63/300
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0455 - mean_absolute_error: 0.1684 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - val_mean_absolute_error: 0.2034
# Epoch 64/300
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0456 - mean_absolute_error: 0.1683 - val_loss: 0.0643 - val_mean_squared_error: 0.0643 - val_mean_absolute_error: 0.2036
# Epoch 65/300
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0459 - mean_absolute_error: 0.1687 - val_loss: 0.0645 - val_mean_squared_error: 0.0645 - val_mean_absolute_error: 0.2035
# Epoch 66/300
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1677 - val_loss: 0.0645 - val_mean_squared_error: 0.0645 - val_mean_absolute_error: 0.2036
# Epoch 67/300
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0453 - mean_absolute_error: 0.1674 - val_loss: 0.0642 - val_mean_squared_error: 0.0642 - val_mean_absolute_error: 0.2035
# Epoch 68/300
#  - 1s - loss: 0.0448 - mean_squared_error: 0.0448 - mean_absolute_error: 0.1664 - val_loss: 0.0645 - val_mean_squared_error: 0.0645 - val_mean_absolute_error: 0.2037
# Epoch 69/300
#  - 1s - loss: 0.0448 - mean_squared_error: 0.0448 - mean_absolute_error: 0.1668 - val_loss: 0.0650 - val_mean_squared_error: 0.0650 - val_mean_absolute_error: 0.2031
# Epoch 70/300
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0451 - mean_absolute_error: 0.1664 - val_loss: 0.0646 - val_mean_squared_error: 0.0646 - val_mean_absolute_error: 0.2040
# Epoch 71/300
#  - 1s - loss: 0.0443 - mean_squared_error: 0.0443 - mean_absolute_error: 0.1651 - val_loss: 0.0648 - val_mean_squared_error: 0.0648 - val_mean_absolute_error: 0.2043
# Epoch 72/300
#  - 1s - loss: 0.0440 - mean_squared_error: 0.0440 - mean_absolute_error: 0.1647 - val_loss: 0.0654 - val_mean_squared_error: 0.0654 - val_mean_absolute_error: 0.2034
# Epoch 73/300
#  - 1s - loss: 0.0442 - mean_squared_error: 0.0442 - mean_absolute_error: 0.1646 - val_loss: 0.0652 - val_mean_squared_error: 0.0652 - val_mean_absolute_error: 0.2044
# Epoch 74/300
#  - 1s - loss: 0.0438 - mean_squared_error: 0.0438 - mean_absolute_error: 0.1637 - val_loss: 0.0652 - val_mean_squared_error: 0.0652 - val_mean_absolute_error: 0.2046
# Epoch 75/300
#  - 1s - loss: 0.0438 - mean_squared_error: 0.0438 - mean_absolute_error: 0.1639 - val_loss: 0.0654 - val_mean_squared_error: 0.0654 - val_mean_absolute_error: 0.2043
# Epoch 76/300
#  - 1s - loss: 0.0438 - mean_squared_error: 0.0438 - mean_absolute_error: 0.1635 - val_loss: 0.0657 - val_mean_squared_error: 0.0657 - val_mean_absolute_error: 0.2044
# Epoch 77/300
#  - 1s - loss: 0.0432 - mean_squared_error: 0.0432 - mean_absolute_error: 0.1625 - val_loss: 0.0660 - val_mean_squared_error: 0.0660 - val_mean_absolute_error: 0.2044
# Epoch 78/300
#  - 1s - loss: 0.0432 - mean_squared_error: 0.0432 - mean_absolute_error: 0.1622 - val_loss: 0.0659 - val_mean_squared_error: 0.0659 - val_mean_absolute_error: 0.2048
# Epoch 79/300
#  - 1s - loss: 0.0435 - mean_squared_error: 0.0435 - mean_absolute_error: 0.1626 - val_loss: 0.0658 - val_mean_squared_error: 0.0658 - val_mean_absolute_error: 0.2044
# Epoch 80/300
#  - 1s - loss: 0.0430 - mean_squared_error: 0.0430 - mean_absolute_error: 0.1618 - val_loss: 0.0661 - val_mean_squared_error: 0.0661 - val_mean_absolute_error: 0.2041
# Epoch 81/300
#  - 1s - loss: 0.0427 - mean_squared_error: 0.0427 - mean_absolute_error: 0.1609 - val_loss: 0.0663 - val_mean_squared_error: 0.0663 - val_mean_absolute_error: 0.2051
# Epoch 82/300
#  - 1s - loss: 0.0425 - mean_squared_error: 0.0425 - mean_absolute_error: 0.1602 - val_loss: 0.0664 - val_mean_squared_error: 0.0664 - val_mean_absolute_error: 0.2046
# Epoch 83/300
#  - 1s - loss: 0.0422 - mean_squared_error: 0.0422 - mean_absolute_error: 0.1597 - val_loss: 0.0664 - val_mean_squared_error: 0.0664 - val_mean_absolute_error: 0.2046
# Epoch 84/300
#  - 1s - loss: 0.0420 - mean_squared_error: 0.0420 - mean_absolute_error: 0.1592 - val_loss: 0.0661 - val_mean_squared_error: 0.0661 - val_mean_absolute_error: 0.2050
# Epoch 85/300
#  - 1s - loss: 0.0419 - mean_squared_error: 0.0419 - mean_absolute_error: 0.1594 - val_loss: 0.0668 - val_mean_squared_error: 0.0668 - val_mean_absolute_error: 0.2047
# Epoch 86/300
#  - 1s - loss: 0.0418 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1587 - val_loss: 0.0668 - val_mean_squared_error: 0.0668 - val_mean_absolute_error: 0.2051
# Epoch 87/300
#  - 1s - loss: 0.0420 - mean_squared_error: 0.0420 - mean_absolute_error: 0.1588 - val_loss: 0.0667 - val_mean_squared_error: 0.0667 - val_mean_absolute_error: 0.2051
# Epoch 88/300
#  - 1s - loss: 0.0421 - mean_squared_error: 0.0421 - mean_absolute_error: 0.1595 - val_loss: 0.0667 - val_mean_squared_error: 0.0667 - val_mean_absolute_error: 0.2051
# Epoch 89/300
#  - 1s - loss: 0.0414 - mean_squared_error: 0.0414 - mean_absolute_error: 0.1579 - val_loss: 0.0668 - val_mean_squared_error: 0.0668 - val_mean_absolute_error: 0.2051
# Epoch 90/300
#  - 1s - loss: 0.0417 - mean_squared_error: 0.0417 - mean_absolute_error: 0.1582 - val_loss: 0.0671 - val_mean_squared_error: 0.0671 - val_mean_absolute_error: 0.2052
# Epoch 91/300
#  - 1s - loss: 0.0411 - mean_squared_error: 0.0411 - mean_absolute_error: 0.1572 - val_loss: 0.0673 - val_mean_squared_error: 0.0673 - val_mean_absolute_error: 0.2056
# Epoch 92/300
#  - 1s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1567 - val_loss: 0.0674 - val_mean_squared_error: 0.0674 - val_mean_absolute_error: 0.2059
# Epoch 93/300
#  - 1s - loss: 0.0410 - mean_squared_error: 0.0410 - mean_absolute_error: 0.1568 - val_loss: 0.0675 - val_mean_squared_error: 0.0675 - val_mean_absolute_error: 0.2056
# Epoch 94/300
#  - 1s - loss: 0.0404 - mean_squared_error: 0.0404 - mean_absolute_error: 0.1555 - val_loss: 0.0679 - val_mean_squared_error: 0.0679 - val_mean_absolute_error: 0.2061
# Epoch 95/300
#  - 1s - loss: 0.0407 - mean_squared_error: 0.0407 - mean_absolute_error: 0.1554 - val_loss: 0.0680 - val_mean_squared_error: 0.0680 - val_mean_absolute_error: 0.2059
# Epoch 96/300
#  - 1s - loss: 0.0405 - mean_squared_error: 0.0405 - mean_absolute_error: 0.1552 - val_loss: 0.0680 - val_mean_squared_error: 0.0680 - val_mean_absolute_error: 0.2061
# Epoch 97/300
#  - 1s - loss: 0.0402 - mean_squared_error: 0.0402 - mean_absolute_error: 0.1548 - val_loss: 0.0679 - val_mean_squared_error: 0.0679 - val_mean_absolute_error: 0.2064
# Epoch 98/300
#  - 1s - loss: 0.0404 - mean_squared_error: 0.0404 - mean_absolute_error: 0.1549 - val_loss: 0.0683 - val_mean_squared_error: 0.0683 - val_mean_absolute_error: 0.2063
# Epoch 99/300
#  - 1s - loss: 0.0402 - mean_squared_error: 0.0402 - mean_absolute_error: 0.1544 - val_loss: 0.0682 - val_mean_squared_error: 0.0682 - val_mean_absolute_error: 0.2063
# Epoch 100/300
#  - 1s - loss: 0.0398 - mean_squared_error: 0.0398 - mean_absolute_error: 0.1536 - val_loss: 0.0682 - val_mean_squared_error: 0.0682 - val_mean_absolute_error: 0.2063
# Epoch 101/300
#  - 1s - loss: 0.0400 - mean_squared_error: 0.0400 - mean_absolute_error: 0.1535 - val_loss: 0.0684 - val_mean_squared_error: 0.0684 - val_mean_absolute_error: 0.2068
# Epoch 102/300
#  - 1s - loss: 0.0398 - mean_squared_error: 0.0398 - mean_absolute_error: 0.1538 - val_loss: 0.0685 - val_mean_squared_error: 0.0685 - val_mean_absolute_error: 0.2063
# Epoch 103/300
#  - 1s - loss: 0.0399 - mean_squared_error: 0.0399 - mean_absolute_error: 0.1537 - val_loss: 0.0684 - val_mean_squared_error: 0.0684 - val_mean_absolute_error: 0.2064
# Epoch 104/300
#  - 1s - loss: 0.0397 - mean_squared_error: 0.0397 - mean_absolute_error: 0.1530 - val_loss: 0.0687 - val_mean_squared_error: 0.0687 - val_mean_absolute_error: 0.2066
# Epoch 105/300
#  - 1s - loss: 0.0393 - mean_squared_error: 0.0393 - mean_absolute_error: 0.1526 - val_loss: 0.0689 - val_mean_squared_error: 0.0689 - val_mean_absolute_error: 0.2067
# Epoch 106/300
#  - 1s - loss: 0.0392 - mean_squared_error: 0.0392 - mean_absolute_error: 0.1520 - val_loss: 0.0689 - val_mean_squared_error: 0.0689 - val_mean_absolute_error: 0.2070
# Epoch 107/300
#  - 1s - loss: 0.0392 - mean_squared_error: 0.0392 - mean_absolute_error: 0.1515 - val_loss: 0.0691 - val_mean_squared_error: 0.0691 - val_mean_absolute_error: 0.2070
# Epoch 108/300
#  - 1s - loss: 0.0390 - mean_squared_error: 0.0390 - mean_absolute_error: 0.1516 - val_loss: 0.0690 - val_mean_squared_error: 0.0690 - val_mean_absolute_error: 0.2066
# Epoch 109/300
#  - 1s - loss: 0.0392 - mean_squared_error: 0.0392 - mean_absolute_error: 0.1517 - val_loss: 0.0688 - val_mean_squared_error: 0.0688 - val_mean_absolute_error: 0.2070
# Epoch 110/300
#  - 1s - loss: 0.0391 - mean_squared_error: 0.0391 - mean_absolute_error: 0.1520 - val_loss: 0.0692 - val_mean_squared_error: 0.0692 - val_mean_absolute_error: 0.2068
# Epoch 111/300
#  - 1s - loss: 0.0392 - mean_squared_error: 0.0392 - mean_absolute_error: 0.1515 - val_loss: 0.0691 - val_mean_squared_error: 0.0691 - val_mean_absolute_error: 0.2067
# Epoch 112/300
#  - 1s - loss: 0.0387 - mean_squared_error: 0.0387 - mean_absolute_error: 0.1508 - val_loss: 0.0691 - val_mean_squared_error: 0.0691 - val_mean_absolute_error: 0.2070
# Epoch 113/300
#  - 1s - loss: 0.0388 - mean_squared_error: 0.0388 - mean_absolute_error: 0.1510 - val_loss: 0.0694 - val_mean_squared_error: 0.0694 - val_mean_absolute_error: 0.2072
# Epoch 114/300
#  - 1s - loss: 0.0388 - mean_squared_error: 0.0388 - mean_absolute_error: 0.1510 - val_loss: 0.0695 - val_mean_squared_error: 0.0695 - val_mean_absolute_error: 0.2073
# Epoch 115/300
#  - 1s - loss: 0.0382 - mean_squared_error: 0.0382 - mean_absolute_error: 0.1497 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - val_mean_absolute_error: 0.2072
# Epoch 116/300
#  - 1s - loss: 0.0381 - mean_squared_error: 0.0381 - mean_absolute_error: 0.1490 - val_loss: 0.0697 - val_mean_squared_error: 0.0697 - val_mean_absolute_error: 0.2074
# Epoch 117/300
#  - 1s - loss: 0.0380 - mean_squared_error: 0.0380 - mean_absolute_error: 0.1491 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - val_mean_absolute_error: 0.2069
# Epoch 118/300
#  - 1s - loss: 0.0384 - mean_squared_error: 0.0384 - mean_absolute_error: 0.1497 - val_loss: 0.0694 - val_mean_squared_error: 0.0694 - val_mean_absolute_error: 0.2076
# Epoch 119/300
#  - 1s - loss: 0.0380 - mean_squared_error: 0.0380 - mean_absolute_error: 0.1494 - val_loss: 0.0696 - val_mean_squared_error: 0.0696 - val_mean_absolute_error: 0.2073
# Epoch 120/300
#  - 1s - loss: 0.0380 - mean_squared_error: 0.0380 - mean_absolute_error: 0.1489 - val_loss: 0.0697 - val_mean_squared_error: 0.0697 - val_mean_absolute_error: 0.2074
# Epoch 121/300
#  - 1s - loss: 0.0377 - mean_squared_error: 0.0377 - mean_absolute_error: 0.1485 - val_loss: 0.0696 - val_mean_squared_error: 0.0696 - val_mean_absolute_error: 0.2072
# Epoch 122/300
#  - 1s - loss: 0.0377 - mean_squared_error: 0.0377 - mean_absolute_error: 0.1485 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - val_mean_absolute_error: 0.2077
# Epoch 123/300
#  - 1s - loss: 0.0380 - mean_squared_error: 0.0380 - mean_absolute_error: 0.1489 - val_loss: 0.0700 - val_mean_squared_error: 0.0700 - val_mean_absolute_error: 0.2077
# Epoch 124/300
#  - 1s - loss: 0.0378 - mean_squared_error: 0.0378 - mean_absolute_error: 0.1482 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - val_mean_absolute_error: 0.2076
# Epoch 125/300
#  - 1s - loss: 0.0376 - mean_squared_error: 0.0376 - mean_absolute_error: 0.1474 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - val_mean_absolute_error: 0.2074
# Epoch 126/300
#  - 1s - loss: 0.0373 - mean_squared_error: 0.0373 - mean_absolute_error: 0.1474 - val_loss: 0.0700 - val_mean_squared_error: 0.0700 - val_mean_absolute_error: 0.2074
# Epoch 127/300
#  - 1s - loss: 0.0370 - mean_squared_error: 0.0370 - mean_absolute_error: 0.1462 - val_loss: 0.0702 - val_mean_squared_error: 0.0702 - val_mean_absolute_error: 0.2077
# Epoch 128/300
#  - 1s - loss: 0.0370 - mean_squared_error: 0.0370 - mean_absolute_error: 0.1466 - val_loss: 0.0702 - val_mean_squared_error: 0.0702 - val_mean_absolute_error: 0.2074
# Epoch 129/300
#  - 1s - loss: 0.0370 - mean_squared_error: 0.0370 - mean_absolute_error: 0.1467 - val_loss: 0.0704 - val_mean_squared_error: 0.0704 - val_mean_absolute_error: 0.2077
# Epoch 130/300
#  - 1s - loss: 0.0373 - mean_squared_error: 0.0373 - mean_absolute_error: 0.1466 - val_loss: 0.0705 - val_mean_squared_error: 0.0705 - val_mean_absolute_error: 0.2078
# Epoch 131/300
#  - 1s - loss: 0.0371 - mean_squared_error: 0.0371 - mean_absolute_error: 0.1467 - val_loss: 0.0703 - val_mean_squared_error: 0.0703 - val_mean_absolute_error: 0.2078
# Epoch 132/300
#  - 1s - loss: 0.0369 - mean_squared_error: 0.0369 - mean_absolute_error: 0.1458 - val_loss: 0.0703 - val_mean_squared_error: 0.0703 - val_mean_absolute_error: 0.2076
# Epoch 133/300
#  - 1s - loss: 0.0371 - mean_squared_error: 0.0371 - mean_absolute_error: 0.1469 - val_loss: 0.0700 - val_mean_squared_error: 0.0700 - val_mean_absolute_error: 0.2079
# Epoch 134/300
#  - 1s - loss: 0.0368 - mean_squared_error: 0.0368 - mean_absolute_error: 0.1463 - val_loss: 0.0705 - val_mean_squared_error: 0.0705 - val_mean_absolute_error: 0.2077
# Epoch 135/300
#  - 1s - loss: 0.0367 - mean_squared_error: 0.0367 - mean_absolute_error: 0.1456 - val_loss: 0.0707 - val_mean_squared_error: 0.0707 - val_mean_absolute_error: 0.2082
# Epoch 136/300
#  - 1s - loss: 0.0365 - mean_squared_error: 0.0365 - mean_absolute_error: 0.1455 - val_loss: 0.0711 - val_mean_squared_error: 0.0711 - val_mean_absolute_error: 0.2082
# Epoch 137/300
#  - 1s - loss: 0.0359 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1435 - val_loss: 0.0708 - val_mean_squared_error: 0.0708 - val_mean_absolute_error: 0.2084
# Epoch 138/300
#  - 1s - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1442 - val_loss: 0.0705 - val_mean_squared_error: 0.0705 - val_mean_absolute_error: 0.2079
# Epoch 139/300
#  - 1s - loss: 0.0362 - mean_squared_error: 0.0362 - mean_absolute_error: 0.1447 - val_loss: 0.0708 - val_mean_squared_error: 0.0708 - val_mean_absolute_error: 0.2081
# Epoch 140/300
#  - 1s - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1446 - val_loss: 0.0711 - val_mean_squared_error: 0.0711 - val_mean_absolute_error: 0.2080
# Epoch 141/300
#  - 1s - loss: 0.0357 - mean_squared_error: 0.0357 - mean_absolute_error: 0.1431 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2086
# Epoch 142/300
#  - 1s - loss: 0.0358 - mean_squared_error: 0.0358 - mean_absolute_error: 0.1433 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2087
# Epoch 143/300
#  - 1s - loss: 0.0355 - mean_squared_error: 0.0355 - mean_absolute_error: 0.1427 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2083
# Epoch 144/300
#  - 1s - loss: 0.0361 - mean_squared_error: 0.0361 - mean_absolute_error: 0.1441 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2086
# Epoch 145/300
#  - 1s - loss: 0.0358 - mean_squared_error: 0.0358 - mean_absolute_error: 0.1437 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2084
# Epoch 146/300
#  - 1s - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1438 - val_loss: 0.0713 - val_mean_squared_error: 0.0713 - val_mean_absolute_error: 0.2089
# Epoch 147/300
#  - 1s - loss: 0.0359 - mean_squared_error: 0.0359 - mean_absolute_error: 0.1436 - val_loss: 0.0714 - val_mean_squared_error: 0.0714 - val_mean_absolute_error: 0.2085
# Epoch 148/300
#  - 1s - loss: 0.0353 - mean_squared_error: 0.0353 - mean_absolute_error: 0.1422 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2089
# Epoch 149/300
#  - 1s - loss: 0.0360 - mean_squared_error: 0.0360 - mean_absolute_error: 0.1436 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2088
# Epoch 150/300
#  - 1s - loss: 0.0354 - mean_squared_error: 0.0354 - mean_absolute_error: 0.1428 - val_loss: 0.0715 - val_mean_squared_error: 0.0715 - val_mean_absolute_error: 0.2087
# Epoch 151/300
#  - 1s - loss: 0.0357 - mean_squared_error: 0.0357 - mean_absolute_error: 0.1434 - val_loss: 0.0715 - val_mean_squared_error: 0.0715 - val_mean_absolute_error: 0.2090
# Epoch 152/300
#  - 1s - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1414 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2087
# Epoch 153/300
#  - 1s - loss: 0.0349 - mean_squared_error: 0.0349 - mean_absolute_error: 0.1411 - val_loss: 0.0716 - val_mean_squared_error: 0.0716 - val_mean_absolute_error: 0.2089
# Epoch 154/300
#  - 1s - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1414 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2084
# Epoch 155/300
#  - 1s - loss: 0.0353 - mean_squared_error: 0.0353 - mean_absolute_error: 0.1424 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2089
# Epoch 156/300
#  - 1s - loss: 0.0351 - mean_squared_error: 0.0351 - mean_absolute_error: 0.1420 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2084
# Epoch 157/300
#  - 1s - loss: 0.0351 - mean_squared_error: 0.0351 - mean_absolute_error: 0.1417 - val_loss: 0.0715 - val_mean_squared_error: 0.0715 - val_mean_absolute_error: 0.2086
# Epoch 158/300
#  - 1s - loss: 0.0350 - mean_squared_error: 0.0350 - mean_absolute_error: 0.1415 - val_loss: 0.0716 - val_mean_squared_error: 0.0716 - val_mean_absolute_error: 0.2086
# Epoch 159/300
#  - 1s - loss: 0.0349 - mean_squared_error: 0.0349 - mean_absolute_error: 0.1410 - val_loss: 0.0716 - val_mean_squared_error: 0.0716 - val_mean_absolute_error: 0.2084
# Epoch 160/300
#  - 1s - loss: 0.0349 - mean_squared_error: 0.0349 - mean_absolute_error: 0.1409 - val_loss: 0.0717 - val_mean_squared_error: 0.0717 - val_mean_absolute_error: 0.2089
# Epoch 161/300
#  - 1s - loss: 0.0351 - mean_squared_error: 0.0351 - mean_absolute_error: 0.1414 - val_loss: 0.0718 - val_mean_squared_error: 0.0718 - val_mean_absolute_error: 0.2086
# Epoch 162/300
#  - 1s - loss: 0.0344 - mean_squared_error: 0.0344 - mean_absolute_error: 0.1403 - val_loss: 0.0718 - val_mean_squared_error: 0.0718 - val_mean_absolute_error: 0.2089
# Epoch 163/300
#  - 1s - loss: 0.0347 - mean_squared_error: 0.0347 - mean_absolute_error: 0.1406 - val_loss: 0.0718 - val_mean_squared_error: 0.0718 - val_mean_absolute_error: 0.2086
# Epoch 164/300
#  - 1s - loss: 0.0345 - mean_squared_error: 0.0345 - mean_absolute_error: 0.1406 - val_loss: 0.0720 - val_mean_squared_error: 0.0720 - val_mean_absolute_error: 0.2090
# Epoch 165/300
#  - 1s - loss: 0.0344 - mean_squared_error: 0.0344 - mean_absolute_error: 0.1404 - val_loss: 0.0720 - val_mean_squared_error: 0.0720 - val_mean_absolute_error: 0.2090
# Epoch 166/300
#  - 1s - loss: 0.0348 - mean_squared_error: 0.0348 - mean_absolute_error: 0.1408 - val_loss: 0.0719 - val_mean_squared_error: 0.0719 - val_mean_absolute_error: 0.2086
# Epoch 167/300
#  - 1s - loss: 0.0342 - mean_squared_error: 0.0342 - mean_absolute_error: 0.1392 - val_loss: 0.0719 - val_mean_squared_error: 0.0719 - val_mean_absolute_error: 0.2089
# Epoch 168/300
#  - 1s - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1406 - val_loss: 0.0718 - val_mean_squared_error: 0.0718 - val_mean_absolute_error: 0.2087
# Epoch 169/300
#  - 1s - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1390 - val_loss: 0.0720 - val_mean_squared_error: 0.0720 - val_mean_absolute_error: 0.2090
# Epoch 170/300
#  - 1s - loss: 0.0343 - mean_squared_error: 0.0343 - mean_absolute_error: 0.1398 - val_loss: 0.0722 - val_mean_squared_error: 0.0722 - val_mean_absolute_error: 0.2089
# Epoch 171/300
#  - 1s - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1390 - val_loss: 0.0722 - val_mean_squared_error: 0.0722 - val_mean_absolute_error: 0.2091
# Epoch 172/300
#  - 1s - loss: 0.0336 - mean_squared_error: 0.0336 - mean_absolute_error: 0.1379 - val_loss: 0.0724 - val_mean_squared_error: 0.0724 - val_mean_absolute_error: 0.2089
# Epoch 173/300
#  - 1s - loss: 0.0340 - mean_squared_error: 0.0340 - mean_absolute_error: 0.1389 - val_loss: 0.0724 - val_mean_squared_error: 0.0724 - val_mean_absolute_error: 0.2094
# Epoch 174/300
#  - 1s - loss: 0.0341 - mean_squared_error: 0.0341 - mean_absolute_error: 0.1392 - val_loss: 0.0725 - val_mean_squared_error: 0.0725 - val_mean_absolute_error: 0.2090
# Epoch 175/300
#  - 1s - loss: 0.0340 - mean_squared_error: 0.0340 - mean_absolute_error: 0.1391 - val_loss: 0.0725 - val_mean_squared_error: 0.0725 - val_mean_absolute_error: 0.2095
# Epoch 176/300
#  - 1s - loss: 0.0338 - mean_squared_error: 0.0338 - mean_absolute_error: 0.1387 - val_loss: 0.0725 - val_mean_squared_error: 0.0725 - val_mean_absolute_error: 0.2095
# Epoch 177/300
#  - 1s - loss: 0.0337 - mean_squared_error: 0.0337 - mean_absolute_error: 0.1384 - val_loss: 0.0725 - val_mean_squared_error: 0.0725 - val_mean_absolute_error: 0.2090
# Epoch 178/300
#  - 1s - loss: 0.0340 - mean_squared_error: 0.0340 - mean_absolute_error: 0.1388 - val_loss: 0.0724 - val_mean_squared_error: 0.0724 - val_mean_absolute_error: 0.2092
# Epoch 179/300
#  - 1s - loss: 0.0337 - mean_squared_error: 0.0337 - mean_absolute_error: 0.1387 - val_loss: 0.0727 - val_mean_squared_error: 0.0727 - val_mean_absolute_error: 0.2095
# Epoch 180/300
#  - 1s - loss: 0.0335 - mean_squared_error: 0.0335 - mean_absolute_error: 0.1379 - val_loss: 0.0727 - val_mean_squared_error: 0.0727 - val_mean_absolute_error: 0.2095
# Epoch 181/300
#  - 1s - loss: 0.0332 - mean_squared_error: 0.0332 - mean_absolute_error: 0.1367 - val_loss: 0.0728 - val_mean_squared_error: 0.0728 - val_mean_absolute_error: 0.2098
# Epoch 182/300
#  - 1s - loss: 0.0336 - mean_squared_error: 0.0336 - mean_absolute_error: 0.1378 - val_loss: 0.0728 - val_mean_squared_error: 0.0728 - val_mean_absolute_error: 0.2092
# Epoch 183/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1371 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2099
# Epoch 184/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1375 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2099
# Epoch 185/300
#  - 1s - loss: 0.0335 - mean_squared_error: 0.0335 - mean_absolute_error: 0.1374 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2095
# Epoch 186/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1373 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2100
# Epoch 187/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1375 - val_loss: 0.0730 - val_mean_squared_error: 0.0730 - val_mean_absolute_error: 0.2096
# Epoch 188/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1377 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2093
# Epoch 189/300
#  - 1s - loss: 0.0331 - mean_squared_error: 0.0331 - mean_absolute_error: 0.1366 - val_loss: 0.0728 - val_mean_squared_error: 0.0728 - val_mean_absolute_error: 0.2096
# Epoch 190/300
#  - 1s - loss: 0.0335 - mean_squared_error: 0.0335 - mean_absolute_error: 0.1377 - val_loss: 0.0727 - val_mean_squared_error: 0.0727 - val_mean_absolute_error: 0.2094
# Epoch 191/300
#  - 1s - loss: 0.0333 - mean_squared_error: 0.0333 - mean_absolute_error: 0.1374 - val_loss: 0.0727 - val_mean_squared_error: 0.0727 - val_mean_absolute_error: 0.2093
# Epoch 192/300
#  - 1s - loss: 0.0326 - mean_squared_error: 0.0326 - mean_absolute_error: 0.1358 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2097
# Epoch 193/300
#  - 1s - loss: 0.0334 - mean_squared_error: 0.0334 - mean_absolute_error: 0.1377 - val_loss: 0.0728 - val_mean_squared_error: 0.0728 - val_mean_absolute_error: 0.2094
# Epoch 194/300
#  - 1s - loss: 0.0328 - mean_squared_error: 0.0328 - mean_absolute_error: 0.1365 - val_loss: 0.0729 - val_mean_squared_error: 0.0729 - val_mean_absolute_error: 0.2091
# Epoch 195/300
#  - 1s - loss: 0.0328 - mean_squared_error: 0.0328 - mean_absolute_error: 0.1365 - val_loss: 0.0730 - val_mean_squared_error: 0.0730 - val_mean_absolute_error: 0.2097
# Epoch 196/300
#  - 1s - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1353 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2096
# Epoch 197/300
#  - 1s - loss: 0.0330 - mean_squared_error: 0.0330 - mean_absolute_error: 0.1367 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2101
# Epoch 198/300
#  - 1s - loss: 0.0329 - mean_squared_error: 0.0329 - mean_absolute_error: 0.1365 - val_loss: 0.0735 - val_mean_squared_error: 0.0735 - val_mean_absolute_error: 0.2097
# Epoch 199/300
#  - 1s - loss: 0.0329 - mean_squared_error: 0.0329 - mean_absolute_error: 0.1366 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2103
# Epoch 200/300
#  - 1s - loss: 0.0328 - mean_squared_error: 0.0328 - mean_absolute_error: 0.1356 - val_loss: 0.0732 - val_mean_squared_error: 0.0732 - val_mean_absolute_error: 0.2093
# Epoch 201/300
#  - 1s - loss: 0.0327 - mean_squared_error: 0.0327 - mean_absolute_error: 0.1356 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2099
# Epoch 202/300
#  - 1s - loss: 0.0328 - mean_squared_error: 0.0328 - mean_absolute_error: 0.1359 - val_loss: 0.0732 - val_mean_squared_error: 0.0732 - val_mean_absolute_error: 0.2098
# Epoch 203/300
#  - 1s - loss: 0.0326 - mean_squared_error: 0.0326 - mean_absolute_error: 0.1352 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2098
# Epoch 204/300
#  - 1s - loss: 0.0322 - mean_squared_error: 0.0322 - mean_absolute_error: 0.1348 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2099
# Epoch 205/300
#  - 1s - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1352 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2100
# Epoch 206/300
#  - 1s - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1351 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2097
# Epoch 207/300
#  - 1s - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1349 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2098
# Epoch 208/300
#  - 1s - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1356 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2096
# Epoch 209/300
#  - 1s - loss: 0.0325 - mean_squared_error: 0.0325 - mean_absolute_error: 0.1351 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2094
# Epoch 210/300
#  - 1s - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1347 - val_loss: 0.0732 - val_mean_squared_error: 0.0732 - val_mean_absolute_error: 0.2095
# Epoch 211/300
#  - 1s - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1352 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2096
# Epoch 212/300
#  - 1s - loss: 0.0324 - mean_squared_error: 0.0324 - mean_absolute_error: 0.1350 - val_loss: 0.0736 - val_mean_squared_error: 0.0736 - val_mean_absolute_error: 0.2100
# Epoch 213/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1335 - val_loss: 0.0735 - val_mean_squared_error: 0.0735 - val_mean_absolute_error: 0.2101
# Epoch 214/300
#  - 1s - loss: 0.0323 - mean_squared_error: 0.0323 - mean_absolute_error: 0.1348 - val_loss: 0.0736 - val_mean_squared_error: 0.0736 - val_mean_absolute_error: 0.2100
# Epoch 215/300
#  - 1s - loss: 0.0322 - mean_squared_error: 0.0322 - mean_absolute_error: 0.1346 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - val_mean_absolute_error: 0.2099
# Epoch 216/300
#  - 1s - loss: 0.0319 - mean_squared_error: 0.0319 - mean_absolute_error: 0.1340 - val_loss: 0.0736 - val_mean_squared_error: 0.0736 - val_mean_absolute_error: 0.2099
# Epoch 217/300
#  - 1s - loss: 0.0321 - mean_squared_error: 0.0321 - mean_absolute_error: 0.1343 - val_loss: 0.0739 - val_mean_squared_error: 0.0739 - val_mean_absolute_error: 0.2104
# Epoch 218/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1335 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2098
# Epoch 219/300
#  - 1s - loss: 0.0319 - mean_squared_error: 0.0319 - mean_absolute_error: 0.1338 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2099
# Epoch 220/300
#  - 1s - loss: 0.0320 - mean_squared_error: 0.0320 - mean_absolute_error: 0.1339 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2100
# Epoch 221/300
#  - 1s - loss: 0.0317 - mean_squared_error: 0.0317 - mean_absolute_error: 0.1328 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2099
# Epoch 222/300
#  - 1s - loss: 0.0322 - mean_squared_error: 0.0322 - mean_absolute_error: 0.1339 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2102
# Epoch 223/300
#  - 1s - loss: 0.0317 - mean_squared_error: 0.0317 - mean_absolute_error: 0.1334 - val_loss: 0.0737 - val_mean_squared_error: 0.0737 - val_mean_absolute_error: 0.2099
# Epoch 224/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1337 - val_loss: 0.0738 - val_mean_squared_error: 0.0738 - val_mean_absolute_error: 0.2100
# Epoch 225/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1336 - val_loss: 0.0738 - val_mean_squared_error: 0.0738 - val_mean_absolute_error: 0.2101
# Epoch 226/300
#  - 1s - loss: 0.0315 - mean_squared_error: 0.0315 - mean_absolute_error: 0.1331 - val_loss: 0.0738 - val_mean_squared_error: 0.0738 - val_mean_absolute_error: 0.2099
# Epoch 227/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1334 - val_loss: 0.0738 - val_mean_squared_error: 0.0738 - val_mean_absolute_error: 0.2100
# Epoch 228/300
#  - 1s - loss: 0.0318 - mean_squared_error: 0.0318 - mean_absolute_error: 0.1332 - val_loss: 0.0739 - val_mean_squared_error: 0.0739 - val_mean_absolute_error: 0.2099
# Epoch 229/300
#  - 1s - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1324 - val_loss: 0.0740 - val_mean_squared_error: 0.0740 - val_mean_absolute_error: 0.2103
# Epoch 230/300
#  - 1s - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1325 - val_loss: 0.0739 - val_mean_squared_error: 0.0739 - val_mean_absolute_error: 0.2100
# Epoch 231/300
#  - 1s - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1323 - val_loss: 0.0740 - val_mean_squared_error: 0.0740 - val_mean_absolute_error: 0.2102
# Epoch 232/300
#  - 1s - loss: 0.0313 - mean_squared_error: 0.0313 - mean_absolute_error: 0.1325 - val_loss: 0.0743 - val_mean_squared_error: 0.0743 - val_mean_absolute_error: 0.2107
# Epoch 233/300
#  - 1s - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1322 - val_loss: 0.0742 - val_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.2106
# Epoch 234/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1317 - val_loss: 0.0745 - val_mean_squared_error: 0.0745 - val_mean_absolute_error: 0.2106
# Epoch 235/300
#  - 1s - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1324 - val_loss: 0.0743 - val_mean_squared_error: 0.0743 - val_mean_absolute_error: 0.2105
# Epoch 236/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1315 - val_loss: 0.0741 - val_mean_squared_error: 0.0741 - val_mean_absolute_error: 0.2104
# Epoch 237/300
#  - 1s - loss: 0.0307 - mean_squared_error: 0.0307 - mean_absolute_error: 0.1306 - val_loss: 0.0742 - val_mean_squared_error: 0.0742 - val_mean_absolute_error: 0.2104
# Epoch 238/300
#  - 1s - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1318 - val_loss: 0.0743 - val_mean_squared_error: 0.0743 - val_mean_absolute_error: 0.2108
# Epoch 239/300
#  - 1s - loss: 0.0310 - mean_squared_error: 0.0310 - mean_absolute_error: 0.1316 - val_loss: 0.0743 - val_mean_squared_error: 0.0743 - val_mean_absolute_error: 0.2104
# Epoch 240/300
#  - 1s - loss: 0.0309 - mean_squared_error: 0.0309 - mean_absolute_error: 0.1316 - val_loss: 0.0744 - val_mean_squared_error: 0.0744 - val_mean_absolute_error: 0.2105
# Epoch 241/300
#  - 1s - loss: 0.0309 - mean_squared_error: 0.0309 - mean_absolute_error: 0.1315 - val_loss: 0.0744 - val_mean_squared_error: 0.0744 - val_mean_absolute_error: 0.2106
# Epoch 242/300
#  - 1s - loss: 0.0309 - mean_squared_error: 0.0309 - mean_absolute_error: 0.1317 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2107
# Epoch 243/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1319 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2109
# Epoch 244/300
#  - 1s - loss: 0.0310 - mean_squared_error: 0.0310 - mean_absolute_error: 0.1317 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2110
# Epoch 245/300
#  - 1s - loss: 0.0312 - mean_squared_error: 0.0312 - mean_absolute_error: 0.1324 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2104
# Epoch 246/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1316 - val_loss: 0.0745 - val_mean_squared_error: 0.0745 - val_mean_absolute_error: 0.2107
# Epoch 247/300
#  - 1s - loss: 0.0310 - mean_squared_error: 0.0310 - mean_absolute_error: 0.1315 - val_loss: 0.0744 - val_mean_squared_error: 0.0744 - val_mean_absolute_error: 0.2104
# Epoch 248/300
#  - 1s - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1326 - val_loss: 0.0747 - val_mean_squared_error: 0.0747 - val_mean_absolute_error: 0.2108
# Epoch 249/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1321 - val_loss: 0.0747 - val_mean_squared_error: 0.0747 - val_mean_absolute_error: 0.2111
# Epoch 250/300
#  - 1s - loss: 0.0305 - mean_squared_error: 0.0305 - mean_absolute_error: 0.1306 - val_loss: 0.0747 - val_mean_squared_error: 0.0747 - val_mean_absolute_error: 0.2109
# Epoch 251/300
#  - 1s - loss: 0.0309 - mean_squared_error: 0.0309 - mean_absolute_error: 0.1310 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2109
# Epoch 252/300
#  - 1s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1306 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2110
# Epoch 253/300
#  - 1s - loss: 0.0311 - mean_squared_error: 0.0311 - mean_absolute_error: 0.1319 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2109
# Epoch 254/300
#  - 1s - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1312 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2110
# Epoch 255/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1303 - val_loss: 0.0747 - val_mean_squared_error: 0.0747 - val_mean_absolute_error: 0.2109
# Epoch 256/300
#  - 1s - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1311 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2107
# Epoch 257/300
#  - 1s - loss: 0.0310 - mean_squared_error: 0.0310 - mean_absolute_error: 0.1313 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2110
# Epoch 258/300
#  - 1s - loss: 0.0307 - mean_squared_error: 0.0307 - mean_absolute_error: 0.1306 - val_loss: 0.0745 - val_mean_squared_error: 0.0745 - val_mean_absolute_error: 0.2111
# Epoch 259/300
#  - 1s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1305 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - val_mean_absolute_error: 0.2107
# Epoch 260/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1302 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2111
# Epoch 261/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1303 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2112
# Epoch 262/300
#  - 1s - loss: 0.0303 - mean_squared_error: 0.0303 - mean_absolute_error: 0.1298 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2111
# Epoch 263/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1302 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2111
# Epoch 264/300
#  - 1s - loss: 0.0305 - mean_squared_error: 0.0305 - mean_absolute_error: 0.1303 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2113
# Epoch 265/300
#  - 1s - loss: 0.0305 - mean_squared_error: 0.0305 - mean_absolute_error: 0.1305 - val_loss: 0.0750 - val_mean_squared_error: 0.0750 - val_mean_absolute_error: 0.2114
# Epoch 266/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1303 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2114
# Epoch 267/300
#  - 1s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1309 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2109
# Epoch 268/300
#  - 1s - loss: 0.0305 - mean_squared_error: 0.0305 - mean_absolute_error: 0.1305 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2115
# Epoch 269/300
#  - 1s - loss: 0.0307 - mean_squared_error: 0.0307 - mean_absolute_error: 0.1312 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2112
# Epoch 270/300
#  - 1s - loss: 0.0302 - mean_squared_error: 0.0302 - mean_absolute_error: 0.1295 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2112
# Epoch 271/300
#  - 1s - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1313 - val_loss: 0.0751 - val_mean_squared_error: 0.0751 - val_mean_absolute_error: 0.2116
# Epoch 272/300
#  - 1s - loss: 0.0302 - mean_squared_error: 0.0302 - mean_absolute_error: 0.1296 - val_loss: 0.0750 - val_mean_squared_error: 0.0750 - val_mean_absolute_error: 0.2113
# Epoch 273/300
#  - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1291 - val_loss: 0.0750 - val_mean_squared_error: 0.0750 - val_mean_absolute_error: 0.2115
# Epoch 274/300
#  - 1s - loss: 0.0306 - mean_squared_error: 0.0306 - mean_absolute_error: 0.1309 - val_loss: 0.0749 - val_mean_squared_error: 0.0749 - val_mean_absolute_error: 0.2111
# Epoch 275/300
#  - 1s - loss: 0.0304 - mean_squared_error: 0.0304 - mean_absolute_error: 0.1303 - val_loss: 0.0748 - val_mean_squared_error: 0.0748 - val_mean_absolute_error: 0.2110
# Epoch 276/300
#  - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1292 - val_loss: 0.0750 - val_mean_squared_error: 0.0750 - val_mean_absolute_error: 0.2111
# Epoch 277/300
#  - 1s - loss: 0.0302 - mean_squared_error: 0.0302 - mean_absolute_error: 0.1299 - val_loss: 0.0752 - val_mean_squared_error: 0.0752 - val_mean_absolute_error: 0.2115
# Epoch 278/300
#  - 1s - loss: 0.0301 - mean_squared_error: 0.0301 - mean_absolute_error: 0.1294 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2117
# Epoch 279/300
#  - 1s - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1289 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2116
# Epoch 280/300
#  - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1286 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2117
# Epoch 281/300
#  - 1s - loss: 0.0301 - mean_squared_error: 0.0301 - mean_absolute_error: 0.1295 - val_loss: 0.0753 - val_mean_squared_error: 0.0753 - val_mean_absolute_error: 0.2118
# Epoch 282/300
#  - 1s - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1286 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2117
# Epoch 283/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1282 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2117
# Epoch 284/300
#  - 1s - loss: 0.0302 - mean_squared_error: 0.0302 - mean_absolute_error: 0.1298 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2118
# Epoch 285/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1281 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2114
# Epoch 286/300
#  - 1s - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1288 - val_loss: 0.0753 - val_mean_squared_error: 0.0753 - val_mean_absolute_error: 0.2115
# Epoch 287/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1285 - val_loss: 0.0755 - val_mean_squared_error: 0.0755 - val_mean_absolute_error: 0.2116
# Epoch 288/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1283 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2116
# Epoch 289/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1285 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2117
# Epoch 290/300
#  - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1286 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2116
# Epoch 291/300
#  - 1s - loss: 0.0298 - mean_squared_error: 0.0298 - mean_absolute_error: 0.1286 - val_loss: 0.0756 - val_mean_squared_error: 0.0756 - val_mean_absolute_error: 0.2120
# Epoch 292/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1281 - val_loss: 0.0758 - val_mean_squared_error: 0.0758 - val_mean_absolute_error: 0.2119
# Epoch 293/300
#  - 1s - loss: 0.0292 - mean_squared_error: 0.0292 - mean_absolute_error: 0.1274 - val_loss: 0.0758 - val_mean_squared_error: 0.0758 - val_mean_absolute_error: 0.2119
# Epoch 294/300
#  - 1s - loss: 0.0294 - mean_squared_error: 0.0294 - mean_absolute_error: 0.1279 - val_loss: 0.0758 - val_mean_squared_error: 0.0758 - val_mean_absolute_error: 0.2118
# Epoch 295/300
#  - 1s - loss: 0.0292 - mean_squared_error: 0.0292 - mean_absolute_error: 0.1273 - val_loss: 0.0757 - val_mean_squared_error: 0.0757 - val_mean_absolute_error: 0.2117
# Epoch 296/300
#  - 1s - loss: 0.0295 - mean_squared_error: 0.0295 - mean_absolute_error: 0.1284 - val_loss: 0.0758 - val_mean_squared_error: 0.0758 - val_mean_absolute_error: 0.2117
# Epoch 297/300
#  - 1s - loss: 0.0296 - mean_squared_error: 0.0296 - mean_absolute_error: 0.1279 - val_loss: 0.0757 - val_mean_squared_error: 0.0757 - val_mean_absolute_error: 0.2118
# Epoch 298/300
#  - 1s - loss: 0.0295 - mean_squared_error: 0.0295 - mean_absolute_error: 0.1280 - val_loss: 0.0755 - val_mean_squared_error: 0.0755 - val_mean_absolute_error: 0.2117
# Epoch 299/300
#  - 1s - loss: 0.0295 - mean_squared_error: 0.0295 - mean_absolute_error: 0.1281 - val_loss: 0.0754 - val_mean_squared_error: 0.0754 - val_mean_absolute_error: 0.2116
# Epoch 300/300
#  - 1s - loss: 0.0293 - mean_squared_error: 0.0293 - mean_absolute_error: 0.1277 - val_loss: 0.0755 - val_mean_squared_error: 0.0755 - val_mean_absolute_error: 0.2116
# Wall time: 4min 16s

# %% [markdown]
# ### Timestep (Equal to Lag) - Evaluation  (CPU + IO)
#
# The remaining left out data (the other half of t he dataset) is used to validate the trained model. This validation set equates to 7 days worth of data points. Below's test replicates a 7 day distribution, wherein the accuracy and f1 score of the model are evaluated at the end of each day, fit to the model in an online manner, and the process repeated for each of the following days.

# %%
# %%time
n=7
accuracy_per_day, f1score_per_day = [], []
for i in range(0, n):
    
    print('Day ' + str(i+1))
    
    # Segregate data for specific day
    X_validate_temp = X_validate[(int(X_validate.shape[0]/n)*i):(int(X_validate.shape[0]/n)*(i+1)),:]
    y_validate_temp = y_validate[(int(y_validate.shape[0]/n)*i):(int(y_validate.shape[0]/n)*(i+1)),:]
    print('Feature vectors: ' + str(X_validate_temp.shape))
    print('Label vectors: ' + str(y_validate_temp.shape))

    y_list, yhat_list = [], []
    for j in range(0, X_validate_temp.shape[0]):
        
        X = np.array(np.array(X_validate_temp[j,:]))
        X = X.reshape((int(X.shape[0] / timestep), timestep, X.shape[1]))
        y = np.array(y_validate_temp[j, :])
        yhat = model.predict(X, batch_size=batch)
        
        y = y.reshape(1,-1)
        model.fit_model(X_train=X,
                        y_train=y,
                        epochs=2, 
                        batch_size=1,
                        verbose=0, 
                        shuffle=False,
                        plot=False) # Online Learning, Training on validation predictions. 
        
        y = y.flatten()
        yhat = yhat.flatten()
        
        for z in range(yhat.shape[0]):
            if z % 2 == 0:
                #print('CPU')
                y[z] = BinClass.discretize_value(y[z], cpu_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], cpu_avg)
            else:
                #print('IO')
                y[z] = BinClass.discretize_value(y[z], io_avg)
                yhat[z] = BinClass.discretize_value(yhat[z], io_avg)
        y_list.append(y)
        yhat_list.append(yhat)
        
#         print('Actual: ' + str(y))
#         print('Predicted: ' + str(yhat) + '\n--------------------------')
    
    y_list = np.array(y_list)
    yhat_list = np.array(yhat_list)
    
    acc_score_list, f1_score_list = [], []
    for j in range(lag * len(y_label)):
        print('Label: ' + str(j))
        acc = accuracy_score(y_list[:,j],yhat_list[:,j])
        f1 = f1_score(y_list[:,j],yhat_list[:,j], average='binary')
        print('Accuracy: ' + str(acc) + '\nF1Score: ' +  str(f1) + '\n--------------------------')
        acc_score_list.append(acc)
        f1_score_list.append(f1)
    accuracy_per_day.append(sum(acc_score_list)/len(acc_score_list))
    f1score_per_day.append(sum(f1_score_list)/len(f1_score_list))
    print('Averaged Day ' + str(i+1) + ' Accuracy: ' + str(sum(accuracy_per_day)/len(accuracy_per_day)) + '\nF1Score: ' + str(sum(f1score_per_day)/len(f1score_per_day)) + '\n--------------------------')
    print('-'*40)
# Out:
# Day 1
# Feature vectors: (117, 12, 59)
# Label vectors: (117, 26)
# Label: 0
# Accuracy: 0.5555555555555556
# F1Score: 0.43478260869565216
# --------------------------
# Label: 1
# Accuracy: 0.41025641025641024
# F1Score: 0.481203007518797
# --------------------------
# Label: 2
# Accuracy: 0.5384615384615384
# F1Score: 0.6351351351351351
# --------------------------
# Label: 3
# Accuracy: 0.5213675213675214
# F1Score: 0.6626506024096385
# --------------------------
# Label: 4
# Accuracy: 0.48717948717948717
# F1Score: 0.18918918918918917
# --------------------------
# Label: 5
# Accuracy: 0.4700854700854701
# F1Score: 0.4745762711864407
# --------------------------
# Label: 6
# Accuracy: 0.47863247863247865
# F1Score: 0.2278481012658228
# --------------------------
# Label: 7
# Accuracy: 0.5042735042735043
# F1Score: 0.532258064516129
# --------------------------
# Label: 8
# Accuracy: 0.41025641025641024
# F1Score: 0.34285714285714286
# --------------------------
# Label: 9
# Accuracy: 0.5128205128205128
# F1Score: 0.5714285714285714
# --------------------------
# Label: 10
# Accuracy: 0.5470085470085471
# F1Score: 0.40449438202247195
# --------------------------
# Label: 11
# Accuracy: 0.5641025641025641
# F1Score: 0.37037037037037035
# --------------------------
# Label: 12
# Accuracy: 0.5726495726495726
# F1Score: 0.3421052631578947
# --------------------------
# Label: 13
# Accuracy: 0.5042735042735043
# F1Score: 0.4528301886792453
# --------------------------
# Label: 14
# Accuracy: 0.6324786324786325
# F1Score: 0.2711864406779661
# --------------------------
# Label: 15
# Accuracy: 0.5982905982905983
# F1Score: 0.2033898305084746
# --------------------------
# Label: 16
# Accuracy: 0.5384615384615384
# F1Score: 0.4807692307692307
# --------------------------
# Label: 17
# Accuracy: 0.48717948717948717
# F1Score: 0.4915254237288136
# --------------------------
# Label: 18
# Accuracy: 0.5128205128205128
# F1Score: 0.37362637362637363
# --------------------------
# Label: 19
# Accuracy: 0.4358974358974359
# F1Score: 0.4406779661016949
# --------------------------
# Label: 20
# Accuracy: 0.5042735042735043
# F1Score: 0.532258064516129
# --------------------------
# Label: 21
# Accuracy: 0.4444444444444444
# F1Score: 0.3689320388349515
# --------------------------
# F1Score: 0.3116883116883117
# --------------------------
# Averaged Day 6 Accuracy: 0.4976851851851852
# F1Score: 0.4352924449471409
# --------------------------
# ----------------------------------------
# Day 7
# Feature vectors: (117, 12, 59)
# Label vectors: (117, 26)
# Label: 0
# Accuracy: 0.47863247863247865
# F1Score: 0.5481481481481482
# --------------------------
# Label: 1
# Accuracy: 0.49572649572649574
# F1Score: 0.6628571428571429
# --------------------------
# Label: 2
# Accuracy: 0.47863247863247865
# F1Score: 0.37113402061855666
# --------------------------
# Label: 3
# Accuracy: 0.5384615384615384
# F1Score: 0.06896551724137931
# --------------------------
# Label: 4
# Accuracy: 0.5299145299145299
# F1Score: 0.6308724832214765
# --------------------------
# Label: 5
# Accuracy: 0.4444444444444444
# F1Score: 0.5255474452554746
# --------------------------
# Label: 6
# Accuracy: 0.5213675213675214
# F1Score: 0.4509803921568628
# --------------------------
# Label: 7
# Accuracy: 0.6153846153846154
# F1Score: 0.28571428571428575
# --------------------------
# Label: 8
# Accuracy: 0.4188034188034188
# F1Score: 0.5584415584415585
# --------------------------
# Label: 9
# Accuracy: 0.5470085470085471
# F1Score: 0.2535211267605634
# --------------------------
# Label: 10
# Accuracy: 0.49572649572649574
# F1Score: 0.5354330708661418
# --------------------------
# Label: 11
# Accuracy: 0.5470085470085471
# F1Score: 0.39080459770114945
# --------------------------
# Label: 12
# Accuracy: 0.5555555555555556
# F1Score: 0.2972972972972973
# --------------------------
# Label: 13
# Accuracy: 0.5726495726495726
# F1Score: 0.19354838709677416
# --------------------------
# Label: 14
# Accuracy: 0.5128205128205128
# F1Score: 0.41237113402061853
# --------------------------
# Label: 15
# Accuracy: 0.5042735042735043
# F1Score: 0.34090909090909094
# --------------------------
# Label: 16
# Accuracy: 0.4444444444444444
# F1Score: 0.48000000000000004
# --------------------------
# Label: 17
# Accuracy: 0.5641025641025641
# F1Score: 0.5233644859813085
# --------------------------
# Label: 18
# Accuracy: 0.48717948717948717
# F1Score: 0.4915254237288135
# --------------------------
# Label: 19
# Accuracy: 0.3418803418803419
# F1Score: 0.37398373983739835
# --------------------------
# Label: 20
# Accuracy: 0.5128205128205128
# F1Score: 0.6586826347305389
# --------------------------
# Label: 21
# Accuracy: 0.5213675213675214
# F1Score: 0.5555555555555555
# --------------------------
# Label: 22
# Accuracy: 0.5641025641025641
# F1Score: 0.21538461538461537
# --------------------------
# Label: 23
# Accuracy: 0.42735042735042733
# F1Score: 0.3853211009174312
# --------------------------
# Averaged Day 7 Accuracy: 0.4987281237281237
# F1Score: 0.4338837817073243
# --------------------------
# ----------------------------------------
# Wall time: 1min 23s

# %% [markdown]
# ### Scoring per day  (CPU + IO)
#
# The following plot exhibits the general effectiveness of the model over the subsequent week upon which it was tested.

# %%
plt.rcParams['figure.figsize'] = [20, 15]
plt.plot(accuracy_per_day, label='accuracy')
plt.plot(f1score_per_day, label='f1score')
plt.legend(['accuracy', 'f1score'], loc='upper left')
plt.xlabel('Distribution over days')
plt.ylabel('Score')
plt.title(tpcds + ' model scoring over subsequent week')
plt.show()
