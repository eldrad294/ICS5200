# %% [markdown]
# # Benchmark
#
# This notebook contains work pertatining to benchmark metrics and data visualization / descriptions

# %%
#
# Module Import
import pandas as pd
import matplotlib.pyplot as plt
#
# Open Data
rep_execution_plans_path = 'C:/Users/gabriel.sammut/University/Data_ICS5200/Benchmark/tpcds1/rep_execution_plans.csv'
rep_explain_plans_path = 'C:/Users/gabriel.sammut/University/Data_ICS5200/Benchmark/tpcds1/rep_explain_plans.csv'
#
rep_execution_plans_df = pd.read_csv(rep_execution_plans_path)
rep_explain_plans_df = pd.read_csv(rep_explain_plans_path)
#
def clean_header(df_header):
    """
    Cleans header list from unwated character strings
    """
    header_list = []
    for header in df_header.columns.values:
        header = header.replace("(","").replace(")","").replace("'","").replace(",","")
        header_list.append(header)
    return pd.Series(header_list)
#
# Cleans headers from unwanted characters eg: " , ( )
# rep_execution_plans_df = pd.DataFrame(rep_execution_plans_df, columns=clean_header(rep_execution_plans_df))
# rep_explain_plans_df = pd.DataFrame(rep_explain_plans_df, columns=clean_header(rep_explain_plans_df))
#
print(rep_execution_plans_df.head())
print("---------------------------------------------------------------------------------")
print(rep_explain_plans_df.head())
# Out:
#    SQL_TEXT  SQL_FULLTEXT  SQL_ID  SHARABLE_MEM  PERSISTENT_MEM  RUNTIME_MEM  \
# 0       NaN           NaN     NaN           NaN             NaN          NaN
# 1       NaN           NaN     NaN           NaN             NaN          NaN
# 2       NaN           NaN     NaN           NaN             NaN          NaN
# 3       NaN           NaN     NaN           NaN             NaN          NaN
# 4       NaN           NaN     NaN           NaN             NaN          NaN
#
#    SORTS  LOADED_VERSIONS  OPEN_VERSIONS  USERS_OPENING       ...        \
# 0    NaN              NaN            NaN            NaN       ...
# 1    NaN              NaN            NaN            NaN       ...
# 2    NaN              NaN            NaN            NaN       ...
# 3    NaN              NaN            NaN            NaN       ...
# 4    NaN              NaN            NaN            NaN       ...
#
#    CON_ID  IS_REOPTIMIZABLE  IS_RESOLVED_ADAPTIVE_PLAN  IM_SCANS  \
# 0     NaN               NaN                        NaN       NaN
# 1     NaN               NaN                        NaN       NaN
# 2     NaN               NaN                        NaN       NaN
# 3     NaN               NaN                        NaN       NaN
# 4     NaN               NaN                        NaN       NaN
#
#    IM_SCAN_BYTES_UNCOMPRESSED  IM_SCAN_BYTES_INMEMORY  TPC_TRANSACTION_NAME  \
# 0                         NaN                     NaN                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                         NaN                     NaN                   NaN
#
#    STATEMENT_HASH_SUM  BENCHMARK_ITERATION  GATHERED_STATS
# 0                 NaN                  NaN             NaN
# 1                 NaN                  NaN             NaN
# 2                 NaN                  NaN             NaN
# 3                 NaN                  NaN             NaN
# 4                 NaN                  NaN             NaN
#
# [5 rows x 98 columns]
# ---------------------------------------------------------------------------------
#    STATEMENT_ID  PLAN_ID  TIMESTAMP  REMARKS  OPERATION  OPTIONS  OBJECT_NODE  \
# 0           NaN      NaN        NaN      NaN        NaN      NaN          NaN
# 1           NaN      NaN        NaN      NaN        NaN      NaN          NaN
# 2           NaN      NaN        NaN      NaN        NaN      NaN          NaN
# 3           NaN      NaN        NaN      NaN        NaN      NaN          NaN
# 4           NaN      NaN        NaN      NaN        NaN      NaN          NaN
#
#    OBJECT_OWNER  OBJECT_NAME  OBJECT_INSTANCE       ...        CPU_COST  \
# 0           NaN          NaN              NaN       ...             NaN
# 1           NaN          NaN              NaN       ...             NaN
# 2           NaN          NaN              NaN       ...             NaN
# 3           NaN          NaN              NaN       ...             NaN
# 4           NaN          NaN              NaN       ...             NaN
#
#    IO_COST  TEMP_SPACE  ACCESS_PREDICATES  FILTER_PREDICATES  TIME  \
# 0      NaN         NaN                NaN                NaN   NaN
# 1      NaN         NaN                NaN                NaN   NaN
# 2      NaN         NaN                NaN                NaN   NaN
# 3      NaN         NaN                NaN                NaN   NaN
# 4      NaN         NaN                NaN                NaN   NaN
#
#    TPC_TRANSACTION_NAME  STATEMENT_HASH_SUM  BENCHMARK_ITERATION  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    GATHERED_STATS
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# # Dataset Description
#
# Statistical calculations:
#
# * Column Names
# * Dataframe Row Counts
# * Mean (were applicable)
# * Standard Dev (were applicable)
# * Quartile Percentile
# * Min / Max

# %%
print('\n-----------------------------------------------------------\nDataframe Row Count: REP_EXECUTION_PLANS - ' + str(len(rep_execution_plans_df)))
print('Dataframe Row Count: REP_EXPLAIN_PLANS - ' + str(len(rep_explain_plans_df)) + '\n-----------------------------------------------------------\n')
#
print('REP_EXECUTION_PLANS:')
print(rep_execution_plans_df.describe())
print('\n\nREP_EXPLAIN_PLANS:')
print(rep_explain_plans_df.describe())
# Out:
# -----------------------------------------------------------
# Dataframe Row Count: REP_EXECUTION_PLANS - 1344
# Dataframe Row Count: REP_EXPLAIN_PLANS - 21659
# -----------------------------------------------------------
#
# REP_EXECUTION_PLANS:
#        ('SHARABLE_MEM',)  ('PERSISTENT_MEM',)  ('RUNTIME_MEM',)  \
# count        1344.000000         1.344000e+03      1.344000e+03
# mean       100263.858631         1.337588e+05      1.323623e+05
# std         88540.123373         1.579462e+05      1.578645e+05
# min         15299.000000         1.704000e+03      6.000000e+02
# 25%         30857.500000         3.540800e+04      3.372800e+04
# 50%         81304.000000         8.542400e+04      8.412000e+04
# 75%        130194.000000         1.717120e+05      1.706080e+05
# max        563348.000000         1.142144e+06      1.140272e+06
#
#           ('SORTS',)  ('LOADED_VERSIONS',)  ('OPEN_VERSIONS',)  \
# count    1344.000000                1344.0              1344.0
# mean      544.347470                   1.0                 0.0
# std      8897.979267                   0.0                 0.0
# min         0.000000                   1.0                 0.0
# 25%         0.000000                   1.0                 0.0
# 50%         0.000000                   1.0                 0.0
# 75%         1.000000                   1.0                 0.0
# max    146102.000000                   1.0                 0.0
#
#        ('USERS_OPENING',)  ('FETCHES',)  ('EXECUTIONS',)  \
# count              1344.0   1344.000000      1344.000000
# mean                  0.0      0.605655         1.011905
# std                   0.0      0.519892         0.138628
# min                   0.0      0.000000         1.000000
# 25%                   0.0      0.000000         1.000000
# 50%                   0.0      1.000000         1.000000
# 75%                   0.0      1.000000         1.000000
# max                   0.0      3.000000         3.000000
#
#        ('PX_SERVERS_EXECUTIONS',)            ...             \
# count                      1344.0            ...
# mean                          0.0            ...
# std                           0.0            ...
# min                           0.0            ...
# 25%                           0.0            ...
# 50%                           0.0            ...
# 75%                           0.0            ...
# max                           0.0            ...
#
#        ('OPTIMIZED_PHY_READ_REQUESTS',)  ('LOCKED_TOTAL',)  ('PINNED_TOTAL',)  \
# count                            1344.0        1344.000000        1344.000000
# mean                                0.0           1.020833           2.025298
# std                                 0.0           0.191822           0.242750
# min                                 0.0           1.000000           2.000000
# 25%                                 0.0           1.000000           2.000000
# 50%                                 0.0           1.000000           2.000000
# 75%                                 0.0           1.000000           2.000000
# max                                 0.0           3.000000           5.000000
#
#        ('IO_CELL_UNCOMPRESSED_BYTES',)  ('IO_CELL_OFFLOAD_RETURNED_BYTES',)  \
# count                           1344.0                               1344.0
# mean                               0.0                                  0.0
# std                                0.0                                  0.0
# min                                0.0                                  0.0
# 25%                                0.0                                  0.0
# 50%                                0.0                                  0.0
# 75%                                0.0                                  0.0
# max                                0.0                                  0.0
#
#        ('CON_ID',)  ('IM_SCANS',)  ('IM_SCAN_BYTES_UNCOMPRESSED',)  \
# count       1344.0         1344.0                           1344.0
# mean           0.0            0.0                              0.0
# std            0.0            0.0                              0.0
# min            0.0            0.0                              0.0
# 25%            0.0            0.0                              0.0
# 50%            0.0            0.0                              0.0
# 75%            0.0            0.0                              0.0
# max            0.0            0.0                              0.0
#
#        ('IM_SCAN_BYTES_INMEMORY',)  ('BENCHMARK_ITERATION',)
# count                       1344.0               1344.000000
# mean                           0.0                  3.500000
# std                            0.0                  1.708461
# min                            0.0                  1.000000
# 25%                            0.0                  2.000000
# 50%                            0.0                  3.500000
# 75%                            0.0                  5.000000
# max                            0.0                  6.000000
#
# [8 rows x 73 columns]
#
#
# REP_EXPLAIN_PLANS:
#        ('STATEMENT_ID',)  ('PLAN_ID',)  ('REMARKS',)  ('OBJECT_NODE',)  \
# count                0.0  21659.000000           0.0               0.0
# mean                 NaN  11066.945981           NaN               NaN
# std                  NaN     40.645191           NaN               NaN
# min                  NaN  11007.000000           NaN               NaN
# 25%                  NaN  11031.000000           NaN               NaN
# 50%                  NaN  11067.000000           NaN               NaN
# 75%                  NaN  11094.000000           NaN               NaN
# max                  NaN  11188.000000           NaN               NaN
#
#        ('OBJECT_INSTANCE',)  ('SEARCH_COLUMNS',)       ('ID',)  \
# count           8183.000000          1775.000000  21659.000000
# mean              22.726262             1.072113     20.693199
# std               60.423739             0.279686     22.226109
# min                1.000000             1.000000      0.000000
# 25%                3.000000             1.000000      5.000000
# 50%                6.000000             1.000000     14.000000
# 75%               14.000000             1.000000     28.000000
# max              757.000000             3.000000    130.000000
#
#        ('PARENT_ID',)    ('DEPTH',)  ('POSITION',)            ...             \
# count    20621.000000  21659.000000   2.165900e+04            ...
# mean        18.471122      7.281823   2.883882e+09            ...
# std         21.522465      4.245588   1.830715e+11            ...
# min          0.000000      0.000000   1.000000e+00            ...
# 25%          4.000000      4.000000   1.000000e+00            ...
# 50%         11.000000      7.000000   1.000000e+00            ...
# 75%         25.000000     10.000000   2.000000e+00            ...
# max        127.000000     27.000000   1.200000e+13            ...
#
#        ('OTHER_TAG',)  ('PARTITION_START',)  ('PARTITION_STOP',)  \
# count             0.0                   0.0                  0.0
# mean              NaN                   NaN                  NaN
# std               NaN                   NaN                  NaN
# min               NaN                   NaN                  NaN
# 25%               NaN                   NaN                  NaN
# 50%               NaN                   NaN                  NaN
# 75%               NaN                   NaN                  NaN
# max               NaN                   NaN                  NaN
#
#        ('PARTITION_ID',)  ('DISTRIBUTION',)  ('CPU_COST',)  ('IO_COST',)  \
# count                0.0                0.0   1.896600e+04  1.896600e+04
# mean                 NaN                NaN   1.847692e+16  1.097105e+07
# std                  NaN                NaN   5.693837e+17  2.648789e+08
# min                  NaN                NaN   0.000000e+00  0.000000e+00
# 25%                  NaN                NaN   2.995505e+06  8.400000e+01
# 50%                  NaN                NaN   5.268366e+07  7.550000e+02
# 75%                  NaN                NaN   4.798725e+08  4.981000e+03
# max                  NaN                NaN   1.840000e+19  7.769642e+09
#
#        ('TEMP_SPACE',)     ('TIME',)  ('BENCHMARK_ITERATION',)
# count     8.870000e+02  1.896600e+04              21659.000000
# mean      1.105178e+17  3.154746e+05                  3.500808
# std       1.392147e+18  1.130436e+07                  1.706602
# min       1.000000e+06  1.000000e+00                  1.000000
# 25%       3.551500e+06  1.000000e+00                  2.000000
# 50%       8.856000e+06  1.000000e+00                  4.000000
# 75%       8.704050e+07  1.000000e+00                  5.000000
# max       1.840000e+19  4.676770e+08                  6.000000
#
# [8 rows x 23 columns]
